# %%
import os

path = 'C:/Users/'+os.getlogin()+'/Google Drive/University/Dissertation'
datapath = 'C:/Users/'+os.getlogin()+'/Dissertation Data'

os.chdir(path+'/Code')
os.getcwd()
# Out:
# 'C:\\Users\\tom\\Google Drive\\University\\Dissertation\\Code'

# %% [markdown]
# We collect lexical co-occurrence statistics on all words in
# the English Wikipedia, using the WikiExtractor tool2 to retrieve
# plain text from the April 2015 dump (ca. 2.8B words),
# and using simple regular expressions to segment sentences
# and words, and remove URLs and punctuation. We perform
# no POS tagging, lemmatisation, case normalisation,
# or removal of numbers or symbols.

# %%
import pandas as pd
import re
import numpy as np

import nltk
from nltk.tokenize import MWETokenizer

from glove import Corpus, Glove

from gensim.models import Word2Vec

# %%
# On Simple English wiki

sf = open(datapath+'/Corpora/wiki/simple_20200601/simple_sample.txt', 'r', encoding='utf-8')

for lines in range(5):
    print(sf.readline())
# Out:
# ﻿April is the fourth month of the year, and comes between March and May.
#
#  It is one of four months to have 30 days.
#
#  April always begins on the same day of week as July, and additionally, January in leap years.
#
#  April always ends on the same day of the week as December.
#
#  April's flowers are the Sweet Pea and Daisy.

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader

from nltk.tokenize import WhitespaceTokenizer

# %%
simp = PlaintextCorpusReader(datapath+'/Corpora/wiki/simple_20200601/','simple_sample.txt',
                            word_tokenizer = WhitespaceTokenizer()
                            )

# %%
# Import word and sentence generators

from generators import sent_gen, word_gen, Sent_Seq

# %% [markdown]
# We collect word frequency information with the
# SRILM language modelling toolkit (Stolcke, 2002), counting
# n-grams (n <= 3), treating MWEs as contiguous bigrams
# and trigrams), and identify MWE candidates by computing
# the Poisson collocation measure (Quasthoff and Wolff,
# 2002) for all bigrams and trigrams (ca. 23M n-grams).
# This method should be readily extensible to include longer
# n-grams.

# %%
# Collate n-grams

from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder

from nltk.metrics import (
    BigramAssocMeasures,
    TrigramAssocMeasures,
    NgramAssocMeasures,
)

from nltk.metrics.spearman import (
    spearman_correlation,
    ranks_from_scores,
)

# %%
scorer = NgramAssocMeasures.poisson_stirling

tri_cf = TrigramCollocationFinder.from_words(word_gen(simp))
tri_cf.apply_word_filter(lambda w: w in ('|^|'))  # Filter out associations with sentence boundary marker

# %%
bi_cf = tri_cf.bigram_finder()                   # Make bigram finder from trigram, don't need to count again
bi_cf.apply_word_filter(lambda w: w in ('|^|'))  # Filter out associations with sentence boundary marker

# %%
bi_dict = {}
tri_dict = {}

for bigram in bi_cf.score_ngrams(scorer):    
    bi_dict[bigram[0]] = [bigram[0], bi_cf.ngram_fd[bigram[0]], bigram[-1]]
    
for trigram in tri_cf.score_ngrams(scorer):    
    tri_dict[trigram[0]] = [trigram[0], tri_cf.ngram_fd[trigram[0]], trigram[-1]]
    
tri_dict
# Out:
# {('0050d0',
#   'Administrative',
#   'subdivisions'): [('0050d0',
#    'Administrative',
#    'subdivisions'), 1, -17.030667136246944],
#  ('1,319', 'Teppo', 'Numminen'): [('1,319', 'Teppo', 'Numminen'),
#   1,
#   -17.030667136246944],
#  ('1125', '1219', '1.08'): [('1125', '1219', '1.08'), 1, -17.030667136246944],
#  ('1273', '1599', '1.26'): [('1273', '1599', '1.26'), 1, -17.030667136246944],
#  ('1282', '1590', '1.24'): [('1282', '1590', '1.24'), 1, -17.030667136246944],
#  ('1294', '1327', '1.03'): [('1294', '1327', '1.03'), 1, -17.030667136246944],
#  ('1432', '1335', '0.93'): [('1432', '1335', '0.93'), 1, -17.030667136246944],
#  ('1487', '2857', '1.92'): [('1487', '2857', '1.92'), 1, -17.030667136246944],
#  ('1502', 'Pedro', 'Alvares'): [('1502', 'Pedro', 'Alvares'),
#   1,
#   -17.030667136246944],
#  ('1514', '1755', '1.16'): [('1514', '1755', '1.16'), 1, -17.030667136246944],
#  ('1615', '1216', '0.75'): [('1615', '1216', '0.75'), 1, -17.030667136246944],
#  ('1731', '1798', '1.04'): [('1731', '1798', '1.04'), 1, -17.030667136246944],
#  ('1814', 'Napoleon', 'Bonaparte'): [('1814', 'Napoleon', 'Bonaparte'),
#   1,
#   -17.030667136246944],
#  ('1909–1911', '1918–1919', '3,000'): [('1909–1911', '1918–1919', '3,000'),
#   1,
#   -17.030667136246944],
#  ('1927–1979', '16,700', '1927'): [('1927–1979', '16,700', '1927'),
#   1,
#   -17.030667136246944],
#  ('1972–2015',
#   '2018–present',
#   'temporary'): [('1972–2015',
#    '2018–present',
#    'temporary'), 1, -17.030667136246944],
#  ('1977–1983', '1967–1994', '17,188'): [('1977–1983', '1967–1994', '17,188'),
#   1,
#   -17.030667136246944],
#  ('1988–1999', '1967–1999', '16,005'): [('1988–1999', '1967–1999', '16,005'),
#   1,
#   -17.030667136246944],
#  ('1996–1997', '1974–1997', '18,130'): [('1996–1997', '1974–1997', '18,130'),
#   1,
#   -17.030667136246944],
#  ('1996–2007', '1982–2007', '19,040'): [('1996–2007', '1982–2007', '19,040'),
#   1,
#   -17.030667136246944],
#  ('1999–2010', '1967–2010', '16,940'): [('1999–2010', '1967–2010', '16,940'),
#   1,
#   -17.030667136246944],
#  ('2003–2004',
#   '2005–2006',
#   'Rochester'): [('2003–2004',
#    '2005–2006',
#    'Rochester'), 1, -17.030667136246944],
#  ('2003–2016', '1974–2016', '16,839'): [('2003–2016', '1974–2016', '16,839'),
#   1,
#   -17.030667136246944],
#  ('254', '390', '1695'): [('254', '390', '1695'), 1, -17.030667136246944],
#  ('2785', 'Willi', 'Plett'): [('2785', 'Willi', 'Plett'),
#   1,
#   -17.030667136246944],
#  ('288', '320', '1184'): [('288', '320', '1184'), 1, -17.030667136246944],
#  ('325′', '52′', 'Kauffman'): [('325′', '52′', 'Kauffman'),
#   1,
#   -17.030667136246944],
#  ('33.626057',
#   '73.071442',
#   'properties'): [('33.626057',
#    '73.071442',
#    'properties'), 1, -17.030667136246944],
#  ('355', 'Gump', 'Worsley'): [('355', 'Gump', 'Worsley'),
#   1,
#   -17.030667136246944],
#  ('3565', 'Tie', 'Domi'): [('3565', 'Tie', 'Domi'), 1, -17.030667136246944],
#  ('357', '269', '1157'): [('357', '269', '1157'), 1, -17.030667136246944],
#  ('365′', '325′', '52′'): [('365′', '325′', '52′'), 1, -17.030667136246944],
#  ('43,647', '401′', 'Comerica'): [('43,647', '401′', 'Comerica'),
#   1,
#   -17.030667136246944],
#  ('752', '1126', '1.50'): [('752', '1126', '1.50'), 1, -17.030667136246944],
#  ('915', '1723', '1.88'): [('915', '1723', '1.88'), 1, -17.030667136246944],
#  ('977', '1239', '1.27'): [('977', '1239', '1.27'), 1, -17.030667136246944],
#  ('AVNOJ', 'Presidium', 'issued'): [('AVNOJ', 'Presidium', 'issued'),
#   1,
#   -17.030667136246944],
#  ('Abravanel', 'Benveniste', 'Hajj'): [('Abravanel', 'Benveniste', 'Hajj'),
#   1,
#   -17.030667136246944],
#  ('Adolf', 'Hitler', 'commits'): [('Adolf', 'Hitler', 'commits'),
#   1,
#   -17.030667136246944],
#  ('Akira', "Kurosawa's", 'Seven'): [('Akira', "Kurosawa's", 'Seven'),
#   1,
#   -17.030667136246944],
#  ('Albert', 'Hofmann', 'discovers'): [('Albert', 'Hofmann', 'discovers'),
#   1,
#   -17.030667136246944],
#  ('Alfred', 'Baring', 'Garrod'): [('Alfred', 'Baring', 'Garrod'),
#   1,
#   -17.030667136246944],
#  ('Alyson', 'Stoner', 'Catilyn'): [('Alyson', 'Stoner', 'Catilyn'),
#   1,
#   -17.030667136246944],
#  ('Amitri', 'Basket', 'Case'): [('Amitri', 'Basket', 'Case'),
#   1,
#   -17.030667136246944],
#  ('ArenaThe',
#   'Checkerdome',
#   '1977–1983'): [('ArenaThe',
#    'Checkerdome',
#    '1977–1983'), 1, -17.030667136246944],
#  ('Aristotle', '384–322', 'B.C'): [('Aristotle', '384–322', 'B.C'),
#   1,
#   -17.030667136246944],
#  ('Arjumand', 'Banu', 'Begum'): [('Arjumand', 'Banu', 'Begum'),
#   1,
#   -17.030667136246944],
#  ('Athletic',
#   'Club)(1919–1920',
#   'Barton'): [('Athletic',
#    'Club)(1919–1920',
#    'Barton'), 1, -17.030667136246944],
#  ('Aulus', 'Cornelius', 'Celsus'): [('Aulus', 'Cornelius', 'Celsus'),
#   1,
#   -17.030667136246944],
#  ('Benveniste', 'Hajj', 'Yachya'): [('Benveniste', 'Hajj', 'Yachya'),
#   1,
#   -17.030667136246944],
#  ('Bernardino',
#   'Downey',
#   'Montebello'): [('Bernardino',
#    'Downey',
#    'Montebello'), 1, -17.030667136246944],
#  ('Bet', 'Hounding', 'Leading'): [('Bet', 'Hounding', 'Leading'),
#   1,
#   -17.030667136246944],
#  ('Bonjour',
#   "Apple's",
#   'implementation'): [('Bonjour',
#    "Apple's",
#    'implementation'), 1, -17.030667136246944],
#  ("Bravo's", 'Celebrity', 'Poker'): [("Bravo's", 'Celebrity', 'Poker'),
#   1,
#   -17.030667136246944],
#  ('Bursitis',
#   'Tendinitis',
#   'Shoulder'): [('Bursitis',
#    'Tendinitis',
#    'Shoulder'), 1, -17.030667136246944],
#  ('COPD', 'Chronic', 'obstructive'): [('COPD', 'Chronic', 'obstructive'),
#   1,
#   -17.030667136246944],
#  ('CPR',
#   'Cardiopulmonary',
#   'resuscitation'): [('CPR',
#    'Cardiopulmonary',
#    'resuscitation'), 1, -17.030667136246944],
#  ('CT', 'Computed', 'tomography'): [('CT', 'Computed', 'tomography'),
#   1,
#   -17.030667136246944],
#  ('Camily', 'Acuña', 'Miriam'): [('Camily', 'Acuña', 'Miriam'),
#   1,
#   -17.030667136246944],
#  ('Canals', 'Barrera', 'Connie'): [('Canals', 'Barrera', 'Connie'),
#   1,
#   -17.030667136246944],
#  ('Capital,”',
#   'Portland',
#   'Oregonian'): [('Capital,”',
#    'Portland',
#    'Oregonian'), 1, -17.030667136246944],
#  ('Celebrity', 'Poker', 'Showdown'): [('Celebrity', 'Poker', 'Showdown'),
#   1,
#   -17.030667136246944],
#  ('Checkerdome',
#   '1977–1983',
#   '1967–1994'): [('Checkerdome',
#    '1977–1983',
#    '1967–1994'), 1, -17.030667136246944],
#  ('Cheryl', 'Boone', 'Issacs'): [('Cheryl', 'Boone', 'Issacs'),
#   1,
#   -17.030667136246944],
#  ('Chronic',
#   'obstructive',
#   'pulmonary'): [('Chronic',
#    'obstructive',
#    'pulmonary'), 1, -17.030667136246944],
#  ('Classicism',
#   'Romanticism',
#   'Realism'): [('Classicism',
#    'Romanticism',
#    'Realism'), 1, -17.030667136246944],
#  ('Clockers', 'Ronald', 'Strike'): [('Clockers', 'Ronald', 'Strike'),
#   1,
#   -17.030667136246944],
#  ('Corporate', '“Company', 'History”'): [('Corporate', '“Company', 'History”'),
#   1,
#   -17.030667136246944],
#  ('Corral', '1980–1983', '7,424'): [('Corral', '1980–1983', '7,424'),
#   1,
#   -17.030667136246944],
#  ('Cubism', 'Dadaism', 'Surrealism'): [('Cubism', 'Dadaism', 'Surrealism'),
#   1,
#   -17.030667136246944],
#  ("DK's", 'Jungle', 'Parkway'): [("DK's", 'Jungle', 'Parkway'),
#   1,
#   -17.030667136246944],
#  ('DM2', 'DJD', 'Degenerative'): [('DM2', 'DJD', 'Degenerative'),
#   1,
#   -17.030667136246944],
#  ('Dangerous', 'Mind', 'Penny'): [('Dangerous', 'Mind', 'Penny'),
#   1,
#   -17.030667136246944],
#  ('Darko', 'Karen', 'Pomeroy'): [('Darko', 'Karen', 'Pomeroy'),
#   1,
#   -17.030667136246944],
#  ('Democratic',
#   'Assembly',
#   'NDA-Balad'): [('Democratic',
#    'Assembly',
#    'NDA-Balad'), 1, -17.030667136246944],
#  ('Die', 'Rakete', 'zu'): [('Die', 'Rakete', 'zu'), 1, -17.030667136246944],
#  ('Distance', 'Erin', 'Langford'): [('Distance', 'Erin', 'Langford'),
#   1,
#   -17.030667136246944],
#  ('Donnie', 'Darko', 'Karen'): [('Donnie', 'Darko', 'Karen'),
#   1,
#   -17.030667136246944],
#  ('Duba', 'Saudi', 'Arabia'): [('Duba', 'Saudi', 'Arabia'),
#   1,
#   -17.030667136246944],
#  ('Duplex', 'Nancy', 'Kendricks'): [('Duplex', 'Nancy', 'Kendricks'),
#   1,
#   -17.030667136246944],
#  ('Dying', 'Jefferson', 'Uninvited'): [('Dying', 'Jefferson', 'Uninvited'),
#   1,
#   -17.030667136246944],
#  ('ECG', 'EKG', 'Electrocardiogram'): [('ECG', 'EKG', 'Electrocardiogram'),
#   1,
#   -17.030667136246944],
#  ('ENT', 'Ears', 'Nose'): [('ENT', 'Ears', 'Nose'), 1, -17.030667136246944],
#  ('Eating',
#   'purine-rich',
#   'vegetables'): [('Eating',
#    'purine-rich',
#    'vegetables'), 1, -17.030667136246944],
#  ('Exists',
#   'hu:Panthera',
#   'hibridek#Liger'): [('Exists',
#    'hu:Panthera',
#    'hibridek#Liger'), 1, -17.030667136246944],
#  ('Expressionism',
#   'Fauvism',
#   'Cubism'): [('Expressionism', 'Fauvism', 'Cubism'), 1, -17.030667136246944],
#  ("Eysenck's", 'opinion', 'Professor'): [("Eysenck's", 'opinion', 'Professor'),
#   1,
#   -17.030667136246944],
#  ('Farm', 'Frappe', 'Snowland'): [('Farm', 'Frappe', 'Snowland'),
#   1,
#   -17.030667136246944],
#  ('Fatal', 'Car', 'Crash'): [('Fatal', 'Car', 'Crash'),
#   1,
#   -17.030667136246944],
#  ('Fauvism', 'Cubism', 'Dadaism'): [('Fauvism', 'Cubism', 'Dadaism'),
#   1,
#   -17.030667136246944],
#  ('Fever', 'Pitch', 'Lindsey'): [('Fever', 'Pitch', 'Lindsey'),
#   1,
#   -17.030667136246944],
#  ('Fingered',
#   "Davidson's",
#   'Receptionist'): [('Fingered',
#    "Davidson's",
#    'Receptionist'), 1, -17.030667136246944],
#  ('Frappe', 'Snowland', 'Sherbet'): [('Frappe', 'Snowland', 'Sherbet'),
#   1,
#   -17.030667136246944],
#  ('GEneral', 'NEural', 'SImulation'): [('GEneral', 'NEural', 'SImulation'),
#   1,
#   -17.030667136246944],
#  ('Gene', 'Roddenberry', 'Yenesis'): [('Gene', 'Roddenberry', 'Yenesis'),
#   1,
#   -17.030667136246944],
#  ('Gorilla', 'Systems', 'Corp'): [('Gorilla', 'Systems', 'Corp'),
#   1,
#   -17.030667136246944],
#  ('Gump', 'Worsley', '335'): [('Gump', 'Worsley', '335'),
#   1,
#   -17.030667136246944],
#  ('Guncrazy', 'Anita', 'Minteer'): [('Guncrazy', 'Anita', 'Minteer'),
#   1,
#   -17.030667136246944],
#  ('HEEM-onk', 'ICU', 'Intensive'): [('HEEM-onk', 'ICU', 'Intensive'),
#   1,
#   -17.030667136246944],
#  ('HTN',
#   'Hypertension',
#   'Circulatory'): [('HTN',
#    'Hypertension',
#    'Circulatory'), 1, -17.030667136246944],
#  ('Harappan',
#   'Aryan',
#   'Persian,Hindu'): [('Harappan',
#    'Aryan',
#    'Persian,Hindu'), 1, -17.030667136246944],
#  ('Herbie', 'Fully', 'Loaded'): [('Herbie', 'Fully', 'Loaded'),
#   1,
#   -17.030667136246944],
#  ('Hezekiah', 'Hiyya', 'al-Daudi'): [('Hezekiah', 'Hiyya', 'al-Daudi'),
#   1,
#   -17.030667136246944],
#  ('Hide', 'Tinsel', 'Hanley'): [('Hide', 'Tinsel', 'Hanley'),
#   1,
#   -17.030667136246944],
#  ('Himself', 'Uncredited', 'cameo'): [('Himself', 'Uncredited', 'cameo'),
#   1,
#   -17.030667136246944],
#  ('Hip', 'Hopera', 'Derek'): [('Hip', 'Hopera', 'Derek'),
#   1,
#   -17.030667136246944],
#  ('Hiyya', 'al-Daudi', 'Gaon'): [('Hiyya', 'al-Daudi', 'Gaon'),
#   1,
#   -17.030667136246944],
#  ('Hofmann', 'discovers', "LSD's"): [('Hofmann', 'discovers', "LSD's"),
#   1,
#   -17.030667136246944],
#  ("Hotel's", 'Coconut', 'Grove'): [("Hotel's", 'Coconut', 'Grove'),
#   1,
#   -17.030667136246944],
#  ('Hurricane', 'Katrina', 'wreaks'): [('Hurricane', 'Katrina', 'wreaks'),
#   1,
#   -17.030667136246944],
#  ('ICU', 'Intensive', 'Care'): [('ICU', 'Intensive', 'Care'),
#   1,
#   -17.030667136246944],
#  ('INH', 'Inhaled', 'breathed'): [('INH', 'Inhaled', 'breathed'),
#   1,
#   -17.030667136246944],
#  ('Initiation', 'Protocol', 'SIP'): [('Initiation', 'Protocol', 'SIP'),
#   1,
#   -17.030667136246944],
#  ('Intensive', 'Care', 'Unit'): [('Intensive', 'Care', 'Unit'),
#   1,
#   -17.030667136246944],
#  ('Jabber', 'Google', 'Talk'): [('Jabber', 'Google', 'Talk'),
#   1,
#   -17.030667136246944],
#  ('Jamaican', 'lager-style', 'beer'): [('Jamaican', 'lager-style', 'beer'),
#   1,
#   -17.030667136246944],
#  ('Jefferson', 'Uninvited', 'Guest'): [('Jefferson', 'Uninvited', 'Guest'),
#   1,
#   -17.030667136246944],
#  ('Jennifer', 'Ricci', 'TJ'): [('Jennifer', 'Ricci', 'TJ'),
#   1,
#   -17.030667136246944],
#  ('José', 'dos', 'Pinhais'): [('José', 'dos', 'Pinhais'),
#   1,
#   -17.030667136246944],
#  ('Judi', 'Dench', 'referenced'): [('Judi', 'Dench', 'referenced'),
#   1,
#   -17.030667136246944],
#  ('Jīn', 'Jī', 'Jiăng'): [('Jīn', 'Jī', 'Jiăng'), 1, -17.030667136246944],
#  ('Kamen', 'Rider', 'Den-O'): [('Kamen', 'Rider', 'Den-O'),
#   1,
#   -17.030667136246944],
#  ('Katrina', 'wreaks', 'devastation'): [('Katrina', 'wreaks', 'devastation'),
#   1,
#   -17.030667136246944],
#  ('Khawaja', 'Baqi', 'Billah'): [('Khawaja', 'Baqi', 'Billah'),
#   1,
#   -17.030667136246944],
#  ('Kot', 'Diji', 'Mohenjo-daro'): [('Kot', 'Diji', 'Mohenjo-daro'),
#   1,
#   -17.030667136246944],
#  ('Kočevski', 'Rog', 'butchery'): [('Kočevski', 'Rog', 'butchery'),
#   1,
#   -17.030667136246944],
#  ("Kurosawa's", 'Seven', 'Samurai'): [("Kurosawa's", 'Seven', 'Samurai'),
#   1,
#   -17.030667136246944],
#  ('Le', 'Coq', 'Grandé'): [('Le', 'Coq', 'Grandé'), 1, -17.030667136246944],
#  ('Lean', 'Mean', 'Machine'): [('Lean', 'Mean', 'Machine'),
#   1,
#   -17.030667136246944],
#  ('Leonardo', 'da', 'Vinci'): [('Leonardo', 'da', 'Vinci'),
#   1,
#   -17.030667136246944],
#  ('Lil', 'Romeo,Zachary', 'Isaiah'): [('Lil', 'Romeo,Zachary', 'Isaiah'),
#   1,
#   -17.030667136246944],
#  ('MRSA',
#   'Methicillin-resistant',
#   'Staphylococcus'): [('MRSA',
#    'Methicillin-resistant',
#    'Staphylococcus'), 1, -17.030667136246944],
#  ('MURR-suh', 'PID', 'Pelvic'): [('MURR-suh', 'PID', 'Pelvic'),
#   1,
#   -17.030667136246944],
#  ('Marius', 'Niculae', 'Romania'): [('Marius', 'Niculae', 'Romania'),
#   1,
#   -17.030667136246944],
#  ("Mater's", 'Tall', 'Tales'): [("Mater's", 'Tall', 'Tales'),
#   1,
#   -17.030667136246944],
#  ('Melcher', '“Dusting', 'Off'): [('Melcher', '“Dusting', 'Off'),
#   1,
#   -17.030667136246944],
#  ('Mery', 'Gambarotta', 'Sibley'): [('Mery', 'Gambarotta', 'Sibley'),
#   1,
#   -17.030667136246944],
#  ('Methicillin-resistant',
#   'Staphylococcus',
#   'aureus'): [('Methicillin-resistant',
#    'Staphylococcus',
#    'aureus'), 1, -17.030667136246944],
#  ('Michalis',
#   'Hadjiyiannis',
#   'Cyprus'): [('Michalis', 'Hadjiyiannis', 'Cyprus'), 1, -17.030667136246944],
#  ('Mind', 'Penny', 'Pacino'): [('Mind', 'Penny', 'Pacino'),
#   1,
#   -17.030667136246944],
#  ('Mitch', 'Impostor', 'Cale'): [('Mitch', 'Impostor', 'Cale'),
#   1,
#   -17.030667136246944],
#  ('Morning', 'Cathy', 'Goodwin'): [('Morning', 'Cathy', 'Goodwin'),
#   1,
#   -17.030667136246944],
#  ('Mrinal', 'Sen', 'Software'): [('Mrinal', 'Sen', 'Software'),
#   1,
#   -17.030667136246944],
#  ('NIDDM', 'Non-Insulin', 'Dependent'): [('NIDDM', 'Non-Insulin', 'Dependent'),
#   1,
#   -17.030667136246944],
#  ('NURR-oh', 'OB', 'Obstetrics'): [('NURR-oh', 'OB', 'Obstetrics'),
#   1,
#   -17.030667136246944],
#  ('Neuro', 'Neurology', 'Involves'): [('Neuro', 'Neurology', 'Involves'),
#   1,
#   -17.030667136246944],
#  ('Nexus', 'Wade', 'Barrett'): [('Nexus', 'Wade', 'Barrett'),
#   1,
#   -17.030667136246944],
#  ("Nora's", 'Hair', 'Salon'): [("Nora's", 'Hair', 'Salon'),
#   1,
#   -17.030667136246944],
#  ('OC', 'oral', 'contraceptive'): [('OC', 'oral', 'contraceptive'),
#   1,
#   -17.030667136246944],
#  ('OD', 'Overdose', 'Taking'): [('OD', 'Overdose', 'Taking'),
#   1,
#   -17.030667136246944],
#  ('ODD', 'Oppositional', 'defiant'): [('ODD', 'Oppositional', 'defiant'),
#   1,
#   -17.030667136246944],
#  ('Olesya', 'Rulin', 'Taira'): [('Olesya', 'Rulin', 'Taira'),
#   1,
#   -17.030667136246944],
#  ('PTSD', 'Post-traumatic', 'stress'): [('PTSD', 'Post-traumatic', 'stress'),
#   1,
#   -17.030667136246944],
#  ('Paolo', 'Kaire', 'Kyle'): [('Paolo', 'Kaire', 'Kyle'),
#   1,
#   -17.030667136246944],
#  ("Paul's", 'Parish', 'Orange'): [("Paul's", 'Parish', 'Orange'),
#   1,
#   -17.030667136246944],
#  ('Pedi', 'Pediatrics', 'Pediatric'): [('Pedi', 'Pediatrics', 'Pediatric'),
#   1,
#   -17.030667136246944],
#  ('Pedro', 'Alvares', 'Cabral'): [('Pedro', 'Alvares', 'Cabral'),
#   1,
#   -17.030667136246944],
#  ('Perseid', 'Meteor', 'Shower'): [('Perseid', 'Meteor', 'Shower'),
#   1,
#   -17.030667136246944],
#  ('Pitch', 'Lindsey', 'Meeks'): [('Pitch', 'Lindsey', 'Meeks'),
#   1,
#   -17.030667136246944],
#  ('Pollux', 'le', 'manège'): [('Pollux', 'le', 'manège'),
#   1,
#   -17.030667136246944],
#  ('Psychiatry', 'stated', 'Unless'): [('Psychiatry', 'stated', 'Unless'),
#   1,
#   -17.030667136246944],
#  ('Puente', 'El', 'Monte'): [('Puente', 'El', 'Monte'),
#   1,
#   -17.030667136246944],
#  ('Pāvels', 'Mihadjuks', 'Latvia'): [('Pāvels', 'Mihadjuks', 'Latvia'),
#   1,
#   -17.030667136246944],
#  ('Rabbanic', 'Dynasty', 'Charlap'): [('Rabbanic', 'Dynasty', 'Charlap'),
#   1,
#   -17.030667136246944],
#  ('Rabbi', 'Elazar', 'Rokeach'): [('Rabbi', 'Elazar', 'Rokeach'),
#   1,
#   -17.030667136246944],
#  ('Raise', 'Capital,”', 'Portland'): [('Raise', 'Capital,”', 'Portland'),
#   1,
#   -17.030667136246944],
#  ('Rakete', 'zu', 'den'): [('Rakete', 'zu', 'den'), 1, -17.030667136246944],
#  ('Rogatien', 'Vachon', '355'): [('Rogatien', 'Vachon', '355'),
#   1,
#   -17.030667136246944],
#  ('Ronald', 'Strike', 'Dunham'): [('Ronald', 'Strike', 'Dunham'),
#   1,
#   -17.030667136246944],
#  ('Rushd', 'Averroes', 'Prize'): [('Rushd', 'Averroes', 'Prize'),
#   1,
#   -17.030667136246944],
#  ('SC', 'SQ', 'Sub-q'): [('SC', 'SQ', 'Sub-q'), 1, -17.030667136246944],
#  ('SEE-diff', 'HCV', 'Hepatitis'): [('SEE-diff', 'HCV', 'Hepatitis'),
#   1,
#   -17.030667136246944],
#  ('SI', 'Suicidal', 'ideation'): [('SI', 'Suicidal', 'ideation'),
#   1,
#   -17.030667136246944],
#  ('SQ', 'Sub-q', 'Subcutaneous'): [('SQ', 'Sub-q', 'Subcutaneous'),
#   1,
#   -17.030667136246944],
#  ('SSRI', 'Selective', 'serotonin'): [('SSRI', 'Selective', 'serotonin'),
#   1,
#   -17.030667136246944],
#  ('Seals)(1970–1976)(Oakland',
#   'Seals)(1967–1970)(California',
#   'Seals)(1967'): [('Seals)(1970–1976)(Oakland',
#    'Seals)(1967–1970)(California',
#    'Seals)(1967'),
#   1,
#   -17.030667136246944],
#  ('Selective',
#   'serotonin',
#   'reuptake'): [('Selective',
#    'serotonin',
#    'reuptake'), 1, -17.030667136246944],
#  ('Session', 'Initiation', 'Protocol'): [('Session', 'Initiation', 'Protocol'),
#   1,
#   -17.030667136246944],
#  ('Shahi', 'rulars', 'controlling'): [('Shahi', 'rulars', 'controlling'),
#   1,
#   -17.030667136246944],
#  ('Shanica', 'Towels', 'Jennifer'): [('Shanica', 'Towels', 'Jennifer'),
#   1,
#   -17.030667136246944],
#  ('Shannon', 'Leelee', 'Sobieski'): [('Shannon', 'Leelee', 'Sobieski'),
#   1,
#   -17.030667136246944],
#  ('Shin', 'Bet', 'Hounding'): [('Shin', 'Bet', 'Hounding'),
#   1,
#   -17.030667136246944],
#  ('Sir', 'Cyril', 'Radcliffe'): [('Sir', 'Cyril', 'Radcliffe'),
#   1,
#   -17.030667136246944],
#  ('Slaughter', 'Colonel', 'Mustafa'): [('Slaughter', 'Colonel', 'Mustafa'),
#   1,
#   -17.030667136246944],
#  ('Snowland', 'Sherbet', 'Land'): [('Snowland', 'Sherbet', 'Land'),
#   1,
#   -17.030667136246944],
#  ('Source', '1945–2003', 'Honoured'): [('Source', '1945–2003', 'Honoured'),
#   1,
#   -17.030667136246944],
#  ('Sri', 'Lanka', 'Maldives'): [('Sri', 'Lanka', 'Maldives'),
#   1,
#   -17.030667136246944],
#  ('Stampede', 'Corral', '1980–1983'): [('Stampede', 'Corral', '1980–1983'),
#   1,
#   -17.030667136246944],
#  ('Statistical', 'Manual', 'DSM'): [('Statistical', 'Manual', 'DSM'),
#   1,
#   -17.030667136246944],
#  ('Systemic',
#   'lupus',
#   'erythematosus'): [('Systemic',
#    'lupus',
#    'erythematosus'), 1, -17.030667136246944],
#  ('São', 'José', 'dos'): [('São', 'José', 'dos'), 1, -17.030667136246944],
#  ('TIA', 'Transient', 'ischemic'): [('TIA', 'Transient', 'ischemic'),
#   1,
#   -17.030667136246944],
#  ('Teppo', 'Numminen', '1,315'): [('Teppo', 'Numminen', '1,315'),
#   1,
#   -17.030667136246944],
#  ('Tie', 'Domi', '3515'): [('Tie', 'Domi', '3515'), 1, -17.030667136246944],
#  ('Tigers)(1920–1925)(Quebec',
#   'Athletic',
#   'Club)(1919–1920'): [('Tigers)(1920–1925)(Quebec',
#    'Athletic',
#    'Club)(1919–1920'), 1, -17.030667136246944],
#  ('Toons', "Mater's", 'Tall'): [('Toons', "Mater's", 'Tall'),
#   1,
#   -17.030667136246944],
#  ('Towels', 'Jennifer', 'Ricci'): [('Towels', 'Jennifer', 'Ricci'),
#   1,
#   -17.030667136246944],
#  ('Trachtenberg', 'Shanica', 'Towels'): [('Trachtenberg', 'Shanica', 'Towels'),
#   1,
#   -17.030667136246944],
#  ('Tyrannosaurus', 'rex', 'specimen'): [('Tyrannosaurus', 'rex', 'specimen'),
#   1,
#   -17.030667136246944],
#  ('UNICEF', 'terre', 'des'): [('UNICEF', 'terre', 'des'),
#   1,
#   -17.030667136246944],
#  ('Uninvited', 'Guest', 'Silk'): [('Uninvited', 'Guest', 'Silk'),
#   1,
#   -17.030667136246944],
#  ('VAN', '1756', '1887'): [('VAN', '1756', '1887'), 1, -17.030667136246944],
#  ('Vachon', '355', 'Gump'): [('Vachon', '355', 'Gump'),
#   1,
#   -17.030667136246944],
#  ('Vasquez', 'Paolo', 'Kaire'): [('Vasquez', 'Paolo', 'Kaire'),
#   1,
#   -17.030667136246944],
#  ('Village', 'Duba', 'Saudi'): [('Village', 'Duba', 'Saudi'),
#   1,
#   -17.030667136246944],
#  ('Watch', 'repair', 'etc'): [('Watch', 'repair', 'etc'),
#   1,
#   -17.030667136246944],
#  ('Willi', 'Plett', '2572'): [('Willi', 'Plett', '2572'),
#   1,
#   -17.030667136246944],
#  ('Wings(Detroit',
#   'Falcons)(Detroit',
#   'Cougars'): [('Wings(Detroit',
#    'Falcons)(Detroit',
#    'Cougars'), 1, -17.030667136246944],
#  ('WorldStatesmen',
#   'Religious',
#   'Organisations'): [('WorldStatesmen',
#    'Religious',
#    'Organisations'), 1, -17.030667136246944],
#  ('XMPP', 'Jabber', 'Google'): [('XMPP', 'Jabber', 'Google'),
#   1,
#   -17.030667136246944],
#  ('XRT', 'X-ray', 'Therapy'): [('XRT', 'X-ray', 'Therapy'),
#   1,
#   -17.030667136246944],
#  ('Xbox', 'Live', 'Arcade'): [('Xbox', 'Live', 'Arcade'),
#   1,
#   -17.030667136246944],
#  ('acidosis',
#   'articular',
#   'hydration'): [('acidosis',
#    'articular',
#    'hydration'), 1, -17.030667136246944],
#  ('actions', 'ODD', 'Oppositional'): [('actions', 'ODD', 'Oppositional'),
#   1,
#   -17.030667136246944],
#  ('advertising', 'slogan', 'Where'): [('advertising', 'slogan', 'Where'),
#   1,
#   -17.030667136246944],
#  ('aerial', 'stunts', 'tumbling'): [('aerial', 'stunts', 'tumbling'),
#   1,
#   -17.030667136246944],
#  ('aspirin', 'NTG', 'Nitroglycerin'): [('aspirin', 'NTG', 'Nitroglycerin'),
#   1,
#   -17.030667136246944],
#  ('autobiography', 'Dusty', 'Rhodes'): [('autobiography', 'Dusty', 'Rhodes'),
#   1,
#   -17.030667136246944],
#  ('bakeries',
#   'delicatessens',
#   'banks'): [('bakeries', 'delicatessens', 'banks'), 1, -17.030667136246944],
#  ('beans', 'peas', 'lentils'): [('beans', 'peas', 'lentils'),
#   1,
#   -17.030667136246944],
#  ('boss', 'select', 'screen'): [('boss', 'select', 'screen'),
#   1,
#   -17.030667136246944],
#  ('bypass', 'graft', 'Surgery'): [('bypass', 'graft', 'Surgery'),
#   1,
#   -17.030667136246944],
#  ('carving', 'bronze', 'pottery'): [('carving', 'bronze', 'pottery'),
#   1,
#   -17.030667136246944],
#  ('collision', 'avoidance', 'systems'): [('collision', 'avoidance', 'systems'),
#   1,
#   -17.030667136246944],
#  ('coloinal',
#   'imperialistic',
#   'romanic'): [('coloinal',
#    'imperialistic',
#    'romanic'), 1, -17.030667136246944],
#  ('coordinates',
#   '33.626057',
#   '73.071442'): [('coordinates',
#    '33.626057',
#    '73.071442'), 1, -17.030667136246944],
#  ('cosplay', 'Susan', 'Storm'): [('cosplay', 'Susan', 'Storm'),
#   1,
#   -17.030667136246944],
#  ('cylinder',
#   'stereotypically',
#   'embodied'): [('cylinder',
#    'stereotypically',
#    'embodied'), 1, -17.030667136246944],
#  ('delicatessens',
#   'banks',
#   'florists'): [('delicatessens',
#    'banks',
#    'florists'), 1, -17.030667136246944],
#  ('dizzy', 'unsteady', 'lightheaded'): [('dizzy', 'unsteady', 'lightheaded'),
#   1,
#   -17.030667136246944],
#  ("doctor's", 'prescription', 'PCP'): [("doctor's", 'prescription', 'PCP'),
#   1,
#   -17.030667136246944],
#  ('e.g', 'beans', 'peas'): [('e.g', 'beans', 'peas'), 1, -17.030667136246944],
#  ('emergencies',
#   'GI',
#   'Gastrointestinal'): [('emergencies',
#    'GI',
#    'Gastrointestinal'), 1, -17.030667136246944],
#  ('emit', 'high-pitched', 'clicks'): [('emit', 'high-pitched', 'clicks'),
#   1,
#   -17.030667136246944],
#  ('erythrocyte',
#   'sedimentation',
#   'rate(ESR'): [('erythrocyte',
#    'sedimentation',
#    'rate(ESR'), 1, -17.030667136246944],
#  ('external',
#   'malleolus',
#   'Image:Tophigout.JPGGout'): [('external',
#    'malleolus',
#    'Image:Tophigout.JPGGout'), 1, -17.030667136246944],
#  ('first-ever', 'mobile', 'phone'): [('first-ever', 'mobile', 'phone'),
#   1,
#   -17.030667136246944],
#  ('grabs', "Samuel's", 'robe'): [('grabs', "Samuel's", 'robe'),
#   1,
#   -17.030667136246944],
#  ('guardian', 'Bairam', 'Khan'): [('guardian', 'Bairam', 'Khan'),
#   1,
#   -17.030667136246944],
#  ('hallucinations',
#   'SSRI',
#   'Selective'): [('hallucinations',
#    'SSRI',
#    'Selective'), 1, -17.030667136246944],
#  ('hedge', 'fund', 'managers'): [('hedge', 'fund', 'managers'),
#   1,
#   -17.030667136246944],
#  ('hemolytic', 'anemia', 'psoriasis'): [('hemolytic', 'anemia', 'psoriasis'),
#   1,
#   -17.030667136246944],
#  ('hibridek#Liger',
#   'sv:Lejonhybrid#Liger',
#   'och'): [('hibridek#Liger',
#    'sv:Lejonhybrid#Liger',
#    'och'), 1, -17.030667136246944],
#  ('hu:Panthera',
#   'hibridek#Liger',
#   'sv:Lejonhybrid#Liger'): [('hu:Panthera',
#    'hibridek#Liger',
#    'sv:Lejonhybrid#Liger'), 1, -17.030667136246944],
#  ('imperialistic',
#   'romanic',
#   'empire'): [('imperialistic', 'romanic', 'empire'), 1, -17.030667136246944],
#  ('jade', 'carving', 'bronze'): [('jade', 'carving', 'bronze'),
#   1,
#   -17.030667136246944],
#  ('le', 'manège', 'enchanté'): [('le', 'manège', 'enchanté'),
#   1,
#   -17.030667136246944],
#  ('longtime', 'advertising', 'slogan'): [('longtime', 'advertising', 'slogan'),
#   1,
#   -17.030667136246944],
#  ('luck', 'charm', 'lover'): [('luck', 'charm', 'lover'),
#   1,
#   -17.030667136246944],
#  ('lunar', 'crust', 'retrieved'): [('lunar', 'crust', 'retrieved'),
#   1,
#   -17.030667136246944],
#  ('marker-color',
#   '0050d0',
#   'Administrative'): [('marker-color',
#    '0050d0',
#    'Administrative'), 1, -17.030667136246944],
#  ('mountain', 'Ye', 'mountains'): [('mountain', 'Ye', 'mountains'),
#   1,
#   -17.030667136246944],
#  ('muscle', 'INH', 'Inhaled'): [('muscle', 'INH', 'Inhaled'),
#   1,
#   -17.030667136246944],
#  ('oral', 'contraceptive', 'OTC'): [('oral', 'contraceptive', 'OTC'),
#   1,
#   -17.030667136246944],
#  ('paintings', 'stained', 'glass'): [('paintings', 'stained', 'glass'),
#   1,
#   -17.030667136246944],
#  ('perfumes', 'spices', 'textiles'): [('perfumes', 'spices', 'textiles'),
#   1,
#   -17.030667136246944],
#  ('philosopher',
#   'Aristotle',
#   '384–322'): [('philosopher',
#    'Aristotle',
#    '384–322'), 1, -17.030667136246944],
#  ('pinyin', 'Jīn', 'Jī'): [('pinyin', 'Jīn', 'Jī'), 1, -17.030667136246944],
#  ("pitcher's", 'mound', 'allow'): [("pitcher's", 'mound', 'allow'),
#   1,
#   -17.030667136246944],
#  ('postal', 'ZIP', 'codes'): [('postal', 'ZIP', 'codes'),
#   1,
#   -17.030667136246944],
#  ('prescription',
#   'PCP',
#   'Phencyclidine'): [('prescription',
#    'PCP',
#    'Phencyclidine'), 1, -17.030667136246944],
#  ('primus', 'inter', 'pares'): [('primus', 'inter', 'pares'),
#   1,
#   -17.030667136246944],
#  ('purine-rich', 'vegetables', 'e.g'): [('purine-rich', 'vegetables', 'e.g'),
#   1,
#   -17.030667136246944],
#  ('real-world', 'aerial', 'stunts'): [('real-world', 'aerial', 'stunts'),
#   1,
#   -17.030667136246944],
#  ('revealing',
#   'pictorials',
#   'featuring'): [('revealing',
#    'pictorials',
#    'featuring'), 1, -17.030667136246944],
#  ('seemingly',
#   'perfect',
#   'play-setting'): [('seemingly',
#    'perfect',
#    'play-setting'), 1, -17.030667136246944],
#  ('shaggy', 'candy-loving', 'puppy'): [('shaggy', 'candy-loving', 'puppy'),
#   1,
#   -17.030667136246944],
#  ('six-figure',
#   'multi-fight',
#   'contract'): [('six-figure',
#    'multi-fight',
#    'contract'), 1, -17.030667136246944],
#  ('slitless',
#   'spectroscopy',
#   'simulator'): [('slitless',
#    'spectroscopy',
#    'simulator'), 1, -17.030667136246944],
#  ('slogan', 'Where', "there's"): [('slogan', 'Where', "there's"),
#   1,
#   -17.030667136246944],
#  ('soap', 'opera', 'airing'): [('soap', 'opera', 'airing'),
#   1,
#   -17.030667136246944],
#  ('solid', 'organ', 'transplants'): [('solid', 'organ', 'transplants'),
#   1,
#   -17.030667136246944],
#  ('spectroscopy',
#   'simulator',
#   'programme'): [('spectroscopy',
#    'simulator',
#    'programme'), 1, -17.030667136246944],
#  ('squeeze', 'toy', 'aliens'): [('squeeze', 'toy', 'aliens'),
#   1,
#   -17.030667136246944],
#  ("suburb's", 'postal', 'ZIP'): [("suburb's", 'postal', 'ZIP'),
#   1,
#   -17.030667136246944],
#  ('supposed', 'Chetnik', 'Serbs'): [('supposed', 'Chetnik', 'Serbs'),
#   1,
#   -17.030667136246944],
#  ('swallowed',
#   'IM',
#   'Intramuscularly'): [('swallowed',
#    'IM',
#    'Intramuscularly'), 1, -17.030667136246944],
#  ('terre', 'des', 'hommes'): [('terre', 'des', 'hommes'),
#   1,
#   -17.030667136246944],
#  ('und', 'Heimatkunde', 'Heft'): [('und', 'Heimatkunde', 'Heft'),
#   1,
#   -17.030667136246944],
#  ('vegetables', 'e.g', 'beans'): [('vegetables', 'e.g', 'beans'),
#   1,
#   -17.030667136246944],
#  ('zu', 'den', 'Planetenräumen'): [('zu', 'den', 'Planetenräumen'),
#   1,
#   -17.030667136246944],
#  ('“Ibn', 'Rushd', 'Averroes'): [('“Ibn', 'Rushd', 'Averroes'),
#   1,
#   -17.030667136246944],
#  ('1,000', 'square', 'kilometers'): [('1,000', 'square', 'kilometers'),
#   1,
#   -18.030667136246944],
#  ('1,824', 'Owen', 'Nolan'): [('1,824', 'Owen', 'Nolan'),
#   1,
#   -18.030667136246944],
#  ('1188', '1409', '1.19'): [('1188', '1409', '1.19'), 1, -18.030667136246944],
#  ('1191', '1326', '1.11'): [('1191', '1326', '1.11'), 1, -18.030667136246944],
#  ('1251', '1398', '1.12'): [('1251', '1398', '1.12'), 1, -18.030667136246944],
#  ('1269', '1391', '1.10'): [('1269', '1391', '1.10'), 1, -18.030667136246944],
#  ('1279', '1425', '1.11'): [('1279', '1425', '1.11'), 1, -18.030667136246944],
#  ('1348', '1771', '1.31'): [('1348', '1771', '1.31'), 1, -18.030667136246944],
#  ('1378', '1205', '0.87'): [('1378', '1205', '0.87'), 1, -18.030667136246944],
#  ('1416', '1274', '0.90'): [('1416', '1274', '0.90'), 1, -18.030667136246944],
#  ('1540', '1369', '0.89'): [('1540', '1369', '0.89'), 1, -18.030667136246944],
#  ('16,700', '1927', 'Border'): [('16,700', '1927', 'Border'),
#   1,
#   -18.030667136246944],
#  ('1756', '1887', '1.07'): [('1756', '1887', '1.07'), 1, -18.030667136246944],
#  ('1767', '1850', '1.05'): [('1767', '1850', '1.05'), 1, -18.030667136246944],
#  ('1902', 'Marie', 'Curie'): [('1902', 'Marie', 'Curie'),
#   1,
#   -18.030667136246944],
#  ('1918–1919', '3,000', '1908'): [('1918–1919', '3,000', '1908'),
#   1,
#   -18.030667136246944],
#  ('1991–1993', '11,089', '1941'): [('1991–1993', '11,089', '1941'),
#   1,
#   -18.030667136246944],
#  ('230', '338', '1270'): [('230', '338', '1270'), 1, -18.030667136246944],
#  ('257', '394', '1859'): [('257', '394', '1859'), 1, -18.030667136246944],
#  ('263', '344', '1064'): [('263', '344', '1064'), 1, -18.030667136246944],
#  ('300–360', 'µmol/L', '5.0-6.0'): [('300–360', 'µmol/L', '5.0-6.0'),
#   1,
#   -18.030667136246944],
#  ('302', '226', '1266'): [('302', '226', '1266'), 1, -18.030667136246944],
#  ('303', '387', '1682'): [('303', '387', '1682'), 1, -18.030667136246944],
#  ('308', '365', '1367'): [('308', '365', '1367'), 1, -18.030667136246944],
#  ('318', '285', '1031'): [('318', '285', '1031'), 1, -18.030667136246944],
#  ('327', '228', '1202'): [('327', '228', '1202'), 1, -18.030667136246944],
#  ('338', '268', '1185'): [('338', '268', '1185'), 1, -18.030667136246944],
#  ('343', '336', '1648'): [('343', '336', '1648'), 1, -18.030667136246944],
#  ('345', '344', '1696'): [('345', '344', '1696'), 1, -18.030667136246944],
#  ('360', '278', '1600'): [('360', '278', '1600'), 1, -18.030667136246944],
#  ('363', 'Rogatien', 'Vachon'): [('363', 'Rogatien', 'Vachon'),
#   1,
#   -18.030667136246944],
#  ('365', '1367', 'Scoring'): [('365', '1367', 'Scoring'),
#   1,
#   -18.030667136246944],
#  ('420', 'μmol/L', '7.0'): [('420', 'μmol/L', '7.0'), 1, -18.030667136246944],
#  ('7-on-7', 'Elimination', 'Tag'): [('7-on-7', 'Elimination', 'Tag'),
#   1,
#   -18.030667136246944],
#  ('A-fib', 'Atrial', 'fibrillation'): [('A-fib', 'Atrial', 'fibrillation'),
#   1,
#   -18.030667136246944],
#  ('ADHD',
#   'Attention-deficit',
#   'hyperactivity'): [('ADHD',
#    'Attention-deficit',
#    'hyperactivity'), 1, -18.030667136246944],
#  ('AMA', 'BMI', 'Body'): [('AMA', 'BMI', 'Body'), 1, -18.030667136246944],
#  ('ASD', 'Autism', 'spectrum'): [('ASD', 'Autism', 'spectrum'),
#   1,
#   -18.030667136246944],
#  ('Aerosmith', 'Baba', "O'Riley"): [('Aerosmith', 'Baba', "O'Riley"),
#   1,
#   -18.030667136246944],
#  ('BMI', 'Body', 'Mass'): [('BMI', 'Body', 'Mass'), 1, -18.030667136246944],
#  ('Bad', 'Girls', 'Lilly'): [('Bad', 'Girls', 'Lilly'),
#   1,
#   -18.030667136246944],
#  ('Banshee', 'Boardwalk', 'Kalimari'): [('Banshee', 'Boardwalk', 'Kalimari'),
#   1,
#   -18.030667136246944],
#  ('Banu', 'Begum', 'Taj'): [('Banu', 'Begum', 'Taj'), 1, -18.030667136246944],
#  ('Bashara', 'Jamal', 'Zahalka'): [('Bashara', 'Jamal', 'Zahalka'),
#   1,
#   -18.030667136246944],
#  ('Beiträge', 'zur', 'Stolberger'): [('Beiträge', 'zur', 'Stolberger'),
#   1,
#   -18.030667136246944],
#  ('Benicio', 'Del', 'Toro'): [('Benicio', 'Del', 'Toro'),
#   1,
#   -18.030667136246944],
#  ('Body', 'Mass', 'Index'): [('Body', 'Mass', 'Index'),
#   1,
#   -18.030667136246944],
#  ('Bookshelf,”',
#   'Knowledge',
#   'Management'): [('Bookshelf,”', 'Knowledge', 'Management'),
#   1,
#   -18.030667136246944],
#  ('Brain', 'Stroke', 'DM'): [('Brain', 'Stroke', 'DM'),
#   1,
#   -18.030667136246944],
#  ('Breath', 'Breathing', 'Having'): [('Breath', 'Breathing', 'Having'),
#   1,
#   -18.030667136246944],
#  ("Brian's", 'Song', 'Gale'): [("Brian's", 'Song', 'Gale'),
#   1,
#   -18.030667136246944],
#  ('CAT', 'scan', 'ECG'): [('CAT', 'scan', 'ECG'), 1, -18.030667136246944],
#  ('Cardiopulmonary',
#   'resuscitation',
#   'Emergency'): [('Cardiopulmonary',
#    'resuscitation',
#    'Emergency'), 1, -18.030667136246944],
#  ('Cheetah', 'Girls', 'Passport'): [('Cheetah', 'Girls', 'Passport'),
#   1,
#   -18.030667136246944],
#  ('Clive', 'Owen', 'Mickey'): [('Clive', 'Owen', 'Mickey'),
#   1,
#   -18.030667136246944],
#  ('Coach', 'Punch', 'Cherkov'): [('Coach', 'Punch', 'Cherkov'),
#   1,
#   -18.030667136246944],
#  ('ColiseumThe',
#   'Crown',
#   '1997–1999)Firstar'): [('ColiseumThe',
#    'Crown',
#    '1997–1999)Firstar'), 1, -18.030667136246944],
#  ('Computed', 'tomography', 'scan'): [('Computed', 'tomography', 'scan'),
#   1,
#   -18.030667136246944],
#  ('Concubine', 'Rizpah', 'Armoni'): [('Concubine', 'Rizpah', 'Armoni'),
#   1,
#   -18.030667136246944],
#  ('Creative',
#   'Commons',
#   'Attribution/Share-Alike'): [('Creative',
#    'Commons',
#    'Attribution/Share-Alike'), 1, -18.030667136246944],
#  ('Curie', 'refine', 'Radium'): [('Curie', 'refine', 'Radium'),
#   1,
#   -18.030667136246944],
#  ('Del', 'Amitri', 'Basket'): [('Del', 'Amitri', 'Basket'),
#   1,
#   -18.030667136246944],
#  ('Del', 'Toro', 'Clive'): [('Del', 'Toro', 'Clive'), 1, -18.030667136246944],
#  ('Devon', 'Sawa', 'Seth'): [('Devon', 'Sawa', 'Seth'),
#   1,
#   -18.030667136246944],
#  ('Disease', 'Joints', 'Arthritis'): [('Disease', 'Joints', 'Arthritis'),
#   1,
#   -18.030667136246944],
#  ('Doherty', 'Jennie', 'Garth'): [('Doherty', 'Jennie', 'Garth'),
#   1,
#   -18.030667136246944],
#  ('Doppelganger', 'Holly', 'Gooding'): [('Doppelganger', 'Holly', 'Gooding'),
#   1,
#   -18.030667136246944],
#  ('Dorothy', 'Auchter', '“The'): [('Dorothy', 'Auchter', '“The'),
#   1,
#   -18.030667136246944],
#  ('Dungeness',
#   'shingle',
#   'promontory'): [('Dungeness',
#    'shingle',
#    'promontory'), 1, -18.030667136246944],
#  ('Durnan', '2.35', 'Gerry'): [('Durnan', '2.35', 'Gerry'),
#   1,
#   -18.030667136246944],
#  ('Ella', 'Maria', 'Canals'): [('Ella', 'Maria', 'Canals'),
#   1,
#   -18.030667136246944],
#  ('Encarta', 'Archived', '2009-11-01'): [('Encarta', 'Archived', '2009-11-01'),
#   1,
#   -18.030667136246944],
#  ('Eurovision', 'Song', 'Contest'): [('Eurovision', 'Song', 'Contest'),
#   1,
#   -18.030667136246944],
#  ("Everybody's", 'Fine', 'Rosie'): [("Everybody's", 'Fine', 'Rosie'),
#   1,
#   -18.030667136246944],
#  ('Fegan', 'Sander', 'Loya'): [('Fegan', 'Sander', 'Loya'),
#   1,
#   -18.030667136246944],
#  ('Fine', 'Rosie', 'Goode'): [('Fine', 'Rosie', 'Goode'),
#   1,
#   -18.030667136246944],
#  ("France's", 'Dreyfus', 'affair'): [("France's", 'Dreyfus', 'affair'),
#   1,
#   -18.030667136246944],
#  ('Freddy', 'Got', 'Fingered'): [('Freddy', 'Got', 'Fingered'),
#   1,
#   -18.030667136246944],
#  ('Further',
#   'reading',
#   '“Encyclopædia'): [('Further',
#    'reading',
#    '“Encyclopædia'), 1, -18.030667136246944],
#  ('Future', 'Porter', 'Paid'): [('Future', 'Porter', 'Paid'),
#   1,
#   -18.030667136246944],
#  ('GNU', 'Free', 'Documentation'): [('GNU', 'Free', 'Documentation'),
#   1,
#   -18.030667136246944],
#  ('Gardiner', '2.02', 'Lorne'): [('Gardiner', '2.02', 'Lorne'),
#   1,
#   -18.030667136246944],
#  ('Geschichte', 'und', 'Heimatkunde'): [('Geschichte', 'und', 'Heimatkunde'),
#   1,
#   -18.030667136246944],
#  ('Girls', 'Lilly', 'Laronette'): [('Girls', 'Lilly', 'Laronette'),
#   1,
#   -18.030667136246944],
#  ('Got', 'Fingered', "Davidson's"): [('Got', 'Fingered', "Davidson's"),
#   1,
#   -18.030667136246944],
#  ('Gray', 'Olesya', 'Rulin'): [('Gray', 'Olesya', 'Rulin'),
#   1,
#   -18.030667136246944],
#  ('Halifax',
#   'Metro',
#   'CentreScotiabank'): [('Halifax',
#    'Metro',
#    'CentreScotiabank'), 1, -18.030667136246944],
#  ('Halifax', 'Nova', 'Scotia'): [('Halifax', 'Nova', 'Scotia'),
#   1,
#   -18.030667136246944],
#  ('Horizon', 'drilling', 'rig'): [('Horizon', 'drilling', 'rig'),
#   1,
#   -18.030667136246944],
#  ("HyVee's", 'Largest', 'Store'): [("HyVee's", 'Largest', 'Store'),
#   1,
#   -18.030667136246944],
#  ('Infraorder',
#   'Tragulina',
#   'paraphyletic'): [('Infraorder',
#    'Tragulina',
#    'paraphyletic'), 1, -18.030667136246944],
#  ('Jewelry', 'Watch', 'repair'): [('Jewelry', 'Watch', 'repair'),
#   1,
#   -18.030667136246944],
#  ('Jewelry', 'perfumes', 'spices'): [('Jewelry', 'perfumes', 'spices'),
#   1,
#   -18.030667136246944],
#  ('Joints', 'Arthritis', 'DVT'): [('Joints', 'Arthritis', 'DVT'),
#   1,
#   -18.030667136246944],
#  ('Joy', 'Bryant', 'Missy'): [('Joy', 'Bryant', 'Missy'),
#   1,
#   -18.030667136246944],
#  ('Jungle', 'Parkway', 'Moo'): [('Jungle', 'Parkway', 'Moo'),
#   1,
#   -18.030667136246944],
#  ('Karl', 'Schleicher', 'Geschichte'): [('Karl', 'Schleicher', 'Geschichte'),
#   1,
#   -18.030667136246944],
#  ('Knowledge',
#   'Management',
#   'Magazine'): [('Knowledge',
#    'Management',
#    'Magazine'), 1, -18.030667136246944],
#  ('Knowledge', 'Village', 'Duba'): [('Knowledge', 'Village', 'Duba'),
#   1,
#   -18.030667136246944],
#  ('Kon-Tiki', 'expedition', 'aimed'): [('Kon-Tiki', 'expedition', 'aimed'),
#   1,
#   -18.030667136246944],
#  ('Lasseter', 'Andrew', 'Stanton'): [('Lasseter', 'Andrew', 'Stanton'),
#   1,
#   -18.030667136246944],
#  ('Law', 'Nicole', 'Kidman'): [('Law', 'Nicole', 'Kidman'),
#   1,
#   -18.030667136246944],
#  ('Lieutenant', 'Junior', 'Grade'): [('Lieutenant', 'Junior', 'Grade'),
#   1,
#   -18.030667136246944],
#  ('Loew', 'ben', 'Bezalel'): [('Loew', 'ben', 'Bezalel'),
#   1,
#   -18.030667136246944],
#  ('Longhorn', 'quarterback', 'Vince'): [('Longhorn', 'quarterback', 'Vince'),
#   1,
#   -18.030667136246944],
#  ('Lyrics', 'Sophie', 'Fisher'): [('Lyrics', 'Sophie', 'Fisher'),
#   1,
#   -18.030667136246944],
#  ('MI', 'Myocardial', 'infarction'): [('MI', 'Myocardial', 'infarction'),
#   1,
#   -18.030667136246944],
#  ('MRI', 'Magnetic', 'resonance'): [('MRI', 'Magnetic', 'resonance'),
#   1,
#   -18.030667136246944],
#  ('MSN', 'Encarta', 'Archived'): [('MSN', 'Encarta', 'Archived'),
#   1,
#   -18.030667136246944],
#  ('Magnetic', 'resonance', 'imaging'): [('Magnetic', 'resonance', 'imaging'),
#   1,
#   -18.030667136246944],
#  ('Manual', 'DSM', 'DSM-5'): [('Manual', 'DSM', 'DSM-5'),
#   1,
#   -18.030667136246944],
#  ('Maria', 'Canals', 'Barrera'): [('Maria', 'Canals', 'Barrera'),
#   1,
#   -18.030667136246944],
#  ('Michelle',
#   'Trachtenberg',
#   'Shanica'): [('Michelle',
#    'Trachtenberg',
#    'Shanica'), 1, -18.030667136246944],
#  ('Mickey', 'Rourke', 'Bruce'): [('Mickey', 'Rourke', 'Bruce'),
#   1,
#   -18.030667136246944],
#  ('Moo', 'Farm', 'Frappe'): [('Moo', 'Farm', 'Frappe'),
#   1,
#   -18.030667136246944],
#  ('Moti', 'Masjid', 'Shish'): [('Moti', 'Masjid', 'Shish'),
#   1,
#   -18.030667136246944],
#  ('Owen', 'Mickey', 'Rourke'): [('Owen', 'Mickey', 'Rourke'),
#   1,
#   -18.030667136246944],
#  ('Owen', 'Nolan', '1,727'): [('Owen', 'Nolan', '1,727'),
#   1,
#   -18.030667136246944],
#  ('PR', 'Per', 'rectum'): [('PR', 'Per', 'rectum'), 1, -18.030667136246944],
#  ('Pavilion',
#   '2011–2012)Sleep',
#   'Train'): [('Pavilion', '2011–2012)Sleep', 'Train'), 1, -18.030667136246944],
#  ('Peach', 'Toad', 'Yoshi'): [('Peach', 'Toad', 'Yoshi'),
#   1,
#   -18.030667136246944],
#  ('Peggy', 'DuPree', 'Anna'): [('Peggy', 'DuPree', 'Anna'),
#   1,
#   -18.030667136246944],
#  ('Peru', 'Thor', 'Heyerdahl'): [('Peru', 'Thor', 'Heyerdahl'),
#   1,
#   -18.030667136246944],
#  ('Point', 'coordinates', '33.626057'): [('Point', 'coordinates', '33.626057'),
#   1,
#   -18.030667136246944],
#  ('Princess', 'Peach', 'Toad'): [('Princess', 'Peach', 'Toad'),
#   1,
#   -18.030667136246944],
#  ('Prithvi', 'Raj', 'Chauhan'): [('Prithvi', 'Raj', 'Chauhan'),
#   1,
#   -18.030667136246944],
#  ('Propeller',
#   'airliners',
#   'occasionally'): [('Propeller',
#    'airliners',
#    'occasionally'), 1, -18.030667136246944],
#  ('QUE/COL', '1363', '1629'): [('QUE/COL', '1363', '1629'),
#   1,
#   -18.030667136246944],
#  ("Qu'ran", "Bahá'í", 'scripture'): [("Qu'ran", "Bahá'í", 'scripture'),
#   1,
#   -18.030667136246944],
#  ('Rajneesh', "Pitka's", 'assistant'): [('Rajneesh', "Pitka's", 'assistant'),
#   1,
#   -18.030667136246944],
#  ('Recruit', 'Depot', 'Parris'): [('Recruit', 'Depot', 'Parris'),
#   1,
#   -18.030667136246944],
#  ('Riverfront',
#   'ColiseumThe',
#   'Crown'): [('Riverfront', 'ColiseumThe', 'Crown'), 1, -18.030667136246944],
#  ('Sacrilege', 'involves', 'doing'): [('Sacrilege', 'involves', 'doing'),
#   1,
#   -18.030667136246944],
#  ('Saskatchewan',
#   'Copps',
#   'ColiseumFirstOntario'): [('Saskatchewan',
#    'Copps',
#    'ColiseumFirstOntario'), 1, -18.030667136246944],
#  ('Saskatoon',
#   'Saskatchewan',
#   'Copps'): [('Saskatoon', 'Saskatchewan', 'Copps'), 1, -18.030667136246944],
#  ('Sherbet', 'Land', 'Yoshi'): [('Sherbet', 'Land', 'Yoshi'),
#   1,
#   -18.030667136246944],
#  ('Side', 'Holly', 'Pulchik'): [('Side', 'Holly', 'Pulchik'),
#   1,
#   -18.030667136246944],
#  ('Song', 'Gale', 'Sayers'): [('Song', 'Gale', 'Sayers'),
#   1,
#   -18.030667136246944],
#  ('Soul', 'Food', 'Lem'): [('Soul', 'Food', 'Lem'), 1, -18.030667136246944],
#  ('Spectrum', '1967–1996', '17,380'): [('Spectrum', '1967–1996', '17,380'),
#   1,
#   -18.030667136246944],
#  ('Stream', 'Morocco', 'Canary'): [('Stream', 'Morocco', 'Canary'),
#   1,
#   -18.030667136246944],
#  ('Suidae', 'pigs', 'hogs'): [('Suidae', 'pigs', 'hogs'),
#   1,
#   -18.030667136246944],
#  ('Tagle', 'Ella', 'Maria'): [('Tagle', 'Ella', 'Maria'),
#   1,
#   -18.030667136246944],
#  ('Thunderdome',
#   '1993–1996',
#   '28,153'): [('Thunderdome', '1993–1996', '28,153'), 1, -18.030667136246944],
#  ('Toro', 'Clive', 'Owen'): [('Toro', 'Clive', 'Owen'),
#   1,
#   -18.030667136246944],
#  ('Toyland', 'Lisa', 'Piper'): [('Toyland', 'Lisa', 'Piper'),
#   1,
#   -18.030667136246944],
#  ('Turki', 'Shahi', 'rulars'): [('Turki', 'Shahi', 'rulars'),
#   1,
#   -18.030667136246944],
#  ('Tylenol', 'ASA', 'Aspirin'): [('Tylenol', 'ASA', 'Aspirin'),
#   1,
#   -18.030667136246944],
#  ('UN', 'source', '300.000'): [('UN', 'source', '300.000'),
#   1,
#   -18.030667136246944],
#  ('V-tach',
#   'Ventricular',
#   'tachycardia'): [('V-tach',
#    'Ventricular',
#    'tachycardia'), 1, -18.030667136246944],
#  ('Wernher', 'Magnus', 'Maximilian'): [('Wernher', 'Magnus', 'Maximilian'),
#   1,
#   -18.030667136246944],
#  ('Wishful', 'Thinking', 'Lena'): [('Wishful', 'Thinking', 'Lena'),
#   1,
#   -18.030667136246944],
#  ('Within', 'Normal', 'Limits'): [('Within', 'Normal', 'Limits'),
#   1,
#   -18.030667136246944],
#  ('archaic', 'even-toed', 'ungulates'): [('archaic', 'even-toed', 'ungulates'),
#   1,
#   -18.030667136246944],
#  ('artery', 'bypass', 'graft'): [('artery', 'bypass', 'graft'),
#   1,
#   -18.030667136246944],
#  ('breathe', 'CVA', 'Cerebrovascular'): [('breathe', 'CVA', 'Cerebrovascular'),
#   1,
#   -18.030667136246944],
#  ('breathing', 'TIA', 'Transient'): [('breathing', 'TIA', 'Transient'),
#   1,
#   -18.030667136246944],
#  ('cabbage', 'CBC', 'Complete'): [('cabbage', 'CBC', 'Complete'),
#   1,
#   -18.030667136246944],
#  ('chills',
#   'Paresthesias',
#   'numbness'): [('chills',
#    'Paresthesias',
#    'numbness'), 1, -18.030667136246944],
#  ('competitors', 'GQ', 'Esquire'): [('competitors', 'GQ', 'Esquire'),
#   1,
#   -18.030667136246944],
#  ('desktop-independent',
#   'graphical',
#   'login'): [('desktop-independent',
#    'graphical',
#    'login'), 1, -18.030667136246944],
#  ('diff', 'Clostridium', 'difficile'): [('diff', 'Clostridium', 'difficile'),
#   1,
#   -18.030667136246944],
#  ('ear', 'representing', 'gouty'): [('ear', 'representing', 'gouty'),
#   1,
#   -18.030667136246944],
#  ('enjoy', "God's", 'gifts'): [('enjoy', "God's", 'gifts'),
#   1,
#   -18.030667136246944],
#  ('facts', 'figures', 'photos'): [('facts', 'figures', 'photos'),
#   1,
#   -18.030667136246944],
#  ('gigantic',
#   'conspiracy',
#   'involving'): [('gigantic',
#    'conspiracy',
#    'involving'), 1, -18.030667136246944],
#  ('habitat',
#   'destruction',
#   'overfishing'): [('habitat',
#    'destruction',
#    'overfishing'), 1, -18.030667136246944],
#  ('hip-hop', 'singer', 'Aaliyah'): [('hip-hop', 'singer', 'Aaliyah'),
#   1,
#   -18.030667136246944],
#  ('inan', 'Elimination', 'Chamber'): [('inan', 'Elimination', 'Chamber'),
#   1,
#   -18.030667136246944],
#  ('infarction',
#   'NIDDM',
#   'Non-Insulin'): [('infarction',
#    'NIDDM',
#    'Non-Insulin'), 1, -18.030667136246944],
#  ('ironic', 'twist', 'reminiscent'): [('ironic', 'twist', 'reminiscent'),
#   1,
#   -18.030667136246944],
#  ('large-scale',
#   'civic',
#   'surroundings'): [('large-scale',
#    'civic',
#    'surroundings'), 1, -18.030667136246944],
#  ('malleolus',
#   'Image:Tophigout.JPGGout',
#   'complicated'): [('malleolus',
#    'Image:Tophigout.JPGGout',
#    'complicated'), 1, -18.030667136246944],
#  ('mosaic', 'tile', 'floors'): [('mosaic', 'tile', 'floors'),
#   1,
#   -18.030667136246944],
#  ('mound', 'allow', 'ballparks'): [('mound', 'allow', 'ballparks'),
#   1,
#   -18.030667136246944],
#  ('multimedia',
#   'application',
#   'creator'): [('multimedia',
#    'application',
#    'creator'), 1, -18.030667136246944],
#  ('myocardial', 'infarction', 'NIDDM'): [('myocardial', 'infarction', 'NIDDM'),
#   1,
#   -18.030667136246944],
#  ('nitro', 'OBC', 'Oral'): [('nitro', 'OBC', 'Oral'), 1, -18.030667136246944],
#  ('normally',
#   'EEG',
#   'Electroencephalogram'): [('normally',
#    'EEG',
#    'Electroencephalogram'), 1, -18.030667136246944],
#  ('obtain', 'knowledge', 'existing'): [('obtain', 'knowledge', 'existing'),
#   1,
#   -18.030667136246944],
#  ('openers', '1997–1998', 'Tokyo'): [('openers', '1997–1998', 'Tokyo'),
#   1,
#   -18.030667136246944],
#  ('opinion', 'Professor', 'Hans'): [('opinion', 'Professor', 'Hans'),
#   1,
#   -18.030667136246944],
#  ('performing',
#   'artifacts',
#   'expressing'): [('performing',
#    'artifacts',
#    'expressing'), 1, -18.030667136246944],
#  ('pir', 'Ganj', 'Baksh'): [('pir', 'Ganj', 'Baksh'), 1, -18.030667136246944],
#  ('primetime', 'soap', 'opera'): [('primetime', 'soap', 'opera'),
#   1,
#   -18.030667136246944],
#  ('producer',
#   'cinematographer',
#   'editor'): [('producer',
#    'cinematographer',
#    'editor'), 1, -18.030667136246944],
#  ('provides', 'aerospace', 'warning'): [('provides', 'aerospace', 'warning'),
#   1,
#   -18.030667136246944],
#  ('psychological', 'trauma', 'SI'): [('psychological', 'trauma', 'SI'),
#   1,
#   -18.030667136246944],
#  ('radical', 'feminist', 'writers'): [('radical', 'feminist', 'writers'),
#   1,
#   -18.030667136246944],
#  ('rape', 'alcoholism', 'domestic'): [('rape', 'alcoholism', 'domestic'),
#   1,
#   -18.030667136246944],
#  ('rectum', 'SC', 'SQ'): [('rectum', 'SC', 'SQ'), 1, -18.030667136246944],
#  ('references', 'Leonard', "Cohen's"): [('references', 'Leonard', "Cohen's"),
#   1,
#   -18.030667136246944],
#  ('replacing', 'Clarissa', 'Explains'): [('replacing', 'Clarissa', 'Explains'),
#   1,
#   -18.030667136246944],
#  ('resonance', 'imaging', 'Uses'): [('resonance', 'imaging', 'Uses'),
#   1,
#   -18.030667136246944],
#  ('sats', 'Oxygen', 'saturation'): [('sats', 'Oxygen', 'saturation'),
#   1,
#   -18.030667136246944],
#  ('scan', 'ECG', 'EKG'): [('scan', 'ECG', 'EKG'), 1, -18.030667136246944],
#  ('screenwriter',
#   'producer',
#   'cinematographer'): [('screenwriter',
#    'producer',
#    'cinematographer'), 1, -18.030667136246944],
#  ('sculpting',
#   'photography',
#   'performance'): [('sculpting',
#    'photography',
#    'performance'), 1, -18.030667136246944],
#  ('sculptured', 'clay', 'bowl'): [('sculptured', 'clay', 'bowl'),
#   1,
#   -18.030667136246944],
#  ('stained', 'glass', 'windows'): [('stained', 'glass', 'windows'),
#   1,
#   -18.030667136246944],
#  ('stunts', 'tumbling', 'formation'): [('stunts', 'tumbling', 'formation'),
#   1,
#   -18.030667136246944],
#  ('sv:Lejonhybrid#Liger',
#   'och',
#   'tigon'): [('sv:Lejonhybrid#Liger', 'och', 'tigon'), 1, -18.030667136246944],
# ...
#  ('cultures',
#   'influenced',
#   'Mahayana'): [('cultures', 'influenced', 'Mahayana'),
#   1,
#   -19.030667136246944],
#  ('damage', 'V-fib', 'Ventricular'): [('damage', 'V-fib', 'Ventricular'),
#   1,
#   -19.030667136246944],
#  ('der',
#   'Stolberger',
#   'Messingindustrie'): [('der',
#    'Stolberger',
#    'Messingindustrie'), 1, -19.030667136246944],
#  ('dew', 'nor', 'rain'): [('dew', 'nor', 'rain'), 1, -19.030667136246944],
#  ('earliest',
#   'directorial',
#   'efforts'): [('earliest', 'directorial', 'efforts'), 1, -19.030667136246944],
#  ('edited', 'printed', 'circulated'): [('edited', 'printed', 'circulated'),
#   1,
#   -19.030667136246944],
#  ('failure', 'hemolytic', 'anemia'): [('failure', 'hemolytic', 'anemia'),
#   1,
#   -19.030667136246944],
#  ('feelings',
#   'Derealization',
#   'feelings'): [('feelings',
#    'Derealization',
#    'feelings'), 1, -19.030667136246944],
#  ('flexible', 'well-defined', 'neck'): [('flexible', 'well-defined', 'neck'),
#   1,
#   -19.030667136246944],
#  ('foreign',
#   'coloinal',
#   'imperialistic'): [('foreign',
#    'coloinal',
#    'imperialistic'), 1, -19.030667136246944],
#  ('fund', 'managers', 'Wesley'): [('fund', 'managers', 'Wesley'),
#   1,
#   -19.030667136246944],
#  ('gender(Example', 'VS', 'WNL'): [('gender(Example', 'VS', 'WNL'),
#   1,
#   -19.030667136246944],
#  ('graphical', 'user', 'interface'): [('graphical', 'user', 'interface'),
#   1,
#   -19.030667136246944],
#  ('imitative',
#   'decoration',
#   'applied'): [('imitative', 'decoration', 'applied'), 1, -19.030667136246944],
#  ('introduces',
#   'same-sex',
#   'marriage'): [('introduces', 'same-sex', 'marriage'),
#   1,
#   -19.030667136246944],
#  ('irregularly', 'CA', 'Cancer'): [('irregularly', 'CA', 'Cancer'),
#   1,
#   -19.030667136246944],
#  ('issues', 'route', 'clearances'): [('issues', 'route', 'clearances'),
#   1,
#   -19.030667136246944],
#  ('lake', "sturgeon's", 'dark'): [('lake', "sturgeon's", 'dark'),
#   1,
#   -19.030667136246944],
#  ('lion', 'Panthera', 'leo'): [('lion', 'Panthera', 'leo'),
#   1,
#   -19.030667136246944],
#  ('maintaining', 'full', 'communion'): [('maintaining', 'full', 'communion'),
#   1,
#   -19.030667136246944],
#  ('managers', 'Wesley', 'Edens'): [('managers', 'Wesley', 'Edens'),
#   1,
#   -19.030667136246944],
#  ('markings',
#   'numbers',
#   'centerlines'): [('markings',
#    'numbers',
#    'centerlines'), 1, -19.030667136246944],
#  ('meat', 'eggs', 'caviar'): [('meat', 'eggs', 'caviar'),
#   1,
#   -19.030667136246944],
#  ('oh-too', 'O2', 'sats'): [('oh-too', 'O2', 'sats'), 1, -19.030667136246944],
#  ('patellar', 'ankle', 'hip'): [('patellar', 'ankle', 'hip'),
#   1,
#   -19.030667136246944],
#  ('pelagic', 'oceanic', 'feeders'): [('pelagic', 'oceanic', 'feeders'),
#   1,
#   -19.030667136246944],
#  ('printed',
#   'circulated',
#   'reprinted'): [('printed',
#    'circulated',
#    'reprinted'), 1, -19.030667136246944],
#  ('purpose', 'SOB', 'Shortness'): [('purpose', 'SOB', 'Shortness'),
#   1,
#   -19.030667136246944],
#  ('rambunctious',
#   'toy-abusing',
#   'youngest'): [('rambunctious',
#    'toy-abusing',
#    'youngest'), 1, -19.030667136246944],
#  ('recently', 'trained', 'nurses'): [('recently', 'trained', 'nurses'),
#   1,
#   -19.030667136246944],
#  ('shopping', 'malls', 'markets'): [('shopping', 'malls', 'markets'),
#   1,
#   -19.030667136246944],
#  ('soft', 'tissue', 'swelling'): [('soft', 'tissue', 'swelling'),
#   1,
#   -19.030667136246944],
#  ('solar', 'wind', 'samples'): [('solar', 'wind', 'samples'),
#   1,
#   -19.030667136246944],
#  ('spy', 'ring', 'OZNA'): [('spy', 'ring', 'OZNA'), 1, -19.030667136246944],
#  ('teens', 'aged', '12–19'): [('teens', 'aged', '12–19'),
#   1,
#   -19.030667136246944],
#  ('thrombosis', 'Blood', 'clotting'): [('thrombosis', 'Blood', 'clotting'),
#   1,
#   -19.030667136246944],
#  ('tomography', 'scan', 'Uses'): [('tomography', 'scan', 'Uses'),
#   1,
#   -19.030667136246944],
#  ('toy', 'aliens', 'Jeff'): [('toy', 'aliens', 'Jeff'),
#   1,
#   -19.030667136246944],
#  ('toy-abusing',
#   'youngest',
#   'toddlers'): [('toy-abusing', 'youngest', 'toddlers'),
#   1,
#   -19.030667136246944],
#  ('trouble', 'breathing', 'TIA'): [('trouble', 'breathing', 'TIA'),
#   1,
#   -19.030667136246944],
#  ('viscera', 'Joint', 'troubles'): [('viscera', 'Joint', 'troubles'),
#   1,
#   -19.030667136246944],
#  ('visual', 'performing', 'artifacts'): [('visual', 'performing', 'artifacts'),
#   1,
#   -19.030667136246944],
#  ('zur', 'Stolberger', 'Geschichte'): [('zur', 'Stolberger', 'Geschichte'),
#   1,
#   -19.030667136246944],
#  ('1917–1931', '7,500', '1912'): [('1917–1931', '7,500', '1912'),
#   1,
#   -19.352595231134302],
#  ('1930', 'Haile', 'Selassie'): [('1930', 'Haile', 'Selassie'),
#   1,
#   -19.352595231134302],
#  ('1930', 'Upton', 'Sinclair'): [('1930', 'Upton', 'Sinclair'),
#   1,
#   -19.352595231134302],
#  ('2007—Atlanta',
#   'Thrashers',
#   '43–28–11'): [('2007—Atlanta',
#    'Thrashers',
#    '43–28–11'), 1, -19.352595231134302],
#  ('231', '350', '1352'): [('231', '350', '1352'), 1, -19.352595231134302],
#  ('385-635', 'kg', '850-1400'): [('385-635', 'kg', '850-1400'),
#   1,
#   -19.352595231134302],
#  ('390', '1695', 'Clarence'): [('390', '1695', 'Clarence'),
#   1,
#   -19.352595231134302],
#  ('394', '1859', 'Clarence'): [('394', '1859', 'Clarence'),
#   1,
#   -19.352595231134302],
#  ('50,096', 'U.S', 'Cellular'): [('50,096', 'U.S', 'Cellular'),
#   1,
#   -19.352595231134302],
#  ('Adam', 'Joshua', 'Jastro'): [('Adam', 'Joshua', 'Jastro'),
#   1,
#   -19.352595231134302],
#  ('Asperger', 'syndrome', 'GAD'): [('Asperger', 'syndrome', 'GAD'),
#   1,
#   -19.352595231134302],
#  ('Batman', 'Forever', 'Sugar'): [('Batman', 'Forever', 'Sugar'),
#   1,
#   -19.352595231134302],
#  ('Britannica',
#   'Corporate',
#   '“Company'): [('Britannica',
#    'Corporate',
#    '“Company'), 1, -19.352595231134302],
#  ('Caledonia', 'Palau', 'Solomon'): [('Caledonia', 'Palau', 'Solomon'),
#   1,
#   -19.352595231134302],
#  ('Cars', 'Toons', "Mater's"): [('Cars', 'Toons', "Mater's"),
#   1,
#   -19.352595231134302],
#  ('Charlene', 'Charlie', 'McGee'): [('Charlene', 'Charlie', 'McGee'),
#   1,
#   -19.352595231134302],
#  ('Cheerleading',
#   'choreographer',
#   'Tony'): [('Cheerleading', 'choreographer', 'Tony'), 1, -19.352595231134302],
#  ('D.C', '41,888', 'O.co'): [('D.C', '41,888', 'O.co'),
#   1,
#   -19.352595231134302],
#  ("Disney's", 'Herbie', 'Fully'): [("Disney's", 'Herbie', 'Fully'),
#   1,
#   -19.352595231134302],
#  ('Firestarter',
#   'Charlene',
#   'Charlie'): [('Firestarter', 'Charlene', 'Charlie'), 1, -19.352595231134302],
#  ('Forbes', "magazine's", 'annual'): [('Forbes', "magazine's", 'annual'),
#   1,
#   -19.352595231134302],
#  ('Full', 'Mitch', 'Impostor'): [('Full', 'Mitch', 'Impostor'),
#   1,
#   -19.352595231134302],
#  ('HFD', '1767', '1850'): [('HFD', '1767', '1850'), 1, -19.352595231134302],
#  ('HIV', 'Human', 'immunodeficiency'): [('HIV', 'Human', 'immunodeficiency'),
#   1,
#   -19.352595231134302],
#  ('HPV', 'Human', 'papillomavirus'): [('HPV', 'Human', 'papillomavirus'),
#   1,
#   -19.352595231134302],
#  ('IDDM',
#   'Insulin-Dependent',
#   'Diabetes'): [('IDDM',
#    'Insulin-Dependent',
#    'Diabetes'), 1, -19.352595231134302],
#  ('Interior', 'Minister', 'Roni'): [('Interior', 'Minister', 'Roni'),
#   1,
#   -19.352595231134302],
#  ('Jets(Atlanta',
#   'Thrashers',
#   'Philips'): [('Jets(Atlanta',
#    'Thrashers',
#    'Philips'), 1, -19.352595231134302],
#  ('Jr', 'Arthur', 'Howie'): [('Jr', 'Arthur', 'Howie'),
#   1,
#   -19.352595231134302],
#  ('Junichiro',
#   'Tanizaki',
#   'Technology'): [('Junichiro', 'Tanizaki', 'Technology'),
#   1,
#   -19.352595231134302],
#  ('Liger', 'Exists', 'hu:Panthera'): [('Liger', 'Exists', 'hu:Panthera'),
#   1,
#   -19.352595231134302],
#  ('McSwegan', 'Managers', 'Name'): [('McSwegan', 'Managers', 'Name'),
#   1,
#   -19.352595231134302],
#  ('Michal', "Ishbosheth's", 'sister'): [('Michal', "Ishbosheth's", 'sister'),
#   1,
#   -19.352595231134302],
#  ('Minister', 'Roni', 'Bar-On'): [('Minister', 'Roni', 'Bar-On'),
#   1,
#   -19.352595231134302],
#  ('Mountbatten’s',
#   'private',
#   'secretary'): [('Mountbatten’s',
#    'private',
#    'secretary'), 1, -19.352595231134302],
#  ('Non-Insulin',
#   'Dependent',
#   'Diabetes'): [('Non-Insulin',
#    'Dependent',
#    'Diabetes'), 1, -19.352595231134302],
#  ('Outstanding', 'Contribution', 'To'): [('Outstanding', 'Contribution', 'To'),
#   1,
#   -19.352595231134302],
#  ('Palace', '1991–1993', '11,089'): [('Palace', '1991–1993', '11,089'),
#   1,
#   -19.352595231134302],
#  ('RR', 'Respiratory', 'rate'): [('RR', 'Respiratory', 'rate'),
#   1,
#   -19.352595231134302],
#  ('Rulin', 'Taira', 'Stevens'): [('Rulin', 'Taira', 'Stevens'),
#   1,
#   -19.352595231134302],
#  ('Songkan', 'Laos', 'local'): [('Songkan', 'Laos', 'local'),
#   1,
#   -19.352595231134302],
#  ('Stadtbücherei', 'Stolberg', 'Rhld'): [('Stadtbücherei', 'Stolberg', 'Rhld'),
#   1,
#   -19.352595231134302],
#  ('Stevens', '2785', 'Willi'): [('Stevens', '2785', 'Willi'),
#   1,
#   -19.352595231134302],
#  ('Stroke', 'DM', 'Diabetes'): [('Stroke', 'DM', 'Diabetes'),
#   1,
#   -19.352595231134302],
#  ('Technology', 'Terre', 'Haute'): [('Technology', 'Terre', 'Haute'),
#   1,
#   -19.352595231134302],
#  ('UTI', 'Urinary', 'tract'): [('UTI', 'Urinary', 'tract'),
#   1,
#   -19.352595231134302],
#  ('Wirsitz', 'today', 'Wyrzysk'): [('Wirsitz', 'today', 'Wyrzysk'),
#   1,
#   -19.352595231134302],
#  ('WrestleMania', 'Royal', 'Rumble'): [('WrestleMania', 'Royal', 'Rumble'),
#   1,
#   -19.352595231134302],
#  ('X-ray', 'Therapy', 'Usually'): [('X-ray', 'Therapy', 'Usually'),
#   1,
#   -19.352595231134302],
#  ('Yngwie', 'J', 'Malmsteen'): [('Yngwie', 'J', 'Malmsteen'),
#   1,
#   -19.352595231134302],
#  ('Ziegler', 'Jr', 'Arthur'): [('Ziegler', 'Jr', 'Arthur'),
#   1,
#   -19.352595231134302],
#  ('cancer',
#   'MRSA',
#   'Methicillin-resistant'): [('cancer',
#    'MRSA',
#    'Methicillin-resistant'), 1, -19.352595231134302],
#  ('certain',
#   'humanitarian',
#   'circumstances'): [('certain',
#    'humanitarian',
#    'circumstances'), 1, -19.352595231134302],
#  ('depersonalization',
#   'feeling',
#   'detached'): [('depersonalization',
#    'feeling',
#    'detached'), 1, -19.352595231134302],
#  ('diabetes', 'OD', 'Overdose'): [('diabetes', 'OD', 'Overdose'),
#   1,
#   -19.352595231134302],
#  ('dissolute', 'habits', 'none'): [('dissolute', 'habits', 'none'),
#   1,
#   -19.352595231134302],
#  ('extrasensory',
#   'perception',
#   'mental'): [('extrasensory',
#    'perception',
#    'mental'), 1, -19.352595231134302],
#  ('graphein', 'γραφειν', 'write'): [('graphein', 'γραφειν', 'write'),
#   1,
#   -19.352595231134302],
#  ('homeland', 'our', 'intellect'): [('homeland', 'our', 'intellect'),
#   1,
#   -19.352595231134302],
#  ('leg', 'HTN', 'Hypertension'): [('leg', 'HTN', 'Hypertension'),
#   1,
#   -19.352595231134302],
#  ('outsell', 'leading', 'competitors'): [('outsell', 'leading', 'competitors'),
#   1,
#   -19.352595231134302],
#  ('paranormal', 'claims', 'concluded'): [('paranormal', 'claims', 'concluded'),
#   1,
#   -19.352595231134302],
#  ('pressure',
#   'IDDM',
#   'Insulin-Dependent'): [('pressure',
#    'IDDM',
#    'Insulin-Dependent'), 1, -19.352595231134302],
#  ('rate', 'Sweating', 'Trembling'): [('rate', 'Sweating', 'Trembling'),
#   1,
#   -19.352595231134302],
#  ('reactor', 'explosion', 'occurs'): [('reactor', 'explosion', 'occurs'),
#   1,
#   -19.352595231134302],
#  ('select', 'screen', 'giving'): [('select', 'screen', 'giving'),
#   1,
#   -19.352595231134302],
#  ('seven', 'full-text', 'searchable'): [('seven', 'full-text', 'searchable'),
#   1,
#   -19.352595231134302],
#  ('surgery',
#   'chemotherapy',
#   'diuretics'): [('surgery',
#    'chemotherapy',
#    'diuretics'), 1, -19.352595231134302],
#  ('syndrome', 'GAD', 'Generalized'): [('syndrome', 'GAD', 'Generalized'),
#   1,
#   -19.352595231134302],
#  ('third', 'questioning', 'session'): [('third', 'questioning', 'session'),
#   1,
#   -19.352595231134302],
#  ('tract', 'GU', 'Genitourinary'): [('tract', 'GU', 'Genitourinary'),
#   1,
#   -19.352595231134302],
#  ('warm', 'Gulf', 'Stream'): [('warm', 'Gulf', 'Stream'),
#   1,
#   -19.352595231134302],
#  ('wrist', 'biceps', 'leg'): [('wrist', 'biceps', 'leg'),
#   1,
#   -19.352595231134302],
#  ('1,457', 'Tim', 'Horton'): [('1,457', 'Tim', 'Horton'),
#   1,
#   -19.615629636968098],
#  ('1089', '1152', '1.06'): [('1089', '1152', '1.06'), 1, -19.615629636968098],
#  ('1321', '1203', '0.91'): [('1321', '1203', '0.91'), 1, -19.615629636968098],
#  ('1337', '1420', '1.06'): [('1337', '1420', '1.06'), 1, -19.615629636968098],
#  ('1431', '1394', '0.97'): [('1431', '1394', '0.97'), 1, -19.615629636968098],
#  ('1924–1938', '17,959', '1924'): [('1924–1938', '17,959', '1924'),
#   1,
#   -19.615629636968098],
#  ('1925–1942', '15,928', '1925'): [('1925–1942', '15,928', '1925'),
#   1,
#   -19.615629636968098],
#  ('1926–1929', '6,000', '1899'): [('1926–1929', '6,000', '1899'),
#   1,
#   -19.615629636968098],
#  ('1926–1968', '15,928', '1925'): [('1926–1968', '15,928', '1925'),
#   1,
#   -19.615629636968098],
#  ('1926–1996', '17,959', '1924'): [('1926–1996', '17,959', '1924'),
#   1,
#   -19.615629636968098],
#  ('1945–2003', 'Honoured', 'Members'): [('1945–2003', 'Honoured', 'Members'),
#   1,
#   -19.615629636968098],
#  ('1954–1955', '1955–1956', 'Omaha'): [('1954–1955', '1955–1956', 'Omaha'),
#   1,
#   -19.615629636968098],
#  ('286', '295', '1371'): [('286', '295', '1371'), 1, -19.615629636968098],
#  ('306', '328', '1474'): [('306', '328', '1474'), 1, -19.615629636968098],
#  ('311', '333', '1089'): [('311', '333', '1089'), 1, -19.615629636968098],
#  ('330', 'Sean', 'Burke'): [('330', 'Sean', 'Burke'), 1, -19.615629636968098],
#  ('485', 'Darryl', 'Sittler'): [('485', 'Darryl', 'Sittler'),
#   1,
#   -19.615629636968098],
#  ('900', 'pound', 'liger'): [('900', 'pound', 'liger'),
#   1,
#   -19.615629636968098],
#  ('Abraham', 'ibn', 'Daud'): [('Abraham', 'ibn', 'Daud'),
#   1,
#   -19.615629636968098],
#  ('Am', 'Renee', 'Sandstrom'): [('Am', 'Renee', 'Sandstrom'),
#   1,
#   -19.615629636968098],
#  ('Astana', 'Boeing', '757-200'): [('Astana', 'Boeing', '757-200'),
#   1,
#   -19.615629636968098],
#  ('Auchter', '“The', 'Evolution'): [('Auchter', '“The', 'Evolution'),
#   1,
#   -19.615629636968098],
#  ('Auditorium', '1923–1934', '10,000'): [('Auditorium', '1923–1934', '10,000'),
#   1,
#   -19.615629636968098],
#  ('BUF', '1191', '1326'): [('BUF', '1191', '1326'), 1, -19.615629636968098],
#  ('Beersheba',
#   'recognized',
#   'realized'): [('Beersheba',
#    'recognized',
#    'realized'), 1, -19.615629636968098],
#  ('Begum', 'Taj', 'Mahal'): [('Begum', 'Taj', 'Mahal'),
#   1,
#   -19.615629636968098],
#  ('Bellows', '485', 'Darryl'): [('Bellows', '485', 'Darryl'),
#   1,
#   -19.615629636968098],
#  ('Berube', '3149', 'Tim'): [('Berube', '3149', 'Tim'),
#   1,
#   -19.615629636968098],
#  ('Boeing', 'Commercial', 'Airplanes'): [('Boeing', 'Commercial', 'Airplanes'),
#   1,
#   -19.615629636968098],
#  ('Bovidae', 'cattle', 'goats'): [('Bovidae', 'cattle', 'goats'),
#   1,
#   -19.615629636968098],
#  ('Brittany', 'Murphy', 'Benicio'): [('Brittany', 'Murphy', 'Benicio'),
#   1,
#   -19.615629636968098],
#  ('Byrne',
#   'ArenaContinental',
#   'Airlines'): [('Byrne',
#    'ArenaContinental',
#    'Airlines'), 1, -19.615629636968098],
#  ('COL', '1251', '1398'): [('COL', '1251', '1398'), 1, -19.615629636968098],
#  ('COL', '1294', '1327'): [('COL', '1294', '1327'), 1, -19.615629636968098],
#  ('COL', '1378', '1205'): [('COL', '1378', '1205'), 1, -19.615629636968098],
#  ("Cat's", 'Eye', 'Our'): [("Cat's", 'Eye', 'Our'), 1, -19.615629636968098],
#  ('Characters', 'Courses', 'Mushroom'): [('Characters', 'Courses', 'Mushroom'),
#   1,
#   -19.615629636968098],
#  ('Chernobyl', 'nuclear', 'plant'): [('Chernobyl', 'nuclear', 'plant'),
#   1,
#   -19.615629636968098],
#  ("Christianity's", 'Holy', 'Week'): [("Christianity's", 'Holy', 'Week'),
#   1,
#   -19.615629636968098],
#  ('Civic', 'CenterDunkin', 'Donuts'): [('Civic', 'CenterDunkin', 'Donuts'),
#   1,
#   -19.615629636968098],
#  ('Class', 'Premium', 'Economy'): [('Class', 'Premium', 'Economy'),
#   1,
#   -19.615629636968098],
#  ('Commons',
#   'Attribution/Share-Alike',
#   'License'): [('Commons',
#    'Attribution/Share-Alike',
#    'License'), 1, -19.615629636968098],
#  ('Cool', '2:53', 'Our'): [('Cool', '2:53', 'Our'), 1, -19.615629636968098],
#  ('Corps', 'Recruit', 'Depot'): [('Corps', 'Recruit', 'Depot'),
#   1,
#   -19.615629636968098],
#  ('Cusack', 'finally', 'returning'): [('Cusack', 'finally', 'returning'),
#   1,
#   -19.615629636968098],
#  ...}

# %%
bigram_df = pd.DataFrame.from_dict(bi_dict, orient='index',
                       columns=['ngram', 'freq', 'poisson'])

trigram_df = pd.DataFrame.from_dict(tri_dict, orient='index',
                       columns=['ngram', 'freq', 'poisson'])

bigram_df
# Out:
#                                              ngram  freq       poisson
# ($5.84, billion)                  ($5.84, billion)     1    -17.030667
# (0050d0, Administrative)  (0050d0, Administrative)     1    -17.030667
# (1,319, Teppo)                      (1,319, Teppo)     1    -17.030667
# (100th, anniversary)          (100th, anniversary)     1    -17.030667
# (1125, 1219)                          (1125, 1219)     1    -17.030667
# ...                                            ...   ...           ...
# (New, York)                            (New, York)   132  -3273.884672
# (from, the)                            (from, the)   114  -3356.503611
# (is, a)                                    (is, a)   150  -4364.314853
# (in, the)                                (in, the)   285  -8634.385922
# (of, the)                                (of, the)   405 -12260.388518
#
# [39305 rows x 3 columns]

# %%
ngram_df = bigram_df.append(trigram_df).sort_values('poisson', ascending=False).reset_index(drop=True)
ngram_df['len'] = ngram_df.ngram.apply(len)
ngram_df
# Out:
#                               ngram  freq       poisson  len
# 0                  ($5.84, billion)     1    -17.030667    2
# 1      (fructose-sweetened, drinks)     1    -17.030667    2
# 2          (gradual, deforestation)     1    -17.030667    2
# 3                 (grabs, Samuel's)     1    -17.030667    2
# 4             (glittery, bracelets)     1    -17.030667    2
# ...                             ...   ...           ...  ...
# 87590                   (New, York)   132  -3273.884672    2
# 87591                   (from, the)   114  -3356.503611    2
# 87592                       (is, a)   150  -4364.314853    2
# 87593                     (in, the)   285  -8634.385922    2
# 87594                     (of, the)   405 -12260.388518    2
#
# [87595 rows x 4 columns]

# %% [markdown]
# We then automatically score the million most strongly associated
# n-grams (i.e., roughly the top 5% of the Poisson-ranked
# list) for compositionality.
#
# Using word2vec (Mikolov et al., 2013) with the parameters
# found to be most effective by Baroni et al. (2014), we
# build a word embedding vector for every simplex word in
# the vocabulary (ca. 1M types), as well as for each MWE candidate.
#
# * Continuous bag of words model with 400-dimensional vectors, window size 5, subsampling with t = 10^-5, negative sampling with 10 samples. We build vectors only for tokens observed 20 times or more in the corpus.
#
# We then compute the cosine similarity of the vector
# representation for a MWE candidate with the vectors of its
# constituent words, and take the arithmetic mean.
# In scoring
# the compositionality of a candidate, we do not measure the
# cosine similarity of the MWE with any stop words it may
# contain, as stop words may be assumed to be semantically
# uninformative.
# * Stop words are taken here to be the 50 most frequent words in the vocabulary.

# %%
# Stopwords from corpus - 50 most frequent
from nltk import FreqDist

fdist = FreqDist(word_gen(simp, sent_mark=''))

stop = set( word for word, f in fdist.most_common(20))

# %%
stop
# Out:
# {'April',
#  'August',
#  'New',
#  'The',
#  'a',
#  'and',
#  'are',
#  'as',
#  'by',
#  'for',
#  'from',
#  'in',
#  'is',
#  'of',
#  'on',
#  'that',
#  'the',
#  'to',
#  'was',
#  'with'}

# %%
from batcher import batcher  # Custom module with logic for assigning n-grams to batches, avoiding overlap

# %%
min_freq = 10

# %%
# Duplicate entries appearing for some reason. Removing here
ngram_df2 = ngram_df[ngram_df.freq >= min_freq].drop_duplicates().reset_index(drop=True)

ngram_df2
# Out:
#                  ngram  freq       poisson  len
# 0        (Jari, Kurri)    10   -203.525952    2
# 1               (W, L)    10   -209.941413    2
# 2               (L, T)    10   -211.010565    2
# 3    (Martin, Brodeur)    10   -214.900988    2
# 4              (GP, W)    10   -214.966416    2
# ..                 ...   ...           ...  ...
# 428        (New, York)   132  -3273.884672    2
# 429        (from, the)   114  -3356.503611    2
# 430            (is, a)   150  -4364.314853    2
# 431          (in, the)   285  -8634.385922    2
# 432          (of, the)   405 -12260.388518    2
#
# [433 rows x 4 columns]

# %%
eval_count = 150000

ngram_eval = ngram_df2[0:eval_count]

ngram_eval
# Out:
#                  ngram  freq       poisson  len
# 0        (Jari, Kurri)    10   -203.525952    2
# 1               (W, L)    10   -209.941413    2
# 2               (L, T)    10   -211.010565    2
# 3    (Martin, Brodeur)    10   -214.900988    2
# 4              (GP, W)    10   -214.966416    2
# ..                 ...   ...           ...  ...
# 428        (New, York)   132  -3273.884672    2
# 429        (from, the)   114  -3356.503611    2
# 430            (is, a)   150  -4364.314853    2
# 431          (in, the)   285  -8634.385922    2
# 432          (of, the)   405 -12260.388518    2
#
# [433 rows x 4 columns]

# %%
# Clean up
del ngram_df, ngram_df2

# %%
batches, batch_count = batcher(ngram_eval.ngram, stopwords=stop, max_batches = 15)

batches
# Out:
# {('Jari', 'Kurri'): 1,
#  ('W', 'L'): 1,
#  ('Martin', 'Brodeur'): 1,
#  ('Chris', 'Chelios'): 1,
#  ('Mexican', 'Americans'): 1,
#  ('1992–93', '1992–1993'): 1,
#  ('Additional', 'voice'): 1,
#  ('Mike', 'Bossy'): 1,
#  ('Mike', 'Modano'): 1,
#  ('acid', 'levels'): 1,
#  ('Minnesota', 'Wild'): 1,
#  ('Hammerhead', 'sharks'): 1,
#  ('von', 'Braun'): 1,
#  ('Toronto', 'Ontario'): 1,
#  ('Camp', 'Rock'): 1,
#  ('Mughal', 'Empire'): 1,
#  ('Smythe', 'Division'): 1,
#  ('Southeast', 'Division'): 1,
#  ('Brendan', 'Shanahan'): 1,
#  ('King', 'Saul'): 1,
#  ('109', 'pts'): 1,
#  ('television', 'series'): 1,
#  ('North', 'America'): 1,
#  ('Angeles', 'California'): 1,
#  ('n/a', 'n/a'): 1,
#  ('years', 'immediately'): 1,
#  ('American', 'Bash'): 1,
#  ('Mark', 'Thomas'): 1,
#  ('Joe', 'Sakic'): 1,
#  ('August', '27'): 1,
#  ('April', '25'): 1,
#  ('he', 'would'): 1,
#  ('winners', 'produced'): 1,
#  ('a', 'fictional'): 1,
#  ('able', 'to'): 1,
#  ('July', '2006'): 1,
#  ('Packers', 'Quarterback'): 1,
#  ('Gretzky', 'Edmonton'): 1,
#  ('who', 'have'): 1,
#  ('was', 'born'): 1,
#  ('must', 'be'): 1,
#  ('September', '2006'): 1,
#  ('previous', 'year'): 1,
#  ('August', '1'): 1,
#  ('Memorial', 'Trophy'): 1,
#  ('member', 'of'): 1,
#  ('Winter', 'Classic'): 1,
#  ('with', 'him'): 1,
#  ('that', 'time'): 1,
#  ('known', 'for'): 1,
#  ('with', 'their'): 1,
#  ('Louis', 'Rams'): 1,
#  ('the', 'Netherlands'): 1,
#  ('based', 'on'): 1,
#  ('Northeast', 'Division'): 1,
#  ('References', 'Other'): 1,
#  ('is', 'called'): 1,
#  ('2007', '15'): 1,
#  ('49ers', 'Quarterback'): 1,
#  ('Northwest', 'Division'): 1,
#  ('York', 'Giants'): 1,
#  ('Jessica', 'Alba'): 1,
#  ('games', 'in'): 1,
#  ('Central', 'Division'): 1,
#  ('Carolina', 'Hurricanes'): 1,
#  ('they', 'were'): 1,
#  ('want', 'to'): 1,
#  ('a', 'list'): 1,
#  ('August', '15'): 1,
#  ('did', 'not'): 1,
#  ('The', 'tiger'): 1,
#  ('Walt', 'Disney'): 1,
#  ('April', '1'): 1,
#  ('end', 'of'): 1,
#  ('with', 'her'): 1,
#  ('the', 'movie'): 1,
#  ('There', 'are'): 1,
#  ('Night', 'Shift'): 1,
#  ('April', '21'): 1,
#  ('used', 'to'): 1,
#  ('Atlantic', 'Division'): 1,
#  ('the', 'second'): 1,
#  ('Various', 'home'): 1,
#  ('Cleveland', 'Browns'): 1,
#  ('United', 'Kingdom'): 1,
#  ('The', 'Great'): 1,
#  ('Baltimore', 'Colts'): 1,
#  ('the', 'blood'): 1,
#  ('Quebec', 'Nordiques'): 1,
#  ('2005', '14'): 1,
#  ('a', 'group'): 1,
#  ('and', 'other'): 1,
#  ('Mark', 'Messier'): 1,
#  ('York', 'New'): 1,
#  ('as', 'well'): 1,
#  ('will', 'be'): 1,
#  ('Day', 'of'): 1,
#  ('Championship', 'SummerSlam'): 1,
#  ('The', 'movie'): 1,
#  ('the', 'Lord'): 1,
#  ('Anaheim', 'Ducks'): 1,
#  ('he', 'had'): 1,
#  ('as', 'an'): 1,
#  ('San', 'Diego'): 1,
#  ('17', '2010'): 1,
#  ('more', 'than'): 1,
#  ('the', 'National'): 1,
#  ('Lodge', 'Studio'): 1,
#  ('Pacific', 'Division'): 1,
#  ('Florida', 'Panthers'): 1,
#  ('the', 'world'): 1,
#  ('Stanley', 'Cup'): 1,
#  ('Winnipeg', 'Jets'): 1,
#  ('move', 'to'): 1,
#  ('the', 'following'): 1,
#  ('The', 'first'): 1,
#  ('is', 'one'): 1,
#  ('back', 'to'): 1,
#  ('made', 'by'): 1,
#  ('because', 'of'): 1,
#  ('a', 'small'): 1,
#  ('does', 'not'): 1,
#  ('Neutral', 'site'): 1,
#  ('Hall', 'of'): 1,
#  ('type', 'of'): 1,
#  ('and', 'his'): 1,
#  ('the', 'largest'): 1,
#  ('the', 'time'): 1,
#  ('the', 'original'): 1,
#  ('August', '2006'): 1,
#  ('2007', '14'): 1,
#  ('a', 'person'): 1,
#  ('game', 'in'): 1,
#  ('becomes', 'independent'): 1,
#  ('games', 'for'): 1,
#  ('Related', 'pages'): 1,
#  ('Bay', 'Lightning'): 1,
#  ('NY', 'Rangers'): 1,
#  ('is', 'also'): 1,
#  ('April', '30'): 1,
#  ('is', 'found'): 1,
#  ('Chicago', 'Blackhawks'): 1,
#  ('18', '2010'): 1,
#  ('NY', 'Islanders'): 1,
#  ('Jose', 'Sharks'): 1,
#  ('the', 'person'): 1,
#  ('Dallas', 'Stars'): 1,
#  ('Maple', 'Leafs'): 1,
#  ('Ottawa', 'Senators'): 1,
#  ('Louis', 'Blues'): 1,
#  ('has', 'been'): 1,
#  ('son', 'of'): 1,
#  ('Regular', 'season'): 1,
#  ('was', 'released'): 1,
#  ('may', 'be'): 1,
#  ('February', '1999'): 1,
#  ('is', 'not'): 1,
#  ('Angeles', 'Kings'): 1,
#  ('the', 'year'): 1,
#  ('They', 'are'): 1,
#  ('York', 'Rangers'): 1,
#  ('Buffalo', 'Sabres'): 1,
#  ('Detroit', 'Red'): 1,
#  ('Youth', 'in'): 1,
#  ('same', 'day'): 1,
#  ('Pittsburgh', 'Penguins'): 1,
#  ('Colorado', 'Avalanche'): 1,
#  ('up', 'to'): 1,
#  ('San', 'Francisco'): 1,
#  ('State', 'University'): 1,
#  ('Artist', 'Awards'): 1,
#  ('the', 'other'): 1,
#  ('come', 'from'): 1,
#  ('and', 'a', 'time'): 1,
#  ('Montreal', 'Canadiens'): 1,
#  ('number', 'of'): 1,
#  ('Changes', 'from'): 1,
#  ('Vancouver', 'Canucks'): 1,
#  ('the', 'week'): 1,
#  ('Film', 'Awards'): 1,
#  ('the', 'body'): 1,
#  ('Calgary', 'Flames'): 1,
#  ('Washington', 'Capitals'): 1,
#  ('Jersey', 'Devils'): 1,
#  ('June', '2006'): 1,
#  ('Boston', 'Bruins'): 1,
#  ('they', 'are'): 1,
#  ('the', 'most'): 1,
#  ('Philadelphia', 'Flyers'): 1,
#  ('part', 'of'): 1,
#  ('can', 'be'): 1,
#  ('York', 'Islanders'): 1,
#  ('due', 'to'): 1,
#  ('is', 'an'): 1,
#  ('inducted', 'in'): 1,
#  ('0', '0', '0'): 1,
#  ('United', 'States'): 1,
#  ('the', 'first'): 1,
#  ('are', 'a'): -2,
#  ('is', 'in'): -2,
#  ('in', 'April'): -2,
#  ('on', 'April'): -2,
#  ('on', 'a'): -2,
#  ('and', 'was'): -2,
#  ('are', 'the'): -2,
#  ('by', 'a'): -2,
#  ('and', 'is'): -2,
#  ('to', 'a'): -2,
#  ('for', 'a'): -2,
#  ('and', 'in'): -2,
#  ('that', 'the'): -2,
#  ('was', 'a'): -2,
#  ('and', 'a'): -2,
#  ('with', 'a'): -2,
#  ('of', 'a'): -2,
#  ('as', 'a'): -2,
#  ('was', 'the'): -2,
#  ('with', 'the'): -2,
#  ('as', 'the'): -2,
#  ('by', 'the'): -2,
#  ('in', 'a'): -2,
#  ('is', 'the'): -2,
#  ('for', 'the'): -2,
#  ('and', 'the'): -2,
#  ('on', 'the'): -2,
#  ('to', 'the'): -2,
#  ('from', 'the'): -2,
#  ('is', 'a'): -2,
#  ('in', 'the'): -2,
#  ('of', 'the'): -2,
#  ('L', 'T'): 2,
#  ('GP', 'W'): 2,
#  ('when', 'he'): 2,
#  ('uric', 'acid', 'levels'): 2,
#  ('of', 'these'): 2,
#  ('Genesis', 'a'): 2,
#  ('in', 'North'): 2,
#  ('be', 'used'): 2,
#  ('Great', 'American'): 2,
#  ('leap', 'years'): 2,
#  ('has', 'a'): 2,
#  ('in', 'one'): 2,
#  ('have', 'a'): 2,
#  ('in', 'this'): 2,
#  ('as', 'Additional', 'voice'): 2,
#  ('along', 'with'): 2,
#  ('and', 'they'): 2,
#  ('in', 'his'): 2,
#  ('who', 'was'): 2,
#  ('Los', 'Angeles', 'California'): 2,
#  ('in', '1992–93', '1992–1993'): 2,
#  ('of', 'Israel'): 2,
#  ('Wayne', 'Gretzky', 'Edmonton'): 2,
#  ('or', 'the'): 2,
#  ('had', 'a'): 2,
#  ('to', 'kill'): 2,
#  ('Division', 'is'): 2,
#  ('of', 'Saul'): 2,
#  ('between', 'the'): 2,
#  ('of', 'its'): 2,
#  ('Bay', 'Packers', 'Quarterback'): 2,
#  ('August', '2007'): 2,
#  ('common', 'years'): 2,
#  ('Francisco', '49ers', 'Quarterback'): 2,
#  ('References', 'Other', 'websites'): 2,
#  ('St', 'Louis', 'Rams'): 2,
#  ('14', 'July'): 2,
#  ('The', 'tiger', 'shark'): 2,
#  ('called', 'the'): 2,
#  ('at', 'a'): 2,
#  ('of', 'people'): 2,
#  ('June', '2007', '15'): 2,
#  ('but', 'the'): 2,
#  ('under', 'the'): 2,
#  ('of', 'King'): 2,
#  ('June', '17'): 2,
#  ('New', 'York', 'Giants'): 2,
#  ('of', 'Fame'): 2,
#  ('over', 'the'): 2,
#  ('said', 'that'): 2,
#  ('also', 'known'): 2,
#  ('He', 'was'): 2,
#  ('after', 'the'): 2,
#  ('Division', 'NHL'): 2,
#  ('Various', 'home', 'games'): 2,
#  ('Baltimore', 'Colts', 'Quarterback'): 2,
#  ("Sportsmen's", 'Lodge'): 2,
#  ('He', 'is'): 2,
#  ('Studio', 'City'): 2,
#  ('there', 'is'): 2,
#  ('all', 'the'): 2,
#  ('move', 'to', 'the'): 2,
#  ('an', 'American'): 2,
#  ('of', 'this'): 2,
#  ('of', 'the', 'previous'): 2,
#  ('it', 'was'): 2,
#  ('and', 'he'): 2,
#  ('of', 'the', 'following'): 2,
#  ('2010', 'July'): 2,
#  ('June', '18'): 2,
#  ('Tampa', 'Bay', 'Lightning'): 2,
#  ('This', 'is'): 2,
#  ('which', 'is'): 2,
#  ('of', 'art'): 2,
#  ('to', 'make'): 2,
#  ('St', 'Louis', 'Blues'): 2,
#  ('Toronto', 'Maple'): 2,
#  ('of', 'gout'): 2,
#  ('San', 'Jose', 'Sharks'): 2,
#  ('New', 'York', 'Rangers'): 2,
#  ('in', 'Film'): 2,
#  ('are', 'not'): 2,
#  ('Los', 'Angeles', 'Kings'): 2,
#  ('New', 'Jersey', 'Devils'): 2,
#  ('Independence', 'Day'): 2,
#  ('into', 'the'): 2,
#  ('Detroit', 'Red', 'Wings'): 2,
#  ('of', 'his'): 2,
#  ('during', 'the'): 2,
#  ('Young', 'Artist', 'Awards'): 2,
#  ('In', 'the'): 2,
#  ('come', 'from', 'the'): 2,
#  ('of', 'the', 'week'): 2,
#  ('have', 'been'): 2,
#  ('Changes', 'from', 'the'): 2,
#  ('in', 'the', 'United'): 2,
#  ('on', 'the', 'same'): 2,
#  ('It', 'was'): 2,
#  ('Running', 'back'): 2,
#  ('it', 'is'): 2,
#  ('New', 'York', 'Islanders'): 2,
#  ('It', 'is'): 2,
#  ('0', '0'): 2,
#  ('at', 'the'): 2,
#  ('W', 'L', 'T'): 3,
#  ('Great', 'American', 'Bash'): 3,
#  ('of', 'uric'): 3,
#  ('Gretzky', 'Edmonton', 'Oilers'): 3,
#  ('the', 'end'): 3,
#  ('people', 'who'): 3,
#  ('the', 'United', 'Kingdom'): 3,
#  ('year', 'and'): 3,
#  ('in', '1992–93'): 3,
#  ('tiger', 'shark', 'is'): 3,
#  ('the', 'previous'): 3,
#  ('2007', '15', 'June'): 3,
#  ('2010', 'August'): 3,
#  ('Francisco', '49ers'): 3,
#  ('17', '2010', 'June'): 3,
#  ('home', 'games'): 3,
#  ('to', 'have'): 3,
#  ('2005', '14', 'July'): 3,
#  ('York', 'New', 'York'): 3,
#  ("Sportsmen's", 'Lodge', 'Studio'): 3,
#  ('14', 'June'): 3,
#  ('Hall', 'of', 'Fame'): 3,
#  ('Bay', 'Packers'): 3,
#  ('as', 'Additional'): 3,
#  ('Colts', 'Quarterback'): 3,
#  ('18', '2010', 'June'): 3,
#  ('that', 'he'): 3,
#  ('Toronto', 'Maple', 'Leafs'): 3,
#  ('Other', 'websites'): 3,
#  ('Youth', 'in', 'Film'): 3,
#  ('a', 'time'): 3,
#  ('the', 'same', 'day'): 3,
#  ('Young', 'Artist'): 3,
#  ('Red', 'Wings'): 3,
#  ('San', 'Jose'): 3,
#  ('New', 'Jersey'): 3,
#  ('the', 'United', 'States'): 3,
#  ('St', 'Louis'): 3,
#  ('Los', 'Angeles'): 3,
#  ('to', 'be'): 3,
#  ('GP', 'W', 'L'): 4,
#  ('The', 'Great', 'American'): 4,
#  ('15', 'June', '2007'): 4,
#  ('of', 'uric', 'acid'): 4,
#  ('2010', 'June', '17'): 4,
#  ('shark', 'is'): 4,
#  ('the', 'previous', 'year'): 4,
#  ('14', 'July', '2005'): 4,
#  ('New', 'York', 'New'): 4,
#  ('home', 'games', 'for'): 4,
#  ('Lodge', 'Studio', 'City'): 4,
#  ('Green', 'Bay'): 4,
#  ('also', 'known', 'as'): 4,
#  ('14', 'June', '2007'): 4,
#  ('San', 'Francisco', '49ers'): 4,
#  ('2010', 'June', '18'): 4,
#  ('Wayne', 'Gretzky'): 4,
#  ('week', 'as'): 4,
#  ('found', 'in'): 4,
#  ('he', 'was'): 4,
#  ('such', 'as'): 4,
#  ('time', 'to'): 4,
#  ('Tampa', 'Bay'): 4,
#  ('the', 'same'): 4,
#  ('Edmonton', 'Oilers'): 4,
#  ('the', 'United'): 4,
#  ('list', 'of'): 5,
#  ('15', 'June'): 5,
#  ('the', 'end', 'of'): 5,
#  ('is', 'an', 'American'): 5,
#  ('July', '2005', '14'): 5,
#  ('a', 'group', 'of'): 5,
#  ('tiger', 'shark'): 5,
#  ('2007', '14', 'June'): 5,
#  ('is', 'one', 'of'): 5,
#  ('Green', 'Bay', 'Packers'): 5,
#  ('in', 'Film', 'Awards'): 5,
#  ('uric', 'acid'): 5,
#  ('day', 'of'): 5,
#  ('a', 'time', 'to'): 5,
#  ('the', 'week', 'as'): 5,
#  ('known', 'as'): 5,
#  ('2010', 'June'): 5,
#  ('University', 'of'): 5,
#  ('New', 'York'): 5,
#  ('is', 'a', 'list'): 6,
#  ('June', '17', '2010'): 6,
#  ('group', 'of'): 6,
#  ('June', '2007', '14'): 6,
#  ('games', 'for', 'the'): 6,
#  ('June', '18', '2010'): 6,
#  ('same', 'day', 'of'): 6,
#  ('part', 'of', 'the'): 6,
#  ('one', 'of', 'the'): 6,
#  ('July', '2005'): 6,
#  ('a', 'list', 'of'): 7,
#  ('day', 'of', 'the'): 7,
#  ('one', 'of'): 7,
#  ('June', '2007'): 7}

# %%
len(batches)
# Out:
# 433

# %%
# Should be able to add batch information using df.map() but am encountering errors apparently relating
#  to indexing - workaround (though slower).

ngb_cols = ["ngram", "batch"]
rows = []

for ng in ngram_eval['ngram']:
    rows.append({"ngram" : ng,
                "batch" : batches[ng]})
    
ng_batch = pd.DataFrame(rows, columns = ngb_cols)

ng_batch
# Out:
#                  ngram  batch
# 0        (Jari, Kurri)      1
# 1               (W, L)      1
# 2               (L, T)      2
# 3    (Martin, Brodeur)      1
# 4              (GP, W)      2
# ..                 ...    ...
# 428        (New, York)      5
# 429        (from, the)     -2
# 430            (is, a)     -2
# 431          (in, the)     -2
# 432          (of, the)     -2
#
# [433 rows x 2 columns]

# %%
ngram_eval = ngram_eval.merge(ng_batch, on='ngram')

ngram_eval
# Out:
#                  ngram  freq       poisson  len  batch
# 0        (Jari, Kurri)    10   -203.525952    2      1
# 1               (W, L)    10   -209.941413    2      1
# 2               (L, T)    10   -211.010565    2      2
# 3    (Martin, Brodeur)    10   -214.900988    2      1
# 4              (GP, W)    10   -214.966416    2      2
# ..                 ...   ...           ...  ...    ...
# 428        (New, York)   132  -3273.884672    2      5
# 429        (from, the)   114  -3356.503611    2     -2
# 430            (is, a)   150  -4364.314853    2     -2
# 431          (in, the)   285  -8634.385922    2     -2
# 432          (of, the)   405 -12260.388518    2     -2
#
# [433 rows x 5 columns]

# %%
ngram_eval.batch.value_counts()
# Out:
#  1    198
#  2    104
#  3     40
# -2     32
#  4     26
#  5     19
#  6     10
#  7      4
# Name: batch, dtype: int64

# %%
from nltk.tokenize import MWETokenizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Flatten down to a single number
def cosim(x,y):
    return cosine_similarity(x.reshape(1,-1), y.reshape(1,-1))[0][0]

# %%
def mwe_score(exp, model, stats_frame):
    # Combined token for MWE
    mwetoken = '+'.join(exp)

    # Stopwords - 1 if component is a stopword, 0 if present, -1 if simplex word missing from vocab, -2 if MWE missing
    sws = []
    # Component vectors
    cvs = []

    #  Neighbours in original & MWE-aware space
    oldn = []
    newn = []

    # List of individual word similarities (where present in the vocab)
    css = []

    # Empty array
    earr = np.empty(1000)
    earr[:] = np.nan

    # Check that combined token exists in the vocab. This protects against inflation of n-gram counts caused by repeats
    #  of the same token (e.g. in lists like https://simple.wikipedia.org/wiki/List_of_cities,_towns_and_villages_in_Fars_Province)
    if mwetoken in model.dictionary:

        mwv = model.word_vectors[model.dictionary[mwetoken]]

        for w in exp:
            if w in model.dictionary:
                cvs.append(model.word_vectors[model.dictionary[w]])

                oldn.append(model.most_similar(w, number=5))

                if w in stop:
                    sws.append(1)
                    css.append(np.nan)
                else:
                    sws.append(0)
                    css.append(cosim(model.word_vectors[model.dictionary[w]], mwv ))

            # If component is absent from vocab
            else:
                sws.append(-1)
                cvs.append(earr)
                css.append(np.nan)

                oldn.append([])

        #  Mean cosim
        if min(sws) >= 0:
            cs = np.nanmean(css)
        else:
            cs = np.nan

        newn = model.most_similar(mwetoken, number=5)

    # Combined token missing from vocab - mark with defaults
    else:
        sws = [-2]
        mwv = np.empty(400)
        mwv[:] = np.nan


    # Append to stats df
    return stats_frame.append({
        'ngram'  : exp,
        'stopwords' : sws,
        'mwe_vector' : mwv,
        'component_vectors' : cvs,
        'component_cosims'  : css,
        'cosine_sim'  : cs,
        'base_nearest': oldn,
        'mwe_nearest' : newn,
    }, ignore_index=True)

# %%
def mwe_score_par(args, np=np, pd=pd):
    exp, model = args
    
    # Combined token for MWE
    mwetoken = '+'.join(exp)

    # Stopwords - 1 if component is a stopword, 0 if present, -1 if simplex word missing from vocab, -2 if MWE missing
    sws = []
    # Component vectors
    cvs = []

    #  Neighbours in original & MWE-aware space
    oldn = []
    newn = []

    # List of individual word similarities (where present in the vocab)
    css = []

    # Empty array
    earr = np.empty(1000)
    earr[:] = np.nan

    # Check that combined token exists in the vocab. This protects against inflation of n-gram counts caused by repeats
    #  of the same token (e.g. in lists like https://simple.wikipedia.org/wiki/List_of_cities,_towns_and_villages_in_Fars_Province)
    if mwetoken in model.dictionary:

        mwv = model.word_vectors[model.dictionary[mwetoken]]

        for w in exp:
            if w in model.dictionary:
                cvs.append(model.word_vectors[model.dictionary[w]])

                oldn.append(model.most_similar(w, number=5))

                if w in stop:
                    sws.append(1)
                    css.append(np.nan)
                else:
                    sws.append(0)
                    css.append(cosim(model.word_vectors[model.dictionary[w]], mwv ))

            # If component is absent from vocab
            else:
                sws.append(-1)
                cvs.append(earr)
                css.append(np.nan)

                oldn.append([])

        #  Mean cosim
        if min(sws) >= 0:
            cs = np.nanmean(css)
        else:
            cs = np.nan

        newn = model.most_similar(mwetoken, number=5)

    # Combined token missing from vocab - mark with defaults
    else:
        sws = [-2]
        mwv = np.empty(400)
        mwv[:] = np.nan


    # Return stats df
    return pd.DataFrame.from_dict({
        'ngram'  : [exp],
        'stopwords' : [sws],
        'mwe_vector' : [mwv],
        'component_vectors' : [cvs],
        'component_cosims'  : [css],
        'cosine_sim'  : [cs],
        'base_nearest': [oldn],
        'mwe_nearest' : [newn],
    })

# %%
# %%time

batch_dfs = {}

for bb in range(batch_count):
    print('Processing batch {} of {}'.format(bb+1,batch_count))
    # Subset DataFrame
    batch_dfs[bb] = ngram_eval[ngram_eval.batch == bb+1].reset_index(drop=True)
    
    # Initialise MWETokenizer
    batch_token_mwe = MWETokenizer(list(batch_dfs[bb].ngram) , separator='+')
    
    # Build model
    simp_corp = Corpus()

    sents_mwe = Sent_Seq(simp, batch_token_mwe)
    simp_corp.fit( sents_mwe , window = 10)
    
    batch_model = Glove(no_components = 300, 
             learning_rate = 0.05)
    
    batch_model.fit(simp_corp.matrix, 
          epochs=50,
          no_threads=16,
          verbose=False)

    batch_model.add_dictionary(simp_corp.dictionary)

    # Save model
    batch_model.save(datapath+'/Models/2 GloVe/simple_batch{}.model'.format(bb+1))
    # Reload looks like    new_model = Glove.load('glove.model')
    
    # For each MWE, evaluate stats. Record vectors (in case we want to calculate different metrics later).
    statsf = pd.DataFrame(columns=['ngram', 'stopwords', 'mwe_vector', 'component_vectors', 'component_cosims', 
                                   'cosine_sim', 'base_nearest', 'mwe_nearest'])

    for exp in batch_dfs[bb].ngram:
        statsf = mwe_score(exp,batch_model,statsf)

    #  Join back onto DataFrame
    batch_dfs[bb] = batch_dfs[bb].merge(statsf, on='ngram')
    
    
batch_dfs
# Out:
# Processing batch 1 of 7
# Processing batch 2 of 7
# Processing batch 3 of 7
# Processing batch 4 of 7
# Processing batch 5 of 7
# Processing batch 6 of 7
# Processing batch 7 of 7
# Wall time: 1min 50s
# {0:                     ngram  freq      poisson  len  batch  stopwords  \
#  0           (Jari, Kurri)    10  -203.525952    2      1   [-1, -1]
#  1                  (W, L)    10  -209.941413    2      1     [0, 0]
#  2       (Martin, Brodeur)    10  -214.900988    2      1    [0, -1]
#  3        (Chris, Chelios)    10  -217.855546    2      1    [0, -1]
#  4    (Mexican, Americans)    10  -218.635572    2      1     [0, 0]
#  ..                    ...   ...          ...  ...    ...        ...
#  193              (is, an)    34  -976.359183    2      1     [1, 0]
#  194        (inducted, in)    38 -1035.764197    2      1     [0, 1]
#  195             (0, 0, 0)    33 -1072.003121    3      1  [0, 0, 0]
#  196      (United, States)    50 -1157.334956    2      1     [0, 0]
#  197          (the, first)    50 -1471.806387    2      1     [1, 0]
#
#                                              mwe_vector  \
#  0    [-0.005231714711596772, 0.004657420091877666, ...
#  1    [0.03712956321857847, 0.05422869352118101, 0.0...
#  2    [-0.00399630753071913, 0.0016572498029122306, ...
#  3    [-0.00035695207383701594, 0.000231100540153136...
#  4    [-0.0028796956684670303, 0.0008790470829351194...
#  ..                                                 ...
#  193  [0.020345490035160604, -0.045107821056289625, ...
#  194  [-0.004583894517450058, -0.015344473496651552,...
#  195  [-0.052591664304951415, 0.04399638943453887, -...
#  196  [0.00031626841557328875, -0.08986866592159926,...
#  197  [0.01638127438612146, -0.07381033553439989, -0...
#
#                                       component_vectors  \
#  0    [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  1    [[-0.0020536399811814502, 0.000773260478175985...
#  2    [[0.010681729012764214, 0.007046018196167674, ...
#  3    [[-0.004746941512758034, 0.03021327433633852, ...
#  4    [[0.0015378799726352772, -0.025467916104967875...
#  ..                                                 ...
#  193  [[-0.06445296009337868, -0.25796731730042727, ...
#  194  [[0.0010566774719600474, -0.006779377119199148...
#  195  [[-0.05949840427490532, 0.050666382685030036, ...
#  196  [[0.001917414426776749, 0.004375838225847717, ...
#  197  [[-0.015677973048084128, -0.3269811228142642, ...
#
#                                        component_cosims  cosine_sim  \
#  0                                           [nan, nan]         NaN
#  1           [-0.07202609894044824, 0.7851838669918008]    0.356579
#  2                            [0.0982364381202404, nan]         NaN
#  3                           [-0.1830753232207304, nan]         NaN
#  4            [0.5437113701888436, 0.17144951411692835]    0.357580
#  ..                                                 ...         ...
#  193                          [nan, 0.8178347024248701]    0.817835
#  194                         [0.29808384814427025, nan]    0.298084
#  195  [0.9889004186254224, 0.9889004186254224, 0.988...    0.988900
#  196         [-0.3229287016437287, -0.2710401505315797]   -0.296984
#  197                          [nan, 0.9174338553486108]    0.917434
#
#                                            base_nearest  \
#  0                                             [[], []]
#  1    [[(summers, 0.6678498232289362), (manufacturer...
#  2    [[(Pidgin, 0.8927950756107279), (XVI, 0.855836...
#  3    [[(Osgood, 0.9844507140645329), (Malaysia, 0.9...
#  4    [[(names, 0.9789061180374475), (division, 0.97...
#  ..                                                 ...
#  193  [[(This, 0.9891472273099805), (It, 0.972869518...
#  194  [[(rated, 0.8783007323653456), (includes, 0.87...
#  195  [[(0+0+0, 0.9889004186254221), (1, 0.802042832...
#  196  [[(devastation, 0.8882425052532114), (Chad, 0....
#  197  [[(At, 0.9894853417642496), (throat, 0.9872228...
#
#                                             mwe_nearest
#  0    [(Mark+Messier, 0.9361311036771934), (Edmonton...
#  1    [(T, 0.9925242568092713), (GF, 0.9884384052634...
#  2    [(diabetes, 0.7984927322831161), (OZNA, 0.7958...
#  3    [(1474, 0.3576112052315309), (active, 0.342671...
#  4    [(Conference, 0.7552983677650599), (activities...
#  ..                                                 ...
#  193  [(American, 0.969613890896074), (team, 0.95514...
#  194  [(on, 0.9584815559773443), (ends, 0.9529967168...
#  195  [(0, 0.9889004186254221), (1, 0.77224907168450...
#  196  [(joints, 0.9841009272905362), (before, 0.9802...
#  197  [(becomes, 0.9744693255760596), (games, 0.9686...
#
#  [198 rows x 12 columns],
#  1:                       ngram  freq      poisson  len  batch  stopwords  \
#  0                    (L, T)    10  -211.010565    2      2     [0, 0]
#  1                   (GP, W)    10  -214.966416    2      2     [0, 0]
#  2                (when, he)    10  -269.554796    2      2     [0, 0]
#  3      (uric, acid, levels)    10  -277.962019    3      2  [0, 0, 0]
#  4               (of, these)    10  -291.518121    2      2     [1, 0]
#  ..                      ...   ...          ...  ...    ...        ...
#  99                 (it, is)    40 -1132.620806    2      2     [0, 1]
#  100  (New, York, Islanders)    38 -1233.350960    3      2  [1, 0, 0]
#  101                (It, is)    48 -1345.008361    2      2     [0, 1]
#  102                  (0, 0)    55 -1370.329810    2      2     [0, 0]
#  103               (at, the)    57 -1708.491144    2      2     [0, 1]
#
#                                              mwe_vector  \
#  0    [-0.013869128552968627, -0.006945130705751748,...
#  1    [-0.004438829747081011, -0.004065758502402016,...
#  2    [0.013705089782908441, 0.007169401678369257, -...
#  3    [0.006578313474644054, 0.0009269340884045576, ...
#  4    [-0.0013489034803818708, -0.000115184502529957...
#  ..                                                 ...
#  99   [0.033602444462437084, 0.01912072348774281, -0...
#  100  [0.009607799587081448, 0.01499084153213046, -0...
#  101  [0.06752899319262852, 0.0191657719446356, -0.0...
#  102  [0.010613002986599304, 0.021285885170021866, -...
#  103  [0.047694354713399986, -0.02536270407335361, -...
#
#                                       component_vectors  \
#  0    [[-0.0018974226289134074, 0.001651512584208177...
#  1    [[0.007705253620658405, -0.004298650398708735,...
#  2    [[0.04147187499721663, -0.0041275939787331845,...
#  3    [[0.03941572077272331, -0.026168155926800482, ...
#  4    [[0.30739407853579853, -0.14730583307496187, -...
#  ..                                                 ...
#  99   [[0.06276536933751087, -0.011702947894858156, ...
#  100  [[0.10026653456907896, 0.10922985869673278, -0...
#  101  [[0.040585420081368846, -0.021007405902793375,...
#  102  [[0.0234347746081466, 0.02491897909314357, -0....
#  103  [[0.06960937067193636, -0.0028299993763890984,...
#
#                                        component_cosims  cosine_sim  \
#  0             [0.3915510303811974, 0.6832737545251008]    0.537412
#  1            [0.1842500146020897, 0.19373523078181676]    0.188993
#  2             [0.8342079631902433, 0.8717406221392576]    0.852974
#  3    [0.4306821599163017, 0.5426521369514737, -0.08...    0.297239
#  4                           [nan, -0.3755360793853778]   -0.375536
#  ..                                                 ...         ...
#  99                           [0.8927608593847514, nan]    0.892761
#  100      [nan, 0.6789031886534342, 0.6380496069231172]    0.658476
#  101                          [0.8453170244678507, nan]    0.845317
#  102           [0.8113255055613735, 0.8113255055613735]    0.811326
#  103                          [0.9422333760582337, nan]    0.942233
#
#                                            base_nearest  \
#  0    [[(1908, 0.9562033883911015), (1722, 0.9560699...
#  1    [[(Team, 0.9505330004085145), (spin-off, 0.906...
#  2    [[(1993–1994, 0.9739124027805862), (coached, 0...
#  3    [[(acid, 0.9779686981223812), (Republic, 0.901...
#  4    [[(thousands, 0.9882202826611928), (Saul's, 0....
#  ..                                                 ...
#  99   [[(aircraft, 0.9906299391108226), (but, 0.9856...
#  100  [[(York, 0.9838975016202722), (Orleans, 0.9691...
#  101  [[(takes, 0.9720404681663705), (old, 0.9604626...
#  102  [[(Bowser, 0.8503229606114834), (Ghost, 0.8466...
#  103  [[(king, 0.9795733626917605), (war, 0.96857228...
#
#                                             mwe_nearest
#  0    [(Pts, 0.9711581806301111), (GA, 0.96650524806...
#  1    [(L+T, 0.8869055559293291), (GA, 0.79696029302...
#  2    [(causes, 0.9793840672208082), (Bathsheba, 0.9...
#  3    [(described, 0.9652503024948629), (However, 0....
#  4    [(draft, 0.848852225210414), (rank, 0.84793671...
#  ..                                                 ...
#  99   [(Additional, 0.97625257023826), (airplanes, 0...
#  100  [(Kansas, 0.7711274374013883), (Zealand, 0.722...
#  101  [(During, 0.9838592408069899), (system, 0.9784...
#  102  [(1, 0.8880248870641063), (Choco, 0.8684135285...
#  103  [(Cambridge, 0.9870525403302902), (Nazarene, 0...
#
#  [104 rows x 12 columns],
#  2:                            ngram  freq      poisson  len  batch   stopwords  \
#  0                      (W, L, T)    10  -248.014962    3      3   [0, 0, 0]
#  1        (Great, American, Bash)    11  -312.030540    3      3   [0, 0, 0]
#  2                     (of, uric)    11  -321.276490    2      3      [1, 0]
#  3    (Gretzky, Edmonton, Oilers)    11  -335.837636    3      3   [0, 0, 0]
#  4                     (the, end)    12  -343.446628    2      3      [1, 0]
#  5                  (people, who)    13  -348.031001    2      3      [0, 0]
#  6         (the, United, Kingdom)    10  -350.641590    3      3   [1, 0, 0]
#  7                    (year, and)    12  -358.043379    2      3      [0, 1]
#  8                  (in, 1992–93)    13  -359.481684    2      3      [1, 0]
#  9             (tiger, shark, is)    11  -367.314540    3      3   [0, 0, 1]
#  10               (the, previous)    13  -367.882115    2      3     [1, -1]
#  11              (2007, 15, June)    11  -370.140956    3      3   [0, 0, 0]
#  12                (2010, August)    14  -388.907395    2      3      [0, 1]
#  13            (Francisco, 49ers)    18  -389.081333    2      3     [0, -1]
#  14              (17, 2010, June)    12  -392.736830    3      3   [0, 0, 0]
#  15                 (home, games)    17  -414.748819    2      3      [0, 0]
#  16                    (to, have)    14  -420.601195    2      3      [1, 0]
#  17              (2005, 14, July)    13  -422.167235    3      3   [0, 0, 0]
#  18             (York, New, York)    12  -424.441352    3      3   [0, 1, 0]
#  19  (Sportsmen's, Lodge, Studio)    17  -436.678776    3      3   [0, 0, 0]
#  20                    (14, June)    17  -443.144535    2      3      [0, 0]
#  21              (Hall, of, Fame)    14  -447.836387    3      3  [0, 1, -1]
#  22                (Bay, Packers)    20  -461.501225    2      3     [0, -1]
#  23              (as, Additional)    18  -463.020831    2      3      [1, 0]
#  24          (Colts, Quarterback)    20  -477.648324    2      3      [0, 0]
#  25              (18, 2010, June)    16  -520.161096    3      3   [0, 0, 0]
#  26                    (that, he)    19  -536.785580    2      3      [1, 0]
#  27       (Toronto, Maple, Leafs)    21  -580.780243    3      3   [0, 0, 0]
#  28             (Other, websites)    28  -627.843568    2      3     [0, -1]
#  29             (Youth, in, Film)    20  -658.890064    3      3   [0, 1, 0]
#  30                     (a, time)    27  -771.045937    2      3      [1, 0]
#  31              (the, same, day)    23  -795.782186    3      3   [1, 0, 0]
#  32               (Young, Artist)    35  -796.414279    2      3      [0, 0]
#  33                  (Red, Wings)    44 -1003.729181    2      3     [0, -1]
#  34                   (San, Jose)    47 -1109.133390    2      3      [0, 0]
#  35                 (New, Jersey)    46 -1153.332484    2      3      [1, 0]
#  36         (the, United, States)    36 -1255.989146    3      3   [1, 0, 0]
#  37                   (St, Louis)    66 -1545.916981    2      3      [0, 0]
#  38                (Los, Angeles)    70 -1624.041450    2      3     [-1, 0]
#  39                      (to, be)    64 -1814.837328    2      3      [1, 0]
#
#                                             mwe_vector  \
#  0   [0.0388553663992536, -0.04948868239658594, 0.0...
#  1   [0.018307961809017073, 0.01998657727350205, -0...
#  2   [-0.005583004234543853, 0.03935808521219378, -...
#  3   [-0.012487951350797971, -0.011463461121651876,...
#  4   [-0.02782349883654623, 0.041556155999699, -0.0...
#  5   [-0.02065245740387187, 0.026413332466823328, -...
#  6   [-0.030330230710737233, 0.034833564849449966, ...
#  7   [0.0016230107397345876, 0.049919783999714105, ...
#  8   [0.026365987516160126, 0.03526628449585331, -0...
#  9   [0.02108961207197856, 0.030720559411430263, -0...
#  10  [-0.025600390234573497, 0.040358672177656416, ...
#  11  [-0.025186617533562387, -0.013999181922527755,...
#  12  [-0.04087803197915007, -0.0422407322912525, -0...
#  13  [0.01725684250999634, 0.020623554419873673, 0....
#  14  [-0.011122680083793432, -0.017803496746029056,...
#  15  [0.02672585441497574, 0.010418199893012197, 0....
#  16  [0.0034829231320781403, 8.165160058021216e-06,...
#  17  [-0.00798852006696297, -0.020800191181014786, ...
#  18  [-0.034036926020316494, 0.08898493454372962, -...
#  19  [-0.020912690933482907, 0.10814079687157792, 0...
#  20  [-0.08128454290515193, -0.04153939090286635, -...
#  21  [-0.008362825792091178, 0.04574814234655763, 0...
#  22  [0.015092037977607236, 0.006516544261313425, 0...
#  23  [0.008601184866327029, 0.00442904834845527, 0....
#  24  [0.01372631239686122, -0.05287728483936418, -0...
#  25  [-0.01577028476177525, -0.011659160709461392, ...
#  26  [-0.0052665912740802795, 0.006246256594902442,...
#  27  [-0.019075538653877042, 0.03277417613218054, -...
#  28  [0.001955398198317798, -0.02000609458140777, 0...
#  29  [0.03398725863866168, 0.05111797244988955, 0.0...
#  30  [-0.008056772761249994, -0.03243183322805167, ...
#  31  [-0.01789272364152671, 0.01557422630845614, -0...
#  32  [0.02678970124593566, 0.0890660191837783, 0.03...
#  33  [0.030276365946567137, -0.03142371971488349, 0...
#  34  [-0.026194672670511517, 0.00028918750446515486...
#  35  [0.006359170471996641, 0.09330654920622142, 0....
#  36  [-0.0462146093083952, 0.06094998864720484, -0....
#  37  [0.04439854504885371, -0.030986823575935817, 0...
#  38  [-0.04930855742229071, 0.00923080810374788, -0...
#  39  [0.020825306828814123, 0.024795565881160716, 0...
#
#                                      component_vectors  \
#  0   [[-0.001639726342539088, -0.006402934599076767...
#  1   [[-0.009910969294101013, 0.04496610850869677, ...
#  2   [[-0.3870533477316394, 0.16370087568246905, -0...
#  3   [[-0.006026521096484563, -0.021081532966356686...
#  4   [[0.12023975862062082, 0.35956527737937427, 0....
#  5   [[-0.02269068635515566, 0.02960528934736934, -...
#  6   [[0.12023975862062082, 0.35956527737937427, 0....
#  7   [[-0.0067425075300585925, 0.08940995928837425,...
#  8   [[0.013431022687345534, 0.1975021499047783, -0...
#  9   [[0.0007125411929726349, 0.035604265819999543,...
#  10  [[0.12023975862062082, 0.35956527737937427, 0....
#  11  [[-0.11981401679278693, -0.09350962980293243, ...
#  12  [[-0.027384970894814863, -0.08092152719292922,...
#  13  [[0.004776108072930262, -0.0007739177663094629...
#  14  [[-0.042329933136550944, -0.04519192855029095,...
#  15  [[0.04295464462304618, -0.0026971132090766255,...
#  16  [[0.15239541244927796, -0.14487642954941468, -...
#  17  [[-0.00022504861222265608, -0.0222321605412327...
#  18  [[-0.0771365526553157, 0.2388668009779441, -0....
#  19  [[0.0036460246693338, 0.004287802102877093, 0....
#  20  [[-0.045602402935256706, -0.03988804627071024,...
#  21  [[0.00874718096101228, 0.0008936766347696463, ...
#  22  [[0.09092974737106185, -0.15838834489870976, -...
#  23  [[-0.057649204885938526, 0.025575611676011967,...
#  24  [[0.002603193315831443, -0.013317454747797667,...
#  25  [[-0.06331848310235717, -0.007170262942227039,...
#  26  [[0.005861728438106365, 0.03586249837429008, 0...
#  27  [[-0.025144492076297473, 0.014413475194603242,...
#  28  [[-0.0027214689840475356, -0.00037102392031914...
#  29  [[-0.003228115399558386, 0.039374441668979056,...
#  30  [[0.1305899539958301, 0.08997536279471069, -0....
#  31  [[0.12023975862062082, 0.35956527737937427, 0....
#  32  [[-0.012609567909894015, 0.008188467657769382,...
#  33  [[0.012814929533036602, 0.016774198774447205, ...
#  34  [[0.024069085588799218, 0.04012233734215351, 0...
#  35  [[-0.10156718049149077, 0.24561352112342488, -...
#  36  [[0.12023975862062082, 0.35956527737937427, 0....
#  37  [[-0.018736518447087777, 0.009497739175741185,...
#  38  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  39  [[0.15239541244927796, -0.14487642954941468, -...
#
#                                       component_cosims  cosine_sim  \
#  0   [0.22164079944253248, 0.1387271042592947, 0.53...    0.298917
#  1   [0.2339239589857175, 0.8680537315800002, 0.541...    0.547982
#  2                           [nan, 0.7958227216118607]    0.795823
#  3   [0.13723578929842417, -0.4935147538220416, -0....   -0.222612
#  4                          [nan, 0.25947813658065844]    0.259478
#  5             [0.889433909120232, 0.7902681605198337]    0.839851
#  6       [nan, 0.4412697697815778, 0.1792808347920566]    0.310275
#  7                           [0.9332556753800212, nan]    0.933256
#  8                           [nan, 0.9285254289226548]    0.928525
#  9       [0.7605232774656798, 0.8232507276561629, nan]    0.791887
#  10                                         [nan, nan]         NaN
#  11  [0.9604860720306816, 0.8522867721739376, 0.804...    0.872343
#  12                          [0.8549070357701363, nan]    0.854907
#  13                          [0.8102257882329831, nan]         NaN
#  14  [0.9192652397091561, 0.9543338745017104, 0.950...    0.941261
#  15           [0.9473198486826488, 0.9317248732830996]    0.939522
#  16                           [nan, 0.744636249747062]    0.744636
#  17  [0.9418648574296229, 0.835937288352049, 0.9499...    0.909262
#  18      [0.9481834005777956, nan, 0.9481834005777956]    0.948183
#  19  [-0.15825628194209573, -0.20982468892805275, -...   -0.202996
#  20           [0.8596210091458576, 0.7604151213426837]    0.810018
#  21                     [0.5235829887211138, nan, nan]         NaN
#  22                         [0.23136855867802428, nan]         NaN
#  23                        [nan, -0.06520838541633188]   -0.065208
#  24           [0.9124690771941774, 0.1380422781901299]    0.525256
#  25  [0.8354043130589596, 0.9602563688420552, 0.925...    0.907016
#  26                          [nan, 0.9561031143727557]    0.956103
#  27  [-0.693032314886971, -0.9365335498384566, 0.50...   -0.373487
#  28                          [0.8303957962016908, nan]         NaN
#  29      [0.4463941284547236, nan, 0.6200989465085279]    0.533247
#  30                           [nan, 0.697862613451747]    0.697863
#  31      [nan, 0.5689063222683299, 0.8477656060844567]    0.708336
#  32       [0.049579443329913625, -0.07149159719878123]   -0.010956
#  33                         [-0.3027192500769087, nan]         NaN
#  34           [0.5341265064048366, 0.6923880191899605]    0.613257
#  35                          [nan, 0.7048228306882799]    0.704823
#  36     [nan, 0.3030283097683268, 0.44503930210230813]    0.374034
#  37          [-0.5109241952019906, 0.6525966149090795]    0.070836
#  38                          [nan, 0.4394294973109409]         NaN
#  39                          [nan, 0.7277933680080009]    0.727793
#
#                                           base_nearest  \
#  0   [[(army-captains, 0.9778924830916621), (Aposto...
#  1   [[(entered, 0.980157381655282), (urine, 0.9734...
#  2   [[(thousands, 0.9881346543566634), (accusation...
#  3   [[(Summary, 0.7188532393092636), (AT&T, 0.7185...
#  4   [[(U.S, 0.9873557455057703), (skin, 0.98568492...
#  5   [[(children, 0.9790577036593696), (its, 0.9789...
#  6   [[(U.S, 0.9873557455057703), (skin, 0.98568492...
#  7   [[(at, 0.9669039622102), (two, 0.9650554467256...
#  8   [[(1931, 0.9539154799482032), (falls, 0.945715...
#  9   [[(shark, 0.9726079782947971), (second, 0.9610...
#  10  [[(U.S, 0.9873557455057703), (skin, 0.98568492...
#  11  [[(2007+15+June, 0.9604860720306816), (14+June...
#  12  [[(24, 0.9711606887362887), (29, 0.96838321312...
#  13  [[(Edinburgh, 0.9195320013597738), (full, 0.91...
#  14  [[(28, 0.9865603738614459), (23, 0.98579703503...
#  15  [[(together, 0.9661601334340474), (taken, 0.96...
#  16  [[(trying, 0.9790311396881406), (due, 0.967774...
#  17  [[(July, 0.9738803664511717), (8, 0.9606058052...
#  18  [[(Giants, 0.9879083630687077), (New, 0.986502...
#  19  [[(year's, 0.9805010531361357), (whale's, 0.97...
#  20  [[(18+2010+June, 0.98689380487548), (23, 0.986...
#  21  [[(Golden, 0.8714021399362707), (playing, 0.86...
#  22  [[(Tampa, 0.9939949258480729), (Lightning, 0.9...
#  23  [[(such, 0.9908559886954971), (well, 0.9875928...
#  24  [[(Pete, 0.961059924755007), (Allen, 0.9596392...
#  25  [[(Day, 0.935669268305048), (11, 0.91739897483...
#  26  [[(written, 0.962714147408416), (time, 0.95994...
#  27  [[(Montreal, 0.9401236155943755), (Canadiens, ...
#  28  [[(Princess, 0.9049660156561773), (lunar, 0.90...
#  29  [[(main, 0.8731989666645178), (Church, 0.86805...
#  30  [[(small, 0.9703502343801452), (big, 0.9586493...
#  31  [[(U.S, 0.9873557455057703), (skin, 0.98568492...
#  32  [[(Best, 0.9394291941736213), (Germans, 0.9365...
#  33  [[(fighting, 0.9797515754250165), (moon, 0.975...
#  34  [[(Francisco+49ers, 0.9659188968127111), (Dieg...
#  35  [[(Bossy, 0.9880059653086267), (York, 0.986502...
#  36  [[(U.S, 0.9873557455057703), (skin, 0.98568492...
#  37  [[(parts, 0.9375699651505183), (Republic, 0.93...
#  38  [[], [(phone, 0.835747903256287), (receiver, 0...
#  39  [[(trying, 0.9790311396881406), (due, 0.967774...
#
#                                            mwe_nearest
#  0   [(Pts, 0.9719891807708474), (Score, 0.91274542...
#  1   [(statistics, 0.9630114377088246), (Love, 0.95...
#  2   [(Also, 0.9255493116866844), (aviation, 0.9209...
#  3   [(1980, 0.8679995112116192), (1993–94, 0.86588...
#  4   [(date, 0.9804241018509898), (One, 0.977267517...
#  5   [(four, 0.9634513216319215), (two, 0.956014130...
#  6   [(Germany, 0.9713710287072636), (movies, 0.967...
#  7   [(French, 0.9728598449210224), (one, 0.9442753...
#  8   [(1992–1993, 0.9937556211004156), (coached, 0....
#  9   [(The, 0.9595896004241552), (Suspect, 0.957649...
#  10  [(Alabama, 0.9516519732875198), (founding, 0.9...
#  11  [(14+June, 0.995867748161318), (2007, 0.960486...
#  12  [(Earth, 0.9510531644490863), (42, 0.937504139...
#  13  [(San, 0.965918896812711), (Diego, 0.914874633...
#  14  [(29, 0.9899050262895359), (24, 0.973955273686...
#  15  [(Various, 0.9925304029261819), (match, 0.9836...
#  16  [(best, 0.9183954986047194), (rocket, 0.909689...
#  17  [(17+2010+June, 0.9634281892262675), (29, 0.95...
#  18  [(1994—New, 0.9862733585057604), (Islanders, 0...
#  19  [(Oklahoma, 0.9156249952253813), (Recap, 0.878...
#  20  [(2007+15+June, 0.995867748161318), (21, 0.949...
#  21  [(water, 0.9799867665989551), (west, 0.9787917...
#  22  [(Green, 0.9817307272817326), (Quarterback, 0....
#  23  [(Fieldhouse, 0.951531975018423), (Pitch, 0.94...
#  24  [(Baltimore, 0.9717957596617814), (uniforms, 0...
#  25  [(14, 0.9868938048754801), (2006, 0.9801142262...
#  26  [(said, 0.9821995618264886), (he, 0.9561031143...
#  27  [(Pakistan, 0.9818335909033137), (men, 0.97999...
#  28  [(Luther, 0.9176319593147914), (Sacramento, 0....
#  29  [(Awards, 0.9462543622230781), (Young+Artist, ...
#  30  [(others, 0.9758211091665383), (goes, 0.972929...
#  31  [(cheating, 0.9401880646072112), (1993–1994, 0...
#  32  [(Awards, 0.9840596049948048), (Youth+in+Film,...
#  33  [(Lions, 0.9757593067864189), (Detroit, 0.9708...
#  34  [(Sharks, 0.9604356982468844), (thriller, 0.87...
#  35  [(106, 0.9614302049860594), (Nassau, 0.9506399...
#  36  [(diet, 0.9654914525022436), (Germany, 0.96499...
#  37  [(Blues, 0.965018800616403), (Rams, 0.94405870...
#  38  [(Kings, 0.9567387659894969), (Phoenix, 0.8615...
#  39  [(given, 0.969484195826009), (First, 0.9617139...  ,
#  3:                       ngram  freq      poisson  len  batch   stopwords  \
#  0                (GP, W, L)    10  -250.816041    3      4   [0, 0, 0]
#  1    (The, Great, American)    10  -340.632198    3      4   [1, 0, 0]
#  2          (15, June, 2007)    11  -370.140956    3      4   [0, 0, 0]
#  3          (of, uric, acid)    11  -377.238581    3      4   [1, 0, 0]
#  4          (2010, June, 17)    12  -392.736830    3      4   [0, 0, 0]
#  5               (shark, is)    14  -393.923838    2      4      [0, 1]
#  6     (the, previous, year)    12  -412.969217    3      4   [1, 0, 0]
#  7          (14, July, 2005)    13  -422.167235    3      4   [0, 0, 0]
#  8          (New, York, New)    12  -431.627368    3      4   [1, 0, 1]
#  9        (home, games, for)    14  -464.532922    3      4   [0, 0, 1]
#  10    (Lodge, Studio, City)    17  -466.844261    3      4   [0, 0, 0]
#  11             (Green, Bay)    20  -474.146589    2      4      [0, 0]
#  12        (also, known, as)    14  -491.207446    3      4   [0, 0, 1]
#  13         (14, June, 2007)    15  -498.377667    3      4   [0, 0, 0]
#  14  (San, Francisco, 49ers)    18  -506.221637    3      4  [0, 0, -1]
#  15         (2010, June, 18)    16  -520.161096    3      4   [0, 0, 0]
#  16         (Wayne, Gretzky)    24  -524.112529    2      4     [0, -1]
#  17               (week, as)    23  -597.535308    2      4      [0, 1]
#  18              (found, in)    22  -622.786623    2      4      [0, 1]
#  19                (he, was)    24  -680.163444    2      4      [0, 1]
#  20               (such, as)    27  -699.043216    2      4      [0, 1]
#  21               (time, to)    27  -772.034312    2      4      [0, 1]
#  22             (Tampa, Bay)    41  -948.894734    2      4      [0, 0]
#  23              (the, same)    36 -1020.173493    2      4      [1, 0]
#  24       (Edmonton, Oilers)    49 -1165.732218    2      4      [0, 0]
#  25            (the, United)    46 -1327.676155    2      4      [1, 0]
#
#                                             mwe_vector  \
#  0   [0.03483309308846341, 0.02040523056574682, 0.0...
#  1   [0.05954395763525702, 0.010037131961246951, 0....
#  2   [0.0012171753611426802, 0.004040373834516274, ...
#  3   [-0.04666799795124589, 0.0013631535570899267, ...
#  4   [-6.547484792760632e-05, 0.015911119698354986,...
#  5   [-0.02378716613227345, 0.024407998050577095, -...
#  6   [0.05412363891901108, -0.03263232643243506, -0...
#  7   [-0.0008361282948545583, 0.021455900839089256,...
#  8   [-0.07185174080862565, -0.021623400461957227, ...
#  9   [0.035312622104379174, -0.0014540059469793946,...
#  10  [-0.026862737871496043, -0.0414790448317205, -...
#  11  [0.0068036090610292, -0.016668791019433322, -0...
#  12  [0.023725099907208932, 0.038934100784629305, -...
#  13  [0.0025701083226045596, 0.007946938784768477, ...
#  14  [0.01844157380361815, -0.0018815505478749208, ...
#  15  [-0.004245495876385133, 0.016145541612211725, ...
#  16  [-0.011757842489841927, 0.015022800425800937, ...
#  17  [-0.00505698496538047, -0.03721753250028736, -...
#  18  [0.03569653289918261, 0.04436281062188957, 0.0...
#  19  [-0.0065111039587083894, 0.001685663358741242,...
#  20  [-0.03275010566115945, -0.04454385529796765, -...
#  21  [0.1469648262973955, 0.07022635713161754, 0.00...
#  22  [0.059907360001115, 0.03523344444358329, 0.075...
#  23  [0.053659796356723355, 0.02109793443785665, -0...
#  24  [-0.0449453856711765, 0.010111963030347806, -0...
#  25  [-0.00744585432068026, -0.08619155382966563, 0...
#
#                                      component_vectors  \
#  0   [[0.00966949913371133, 0.0018244412868721866, ...
#  1   [[0.017229420098461914, 0.2222075596990513, 0....
#  2   [[-0.00838269494287974, 0.057236715773465986, ...
#  3   [[0.26709646711266094, -0.3020745801349221, -0...
#  4   [[-0.0013829806780478655, 0.09110556942317559,...
#  5   [[-0.045990453793632625, -0.007983161261666328...
#  6   [[-0.8129008293983742, -0.38409954129414553, -...
#  7   [[0.0033585008501883762, 0.06702317012155888, ...
#  8   [[-0.24562582189098067, -0.07980437915123688, ...
#  9   [[0.06005385910244697, 0.0337631156370606, 0.0...
#  10  [[-0.015797544961963346, -0.005975996556779442...
#  11  [[0.0005222897092825803, -0.005104586993581005...
#  12  [[0.048139061372116765, 0.043138602871289476, ...
#  13  [[0.0033585008501883762, 0.06702317012155888, ...
#  14  [[-0.14366406379566493, -0.061251193843312825,...
#  15  [[-0.0013829806780478655, 0.09110556942317559,...
#  16  [[0.004547653844777134, 0.0026037033473483157,...
#  17  [[0.003087246683737864, -0.0018966554092538727...
#  18  [[-0.008208976388377026, 0.0032835152341263614...
#  19  [[-0.02362171713783852, -0.002878954175200602,...
#  20  [[-0.000805032286851288, -0.003292479802506394...
#  21  [[0.06861722566105338, 0.002714870764882022, -...
#  22  [[0.0008312983552239406, 0.004111802790967314,...
#  23  [[-0.8129008293983742, -0.38409954129414553, -...
#  24  [[-0.08630865956912649, -0.03787810296953826, ...
#  25  [[-0.8129008293983742, -0.38409954129414553, -...
#
#                                       component_cosims  cosine_sim  \
#  0   [0.22829454212968486, -0.0989815771309121, -0....   -0.044489
#  1   [nan, -0.5117024857552227, -0.044471567645677876]   -0.278087
#  2   [0.8944035355058121, 0.7858968710783673, 0.900...    0.860195
#  3       [nan, 0.8372084656676155, 0.8510278072651087]    0.844118
#  4   [0.9712383308339234, 0.9337652175610464, 0.934...    0.946462
#  5                           [0.9053596951498089, nan]    0.905360
#  6      [nan, -0.7251093053528282, 0.7016063831581406]   -0.011751
#  7   [0.9031170470391247, 0.9551154321935277, 0.951...    0.936652
#  8                      [nan, 0.9444619545407241, nan]    0.944462
#  9       [0.8266316138331021, 0.7842064505822004, nan]    0.805419
#  10  [-0.2251657315243643, -0.12180627598967159, 0....    0.066819
#  11         [-0.2712548563890708, 0.48310367994361747]    0.105924
#  12      [0.6197903853805342, 0.5935379499526718, nan]    0.606664
#  13  [0.8833083873541316, 0.8409629178265267, 0.961...    0.895367
#  14   [-0.46953984998878817, -0.3556761849834357, nan]         NaN
#  15  [0.9854852726066516, 0.9320970045549906, 0.809...    0.909081
#  16                         [-0.8594876125074615, nan]         NaN
#  17                          [0.5841601450526666, nan]    0.584160
#  18                          [0.8366095922181908, nan]    0.836610
#  19                           [0.956388586198116, nan]    0.956389
#  20                         [-0.3608255153391916, nan]   -0.360826
#  21                          [0.7371876975853369, nan]    0.737188
#  22          [0.4036655547556992, 0.34548915193136936]    0.374577
#  23                        [nan, -0.46883081063376686]   -0.468831
#  24          [0.3038179419638274, 0.13322217252014074]    0.218520
#  25                          [nan, 0.9591579764408303]    0.959158
#
#                                           base_nearest  \
#  0   [[(executed, 0.9370544951838928), (Undertaker,...
#  1   [[(Suspect, 0.943697317591413), (NHL's, 0.9418...
#  2   [[(14, 0.9537013170978111), (2010+June+18, 0.9...
#  3   [[(types, 0.9810712994321503), (parts, 0.97621...
#  4   [[(2010+June+18, 0.9854852726066518), (24, 0.9...
#  5   [[(original, 0.9823647631413447), (largest, 0....
#  6   [[(stomach, 0.9779956767556238), (Israelites, ...
#  7   [[(2010+June+18, 0.9859672675278895), (16, 0.9...
#  8   [[(Bossy, 0.9848928182815365), (York, 0.981591...
#  9   [[(good, 0.9783871763596983), (strong, 0.97536...
#  10  [[(excellent, 0.9552735802778715), (whale's, 0...
#  11  [[(published, 0.8249964299462194), (Jessica, 0...
#  12  [[(commonly, 0.9681697180288948), (Rena, 0.965...
#  13  [[(2010+June+18, 0.9859672675278895), (16, 0.9...
#  14  [[(Diego, 0.9693326275928444), (Jose, 0.912155...
#  15  [[(2010+June+18, 0.9854852726066518), (24, 0.9...
#  16  [[(dinner, 0.9825035358297235), (ferocious, 0....
#  17  [[(Seahawks, 0.9210906681229082), (voice, 0.90...
#  18  [[(performed, 0.976683075452295), (changed, 0....
#  19  [[(said, 0.9635832578682793), (would, 0.960853...
#  20  [[(3%, 0.9562305044469557), (provider, 0.95112...
#  21  [[(character, 0.9738154531591717), (dropped, 0...
#  22  [[(SEE-diff, 0.9627149114675972), (immunodefic...
#  23  [[(stomach, 0.9779956767556238), (Israelites, ...
#  24  [[(1994—New, 0.9337674538574819), (1925, 0.933...
#  25  [[(stomach, 0.9779956767556238), (Israelites, ...
#
#                                            mwe_nearest
#  0   [(T, 0.9003479420676292), (Anzac, 0.8894104513...
#  1   [(Pts, 0.8609860848047743), (Martin, 0.8487366...
#  2   [(14+June+2007, 0.9781306988362747), (21, 0.95...
#  3   [(pitcher, 0.9252600256039468), (Ljubljana, 0....
#  4   [(29, 0.9789617933823063), (2010, 0.9712383308...
#  5   [(tiger, 0.9635792917655871), (main, 0.9348576...
#  6   [(Africa, 0.9601829693076485), (several, 0.947...
#  7   [(2010+June+17, 0.967405894360887), (29, 0.964...
#  8   [(Rangers, 0.9855927219500797), (Islanders, 0....
#  9   [(Various, 0.9889387326903989), (2012–13, 0.97...
#  10  [(Unknown, 0.9200419805257074), (Pixar, 0.9172...
#  11  [(Packers, 0.9793053510254661), (Cleveland, 0....
#  12  [(airport, 0.9442330667060088), (Buzz, 0.90790...
#  13  [(15+June+2007, 0.9781306988362746), (2007, 0....
#  14  [(Quarterback, 0.8022947805448716), (340, 0.66...
#  15  [(14, 0.9859672675278895), (2010, 0.9854852726...
#  16  [(written, 0.945107607732443), (Vézina, 0.9400...
#  17  [(release, 0.9810013864563771), (area, 0.96895...
#  18  [(it, 0.9778395895039077), (which, 0.977738373...
#  19  [(had, 0.9736811895674834), (lied, 0.972383252...
#  20  [(wife, 0.9790701205916427), (culture, 0.96273...
#  21  [(TV, 0.9780029753722668), (die, 0.96884772164...
#  22  [(Lightning, 0.8808049598518126), (Florida, 0....
#  23  [(day, 0.9644002315328005), (finishes, 0.90661...
#  24  [(Recap, 0.7936369494790674), (City, 0.7913147...
#  25  [(States, 0.9965674893871272), (United, 0.9591...  ,
#  4:                     ngram  freq      poisson  len  batch   stopwords  \
#  0              (list, of)    14  -387.329394    2      5     [-1, 1]
#  1              (15, June)    15  -393.366583    2      5      [0, 0]
#  2          (the, end, of)    10  -395.193048    3      5   [1, 0, 1]
#  3      (is, an, American)    11  -403.527606    3      5   [1, 0, 0]
#  4        (July, 2005, 14)    13  -422.167235    3      5   [0, 0, 0]
#  5          (a, group, of)    11  -426.443435    3      5   [1, 0, 1]
#  6          (tiger, shark)    20  -460.837888    2      5      [0, 0]
#  7        (2007, 14, June)    15  -498.377667    3      5   [0, 0, 0]
#  8           (is, one, of)    13  -520.108868    3      5   [1, 0, 1]
#  9   (Green, Bay, Packers)    20  -560.585151    3      5  [0, 0, -1]
#  10     (in, Film, Awards)    20  -684.382512    3      5   [1, 0, 0]
#  11           (uric, acid)    32  -707.780159    2      5     [-1, 0]
#  12              (day, of)    25  -715.930973    2      5      [0, 1]
#  13          (a, time, to)    20  -776.651334    3      5   [1, 0, 1]
#  14        (the, week, as)    21  -784.958950    3      5   [1, 0, 1]
#  15            (known, as)    34  -907.364703    2      5      [0, 1]
#  16           (2010, June)    39 -1001.133019    2      5      [0, 0]
#  17       (University, of)    58 -1704.815272    2      5      [0, 1]
#  18            (New, York)   132 -3273.884672    2      5      [1, 0]
#
#                                             mwe_vector  \
#  0   [-0.0730966697761451, 0.020460042365904707, 0....
#  1   [-0.1445429706024602, -0.04819441799107445, 0....
#  2   [-0.011170546876226144, 0.0054765767893501125,...
#  3   [0.014468272002547963, -0.0020610144915940965,...
#  4   [-0.010889702517554094, -0.023806547001027727,...
#  5   [-0.02194337463438215, 0.015357428034151716, 0...
#  6   [-0.04336781355376341, 0.006865327626552646, 0...
#  7   [-0.048115049927833886, -0.0184120765470934, 0...
#  8   [-0.028066885386410174, 0.007253040709463033, ...
#  9   [0.01171144254645022, 0.015377844524005552, -0...
#  10  [0.05639933004035002, -0.0027544571184697597, ...
#  11  [-0.055393583015494206, 0.0016080175809047746,...
#  12  [-0.014280740304502418, 0.031466597520187795, ...
#  13  [-0.05090609920825316, -0.04209061530988329, 0...
#  14  [-0.015063402038054554, 0.026043319079136006, ...
#  15  [-0.06294407256639561, 0.028579059094528833, 0...
#  16  [0.08035492639467905, 0.08458345000874927, -0....
#  17  [0.0011077009437371723, 0.0008204429458345834,...
#  18  [0.1286995071106611, -0.023307603956559765, -0...
#
#                                      component_vectors  \
#  0   [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  1   [[-0.09895326404110188, -0.06402923513350013, ...
#  2   [[-0.3066800750597189, 0.10882985639952847, 0....
#  3   [[-0.22804558626671248, 0.02823645181053167, 0...
#  4   [[-0.06510646489709104, -0.16087717471176927, ...
#  5   [[-0.2339384588190455, 0.004433742439678139, 0...
#  6   [[-0.002420523386746978, 0.004538250871384892,...
#  7   [[-0.18388108427674837, -0.08764108027302403, ...
#  8   [[-0.22804558626671248, 0.02823645181053167, 0...
#  9   [[0.009130707000236389, 0.0012676354636235135,...
#  10  [[-0.22692010181211908, 0.012042590666936725, ...
#  11  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  12  [[-0.05490996893342197, 0.0022602308536288414,...
#  13  [[-0.2339384588190455, 0.004433742439678139, 0...
#  14  [[-0.3066800750597189, 0.10882985639952847, 0....
#  15  [[-0.08746187126726497, 0.030691761204494402, ...
#  16  [[-0.12740435880301582, -0.0693132560415854, 0...
#  17  [[0.004317564224630977, -0.012941165502272046,...
#  18  [[0.1509123011983876, 0.00022830470688375848, ...
#
#                                       component_cosims  cosine_sim  \
#  0                                          [nan, nan]         NaN
#  1            [0.8526239017021168, 0.8926350348287639]    0.872629
#  2                      [nan, 0.8938325859158032, nan]    0.893833
#  3    [nan, -0.4510959855620576, -0.45156241675857667]   -0.451329
#  4   [0.8895506235331423, 0.8936383871949116, 0.854...    0.879241
#  5                      [nan, 0.6557249205291829, nan]    0.655725
#  6           [0.41528069315560323, 0.7378079326986777]    0.576544
#  7   [0.9766197711827693, 0.9408903380404672, 0.928...    0.948722
#  8                      [nan, 0.5549878189344377, nan]    0.554988
#  9   [-0.02387199678375429, 0.0029067064571148445, ...         NaN
#  10    [nan, 0.28670001515944116, 0.42043471485471823]    0.353567
#  11                         [nan, -0.8245502300395927]         NaN
#  12                         [0.48183964402809554, nan]    0.481840
#  13                     [nan, 0.6156142178661179, nan]    0.615614
#  14                     [nan, 0.6446251286835536, nan]    0.644625
#  15                          [0.8786281345121183, nan]    0.878628
#  16          [0.4129466294936473, 0.32664986316205413]    0.369798
#  17                         [0.07828157730098165, nan]    0.078282
#  18                         [nan, 0.13084974414523204]    0.130850
#
#                                           base_nearest  \
#  0   [[], [(date, 0.9796609621104813), (thousands, ...
#  1   [[(7, 0.9503637607766332), (2010, 0.9412481518...
#  2   [[(hospital, 0.9782203215709768), (throughout,...
#  3   [[(This, 0.9815760537999928), (stars, 0.961218...
#  4   [[(2005, 0.9901596094996487), (8, 0.9186012225...
#  5   [[(small, 0.9684082195152914), (young, 0.96221...
#  6   [[(never, 0.8393013127195939), (hemisphere, 0....
#  7   [[(2007+14+June, 0.9766197711827694), (15+June...
#  8   [[(This, 0.9815760537999928), (stars, 0.961218...
#  9   [[(Stephen, 0.8330713903275796), (Blu-ray, 0.8...
#  10  [[(resulting, 0.9725708060939241), (Kummersdor...
#  11  [[], [(faces, 0.9861366116670084), (γραφή, 0.9...
#  12  [[(without, 0.9828475746231478), (example, 0.9...
#  13  [[(small, 0.9684082195152914), (young, 0.96221...
#  14  [[(hospital, 0.9782203215709768), (throughout,...
#  15  [[(Telegraphs, 0.9716946222165749), (given, 0....
#  16  [[(16, 0.9713265490150778), (9, 0.965120709076...
#  17  [[(State, 0.9289134975138582), (Nazarene, 0.88...
#  18  [[(Zealand, 0.9563589418654135), (Brady, 0.910...
#
#                                            mwe_nearest
#  0   [(Genesis, 0.9894434034358879), (band, 0.98337...
#  1   [(2007+14+June, 0.9928124212443432), (2007, 0....
#  2   [(Mississippi, 0.9567432184218284), (Wii, 0.95...
#  3   [(Pass, 0.9399359230394836), (Burn, 0.93230600...
#  4   [(29, 0.9614593591012631), (1912, 0.9390365176...
#  5   [(changed, 0.9825985262090127), (hunt, 0.96699...
#  6   [(statistics, 0.9655396829777521), (program, 0...
#  7   [(15+June, 0.9928124212443434), (2007, 0.97661...
#  8   [(night, 0.976473516109562), (makes, 0.9758033...
#  9   [(Browns, 0.8129462973643815), (Quarterback, 0...
#  10  [(Youth, 0.8883703292251404), (CM, 0.826746106...
#  11  [(species, 0.9522173277093915), (levels, 0.949...
#  12  [(the+week+as, 0.9795198852670703), (same, 0.9...
#  13  [(again, 0.9772838015835956), (friend, 0.96820...
#  14  [(day+of, 0.9795198852670703), (same, 0.926375...
#  15  [(reason, 0.9739016267110465), (commonly, 0.96...
#  16  [(17, 0.9160199554642143), (24, 0.892988974450...
#  17  [(Ambassador, 0.8881614394131006), (calendar, ...
#  18  [(Giants, 0.9664231148489324), (Islanders, 0.9...  ,
#  5:                ngram  freq      poisson  len  batch  stopwords  \
#  0      (is, a, list)    11  -403.393918    3      6  [1, 1, 0]
#  1   (June, 17, 2010)    13  -423.963695    3      6  [0, 0, 0]
#  2        (group, of)    16  -454.740364    2      6     [0, 1]
#  3   (June, 2007, 14)    15  -498.377667    3      6  [0, 0, 0]
#  4  (games, for, the)    15  -578.519771    3      6  [0, 1, 1]
#  5   (June, 18, 2010)    18  -582.122583    3      6  [0, 0, 0]
#  6    (same, day, of)    22  -748.684571    3      6  [0, 0, 1]
#  7    (part, of, the)    19  -754.885370    3      6  [0, 1, 1]
#  8     (one, of, the)    19  -783.579070    3      6  [0, 1, 1]
#  9       (July, 2005)    46 -1136.065870    2      6     [0, 0]
#
#                                            mwe_vector  \
#  0  [-0.033702738541810905, 0.00124739296665827, 0...
#  1  [0.0026503307024973483, 0.002120574056396748, ...
#  2  [-0.03558798068633231, -0.001625173239132228, ...
#  3  [0.015317683883635686, -0.020816455297039353, ...
#  4  [-0.05420127777882554, -0.029822987279643005, ...
#  5  [0.004804798040967898, 0.0064378894017533776, ...
#  6  [0.008862953743432628, 0.0002535343057665133, ...
#  7  [-0.014733778336433192, -0.002221359474142754,...
#  8  [-0.031290096445573325, -0.019762034949259807,...
#  9  [0.0663695285684151, -0.06564536685813505, -0....
#
#                                     component_vectors  \
#  0  [[-0.14896328738440176, -0.14223561558235073, ...
#  1  [[0.0758413321383367, -0.08232636297539758, -0...
#  2  [[-0.013526257228274228, 0.000664912090024032,...
#  3  [[0.0758413321383367, -0.08232636297539758, -0...
#  4  [[-0.06568308355849196, -0.02418641409738648, ...
#  5  [[0.0758413321383367, -0.08232636297539758, -0...
#  6  [[-0.0005459180157075518, 0.010603444948400164...
#  7  [[-0.017252414376292907, 0.013249692859898741,...
#  8  [[-0.09119831288799571, 0.004524440034368366, ...
#  9  [[0.05613876819729265, -0.04201505235529775, -...
#
#                                      component_cosims  cosine_sim  \
#  0                     [nan, nan, 0.5609519265757568]    0.560952
#  1  [0.5458497134175635, 0.7266935648998476, 0.822...    0.698504
#  2                          [0.8166355290001748, nan]    0.816636
#  3  [0.9479992056944611, 0.9518026268241538, 0.774...    0.891539
#  4                     [0.5495307607810496, nan, nan]    0.549531
#  5  [0.6204961232083201, 0.5091808087068033, 0.501...    0.543619
#  6      [0.8134983697184641, 0.7857727670479667, nan]    0.799636
#  7                     [0.5960842228369229, nan, nan]    0.596084
#  8                      [0.679176027689758, nan, nan]    0.679176
#  9            [0.692658258556612, 0.5823513571823752]    0.637505
#
#                                          base_nearest  \
#  0  [[(one+of+the, 0.9711439534315378), (This, 0.9...
#  1  [[(13, 0.962917048568887), (29, 0.951828695172...
#  2  [[(player, 0.9795210730122926), (described, 0....
#  3  [[(13, 0.962917048568887), (29, 0.951828695172...
#  4  [[(site, 0.977740344306617), (love, 0.96072710...
#  5  [[(13, 0.962917048568887), (29, 0.951828695172...
#  6  [[(under, 0.9695424553642368), (title, 0.96901...
#  7  [[(dynasty, 0.9821127339299021), (phase, 0.982...
#  8  [[(Yugoslavia, 0.9827397819002118), (any, 0.97...
#  9  [[(2010, 0.980054958582963), (24, 0.9589949342...
#
#                                           mwe_nearest
#  0  [(sub-continent, 0.9804032478045849), (sense, ...
#  1  [(2010, 0.8229702097441223), (Flag, 0.81700274...
#  2  [(Genesis, 0.9849185668346166), (small, 0.9805...
#  3  [(28, 0.9837316066829555), (13, 0.983122199440...
#  4  [(home, 0.9253956276091099), (Second, 0.914923...
#  5  [(Taurus, 0.7730224885627246), (offensive, 0.7...
#  6  [(dissolved, 0.9292093675273168), (If, 0.92371...
#  7  [(high, 0.9822666754993081), (commonly, 0.9485...
#  8  [(is, 0.9711439534315377), (Worf, 0.9680093669...
#  9  [(14, 0.9912019335608885), (1912, 0.9173688758...  ,
#  6:             ngram  freq      poisson  len  batch  stopwords  \
#  0   (a, list, of)    11  -416.020577    3      7  [1, 0, 1]
#  1  (day, of, the)    22  -881.971652    3      7  [0, 1, 1]
#  2       (one, of)    37 -1073.426267    2      7     [0, 1]
#  3    (June, 2007)    48 -1228.459659    2      7     [0, 0]
#
#                                            mwe_vector  \
#  0  [0.05283825554630417, -0.03523372947762702, 0....
#  1  [0.09191838258681954, -0.06215375537217488, 0....
#  2  [0.0731575270084718, -0.034678459362443514, 0....
#  3  [-0.014909070919654476, 0.0860387431107362, -0...
#
#                                     component_vectors  \
#  0  [[0.1653854801495751, -0.14355456513237852, 0....
#  1  [[0.04446284194473865, -0.0318723215029166, 0....
#  2  [[0.06126334239723287, -0.08404385285635473, -...
#  3  [[-0.007904308335230373, 0.059577215873887465,...
#
#                             component_cosims  cosine_sim  \
#  0          [nan, -0.05721444798029954, nan]   -0.057214
#  1            [0.5743885616163452, nan, nan]    0.574389
#  2                 [0.5593314987199389, nan]    0.559331
#  3  [0.5427554873505163, 0.3705076222512724]    0.456632
#
#                                          base_nearest  \
#  0  [[(small, 0.9587051319956509), (woman, 0.95020...
#  1  [[(rock, 0.971820186062676), (town, 0.96596241...
#  2  [[(Berlin, 0.961089066898683), (China, 0.95165...
#  3  [[(17, 0.9784732953841905), (24, 0.97288858164...
#
#                                           mwe_nearest
#  0  [(Chakswari, 0.9869407231943237), (divided, 0....
#  1  [(week, 0.9516807666070055), (same, 0.90523981...
#  2  [(reason, 0.9818246441994972), (program, 0.963...
#  3  [(13, 0.9638783386846405), (Flag, 0.9252545226...  }

# %%
import multiprocessing as mp1
import multiprocess as mp

# %%
# %%time

if __name__ == '__main__':
    batch_dfs = {}

    for bb in range(batch_count):
        print('Processing batch {} of {}'.format(bb+1,batch_count))
        # Subset DataFrame
        batch_dfs[bb] = ngram_eval[ngram_eval.batch == bb+1].reset_index(drop=True)

        # Initialise MWETokenizer
        batch_token_mwe = MWETokenizer(list(batch_dfs[bb].ngram) , separator='+')

        # Build model
        simp_corp = Corpus()

        sents_mwe = Sent_Seq(simp, batch_token_mwe)
        simp_corp.fit( sents_mwe , window = 10)

        batch_model = Glove(no_components = 300, 
                 learning_rate = 0.05)

        batch_model.fit(simp_corp.matrix, 
              epochs=50,
              no_threads=16,
              verbose=False)

        batch_model.add_dictionary(simp_corp.dictionary)

        # Save model
        batch_model.save(datapath+'/Models/2 GloVe/simple_batch{}.model'.format(bb+1))
        # Reload looks like    new_model = Glove.load('glove.model')

        # For each MWE, evaluate stats. Record vectors (in case we want to calculate different metrics later).
        # Parallelized version
        #with mp.Pool() as pool:
        #    statslist = pool.imap_unordered( mwe_score_par , [(ng, batch_model) for ng in batch_dfs[bb].ngram] )
         
        statslist = [mwe_score_par((ng, batch_model)) for ng in batch_dfs[bb].ngram]
        
        statsf = pd.concat(statslist)

        #  Join back onto DataFrame
        batch_dfs[bb] = batch_dfs[bb].merge(statsf, on='ngram')
    
    
batch_dfs
# Out:
# Processing batch 1 of 7
# Processing batch 2 of 7
# Processing batch 3 of 7
# Processing batch 4 of 7
# Processing batch 5 of 7
# Processing batch 6 of 7
# Processing batch 7 of 7
# Wall time: 1min 48s
# {0:                     ngram  freq      poisson  len  batch  stopwords  \
#  0           (Jari, Kurri)    10  -203.525952    2      1   [-1, -1]
#  1                  (W, L)    10  -209.941413    2      1     [0, 0]
#  2       (Martin, Brodeur)    10  -214.900988    2      1    [0, -1]
#  3        (Chris, Chelios)    10  -217.855546    2      1    [0, -1]
#  4    (Mexican, Americans)    10  -218.635572    2      1     [0, 0]
#  ..                    ...   ...          ...  ...    ...        ...
#  193              (is, an)    34  -976.359183    2      1     [1, 0]
#  194        (inducted, in)    38 -1035.764197    2      1     [0, 1]
#  195             (0, 0, 0)    33 -1072.003121    3      1  [0, 0, 0]
#  196      (United, States)    50 -1157.334956    2      1     [0, 0]
#  197          (the, first)    50 -1471.806387    2      1     [1, 0]
#
#                                              mwe_vector  \
#  0    [-0.00268128307697482, 0.0013802484932867673, ...
#  1    [-0.03580554917531481, -0.020348773542944648, ...
#  2    [-0.001042546369255624, -0.0020363566788727163...
#  3    [-0.0009590255219174769, 0.0015144903068238429...
#  4    [0.00435566961993808, -0.004219855285289332, 0...
#  ..                                                 ...
#  193  [0.03070172171968528, 0.0067603364099825605, -...
#  194  [0.009945817939205908, -0.0012602424870532987,...
#  195  [-0.02339999747226783, -0.011466790846444721, ...
#  196  [0.06585781810519034, 0.02686537871410535, -0....
#  197  [0.015770046439165016, 0.04663957465049888, -0...
#
#                                       component_vectors  \
#  0    [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  1    [[0.001478845828478702, 0.0019921298248615077,...
#  2    [[-0.009268155348278469, 0.009621663039400957,...
#  3    [[-0.011320854013833162, -0.00575286778909217,...
#  4    [[0.009410955055751952, 0.011381614691739326, ...
#  ..                                                 ...
#  193  [[0.16468877602766333, -0.03726005262637761, -...
#  194  [[0.0029777650796231634, 0.0030329751517623182...
#  195  [[-0.028248672359198455, -0.009550799930743105...
#  196  [[-0.0010200140346876365, 0.000719033256545041...
#  197  [[0.20985207780152199, -0.014597077713012784, ...
#
#                                        component_cosims  cosine_sim  \
#  0                                           [nan, nan]         NaN
#  1           [-0.08195035842577512, 0.8114098567240972]    0.364730
#  2                           [0.08971999183619098, nan]         NaN
#  3                           [-0.1521986072686567, nan]         NaN
#  4            [0.5539132959800068, 0.17347721413130804]    0.363695
#  ..                                                 ...         ...
#  193                          [nan, 0.8206885261347316]    0.820689
#  194                         [0.30463063096697934, nan]    0.304631
#  195  [0.988567913082453, 0.988567913082453, 0.98856...    0.988568
#  196        [-0.3205756882105908, -0.13910049944452824]   -0.229838
#  197                          [nan, 0.9214796362217057]    0.921480
#
#                                            base_nearest  \
#  0                                             [[], []]
#  1    [[(13th, 0.7039621103697957), (manufacturer, 0...
#  2    [[(Pidgin, 0.8793076767132633), (XVI, 0.859307...
#  3    [[(Osgood, 0.9849477404769564), (Malaysia, 0.9...
#  4    [[(names, 0.9780960737003606), (tradition, 0.9...
#  ..                                                 ...
#  193  [[(This, 0.9903826159179665), (It, 0.971381547...
#  194  [[(rated, 0.8808234973537351), (includes, 0.86...
#  195  [[(0+0+0, 0.9885679130824525), (1, 0.778348744...
#  196  [[(devastation, 0.8891073034809696), (Singapor...
#  197  [[(At, 0.9900549203808524), (throat, 0.9848346...
#
#                                             mwe_nearest
#  0    [(Mark+Messier, 0.9262575608495334), (Vancouve...
#  1    [(T, 0.9918041966772155), (GF, 0.9877717830239...
#  2    [(Curtis, 0.7790424911056579), (Angle, 0.76393...
#  3    [(Frank, 0.42707308006932293), (Dates, 0.40243...
#  4    [(ten, 0.756988776772198), (activities, 0.7528...
#  ..                                                 ...
#  193  [(American, 0.9709816287819463), (team, 0.9528...
#  194  [(on, 0.9588299710391347), (ends, 0.9552348298...
#  195  [(0, 0.9885679130824524), (1, 0.73562573277802...
#  196  [(joints, 0.9836249320773329), (United+Kingdom...
#  197  [(becomes, 0.9747979215018437), (Dallas+Stars,...
#
#  [198 rows x 12 columns],
#  1:                       ngram  freq      poisson  len  batch  stopwords  \
#  0                    (L, T)    10  -211.010565    2      2     [0, 0]
#  1                   (GP, W)    10  -214.966416    2      2     [0, 0]
#  2                (when, he)    10  -269.554796    2      2     [0, 0]
#  3      (uric, acid, levels)    10  -277.962019    3      2  [0, 0, 0]
#  4               (of, these)    10  -291.518121    2      2     [1, 0]
#  ..                      ...   ...          ...  ...    ...        ...
#  99                 (it, is)    40 -1132.620806    2      2     [0, 1]
#  100  (New, York, Islanders)    38 -1233.350960    3      2  [1, 0, 0]
#  101                (It, is)    48 -1345.008361    2      2     [0, 1]
#  102                  (0, 0)    55 -1370.329810    2      2     [0, 0]
#  103               (at, the)    57 -1708.491144    2      2     [0, 1]
#
#                                              mwe_vector  \
#  0    [-0.012918374073710055, 0.008979825634106911, ...
#  1    [-0.011915012207325193, 0.011129270482727119, ...
#  2    [-0.007699949034050872, 0.0038273084229464125,...
#  3    [-0.004301125460782326, 0.007909280007124268, ...
#  4    [0.0032213217847726866, -0.002868626550282752,...
#  ..                                                 ...
#  99   [-0.0015683957284120917, 0.024428521040677227,...
#  100  [-0.013548686006117807, 0.0019962447517514765,...
#  101  [-0.05920353641620884, 0.016746112615213464, 0...
#  102  [0.01331465984259551, 0.009532878112417223, -0...
#  103  [-0.028939319373032006, 0.026904580450567605, ...
#
#                                       component_vectors  \
#  0    [[0.0026337067286879897, -0.001807476375405401...
#  1    [[-0.013453194072812215, 0.0026905775519034717...
#  2    [[-0.024010446782271596, 0.03265735632682402, ...
#  3    [[0.027097967261355525, 0.03991489274593013, 0...
#  4    [[-0.12194928496152825, 0.1147937728791694, 0....
#  ..                                                 ...
#  99   [[-0.045264986206069155, 0.05019217716005367, ...
#  100  [[-0.07722722760691694, -0.08803908294788185, ...
#  101  [[-0.0426800301880667, 0.032340537987449784, 0...
#  102  [[-0.007128181659941991, 0.03046184069957738, ...
#  103  [[-0.0401944610990804, 0.004174223500522204, 0...
#
#                                        component_cosims  cosine_sim  \
#  0             [0.3394163054816177, 0.6909495028525203]    0.515183
#  1           [0.17099243036081002, 0.18002554452424274]    0.175509
#  2             [0.8407994368900283, 0.8714958261238558]    0.856148
#  3    [0.4217387661466663, 0.536467312349697, -0.080...    0.292609
#  4                           [nan, -0.3859870540765694]   -0.385987
#  ..                                                 ...         ...
#  99                           [0.8883033605347133, nan]    0.888303
#  100      [nan, 0.7339596506154029, 0.7077689313371025]    0.720864
#  101                          [0.8481439398796708, nan]    0.848144
#  102           [0.8066156572928341, 0.8066156572928341]    0.806616
#  103                          [0.9463607582786054, nan]    0.946361
#
#                                            base_nearest  \
#  0    [[(Sierra, 0.9508238782332877), (1908, 0.95034...
#  1    [[(Team, 0.951190630693225), (John, 0.92652555...
#  2    [[(1993–1994, 0.9729826099556375), (coached, 0...
#  3    [[(acid, 0.9772733019746099), (parts, 0.905709...
#  4    [[(thousands, 0.9864126360705939), (rules, 0.9...
#  ..                                                 ...
#  99   [[(aircraft, 0.9880225852480305), (but, 0.9868...
#  100  [[(York, 0.9827531013968259), (Orleans, 0.9705...
#  101  [[(takes, 0.9712295643502811), (east, 0.961022...
#  102  [[(Bowser, 0.8626426870114782), (Ghost, 0.8516...
#  103  [[(king, 0.9806558151015755), (killing, 0.9729...
#
#                                             mwe_nearest
#  0    [(Pts, 0.972790142475027), (GA, 0.966225470453...
#  1    [(L+T, 0.8879590051468478), (Boeing, 0.8177729...
#  2    [(causes, 0.979210275589754), (wrong, 0.979053...
#  3    [(described, 0.9656355858268794), (However, 0....
#  4    [(draft, 0.8565581363934359), (rank, 0.8470894...
#  ..                                                 ...
#  99   [(Additional, 0.9762186720172039), (children's...
#  100  [(Kansas, 0.8075971343446637), (Zealand, 0.769...
#  101  [(During, 0.983025479142399), (system, 0.97865...
#  102  [(1, 0.8656915253891557), (Choco, 0.8500036590...
#  103  [(Cambridge, 0.9866115080457639), (Nazarene, 0...
#
#  [104 rows x 12 columns],
#  2:                            ngram  freq      poisson  len  batch   stopwords  \
#  0                      (W, L, T)    10  -248.014962    3      3   [0, 0, 0]
#  1        (Great, American, Bash)    11  -312.030540    3      3   [0, 0, 0]
#  2                     (of, uric)    11  -321.276490    2      3      [1, 0]
#  3    (Gretzky, Edmonton, Oilers)    11  -335.837636    3      3   [0, 0, 0]
#  4                     (the, end)    12  -343.446628    2      3      [1, 0]
#  5                  (people, who)    13  -348.031001    2      3      [0, 0]
#  6         (the, United, Kingdom)    10  -350.641590    3      3   [1, 0, 0]
#  7                    (year, and)    12  -358.043379    2      3      [0, 1]
#  8                  (in, 1992–93)    13  -359.481684    2      3      [1, 0]
#  9             (tiger, shark, is)    11  -367.314540    3      3   [0, 0, 1]
#  10               (the, previous)    13  -367.882115    2      3     [1, -1]
#  11              (2007, 15, June)    11  -370.140956    3      3   [0, 0, 0]
#  12                (2010, August)    14  -388.907395    2      3      [0, 1]
#  13            (Francisco, 49ers)    18  -389.081333    2      3     [0, -1]
#  14              (17, 2010, June)    12  -392.736830    3      3   [0, 0, 0]
#  15                 (home, games)    17  -414.748819    2      3      [0, 0]
#  16                    (to, have)    14  -420.601195    2      3      [1, 0]
#  17              (2005, 14, July)    13  -422.167235    3      3   [0, 0, 0]
#  18             (York, New, York)    12  -424.441352    3      3   [0, 1, 0]
#  19  (Sportsmen's, Lodge, Studio)    17  -436.678776    3      3   [0, 0, 0]
#  20                    (14, June)    17  -443.144535    2      3      [0, 0]
#  21              (Hall, of, Fame)    14  -447.836387    3      3  [0, 1, -1]
#  22                (Bay, Packers)    20  -461.501225    2      3     [0, -1]
#  23              (as, Additional)    18  -463.020831    2      3      [1, 0]
#  24          (Colts, Quarterback)    20  -477.648324    2      3      [0, 0]
#  25              (18, 2010, June)    16  -520.161096    3      3   [0, 0, 0]
#  26                    (that, he)    19  -536.785580    2      3      [1, 0]
#  27       (Toronto, Maple, Leafs)    21  -580.780243    3      3   [0, 0, 0]
#  28             (Other, websites)    28  -627.843568    2      3     [0, -1]
#  29             (Youth, in, Film)    20  -658.890064    3      3   [0, 1, 0]
#  30                     (a, time)    27  -771.045937    2      3      [1, 0]
#  31              (the, same, day)    23  -795.782186    3      3   [1, 0, 0]
#  32               (Young, Artist)    35  -796.414279    2      3      [0, 0]
#  33                  (Red, Wings)    44 -1003.729181    2      3     [0, -1]
#  34                   (San, Jose)    47 -1109.133390    2      3      [0, 0]
#  35                 (New, Jersey)    46 -1153.332484    2      3      [1, 0]
#  36         (the, United, States)    36 -1255.989146    3      3   [1, 0, 0]
#  37                   (St, Louis)    66 -1545.916981    2      3      [0, 0]
#  38                (Los, Angeles)    70 -1624.041450    2      3     [-1, 0]
#  39                      (to, be)    64 -1814.837328    2      3      [1, 0]
#
#                                             mwe_vector  \
#  0   [-0.026279200244094202, 0.014395873677039683, ...
#  1   [-0.046179555988589575, -0.02803560476290589, ...
#  2   [0.053723967507736135, 0.012251386201138857, -...
#  3   [-0.02148625310043265, -0.009956966683063097, ...
#  4   [-0.004171275252475687, -0.0063218300159643415...
#  5   [0.0066264203009543535, -0.013750749941186354,...
#  6   [-0.015562497471596307, -0.037599894394753995,...
#  7   [-0.02254253894179163, -0.023089095965179884, ...
#  8   [-0.018604897442211416, -0.050572900071016336,...
#  9   [-0.0022705593172643378, -0.01814460623203236,...
#  10  [-0.016931643832451763, -0.009108724955160715,...
#  11  [-0.0043793115925271275, -0.006330489899206416...
#  12  [0.009043424548027536, 0.0070321876496189754, ...
#  13  [0.01728087170388425, 0.03524032929776525, -0....
#  14  [0.0022361548118057495, 0.01285758693765224, -...
#  15  [-0.08929920910504081, -0.05567070641093001, 0...
#  16  [0.0020573690736804557, -0.012247695342576394,...
#  17  [0.003661426685947644, 0.009535088641732732, -...
#  18  [0.07436535198326345, -0.028210357983047378, 0...
#  19  [0.04800594614449712, -0.04699323991245069, 0....
#  20  [-0.022440926522866143, -0.020147033882468496,...
#  21  [0.04434303734402569, -0.019466365367051645, 0...
#  22  [0.0563880031126483, 0.032289902207578894, 0.0...
#  23  [0.0005012119474685803, -0.005083549089585552,...
#  24  [-0.02359507922556534, 0.022307208016919714, -...
#  25  [0.0003227043738707951, 0.00633665755871058, -...
#  26  [-0.018328703571799568, -0.04825296571608704, ...
#  27  [-0.011795385443088379, -0.033703078113200884,...
#  28  [1.5956474971448495e-05, 0.020579666188037783,...
#  29  [0.03273351175535277, 0.018483838996389595, 0....
#  30  [-0.06372400169475782, -0.08584159824635836, 0...
#  31  [-0.05393282748332038, -0.046240338293284125, ...
#  32  [0.07117133170985188, 0.025039438527241796, 0....
#  33  [0.019388547720146393, 0.054319095768703377, -...
#  34  [0.019727348235878454, 0.0667954669802544, 0.0...
#  35  [0.06466790113845274, -0.014289334185825583, 0...
#  36  [-0.020557181374409744, -0.05837112402549675, ...
#  37  [0.07539281021961772, 0.06692290924213144, -0....
#  38  [0.0021067988449013195, 0.04749640415471446, 0...
#  39  [-0.027494756090118158, -0.04840663617857405, ...
#
#                                      component_vectors  \
#  0   [[0.006921958702574569, 0.008492503046653358, ...
#  1   [[0.05340038082614382, -0.0043912670593929766,...
#  2   [[-0.06305990868565883, 0.004065998493080306, ...
#  3   [[-0.014043470663968105, 0.008868136397800512,...
#  4   [[0.3893307958773947, -0.11579376903174865, 0....
#  5   [[-0.027864442443071236, -0.0706966742520734, ...
#  6   [[0.3893307958773947, -0.11579376903174865, 0....
#  7   [[0.001763271772868603, -0.039967275486426423,...
#  8   [[-0.002392881533077321, -0.12774953186698287,...
#  9   [[0.020819924826555952, -0.003992447313739142,...
#  10  [[0.3893307958773947, -0.11579376903174865, 0....
#  11  [[-0.009102662218210263, 0.021045636747697702,...
#  12  [[-0.0185334063408193, 0.014963463991272628, -...
#  13  [[0.010263150411462295, 0.014292482682518176, ...
#  14  [[0.00580272437476786, 0.010988590086914713, -...
#  15  [[-0.09212437408701497, -0.06367954086743038, ...
#  16  [[-0.15119329815265056, -0.2306927045126063, 0...
#  17  [[0.014694199605936613, 0.001138378978531352, ...
#  18  [[0.1713675949385075, -0.09105876302751488, 0....
#  19  [[0.01799595423840877, 0.007793377069533704, -...
#  20  [[0.0037506880167487767, -0.001493313891484807...
#  21  [[0.012710657857596966, 0.0013709913088620347,...
#  22  [[-0.06558889990656604, 0.19545851922100937, -...
#  23  [[-0.07149590452919577, -0.05571848801104168, ...
#  24  [[-0.006775878450828851, 0.0067192438555036095...
#  25  [[0.013716080562963003, -0.014537502171077866,...
#  26  [[-0.09132372057422736, -0.1009566915147977, 0...
#  27  [[0.030974444152596665, 0.02660185287396765, -...
#  28  [[0.00744575047979362, 0.007678585941666208, -...
#  29  [[0.03307993185842326, 0.00997981773054292, -0...
#  30  [[-0.32533087083828194, -0.12107673715520417, ...
#  31  [[0.3893307958773947, -0.11579376903174865, 0....
#  32  [[-0.0004792582722052097, -0.01618398772473471...
#  33  [[0.02598073231304448, -0.0029755465537395043,...
#  34  [[0.0372446327868641, 0.04075058886369996, -0....
#  35  [[0.1793828742004378, -0.1063327874715215, 0.1...
#  36  [[0.3893307958773947, -0.11579376903174865, 0....
#  37  [[0.0002668053118979042, -0.000954275108867589...
#  38  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  39  [[-0.15119329815265056, -0.2306927045126063, 0...
#
#                                       component_cosims  cosine_sim  \
#  0   [0.2267180413583813, 0.1472021649026936, 0.512...    0.295415
#  1   [0.23735026488320715, 0.8788818787575259, 0.53...    0.550656
#  2                           [nan, 0.7858702387399774]    0.785870
#  3   [0.17660061873484997, -0.49658193938695466, -0...   -0.217209
#  4                           [nan, 0.2581703191539688]    0.258170
#  5            [0.8883580317017596, 0.7924550620790334]    0.840407
#  6      [nan, 0.4191482897096324, 0.18204315077044064]    0.300596
#  7                           [0.9319588728212482, nan]    0.931959
#  8                           [nan, 0.9163751816176149]    0.916375
#  9        [0.7630653961828208, 0.828947789771007, nan]    0.796007
#  10                                         [nan, nan]         NaN
#  11  [0.9594291845275404, 0.854793291552941, 0.8038...    0.872686
#  12                          [0.8251145562072434, nan]    0.825115
#  13                          [0.8028340136911605, nan]         NaN
#  14  [0.9044210074327039, 0.945604251304183, 0.9412...    0.930432
#  15           [0.9478093815118835, 0.9311731466544567]    0.939491
#  16                          [nan, 0.7370812386118818]    0.737081
#  17  [0.9366388500878217, 0.8264057424008395, 0.941...    0.901394
#  18      [0.9495888367810921, nan, 0.9495888367810921]    0.949589
#  19  [-0.1629457441862337, -0.21336787338800955, -0...   -0.215552
#  20           [0.8597672338976591, 0.7640986220457742]    0.811933
#  21                     [0.5413918671167589, nan, nan]         NaN
#  22                          [0.2654994780695441, nan]         NaN
#  23                         [nan, -0.1287679183198176]   -0.128768
#  24          [0.9154791202160977, 0.13564734628976025]    0.525563
#  25  [0.8023335131673284, 0.958672350409608, 0.9255...    0.895508
#  26                          [nan, 0.9528810839469286]    0.952881
#  27  [-0.68336578756492, -0.9350987134477019, 0.513...   -0.368416
#  28                          [0.8309378812049709, nan]         NaN
#  29      [0.4454322796708093, nan, 0.6156803922308872]    0.530556
#  30                          [nan, 0.6893177962341589]    0.689318
#  31      [nan, 0.5716534279848068, 0.8371667387648574]    0.704410
#  32      [-0.019323250566083708, -0.06824340706312641]   -0.043783
#  33                         [-0.3062697351150283, nan]         NaN
#  34           [0.5561707621869195, 0.6935653609716554]    0.624868
#  35                          [nan, 0.7107735956299907]    0.710774
#  36      [nan, 0.2788537030013459, 0.4268721342627334]    0.352863
#  37           [-0.527247959026585, 0.6465977349070773]    0.059675
#  38                         [nan, 0.41867659035275395]         NaN
#  39                          [nan, 0.7325810981796774]    0.732581
#
#                                           base_nearest  \
#  0   [[(reaction, 0.9750451280654572), (Apostolic, ...
#  1   [[(entered, 0.9816398974389569), (urine, 0.978...
#  2   [[(thousands, 0.9875794163735996), (accusation...
#  3   [[(musical, 0.7229806170366736), (Summary, 0.7...
#  4   [[(U.S, 0.988293918029009), (skin, 0.984940471...
#  5   [[(children, 0.980090555423704), (out, 0.97940...
#  6   [[(U.S, 0.988293918029009), (skin, 0.984940471...
#  7   [[(at, 0.9640141854139672), (family, 0.9624258...
#  8   [[(1931, 0.9565913741107965), (falls, 0.941697...
#  9   [[(shark, 0.9717271661203251), (second, 0.9617...
#  10  [[(U.S, 0.988293918029009), (skin, 0.984940471...
#  11  [[(2007+15+June, 0.9594291845275404), (14+June...
#  12  [[(29, 0.9680127977861147), (24, 0.96611710726...
#  13  [[(full, 0.923278087266246), (Edinburgh, 0.922...
#  14  [[(28, 0.9870935059289792), (9, 0.984756201354...
#  15  [[(together, 0.9678002261336864), (taken, 0.96...
#  16  [[(trying, 0.9800638580924572), (treat, 0.9751...
#  17  [[(July, 0.9717666471092555), (8, 0.9588141999...
#  18  [[(Giants, 0.9875568289766052), (New, 0.985511...
#  19  [[(year's, 0.9791429614399906), (whale's, 0.97...
#  20  [[(23, 0.9850090868776354), (18+2010+June, 0.9...
#  21  [[(Golden, 0.8781747903366315), (Convention, 0...
#  22  [[(Tampa, 0.9936292374764139), (Lightning, 0.9...
#  23  [[(such, 0.9895736847774066), (well, 0.9856779...
#  24  [[(Allen, 0.961959470545664), (Pete, 0.9568559...
#  25  [[(Day, 0.9314413079167067), (11, 0.9173484091...
#  26  [[(written, 0.9618153040623456), (time, 0.9602...
#  27  [[(Montreal, 0.9350140989139567), (Canadiens, ...
#  28  [[(Princess, 0.8960281814655261), (lunar, 0.88...
#  29  [[(Church, 0.878505261137787), (main, 0.873958...
#  30  [[(small, 0.9676527795119118), (big, 0.9538018...
#  31  [[(U.S, 0.988293918029009), (skin, 0.984940471...
#  32  [[(Best, 0.9427013438850893), (Germans, 0.9264...
#  33  [[(fighting, 0.9786937380642113), (moon, 0.974...
#  34  [[(Francisco+49ers, 0.9645290239253537), (Dieg...
#  35  [[(York, 0.9855117678725727), (Bossy, 0.981499...
#  36  [[(U.S, 0.988293918029009), (skin, 0.984940471...
#  37  [[(parts, 0.9342590253513363), (Republic, 0.93...
#  38  [[], [(2003—New, 0.8343377398117073), (phone, ...
#  39  [[(trying, 0.9800638580924572), (treat, 0.9751...
#
#                                            mwe_nearest
#  0   [(Pts, 0.970539658365272), (Score, 0.905511390...
#  1   [(statistics, 0.9642750558676977), (Love, 0.95...
#  2   [(Also, 0.9308030998215516), (aviation, 0.9177...
#  3   [(37, 0.8447742373195203), (114)‡†, 0.84054473...
#  4   [(date, 0.982045426862491), (One, 0.9775144353...
#  5   [(four, 0.9645050376024581), (members, 0.95722...
#  6   [(Germany, 0.9693225984904213), (Abraham, 0.96...
#  7   [(French, 0.9742117308367821), (one, 0.9410068...
#  8   [(1992–1993, 0.9939574847882985), (coached, 0....
#  9   [(Suspect, 0.9639719802029696), (The, 0.957894...
#  10  [(Alabama, 0.9506152027420796), (founding, 0.9...
#  11  [(14+June, 0.9961860149374446), (2007, 0.95942...
#  12  [(Earth, 0.9469882609542948), (42, 0.933974039...
#  13  [(San, 0.9645290239253536), (Chargers, 0.91809...
#  14  [(29, 0.9851641759687784), (42, 0.967382558477...
#  15  [(Various, 0.9921597388298011), (match, 0.9841...
#  16  [(best, 0.9138043507079688), (rocket, 0.905872...
#  17  [(17+2010+June, 0.963029121471114), (29, 0.951...
#  18  [(1994—New, 0.9863829367557636), (Islanders, 0...
#  19  [(Oklahoma, 0.9338294662858905), (Recap, 0.894...
#  20  [(2007+15+June, 0.9961860149374449), (21, 0.95...
#  21  [(west, 0.9803443889107858), (water, 0.9802559...
#  22  [(Green, 0.9829331004187494), (Quarterback, 0....
#  23  [(Fever, 0.9447073096606685), (Fieldhouse, 0.9...
#  24  [(Baltimore, 0.9687878052613932), (aborigines,...
#  25  [(14, 0.9839182536870394), (22, 0.979549623233...
#  26  [(said, 0.9806746428057477), (he, 0.9528810839...
#  27  [(Pakistan, 0.9807094814512359), (men, 0.98018...
#  28  [(Sacramento, 0.9228673863001471), (Luther, 0....
#  29  [(Awards, 0.9464260294761673), (Young+Artist, ...
#  30  [(others, 0.9773616229793592), (goes, 0.972880...
#  31  [(1993–1994, 0.9336814148092425), (cheating, 0...
#  32  [(Awards, 0.9833146823921606), (Youth+in+Film,...
#  33  [(Lions, 0.9767235905343402), (Detroit, 0.9705...
#  34  [(Sharks, 0.9629356291499188), (83, 0.88447917...
#  35  [(106, 0.9628763092025862), (Nassau, 0.9524694...
#  36  [(diet, 0.9672876498693875), (set, 0.963797143...
#  37  [(Blues, 0.9660693349435917), (Rams, 0.9429070...
#  38  [(Kings, 0.9524524033637217), (Phoenix, 0.8288...
#  39  [(given, 0.9650911483987703), (added, 0.962640...  ,
#  3:                       ngram  freq      poisson  len  batch   stopwords  \
#  0                (GP, W, L)    10  -250.816041    3      4   [0, 0, 0]
#  1    (The, Great, American)    10  -340.632198    3      4   [1, 0, 0]
#  2          (15, June, 2007)    11  -370.140956    3      4   [0, 0, 0]
#  3          (of, uric, acid)    11  -377.238581    3      4   [1, 0, 0]
#  4          (2010, June, 17)    12  -392.736830    3      4   [0, 0, 0]
#  5               (shark, is)    14  -393.923838    2      4      [0, 1]
#  6     (the, previous, year)    12  -412.969217    3      4   [1, 0, 0]
#  7          (14, July, 2005)    13  -422.167235    3      4   [0, 0, 0]
#  8          (New, York, New)    12  -431.627368    3      4   [1, 0, 1]
#  9        (home, games, for)    14  -464.532922    3      4   [0, 0, 1]
#  10    (Lodge, Studio, City)    17  -466.844261    3      4   [0, 0, 0]
#  11             (Green, Bay)    20  -474.146589    2      4      [0, 0]
#  12        (also, known, as)    14  -491.207446    3      4   [0, 0, 1]
#  13         (14, June, 2007)    15  -498.377667    3      4   [0, 0, 0]
#  14  (San, Francisco, 49ers)    18  -506.221637    3      4  [0, 0, -1]
#  15         (2010, June, 18)    16  -520.161096    3      4   [0, 0, 0]
#  16         (Wayne, Gretzky)    24  -524.112529    2      4     [0, -1]
#  17               (week, as)    23  -597.535308    2      4      [0, 1]
#  18              (found, in)    22  -622.786623    2      4      [0, 1]
#  19                (he, was)    24  -680.163444    2      4      [0, 1]
#  20               (such, as)    27  -699.043216    2      4      [0, 1]
#  21               (time, to)    27  -772.034312    2      4      [0, 1]
#  22             (Tampa, Bay)    41  -948.894734    2      4      [0, 0]
#  23              (the, same)    36 -1020.173493    2      4      [1, 0]
#  24       (Edmonton, Oilers)    49 -1165.732218    2      4      [0, 0]
#  25            (the, United)    46 -1327.676155    2      4      [1, 0]
#
#                                             mwe_vector  \
#  0   [0.02872756104511954, -5.894815816119319e-05, ...
#  1   [0.04319345204207089, 0.0020924494005186253, 0...
#  2   [-0.00937830097991947, 0.00420598660688323, 0....
#  3   [-0.009049184380859231, 0.00043392499745101184...
#  4   [-0.017411035173769893, 0.015011116711357795, ...
#  5   [-0.008724807190378624, -0.029667241655262546,...
#  6   [0.0004449044234036423, -0.01846406931682113, ...
#  7   [-0.03025878829281293, 0.013255788265246213, 0...
#  8   [-0.026789974482065347, -0.07097151760328271, ...
#  9   [-0.013090192542798291, 0.0026026643778057053,...
#  10  [0.012441360229282232, 0.013641470936495922, -...
#  11  [-0.022925275821104773, 0.008190951056400329, ...
#  12  [0.010134893216699827, -0.016326654348230447, ...
#  13  [-0.011435194862934851, 0.006138667650349602, ...
#  14  [0.005371123231108705, 0.027393021203979736, 0...
#  15  [-0.03133013567950913, 0.014608221838010653, 0...
#  16  [-0.024944635927258364, 0.003236033274263104, ...
#  17  [-0.0594841302654391, -0.029141265764993735, -...
#  18  [-0.004488128517752302, -0.007352979796534909,...
#  19  [-0.01010859545441909, 0.019632613705015137, 0...
#  20  [-0.03698001672873067, 0.0031370818770169047, ...
#  21  [0.04466750538894569, 0.05698233025519152, 0.1...
#  22  [0.04287951950813897, 0.08851182385092148, 0.0...
#  23  [-0.1039027121351032, 0.04837425154474007, -0....
#  24  [-0.010814077620167227, -0.005586323227459892,...
#  25  [0.023566577566079213, 0.102325755924031, 0.01...
#
#                                      component_vectors  \
#  0   [[0.00612001785402125, -0.0027845026301122604,...
#  1   [[-0.03331805045259435, 0.009360739900312588, ...
#  2   [[-0.12612308754145568, 0.0376887184459382, 0....
#  3   [[-0.1713189720596116, -0.4073682587485101, -0...
#  4   [[-0.10953161272499543, 0.06659985305053061, 0...
#  5   [[-0.03259542298735735, -0.024419709345014837,...
#  6   [[-0.3710507626693041, -0.3890250850037543, -0...
#  7   [[-0.07392997751010993, 0.041391994584474914, ...
#  8   [[-0.14763445016171747, -0.18135917016972383, ...
#  9   [[-0.014588117533621906, 0.03694390099765167, ...
#  10  [[-0.0015071906608475822, -0.01098758176944736...
#  11  [[0.004267123362532432, 0.012634924654002901, ...
#  12  [[0.011258963823416833, -0.010984089172876695,...
#  13  [[-0.07392997751010993, 0.041391994584474914, ...
#  14  [[0.0031820635947512653, 0.02318356183838844, ...
#  15  [[-0.10953161272499543, 0.06659985305053061, 0...
#  16  [[0.007506235904950404, 0.007504897812486461, ...
#  17  [[-0.000386293047763245, -0.004877119248984554...
#  18  [[0.0003994255900679133, 0.023740545288628533,...
#  19  [[-0.00389085709047278, 0.06459928017438409, 0...
#  20  [[-0.00035644457388611683, -0.0100990544634104...
#  21  [[-0.014482608947673177, -0.00424082640972268,...
#  22  [[0.00479167179492983, 0.0047901749436713775, ...
#  23  [[-0.3710507626693041, -0.3890250850037543, -0...
#  24  [[0.006407001942733859, -0.02663619354727328, ...
#  25  [[-0.3710507626693041, -0.3890250850037543, -0...
#
#                                       component_cosims  cosine_sim  \
#  0   [0.2524316789161351, -0.11158361713370603, -0....   -0.040080
#  1   [nan, -0.5717702639374941, -0.040873252846251575]   -0.306322
#  2   [0.8991398840435927, 0.8083632200559987, 0.911...    0.873016
#  3        [nan, 0.8478614929796369, 0.861651627698514]    0.854757
#  4   [0.9730311025283509, 0.9357179596459755, 0.942...    0.950325
#  5                            [0.898051821180911, nan]    0.898052
#  6      [nan, -0.7497456719698326, 0.6929350075071453]   -0.028405
#  7   [0.9118741126684156, 0.9573186930796993, 0.955...    0.941633
#  8                      [nan, 0.9435684097074714, nan]    0.943568
#  9       [0.8102386723190274, 0.7731686999542094, nan]    0.791704
#  10  [-0.27344357258245566, -0.09418310847773524, 0...    0.051747
#  11         [-0.21340125444918143, 0.4229523213201938]    0.104776
#  12      [0.5710685353065046, 0.5655814572895941, nan]    0.568325
#  13  [0.8849118972922221, 0.8507496591110117, 0.967...    0.900905
#  14   [-0.45764463749251244, -0.3399606468102339, nan]         NaN
#  15  [0.9809686857271864, 0.929190359130079, 0.8298...    0.913334
#  16                         [-0.8568877000927826, nan]         NaN
#  17                          [0.5653712793265019, nan]    0.565371
#  18                          [0.8285555599050655, nan]    0.828556
#  19                          [0.9557977665256929, nan]    0.955798
#  20                        [-0.33136243450765135, nan]   -0.331362
#  21                          [0.7391537852505284, nan]    0.739154
#  22           [0.4391733330971376, 0.2928202862378737]    0.365997
#  23                        [nan, -0.47414632517034605]   -0.474146
#  24         [0.27241241789367077, 0.14693657762158477]    0.209674
#  25                          [nan, 0.9491799109663837]    0.949180
#
#                                           base_nearest  \
#  0   [[(executed, 0.9506239350614152), (retired, 0....
#  1   [[(NHL's, 0.9413557931508919), (Suspect, 0.940...
#  2   [[(14, 0.9537495023388705), (2010+June+18, 0.9...
#  3   [[(types, 0.9742015859488904), (parts, 0.97361...
#  4   [[(2010+June+18, 0.9809686857271859), (29, 0.9...
#  5   [[(original, 0.9808507519775069), (largest, 0....
#  6   [[(Israelites, 0.978917830378362), (stomach, 0...
#  7   [[(2010+June+18, 0.9843646776792867), (16, 0.9...
#  8   [[(Bossy, 0.9842850311554247), (York, 0.981363...
#  9   [[(popular, 0.9776641415268167), (good, 0.9740...
#  10  [[(excellent, 0.9622662117332458), (whale's, 0...
#  11  [[(Jessica, 0.8496366739071434), (Hungarians, ...
#  12  [[(commonly, 0.9673142759554424), (Rena, 0.964...
#  13  [[(2010+June+18, 0.9843646776792867), (16, 0.9...
#  14  [[(Diego, 0.9677028861259679), (Jose, 0.913676...
#  15  [[(2010+June+18, 0.9809686857271859), (29, 0.9...
#  16  [[(Colony, 0.9843286728854781), (ferocious, 0....
#  17  [[(Seahawks, 0.9213591961729101), (GP, 0.91341...
#  18  [[(performed, 0.976456237482818), (changed, 0....
#  19  [[(said, 0.9639162641555811), (would, 0.960946...
#  20  [[(3%, 0.9552798625276913), (provider, 0.94718...
#  21  [[(character, 0.976806457084224), (dropped, 0....
#  22  [[(immunodeficiency, 0.9613264083043531), (SEE...
#  23  [[(Israelites, 0.978917830378362), (stomach, 0...
#  24  [[(1994—New, 0.9349988357781235), (1925, 0.934...
#  25  [[(Israelites, 0.978917830378362), (stomach, 0...
#
#                                            mwe_nearest
#  0   [(T, 0.9010403620958075), (2.50, 0.87633002387...
#  1   [(Pts, 0.8659980360603422), (Lesnar, 0.8596121...
#  2   [(14+June+2007, 0.9801392577828217), (21, 0.96...
#  3   [(pitcher, 0.9307943765793399), (Ljubljana, 0....
#  4   [(29, 0.9799779614943758), (2010, 0.9730311025...
#  5   [(tiger, 0.9609967161788979), (main, 0.9284421...
#  6   [(Africa, 0.9594176452823353), (several, 0.953...
#  7   [(2010+June+17, 0.9669216580438329), (29, 0.96...
#  8   [(Rangers, 0.9869706292180775), (Islanders, 0....
#  9   [(Various, 0.9895061591755736), (2012–13, 0.97...
#  10  [(Unknown, 0.9187908983607515), (Pixar, 0.9152...
#  11  [(Packers, 0.9801593391527709), (Cleveland, 0....
#  12  [(airport, 0.9428710197931488), (Buzz, 0.91856...
#  13  [(15+June+2007, 0.9801392577828218), (2007, 0....
#  14  [(Quarterback, 0.8223574660226559), (33, 0.627...
#  15  [(14, 0.9843646776792868), (16, 0.981257131074...
#  16  [(Vézina, 0.943992405727727), (pain, 0.9432038...
#  17  [(release, 0.9809317149570013), (area, 0.96886...
#  18  [(which, 0.9784033775272015), (it, 0.977098052...
#  19  [(when, 0.9706685319865209), (lied, 0.97048885...
#  20  [(wife, 0.979074178025735), (including, 0.9620...
#  21  [(TV, 0.9769634719801155), (video, 0.968632704...
#  22  [(Lightning, 0.8769624320260094), (Florida, 0....
#  23  [(day, 0.9637542480846016), (finishes, 0.90435...
#  24  [(Recap, 0.7842213594480566), (City, 0.7831962...
#  25  [(States, 0.9962325398646149), (United, 0.9491...  ,
#  4:                     ngram  freq      poisson  len  batch   stopwords  \
#  0              (list, of)    14  -387.329394    2      5     [-1, 1]
#  1              (15, June)    15  -393.366583    2      5      [0, 0]
#  2          (the, end, of)    10  -395.193048    3      5   [1, 0, 1]
#  3      (is, an, American)    11  -403.527606    3      5   [1, 0, 0]
#  4        (July, 2005, 14)    13  -422.167235    3      5   [0, 0, 0]
#  5          (a, group, of)    11  -426.443435    3      5   [1, 0, 1]
#  6          (tiger, shark)    20  -460.837888    2      5      [0, 0]
#  7        (2007, 14, June)    15  -498.377667    3      5   [0, 0, 0]
#  8           (is, one, of)    13  -520.108868    3      5   [1, 0, 1]
#  9   (Green, Bay, Packers)    20  -560.585151    3      5  [0, 0, -1]
#  10     (in, Film, Awards)    20  -684.382512    3      5   [1, 0, 0]
#  11           (uric, acid)    32  -707.780159    2      5     [-1, 0]
#  12              (day, of)    25  -715.930973    2      5      [0, 1]
#  13          (a, time, to)    20  -776.651334    3      5   [1, 0, 1]
#  14        (the, week, as)    21  -784.958950    3      5   [1, 0, 1]
#  15            (known, as)    34  -907.364703    2      5      [0, 1]
#  16           (2010, June)    39 -1001.133019    2      5      [0, 0]
#  17       (University, of)    58 -1704.815272    2      5      [0, 1]
#  18            (New, York)   132 -3273.884672    2      5      [1, 0]
#
#                                             mwe_vector  \
#  0   [-0.0478365676548489, -0.042187529055531595, 0...
#  1   [0.14841473143129263, -0.11156285199052568, 0....
#  2   [0.016749117157921514, -0.01280700292198056, 0...
#  3   [-0.008927658637190507, 0.01801382695669636, -...
#  4   [0.03193493625128913, -0.016821474636477377, 0...
#  5   [-0.01952184177537236, 0.0028584115059364966, ...
#  6   [-0.030318859787140266, -0.0733129396932527, 0...
#  7   [0.05280735245138808, -0.03644744217920578, 0....
#  8   [0.01122899230694465, -0.018165288790717805, -...
#  9   [0.005809796017794592, -0.004705027907995925, ...
#  10  [-0.033854076440908994, 0.006527465479883144, ...
#  11  [0.07802336473741502, -0.06264146420885824, 0....
#  12  [0.009538560074008533, 4.916590332817494e-05, ...
#  13  [0.06824851972555732, -0.041830914472053664, 0...
#  14  [-0.001441763062975226, 0.0021090463994459965,...
#  15  [-0.006140118618973477, -0.03226843868851842, ...
#  16  [0.09792072196568435, 0.030289820768360513, 0....
#  17  [-0.002118733038692456, 0.021314977658012903, ...
#  18  [0.2499938513834773, -0.18124199591665094, -0....
#
#                                      component_vectors  \
#  0   [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  1   [[0.10279807428577019, -0.09813192320599208, 0...
#  2   [[0.31519462365374845, -0.15529002198297334, 0...
#  3   [[-0.12923604933878316, -0.19048118900867683, ...
#  4   [[0.1266840830991826, -0.13152182416159408, 0....
#  5   [[-0.004852577786557259, -0.11526592191042541,...
#  6   [[-0.002383398059354614, 0.0025087023735717844...
#  7   [[0.21000641677442472, -0.14106180797930046, 0...
#  8   [[-0.12923604933878316, -0.19048118900867683, ...
#  9   [[-0.00737653836646296, 0.004573078143159853, ...
#  10  [[0.3935717558084504, -0.08621236451172133, -0...
#  11  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  12  [[0.02376156803115064, -0.03942925037233742, 0...
#  13  [[-0.004852577786557259, -0.11526592191042541,...
#  14  [[0.31519462365374845, -0.15529002198297334, 0...
#  15  [[-0.016737799575819473, -0.018212321617694396...
#  16  [[0.15279673655753323, -0.09423958788531397, 0...
#  17  [[0.006463337755480655, 0.012058389048645864, ...
#  18  [[0.04269558931016827, -0.05329703992424734, 0...
#
#                                       component_cosims  cosine_sim  \
#  0                                          [nan, nan]         NaN
#  1            [0.8513097072965772, 0.8965689927867697]    0.873939
#  2                      [nan, 0.8865085959339649, nan]    0.886509
#  3     [nan, -0.4513940344848785, -0.4346851281142025]   -0.443040
#  4   [0.8878168062454241, 0.8919850471679746, 0.849...    0.876559
#  5                      [nan, 0.6549041638403428, nan]    0.654904
#  6             [0.406718745732928, 0.7392035697269846]    0.572961
#  7   [0.9778411355247747, 0.9422717648961314, 0.930...    0.950266
#  8                       [nan, 0.548025911656137, nan]    0.548026
#  9   [-0.03684059255920609, 0.010752327943081431, nan]         NaN
#  10     [nan, 0.3146411961399528, 0.43736608352759465]    0.376004
#  11                         [nan, -0.8251823740132433]         NaN
#  12                         [0.48769704345708376, nan]    0.487697
#  13                     [nan, 0.6179203401569167, nan]    0.617920
#  14                     [nan, 0.6482254688132594, nan]    0.648225
#  15                          [0.8695448097655196, nan]    0.869545
#  16          [0.42786658687926427, 0.3661001603080456]    0.396983
#  17                          [0.1092866026055559, nan]    0.109287
#  18                          [nan, 0.1357257486677531]    0.135726
#
#                                           base_nearest  \
#  0   [[], [(date, 0.9781303465504174), (thousands, ...
#  1   [[(7, 0.9511938129181027), (2010, 0.9480015536...
#  2   [[(hospital, 0.9789726480820622), (outer, 0.97...
#  3   [[(This, 0.9816403307440209), (stars, 0.963525...
#  4   [[(2005, 0.9913493748386752), (8, 0.9156407493...
#  5   [[(small, 0.9636212614559185), (young, 0.96100...
#  6   [[(never, 0.8526741943708466), (telegraphs, 0....
#  7   [[(2007+14+June, 0.9778411355247747), (15+June...
#  8   [[(This, 0.9816403307440209), (stars, 0.963525...
#  9   [[(cancer, 0.8337671559358109), (Stephen, 0.82...
#  10  [[(resulting, 0.9716799076717068), (Kummersdor...
#  11  [[], [(faces, 0.9867036729940202), (γραφή, 0.9...
#  12  [[(without, 0.9815613402479416), (example, 0.9...
#  13  [[(small, 0.9636212614559185), (young, 0.96100...
#  14  [[(hospital, 0.9789726480820622), (outer, 0.97...
#  15  [[(given, 0.969703204710792), (Telegraphs, 0.9...
#  16  [[(16, 0.9710835990020584), (9, 0.967623050978...
#  17  [[(State, 0.9207421630478144), (Nazarene, 0.88...
#  18  [[(Zealand, 0.9522972498826571), (Brady, 0.900...
#
#                                            mwe_nearest
#  0   [(Genesis, 0.9886967544118258), (band, 0.98423...
#  1   [(2007+14+June, 0.9937352440203975), (2007, 0....
#  2   [(Mississippi, 0.9545092327811603), (Wii, 0.94...
#  3   [(Burn, 0.9313857418693987), (Pass, 0.92982966...
#  4   [(29, 0.9581082491391414), (1912, 0.9394079520...
#  5   [(changed, 0.9803376538358666), (easier, 0.962...
#  6   [(statistics, 0.9650409298935124), (program, 0...
#  7   [(15+June, 0.9937352440203974), (2007, 0.97784...
#  8   [(night, 0.9795713252505085), (makes, 0.977261...
#  9   [(Browns, 0.7852961800537585), (Quarterback, 0...
#  10  [(Youth, 0.8970529088941054), (CM, 0.856571168...
#  11  [(levels, 0.9522542114180192), (species, 0.951...
#  12  [(the+week+as, 0.9789557049137323), (same, 0.9...
#  13  [(again, 0.9792062548116327), (alcohol, 0.9687...
#  14  [(day+of, 0.9789557049137324), (same, 0.929800...
#  15  [(reason, 0.9646042165136527), (commonly, 0.96...
#  16  [(17, 0.9083792149121932), (24, 0.891132622241...
#  17  [(Ambassador, 0.8910818267737052), (calendar, ...
#  18  [(Giants, 0.9669017279544284), (Islanders, 0.9...  ,
#  5:                ngram  freq      poisson  len  batch  stopwords  \
#  0      (is, a, list)    11  -403.393918    3      6  [1, 1, 0]
#  1   (June, 17, 2010)    13  -423.963695    3      6  [0, 0, 0]
#  2        (group, of)    16  -454.740364    2      6     [0, 1]
#  3   (June, 2007, 14)    15  -498.377667    3      6  [0, 0, 0]
#  4  (games, for, the)    15  -578.519771    3      6  [0, 1, 1]
#  5   (June, 18, 2010)    18  -582.122583    3      6  [0, 0, 0]
#  6    (same, day, of)    22  -748.684571    3      6  [0, 0, 1]
#  7    (part, of, the)    19  -754.885370    3      6  [0, 1, 1]
#  8     (one, of, the)    19  -783.579070    3      6  [0, 1, 1]
#  9       (July, 2005)    46 -1136.065870    2      6     [0, 0]
#
#                                            mwe_vector  \
#  0  [-0.018015273626072456, 0.052993548303743046, ...
#  1  [0.006937166637317753, -0.002770240257431423, ...
#  2  [0.003985015743750933, 0.017570437787242273, 0...
#  3  [-0.0038246842005327294, -0.006219638627584587...
#  4  [0.019274815262729995, -0.023717171038538067, ...
#  5  [-0.006090609223208483, 0.0028216847765268832,...
#  6  [-0.017418421481648818, -0.04056843162067509, ...
#  7  [-0.0031442909531299826, -0.002459980840358969...
#  8  [0.018465817079981867, 0.02456736460984812, 0....
#  9  [0.016298766795593507, -0.07777904658930945, -...
#
#                                     component_vectors  \
#  0  [[0.06512042820524869, 0.08258108172792027, 0....
#  1  [[-0.05734918888647329, -0.04040647983322452, ...
#  2  [[-0.009140986934476387, 0.006506739156858706,...
#  3  [[-0.05734918888647329, -0.04040647983322452, ...
#  4  [[0.0053959562864428256, 0.035829426982693584,...
#  5  [[-0.05734918888647329, -0.04040647983322452, ...
#  6  [[-0.04128154457448936, 0.009137362649833641, ...
#  7  [[-0.03512473902133435, 0.048184324536999855, ...
#  8  [[-0.057686282918739014, 0.08704780811446088, ...
#  9  [[0.03769296769447949, -0.05061330791484524, -...
#
#                                      component_cosims  cosine_sim  \
#  0                     [nan, nan, 0.5528072161492621]    0.552807
#  1  [0.5932163127062627, 0.7353565828928661, 0.820...    0.716416
#  2                          [0.8199228108595507, nan]    0.819923
#  3  [0.9526007557544859, 0.952643604307742, 0.7931...    0.899477
#  4                     [0.5453995220063653, nan, nan]    0.545400
#  5  [0.6012402419180702, 0.5099668313517843, 0.490...    0.533805
#  6      [0.8136199578806034, 0.7851755591786888, nan]    0.799398
#  7                     [0.6066974845140725, nan, nan]    0.606697
#  8                     [0.6869702126667945, nan, nan]    0.686970
#  9           [0.7010715005573384, 0.5929017160740412]    0.646987
#
#                                          base_nearest  \
#  0  [[(one+of+the, 0.9721174776592982), (This, 0.9...
#  1  [[(13, 0.9641905842804301), (29, 0.95718144283...
#  2  [[(player, 0.9810817258355922), (described, 0....
#  3  [[(13, 0.9641905842804301), (29, 0.95718144283...
#  4  [[(site, 0.9734424511177248), (love, 0.9645392...
#  5  [[(13, 0.9641905842804301), (29, 0.95718144283...
#  6  [[(under, 0.9679090324815791), (title, 0.96613...
#  7  [[(civilisation, 0.9811267950100866), (phase, ...
#  8  [[(Yugoslavia, 0.981676148653345), (any, 0.970...
#  9  [[(2010, 0.9793201446497867), (24, 0.962872656...
#
#                                           mwe_nearest
#  0  [(sub-continent, 0.9797705103042288), (sense, ...
#  1  [(Earth, 0.8353541780779903), (2010, 0.8206741...
#  2  [(Genesis, 0.9852903852279135), (small, 0.9799...
#  3  [(28, 0.98662758890815), (13, 0.98556172397890...
#  4  [(home, 0.9246192610333183), (Second, 0.903194...
#  5  [(Taurus, 0.7826425119574093), (offensive, 0.7...
#  6  [(If, 0.9285971914141857), (dissolved, 0.92555...
#  7  [(high, 0.983332790794705), (commonly, 0.95031...
#  8  [(is, 0.9721174776592983), (It, 0.965333177343...
#  9  [(14, 0.9931026235034626), (1912, 0.9172997034...  ,
#  6:             ngram  freq      poisson  len  batch  stopwords  \
#  0   (a, list, of)    11  -416.020577    3      7  [1, 0, 1]
#  1  (day, of, the)    22  -881.971652    3      7  [0, 1, 1]
#  2       (one, of)    37 -1073.426267    2      7     [0, 1]
#  3    (June, 2007)    48 -1228.459659    2      7     [0, 0]
#
#                                            mwe_vector  \
#  0  [-0.010653151530108988, 0.05135342567405703, -...
#  1  [0.008305574914137696, 0.08609726242212838, -0...
#  2  [-0.026042134976950314, 0.06655273299316151, -...
#  3  [0.12760939503507707, -0.04508526766240786, 0....
#
#                                     component_vectors  \
#  0  [[-0.1399931980969325, 0.252580746657637, 0.11...
#  1  [[-0.03612786818786725, 0.06693605844456287, 0...
#  2  [[-0.06587062641835996, 0.05423968606627604, 0...
#  3  [[0.00975433068825276, 0.23320046244902046, -0...
#
#                             component_cosims  cosine_sim  \
#  0          [nan, -0.06837456074739166, nan]   -0.068375
#  1            [0.5521267892454202, nan, nan]    0.552127
#  2                 [0.5953191561615538, nan]    0.595319
#  3  [0.5505299942036421, 0.3936387679352816]    0.472084
#
#                                          base_nearest  \
#  0  [[(small, 0.955243341568641), (boy, 0.94949762...
#  1  [[(rock, 0.9738912145875747), (town, 0.9667105...
#  2  [[(Berlin, 0.9619843897328402), (order, 0.9575...
#  3  [[(17, 0.976315968418041), (24, 0.973032006296...
#
#                                           mwe_nearest
#  0  [(Chakswari, 0.9876442602178366), (divided, 0....
#  1  [(week, 0.952657462276149), (same, 0.904215474...
#  2  [(reason, 0.9805882253845297), (program, 0.961...
#  3  [(13, 0.9626769673169097), (Fools', 0.92747573...  }

# %%
# %%time



batch_dfs = {}

for bb in range(batch_count):
    print('Processing batch {} of {}'.format(bb+1,batch_count))
    # Subset DataFrame
    batch_dfs[bb] = ngram_eval[ngram_eval.batch == bb+1].reset_index(drop=True)

    # Initialise MWETokenizer
    batch_token_mwe = MWETokenizer(list(batch_dfs[bb].ngram) , separator='+')

    # Build model
    simp_corp = Corpus()

    sents_mwe = Sent_Seq(simp, batch_token_mwe)
    simp_corp.fit( sents_mwe , window = 10)

    batch_model = Glove(no_components = 300, 
             learning_rate = 0.05)

    batch_model.fit(simp_corp.matrix, 
          epochs=50,
          no_threads=16,
          verbose=False)

    batch_model.add_dictionary(simp_corp.dictionary)

    # Save model
    batch_model.save(datapath+'/Models/2 GloVe/simple_batch{}.model'.format(bb+1))
    # Reload looks like    new_model = Glove.load('glove.model')

    # For each MWE, evaluate stats. Record vectors (in case we want to calculate different metrics later).
    # Parallelized version
    with mp.Pool() as pool:
        statslist = pool.map( mwe_score_par , [(ng, batch_model) for ng in batch_dfs[bb].ngram] )

    # statslist = [mwe_score_par((ng, batch_model)) for ng in batch_dfs[bb].ngram]

    statsf = pd.concat(statslist)

    #  Join back onto DataFrame
    batch_dfs[bb] = batch_dfs[bb].merge(statsf, on='ngram')


batch_dfs
# Out:
# Processing batch 1 of 7
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Anaconda\envs\py_36\lib\site-packages\multiprocess\pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Anaconda\envs\py_36\lib\site-packages\multiprocess\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-36-fd1e2692f17b>", line 35, in mwe_score_par
# NameError: name 'stop' is not defined
# """
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\Anaconda\envs\py_36\lib\site-packages\multiprocess\pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# C:\Anaconda\envs\py_36\lib\site-packages\multiprocess\pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# NameError: name 'stop' is not defined

# %%
# Model inspection
batch_model.most_similar('relationships', number=5)

# %%
# Merge dataframes, sort by compositionality metric, export

# Also want the default batches with batch no < 0
all_batches = ngram_eval[ngram_eval.batch < 0]

for d in range(batch_count):
    all_batches = all_batches.append(batch_dfs[d])
    
all_batches = all_batches.sort_values('cosine_sim')
all_batches = all_batches.reset_index(drop=True)

all_batches.to_csv(datapath+'/Models/2 GloVe/Results/simple_output_001.csv', index=False)

# %%
all_batches
