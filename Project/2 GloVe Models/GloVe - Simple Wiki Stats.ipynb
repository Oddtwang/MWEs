# %%
import os

path = 'C:/Users/'+os.getlogin()+'/Google Drive/University/Dissertation'
#datapath = 'E:/Dissertation Data'
datapath = 'C:/Users/'+os.getlogin()+'/Dissertation Data'

os.chdir(path+'/Code')
os.getcwd()
# Out:
# 'C:\\Users\\tom\\Google Drive\\University\\Dissertation\\Code'

# %% [markdown]
# We collect lexical co-occurrence statistics on all words in
# the English Wikipedia, using the WikiExtractor tool2 to retrieve
# plain text from the April 2015 dump (ca. 2.8B words),
# and using simple regular expressions to segment sentences
# and words, and remove URLs and punctuation. We perform
# no POS tagging, lemmatisation, case normalisation,
# or removal of numbers or symbols.

# %%
import pandas as pd
import re
import numpy as np

import nltk
from nltk.tokenize import MWETokenizer

from glove import Corpus, Glove

from gensim.models import Word2Vec

# %%
# On Simple English wiki

sf = open(datapath+'/Corpora/wiki/simple_20200601/simple_20200601_v2.txt', 'r', encoding='utf-8')

for lines in range(5):
    print(sf.readline())
# Out:
# April is the fourth month of the year, and comes between March and May.
#
#  It is one of four months to have 30 days.
#
#  April always begins on the same day of week as July, and additionally, January in leap years.
#
#  April always ends on the same day of the week as December.
#
#  April's flowers are the Sweet Pea and Daisy.

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader

from nltk.tokenize import WhitespaceTokenizer

# %%
simp = PlaintextCorpusReader(datapath+'/Corpora/wiki/simple_20200601/','simple_20200601_v2.txt',
                            word_tokenizer = WhitespaceTokenizer()
                            )

# %%
# Import word and sentence generators

from generators import sent_gen, word_gen, Sent_Seq

# %% [markdown]
# We collect word frequency information with the
# SRILM language modelling toolkit (Stolcke, 2002), counting
# n-grams (n <= 3), treating MWEs as contiguous bigrams
# and trigrams), and identify MWE candidates by computing
# the Poisson collocation measure (Quasthoff and Wolff,
# 2002) for all bigrams and trigrams (ca. 23M n-grams).
# This method should be readily extensible to include longer
# n-grams.

# %%
# Collate n-grams

from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder

from nltk.metrics import (
    BigramAssocMeasures,
    TrigramAssocMeasures,
    NgramAssocMeasures,
)

from nltk.metrics.spearman import (
    spearman_correlation,
    ranks_from_scores,
)

# %%
# Load n-gram list produced earlier

ngram_eval = pd.read_pickle(datapath+'/Corpora/wiki/simple_20200601/ngram_eval.pkl')

# %% [markdown]
# We then automatically score the million most strongly associated
# n-grams (i.e., roughly the top 5% of the Poisson-ranked
# list) for compositionality.
#
# Using word2vec (Mikolov et al., 2013) with the parameters
# found to be most effective by Baroni et al. (2014), we
# build a word embedding vector for every simplex word in
# the vocabulary (ca. 1M types), as well as for each MWE candidate.
#
# * Continuous bag of words model with 400-dimensional vectors, window size 5, subsampling with t = 10^-5, negative sampling with 10 samples. We build vectors only for tokens observed 20 times or more in the corpus.
#
# We then compute the cosine similarity of the vector
# representation for a MWE candidate with the vectors of its
# constituent words, and take the arithmetic mean.
# In scoring
# the compositionality of a candidate, we do not measure the
# cosine similarity of the MWE with any stop words it may
# contain, as stop words may be assumed to be semantically
# uninformative.
# * Stop words are taken here to be the 50 most frequent words in the vocabulary.

# %%
# Stopwords from corpus - 50 most frequent
from nltk import FreqDist

fdist = FreqDist(word_gen(simp, sent_mark=''))

stop = set( word for word, f in fdist.most_common(50))

# %%
stop
# Out:
# {'0',
#  '1',
#  '2',
#  '3',
#  '4',
#  'A',
#  'American',
#  'He',
#  'In',
#  'It',
#  'References',
#  'The',
#  'This',
#  'a',
#  'also',
#  'an',
#  'and',
#  'are',
#  'as',
#  'at',
#  'be',
#  'born',
#  'by',
#  'can',
#  'first',
#  'for',
#  'from',
#  'had',
#  'has',
#  'have',
#  'he',
#  'his',
#  'in',
#  'is',
#  'it',
#  'not',
#  'of',
#  'on',
#  'one',
#  'or',
#  'people',
#  'that',
#  'the',
#  'their',
#  'they',
#  'to',
#  'was',
#  'were',
#  'which',
#  'with'}

# %%
del fdist

# %%
min_freq = 20

# %%
ngram_eval
# Out:
#                               ngram  freq      poisson  len  batch
# 0                    (Ving, Rhames)    20  -605.625590    2      1
# 1              (Grădina, Zoologică)    20  -605.625590    2      1
# 2       (Gharb-Chrarda-Beni, Hssen)    20  -605.625590    2      1
# 3                   (Karlovy, Vary)    20  -607.033377    2      1
# 4          (waystations, shuku-eki)    20  -607.033377    2      1
# ...                             ...   ...          ...  ...    ...
# 149995         (first, country, to)    45 -3071.582792    3      2
# 149996                    (from, A)    58 -3071.612088    2     -2
# 149997                    (1998, 8)    64 -3071.704678    2      6
# 149998      (had, tested, positive)    55 -3071.728206    3      4
# 149999                     (23, 12)    64 -3071.731328    2      3
#
# [150000 rows x 5 columns]

# %%
batch_count = max(ngram_eval.batch)

# %%
ngram_eval.batch.value_counts()
# Out:
#  1     45301
#  2     33312
#  3     24686
#  4     16668
#  5     10517
#  6      7502
#  7      4240
#  8      2702
#  9      1905
#  10     1051
# -2       832
#  11      450
# -1       300
#  12      247
#  13      123
#  14      107
#  15       57
# Name: batch, dtype: int64

# %%
from nltk.tokenize import MWETokenizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Flatten down to a single number
def cosim(x,y):
    return cosine_similarity(x.reshape(1,-1), y.reshape(1,-1))[0][0]

# %%
def mwe_score(exp, model, stats_frame):
    # Combined token for MWE
    mwetoken = '+'.join(exp)

    # Stopwords - 1 if component is a stopword, 0 if present, -1 if simplex word missing from vocab, -2 if MWE missing
    sws = []
    # Component vectors
    cvs = []

    #  Neighbours in original & MWE-aware space
    oldn = []
    newn = []

    # List of individual word similarities (where present in the vocab)
    css = []

    # Empty array
    earr = np.empty(1000)
    earr[:] = np.nan

    # Check that combined token exists in the vocab. This protects against inflation of n-gram counts caused by repeats
    #  of the same token (e.g. in lists like https://simple.wikipedia.org/wiki/List_of_cities,_towns_and_villages_in_Fars_Province)
    if mwetoken in model.dictionary:

        mwv = model.word_vectors[model.dictionary[mwetoken]]

        for w in exp:
            if w in model.dictionary:
                cvs.append(model.word_vectors[model.dictionary[w]])

                #oldn.append(model.most_similar(w, number=5))

                if w in stop:
                    sws.append(1)
                    css.append(np.nan)
                else:
                    sws.append(0)
                    css.append(cosim(model.word_vectors[model.dictionary[w]], mwv ))

            # If component is absent from vocab
            else:
                sws.append(-1)
                cvs.append(earr)
                css.append(np.nan)

                #oldn.append([])

        #  Mean cosim
        if min(sws) >= 0:
            cs = np.nanmean(css)
        else:
            cs = np.nan

        #newn = model.most_similar(mwetoken, number=5)

    # Combined token missing from vocab - mark with defaults
    else:
        sws = [-2]
        mwv = np.empty(400)
        mwv[:] = np.nan


    # Append to stats df
    return stats_frame.append({
        'ngram'  : exp,
        'stopwords' : sws,
        'mwe_vector' : mwv,
        'component_vectors' : cvs,
        'component_cosims'  : css,
        'cosine_sim'  : cs,
        #'base_nearest': oldn,
        #'mwe_nearest' : newn,
    }, ignore_index=True)

# %%
#batch_model = Glove.load(datapath+'/Models/2 GloVe/simple_batch{}.model'.format(bb+1))
batch_model = Glove.load(datapath+'/Models/2 GloVe/simple_batch2.model')

batch_dict = batch_model.dictionary
batch_vect = batch_model.word_vectors

# %%
len(batch_dict)
# Out:
# 12304

# %%
ngram_eval.iloc[2000]
# Out:
# ngram      (X-Men, Origins)
# freq                     22
# poisson             -832.45
# len                       2
# batch                     2
# Name: 2000, dtype: object

# %%
len(batch_vect[batch_dict['X-Men+Origins']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4e430d526cc6> in <module>
# ----> 1 len(batch_vect[batch_dict['X-Men+Origins']])
#
# KeyError: 'X-Men+Origins'

# %%
len(batch_vect[batch_dict['X-Men']])
# Out:
# 300

# %%
len(batch_vect[batch_dict['Origins']])
# Out:
# 300

# %%
cosim(batch_vect[batch_dict['X-Men']] , batch_vect[batch_dict['X-Men+Origins']] )
# Out:
# 0.14812434685502282

# %%
cosim(batch_vect[batch_dict['Origins']] , batch_vect[batch_dict['X-Men+Origins']] )
# Out:
# 0.06070179878605181

# %%
batch_model.most_similar('X-Men+Origins')
# Out:
# [('Wolverine', 0.8390964118177713),
#  ('RawSmackDownECW', 0.5310791184729097),
#  ('Inhabitants(1989', 0.5044297265924755),
#  ('New+Moon', 0.5030943923889172)]

# %%
batch_model.most_similar('X-Men')
# Out:
# [('TheXverse.com', 0.7612342016656892),
#  ('Astonishing', 0.5977794198210621),
#  ('Apocalypse', 0.5654931846543487),
#  ('Marvel.com', 0.49236101200406673)]

# %%
batch_model.most_similar('Origins')
# Out:
# [('Sfida', 0.6174009132645951),
#  ('Kaitos', 0.5746709058795924),
#  ('The+origins', 0.5296782733795666),
#  ('left:30', 0.5097731461144712)]

# %%
# %%time

batch_dfs = {}

for bb in range(batch_count):
    print('Processing batch {} of {}'.format(bb+1,batch_count))
    
    # Subset DataFrame
    batch_dfs[bb] = ngram_eval[ngram_eval.batch == bb+1].reset_index(drop=True)
    
    # Initialise MWETokenizer
    batch_token_mwe = MWETokenizer(list(batch_dfs[bb].ngram) , separator='+')
    
    # Load model
    print('Loading GloVe model')
    
    batch_model = Glove.load(datapath+'/Models/2 GloVe/simple_batch{}.model'.format(bb+1))
    
    print('Gathering MWE stats')
     # For each MWE, evaluate stats. Record vectors (in case we want to calculate different metrics later).
    statsf = pd.DataFrame(columns=['ngram', 'stopwords', 'mwe_vector', 'component_vectors', 'component_cosims', 
                                   'cosine_sim'])  #, 'base_nearest', 'mwe_nearest'

    batch_len = len(batch_dfs[bb].ngram)
    if batch_len >= 5000: 
        printer = 1000
    else:
        printer = 200
        
    _i = 0
    
    for exp in batch_dfs[bb].ngram:
        if _i % printer == 0:
            print(' MWE '+str(_i)+'/'+str(batch_len)+': '+'+'.join(exp))
        _i += 1
            
        statsf = mwe_score(exp,batch_model,statsf)

      #Join back onto DataFrame
    batch_dfs[bb] = batch_dfs[bb].merge(statsf, on='ngram')
# Out:
# Processing batch 1 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/45301: Ving+Rhames
#  MWE 1000/45301: Real+Murcia
#  MWE 2000/45301: Nguyen+dynasty's
#  MWE 3000/45301: Cyndi+Lauper
#  MWE 4000/45301: Dragon+Tattoo
#  MWE 5000/45301: Southern+Ontario
#  MWE 6000/45301: will+decide
#  MWE 7000/45301: been+affected
#  MWE 8000/45301: and+Gone
#  MWE 9000/45301: being+chased
#  MWE 10000/45301: decoration+presented
#  MWE 11000/45301: Swiss+Federal+Councillor
#  MWE 12000/45301: was+welcomed
#  MWE 13000/45301: at+Duke
#  MWE 14000/45301: more+copies
#  MWE 15000/45301: Without+Borders
#  MWE 16000/45301: insurance+companies
#  MWE 17000/45301: from+disease
#  MWE 18000/45301: the+Willis+Tower
#  MWE 19000/45301: mounted+in
#  MWE 20000/45301: his+twin+brother
#  MWE 21000/45301: his+queen
#  MWE 22000/45301: Nazi+Germany+in
#  MWE 23000/45301: Manchester+in
#  MWE 24000/45301: now+used+by
#  MWE 25000/45301: as+the+Kingdom
#  MWE 26000/45301: Consadole+Sapporo+Football
#  MWE 27000/45301: was+eight+years
#  MWE 28000/45301: to+his+work
#  MWE 29000/45301: is+partially
#  MWE 30000/45301: a+multinational
#  MWE 31000/45301: and+martial+artist
#  MWE 32000/45301: Aires+on
#  MWE 33000/45301: the+Centre-Val
#  MWE 34000/45301: Republican+in
#  MWE 35000/45301: and+Kurt
#  MWE 36000/45301: songwriter+and+actor
#  MWE 37000/45301: stop+working
#  MWE 38000/45301: Paul+Williams
#  MWE 39000/45301: at+dawn
#  MWE 40000/45301: to+the+Medal
#  MWE 41000/45301: statistics+1991
#  MWE 42000/45301: only+used+for
#  MWE 43000/45301: Deportivo+La
#  MWE 44000/45301: also+need
#  MWE 45000/45301: his+school
# Processing batch 2 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/33312: IK+Sävehof
#  MWE 1000/33312: Cabinet+Minister
#  MWE 2000/33312: in+Buckinghamshire
#  MWE 3000/33312: 8+minutes
#  MWE 4000/33312: Maxwell's+equations
#  MWE 5000/33312: Senate+confirmed
#  MWE 6000/33312: years+her
#  MWE 7000/33312: The+Kennedy/Marshall
#  MWE 8000/33312: by+Ralph+Fletcher
#  MWE 9000/33312: in+Hanoi
#  MWE 10000/33312: Press+2004
#  MWE 11000/33312: summit+was
#  MWE 12000/33312: While+they+were
#  MWE 13000/33312: Western+North+America
#  MWE 14000/33312: fiction+series
#  MWE 15000/33312: all+people+who
#  MWE 16000/33312: adults+have
#  MWE 17000/33312: than+him
#  MWE 18000/33312: Women+were
#  MWE 19000/33312: In+December+2018
#  MWE 20000/33312: agreeing+to
#  MWE 21000/33312: River+which+is
#  MWE 22000/33312: Alpha+Ethniki
#  MWE 23000/33312: in+the+WHL
#  MWE 24000/33312: of+the+attacks
#  MWE 25000/33312: A+public
#  MWE 26000/33312: Singles+Year+Title
#  MWE 27000/33312: As+time
#  MWE 28000/33312: of+Units
#  MWE 29000/33312: be+regarded+as
#  MWE 30000/33312: in+there
#  MWE 31000/33312: usually+considered
#  MWE 32000/33312: two+years+before
#  MWE 33000/33312: after+they+have
# Processing batch 3 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/24686: Goh+Chok+Tong
#  MWE 1000/24686: competition+held
#  MWE 2000/24686: music+it
#  MWE 3000/24686: to+flood
#  MWE 4000/24686: to+world
#  MWE 5000/24686: District+Tirana
#  MWE 6000/24686: Soul+Train
#  MWE 7000/24686: job+satisfaction
#  MWE 8000/24686: cavalry+and
#  MWE 9000/24686: USA+for
#  MWE 10000/24686: game+company
#  MWE 11000/24686: its+unique
#  MWE 12000/24686: infantry+and
#  MWE 13000/24686: total+of+about
#  MWE 14000/24686: the+Whig+Party
#  MWE 15000/24686: content+in
#  MWE 16000/24686: Calhoun+County
#  MWE 17000/24686: Calvin+and
#  MWE 18000/24686: soldier+d
#  MWE 19000/24686: record+deal+with
#  MWE 20000/24686: Medical+College
#  MWE 21000/24686: Tierra+del+Fuego
#  MWE 22000/24686: videos+on
#  MWE 23000/24686: One+reason
#  MWE 24000/24686: played+for+Argentina
# Processing batch 4 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/16668: 8:30+9:00+9:30
#  MWE 1000/16668: actress+1942
#  MWE 2000/16668: her+mouth
#  MWE 3000/16668: with+17
#  MWE 4000/16668: involved+in+many
#  MWE 5000/16668: founded+by+a
#  MWE 6000/16668: in+32
#  MWE 7000/16668: 1999+16
#  MWE 8000/16668: what+was+called
#  MWE 9000/16668: years+The
#  MWE 10000/16668: are+old
#  MWE 11000/16668: piece+was
#  MWE 12000/16668: Richard+E
#  MWE 13000/16668: Territory+is
#  MWE 14000/16668: Lonely+Hearts
#  MWE 15000/16668: patients+who
#  MWE 16000/16668: providing+the
# Processing batch 5 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/10517: 9:00+9:30+10:00
#  MWE 1000/10517: High+King
#  MWE 2000/10517: January+7+2013
#  MWE 3000/10517: an+address
#  MWE 4000/10517: 14+episodes
#  MWE 5000/10517: complexity+of
#  MWE 6000/10517: spent+three
#  MWE 7000/10517: was+renovated
#  MWE 8000/10517: Portuguese+football+player
#  MWE 9000/10517: flowering+plants+in
#  MWE 10000/10517: a+1988
# Processing batch 6 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/7502: d’Art+Moderne+de
#  MWE 1000/7502: of+Germany+under
#  MWE 2000/7502: in+English+for
#  MWE 3000/7502: vocals+bass
#  MWE 4000/7502: not+suitable+for
#  MWE 5000/7502: Governor+of+Oregon
#  MWE 6000/7502: organization+is
#  MWE 7000/7502: the+Prairie
# Processing batch 7 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/4240: by+movie
#  MWE 200/4240: South+Carolina+from
#  MWE 400/4240: system+it
#  MWE 600/4240: over+parts+of
#  MWE 800/4240: They+made+it
#  MWE 1000/4240: Tennessee+and+in
#  MWE 1200/4240: can+be+performed
#  MWE 1400/4240: a+Good
#  MWE 1600/4240: Conference+and
#  MWE 1800/4240: a+Russian+politician
#  MWE 2000/4240: majority+government
#  MWE 2200/4240: various+places
#  MWE 2400/4240: companies+have
#  MWE 2600/4240: born+in+Manhattan
#  MWE 2800/4240: jump+and
#  MWE 3000/4240: Progressive+Conservative+Party
#  MWE 3200/4240: river+are+Left
#  MWE 3400/4240: Silk+Road
#  MWE 3600/4240: to+a+son
#  MWE 3800/4240: east+bank+of
#  MWE 4000/4240: a+Triple
#  MWE 4200/4240: not+die
# Processing batch 8 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/2702: 6+31
#  MWE 200/2702: was+having+a
#  MWE 400/2702: the+Queen+Elizabeth
#  MWE 600/2702: London+City
#  MWE 800/2702: away+from+Earth
#  MWE 1000/2702: performed+in+a
#  MWE 1200/2702: were+inducted+into
#  MWE 1400/2702: Dance+before
#  MWE 1600/2702: the+Court+ruled
#  MWE 1800/2702: like+being
#  MWE 2000/2702: the+supervision+of
#  MWE 2200/2702: the+diameter
#  MWE 2400/2702: was+eight
#  MWE 2600/2702: again+this
# Processing batch 9 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/1905: far+more+than
#  MWE 200/1905: in+November+and
#  MWE 400/1905: 7+Ret+5
#  MWE 600/1905: 2019+A
#  MWE 800/1905: August+2019+at
#  MWE 1000/1905: three+most
#  MWE 1200/1905: of+the+normal
#  MWE 1400/1905: after+having+been
#  MWE 1600/1905: on+15+February
#  MWE 1800/1905: on+13+September
# Processing batch 10 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/1051: like+New
#  MWE 200/1051: 10+1+3
#  MWE 400/1051: official+name+after
#  MWE 600/1051: on+the+lake
#  MWE 800/1051: American+company
#  MWE 1000/1051: those+who+were
# Processing batch 11 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/450: 0+1986+0
#  MWE 200/450: that+they+use
#  MWE 400/450: of+singles
# Processing batch 12 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/247: in+Economics+in
#  MWE 200/247: France+during
# Processing batch 13 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/123: of+India+on
# Processing batch 14 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/107: 0+54+0
# Processing batch 15 of 15
# Loading GloVe model
# Gathering MWE stats
#  MWE 0/57: 0+2009+10
# Wall time: 59min 25s
# {0:                              ngram  freq      poisson  len  batch  stopwords  \
#  0                   (Ving, Rhames)    20  -605.625590    2      1   [-1, -1]
#  1             (Grădina, Zoologică)    20  -605.625590    2      1   [-1, -1]
#  2      (Gharb-Chrarda-Beni, Hssen)    20  -605.625590    2      1   [-1, -1]
#  3                  (Karlovy, Vary)    20  -607.033377    2      1    [-1, 0]
#  4         (waystations, shuku-eki)    20  -607.033377    2      1    [-1, 0]
#  ...                            ...   ...          ...  ...    ...        ...
#  45296             (the, South, of)    41 -3070.727239    3      1  [1, 0, 1]
#  45297                   (no, such)    64 -3070.763377    2      1     [0, 0]
#  45298      (very, important, part)    49 -3070.800963    3      1  [0, 0, 0]
#  45299        (a, children's, book)    49 -3071.464079    3      1  [1, 0, 0]
#  45300              (to, get, them)    46 -3071.464786    3      1  [1, 0, 0]
#
#                                                mwe_vector  \
#  0      [-0.01724546694636041, 0.007071709766019013, 0...
#  1      [0.006556066361730045, -0.001033864015936257, ...
#  2      [-0.0354261405657079, 0.022277436845350922, -0...
#  3      [-0.10838211769686436, -0.013813579295091654, ...
#  4      [0.10856211325235977, -0.007332271410285717, -...
#  ...                                                  ...
#  45296  [0.03160305982164961, 0.02959657344259432, 0.0...
#  45297  [-0.18427177322023983, 0.019109537927481098, 0...
#  45298  [-0.08314704327136016, -0.050100199921614165, ...
#  45299  [-0.002892940435502799, 0.042519234533120814, ...
#  45300  [-0.19298622401713939, -0.028911802195969546, ...
#
#                                         component_vectors  \
#  0      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  1      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  2      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  3      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  4      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  ...                                                  ...
#  45296  [[0.29868019360712367, -0.3523399061706708, -0...
#  45297  [[0.036394747134754615, 0.008667922363980212, ...
#  45298  [[0.1480537977116073, -0.07078058867467929, 0....
#  45299  [[0.13349607905969393, -0.3962110365838543, -0...
#  45300  [[0.7035204117246578, -0.18306480150125312, -0...
#
#                                          component_cosims  cosine_sim
#  0                                             [nan, nan]         NaN
#  1                                             [nan, nan]         NaN
#  2                                             [nan, nan]         NaN
#  3                            [nan, -0.07157517005006023]         NaN
#  4                             [nan, 0.04011043511049844]         NaN
#  ...                                                  ...         ...
#  45296                    [nan, 0.13257055552828415, nan]    0.132571
#  45297          [0.2678346854607408, 0.09654301358404979]    0.182189
#  45298  [0.11646953164599859, 0.07751229797258286, 0.1...    0.130380
#  45299      [nan, 0.4395170111734873, 0.3990286452319873]    0.419273
#  45300     [nan, 0.3023575393953188, 0.24674563524340848]    0.274552
#
#  [45301 rows x 10 columns],
#  1:                             ngram  freq      poisson  len  batch  stopwords  \
#  0                   (IK, Sävehof)    20  -668.863344    2      2    [0, -1]
#  1      (Senateacting, asGovernor)    22  -683.949957    2      2    [-1, 0]
#  2                     (Yo, Gabba)    20  -687.353623    2      2     [0, 0]
#  3                     (Goh, Chok)    22  -693.974906    2      2     [0, 0]
#  4                   (CA2010, 2.4)    20  -699.431138    2      2     [0, 0]
#  ...                           ...   ...          ...  ...    ...        ...
#  33307                  (1, Bronx)    68 -3069.954457    2      2     [1, 0]
#  33308           (being, used, to)    45 -3070.094487    3      2  [0, 0, 1]
#  33309                   (1, part)    60 -3070.640808    2      2     [1, 0]
#  33310               (until, 2009)    64 -3071.330997    2      2     [0, 0]
#  33311        (first, country, to)    45 -3071.582792    3      2  [1, 0, 1]
#
#                                                mwe_vector  \
#  0      [-0.024277232152836246, -0.006744830912298698,...
#  1      [0.045637190819396344, -0.005636118740062318, ...
#  2      [0.11282308389377196, -0.04615601511144091, 0....
#  3      [0.10704277796418184, 0.02243382863152508, 0.0...
#  4      [-0.029884418463818955, -0.03362618925546107, ...
#  ...                                                  ...
#  33307  [-0.0398728141043665, -0.014931410217588955, -...
#  33308  [0.1725731637153739, 0.015542718930008578, -0....
#  33309  [-0.17130135461855184, -0.016968771266979838, ...
#  33310  [0.14675952281428312, 0.02450834819906524, -0....
#  33311  [0.165547694406703, -0.003994850462044466, -0....
#
#                                         component_vectors  \
#  0      [[-0.07979172576686591, 0.013483526031680801, ...
#  1      [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#  2      [[-0.20306599322338484, 0.11729062489800374, -...
#  3      [[0.03183243418734175, 0.0010142262821916893, ...
#  4      [[0.015619593495000647, -0.013728477195283997,...
#  ...                                                  ...
#  33307  [[-0.27981412718097587, -0.3593243367969125, -...
#  33308  [[-0.12548973693260573, -0.182448400482946, -0...
#  33309  [[-0.27981412718097587, -0.3593243367969125, -...
#  33310  [[0.11565534389313006, 0.2699857184286672, -0....
#  33311  [[0.0789089411137601, 0.283629737513958, -0.07...
#
#                                       component_cosims  cosine_sim
#  0                           [-0.125740912952845, nan]         NaN
#  1                            [nan, 0.641121394540259]         NaN
#  2          [-0.14325688550625273, 0.8846425418628985]    0.370693
#  3          [0.27172212822291814, 0.19566768384168903]    0.233695
#  4           [-0.2194309497317521, 0.5206082909282816]    0.150589
#  ...                                               ...         ...
#  33307                       [nan, 0.2515291492296922]    0.251529
#  33308  [0.11410919971903467, 0.1537972950059042, nan]    0.133953
#  33309                       [nan, 0.3954383765579474]    0.395438
#  33310       [0.3027237630818119, 0.13754282302793822]    0.220133
#  33311                  [nan, 0.1317702926624683, nan]    0.131770
#
#  [33312 rows x 10 columns],
#  2:                                    ngram  freq      poisson  len  batch  \
#  0                      (Goh, Chok, Tong)    20  -778.404443    3      3
#  1              (Seongnam, Ilhwa, Chunma)    22  -788.572745    3      3
#  2      (ofthe, Senateacting, asGovernor)    22  -794.926628    3      3
#  3                     (Yo, Gabba, Gabba)    20  -797.190685    3      3
#  4                     (Kuch, Kuch, Hota)    21  -808.174975    3      3
#  ...                                  ...   ...          ...  ...    ...
#  24681               (politician, Deputy)    70 -3070.164755    2      3
#  24682                    (machine, code)    73 -3070.374742    2      3
#  24683                       (foods, and)    63 -3070.822944    2      3
#  24684                  (the, album, The)    42 -3071.280894    3      3
#  24685                           (23, 12)    64 -3071.731328    2      3
#
#          stopwords                                         mwe_vector  \
#  0       [0, 0, 0]  [-0.06842416345858092, 0.028793815791450458, 0...
#  1       [0, 0, 0]  [-0.08073768363631932, 0.041484829481541266, -...
#  2      [0, -1, 0]  [0.10722266758347115, -0.03733259540336394, 0....
#  3       [0, 0, 0]  [0.006295412812131675, 0.0019710361445774652, ...
#  4       [0, 0, 0]  [0.08455569532957044, -0.03021903915871385, 0....
#  ...           ...                                                ...
#  24681      [0, 0]  [-0.12963729547064406, -0.03791819850704187, 0...
#  24682      [0, 0]  [0.023797013379439205, 0.07594020264174176, 0....
#  24683      [0, 1]  [0.14314629591536301, -0.10822671639398661, 0....
#  24684   [1, 0, 1]  [0.11761075626804465, -0.009059713258893114, -...
#  24685      [0, 0]  [-0.09017536066178898, -0.0663260150437457, -0...
#
#                                         component_vectors  \
#  0      [[-0.01289341002270056, 0.008526255615435145, ...
#  1      [[-0.10884047308344968, 0.005220551032898865, ...
#  2      [[0.013444935608776446, -0.014980701484783117,...
#  3      [[-0.0006137243593298195, -0.1098873417324243,...
#  4      [[0.048568034633685406, -0.007287179453516194,...
#  ...                                                  ...
#  24681  [[0.24224706770533805, -0.17462282951278715, -...
#  24682  [[-0.15626705108468242, -0.17598371100630228, ...
#  24683  [[0.07562850146873298, -0.1276082289746976, 0....
#  24684  [[0.1504220334678025, -0.33636410072271633, 0....
#  24685  [[0.051324482950291773, -0.25163797307604485, ...
#
#                                          component_cosims  cosine_sim
#  0      [0.17777707237163135, 0.10477472115411954, 0.0...    0.111557
#  1      [0.30334196555114495, -0.28509681842083273, -0...   -0.052703
#  2          [0.4633193725609654, nan, 0.5315704584895258]         NaN
#  3      [-0.045240773315822394, 0.05363061800721064, 0...    0.020673
#  4      [0.5897028988529893, 0.5897028988529893, 0.415...    0.531658
#  ...                                                  ...         ...
#  24681         [0.37078172696407674, 0.28599590270951264]    0.328389
#  24682         [0.22490004712743106, 0.28324561038370843]    0.254073
#  24683                           [0.454572650764533, nan]    0.454573
#  24684                    [nan, 0.20837577230869372, nan]    0.208376
#  24685          [0.5016198399862838, 0.41586093412859826]    0.458740
#
#  [24686 rows x 10 columns],
#  3:                          ngram  freq      poisson  len  batch  stopwords  \
#  0           (8:30, 9:00, 9:30)    21  -848.450913    3      4  [0, 0, 0]
#  1            (Kuch, Hota, Hai)    21  -849.056892    3      4  [0, 0, 0]
#  2                     (Bu, Li)    23  -856.604470    2      4     [0, 0]
#  3              (AM, 11:25, AM)    20  -892.722372    3      4  [0, 0, 0]
#  4           (et, hélicoptères)    24  -894.881206    2      4     [0, 0]
#  ...                        ...   ...          ...  ...    ...        ...
#  16663   (which, contains, the)    45 -3070.331276    3      4  [1, 0, 1]
#  16664                  (43, 4)    66 -3070.418973    2      4     [0, 1]
#  16665           (age, of, 101)    48 -3070.933027    3      4  [0, 1, 0]
#  16666           (City, is, an)    44 -3070.970349    3      4  [0, 1, 1]
#  16667  (had, tested, positive)    55 -3071.728206    3      4  [1, 0, 0]
#
#                                                mwe_vector  \
#  0      [-0.018905806889594323, 0.0009228904125668164,...
#  1      [0.044185283304565566, 0.03704390196125837, 0....
#  2      [-0.04077002419157919, 0.002854422834062453, 0...
#  3      [-0.017125085891381047, -0.009776217438890632,...
#  4      [0.0803588085899585, -0.06828792644203452, -0....
#  ...                                                  ...
#  16663  [-0.029548218054694354, 0.007033694796082669, ...
#  16664  [-0.1267242712969716, -0.016064073513470386, -...
#  16665  [-0.01027729355470879, -0.035121752411509055, ...
#  16666  [0.047878424051562105, -0.06164843138813824, -...
#  16667  [-0.0034506946576025118, -0.04170296495347411,...
#
#                                         component_vectors  \
#  0      [[-0.008805660460714813, -0.004959919870042555...
#  1      [[0.025215658907051196, 0.041568159729370766, ...
#  2      [[-0.11802244296961058, 0.021323912695283866, ...
#  3      [[0.07619434549444377, -0.08069965994329209, -...
#  4      [[-0.09963568354411195, -0.1265980311608735, -...
#  ...                                                  ...
#  16663  [[0.47993865698288746, 0.09075905262479972, -0...
#  16664  [[0.10730885362378162, -0.16751184745190736, 0...
#  16665  [[0.18929096897781428, -0.18774646529388986, -...
#  16666  [[0.06000232336100946, -0.005139619032983189, ...
#  16667  [[0.2417228282389322, -0.2831558986103392, 0.2...
#
#                                          component_cosims  cosine_sim
#  0      [0.4175435767663014, 0.4325400564737779, 0.346...    0.398830
#  1      [0.8841626848019268, -0.05056738271677993, 0.2...    0.363022
#  2           [0.16254253290736592, -0.046360219445503656]    0.058091
#  3      [0.2280645691684439, 0.11838001319777305, 0.22...    0.191503
#  4              [0.18257074101849824, 0.0985683384773847]    0.140570
#  ...                                                  ...         ...
#  16663                   [nan, -0.07628972049204172, nan]   -0.076290
#  16664                          [0.3467059581281653, nan]    0.346706
#  16665   [0.33799870422912776, nan, -0.03447217586240581]    0.151763
#  16666                    [0.26285513499010005, nan, nan]    0.262855
#  16667     [nan, 0.3763484221495747, 0.22466105544129028]    0.300505
#
#  [16668 rows x 10 columns],
#  4:                      ngram  freq      poisson  len  batch  stopwords  \
#  0      (9:00, 9:30, 10:00)    21  -881.110432    3      5  [0, 0, 0]
#  1          (Top, Division)    21  -957.332691    2      5     [0, 0]
#  2      (de, Saint-Etienne)    23  -959.529248    2      5     [0, 0]
#  3               (22, 1986)    20  -962.583143    2      5     [0, 0]
#  4          (CAN, MEX, FRA)    20  -963.188697    3      5  [0, 0, 0]
#  ...                    ...   ...          ...  ...    ...        ...
#  10512      (elected, pope)    75 -3069.751541    2      5     [0, 0]
#  10513        (The, prison)    62 -3069.798357    2      5     [1, 0]
#  10514    (which, are, now)    46 -3071.048260    3      5  [1, 1, 0]
#  10515   (he, signed, with)    47 -3071.290964    3      5  [1, 0, 1]
#  10516           (1, 0, 41)    47 -3071.394399    3      5  [1, 1, 0]
#
#                                                mwe_vector  \
#  0      [-0.23878717111256323, 0.06854352118931617, 0....
#  1      [-0.05337772394110845, -0.0458589224212222, -0...
#  2      [-0.20370330884566112, 0.012803682001446201, 0...
#  3      [0.06604652356904231, 0.01031572539444819, 0.0...
#  4      [-0.08398570891494583, -0.06330946788980704, 0...
#  ...                                                  ...
#  10512  [0.08526121931354051, -0.0274196233443801, 0.0...
#  10513  [-0.16247342479158622, -0.0395498551137764, 0....
#  10514  [-0.11254558159539764, -0.029555328604375236, ...
#  10515  [0.10375581269042208, -0.0033486552401594738, ...
#  10516  [-0.08919722819574234, 0.020516039726751294, 0...
#
#                                         component_vectors  \
#  0      [[-0.0675986080039828, -0.012284549417728675, ...
#  1      [[0.13637873295159073, -0.13192621430325696, -...
#  2      [[0.05815912161909091, -0.24455881351370165, -...
#  3      [[0.1834449458400628, -0.18337553266050466, 0....
#  4      [[0.19411028770055042, -0.20530692464880182, -...
#  ...                                                  ...
#  10512  [[0.34957858448845325, -0.10655080589007557, -...
#  10513  [[0.12552457798141556, -0.30503857273548035, -...
#  10514  [[0.42375046101340147, -0.23302884853180467, -...
#  10515  [[0.09816805427899303, -0.16407924171583232, -...
#  10516  [[0.15276393979699665, -0.3505169751548077, -0...
#
#                                          component_cosims  cosine_sim
#  0      [0.35862969974289943, 0.3197770276418283, 0.17...    0.283272
#  1             [0.19991387418258866, 0.05886341671140512]    0.129389
#  2             [-0.04746020297562636, 0.1296020377678176]    0.041071
#  3             [0.32046439401098215, 0.18288500473402008]    0.251675
#  4      [0.44673316646392136, 0.5553342307895008, 0.53...    0.511917
#  ...                                                  ...         ...
#  10512           [0.2870898473909168, 0.3417864286182619]    0.314438
#  10513                         [nan, 0.23099657908005183]    0.230997
#  10514                     [nan, nan, 0.2777513606934129]    0.277751
#  10515                    [nan, 0.06174716691082203, nan]    0.061747
#  10516                    [nan, nan, 0.28338950958255776]    0.283390
#
#  [10517 rows x 10 columns],
#  5:                                ngram  freq      poisson  len  batch  \
#  0               (d’Art, Moderne, de)    21  -971.368292    3      6
#  1                           (28, 20)    20  -986.110144    2      6
#  2     (et, hélicoptères, militaires)    24 -1004.920306    3      6
#  3                         (10, 1948)    21 -1012.441692    2      6
#  4                    (through, 1992)    21 -1017.762551    2      6
#  ...                              ...   ...          ...  ...    ...
#  7497            (their, environment)    67 -3070.096295    2      6
#  7498          (shooter, video, game)    56 -3070.098123    3      6
#  7499                 (the, song, to)    42 -3070.763801    3      6
#  7500              (the, last, major)    46 -3071.162113    3      6
#  7501                       (1998, 8)    64 -3071.704678    2      6
#
#         stopwords                                         mwe_vector  \
#  0      [0, 0, 0]  [-0.01692187434975682, 0.08498599508707551, -0...
#  1         [0, 0]  [0.05847863555675309, 0.06261997120296443, -0....
#  2     [0, 0, -1]  [0.0646225725412162, 0.02968260886146276, -0.0...
#  3         [0, 0]  [0.08378319057256765, 0.07199854059243493, 0.0...
#  4         [0, 0]  [0.03670311411685269, 0.06558897482160081, 0.1...
#  ...          ...                                                ...
#  7497      [1, 0]  [0.02230243943457776, -0.00449157036466157, -0...
#  7498   [0, 0, 0]  [-0.02769111368853433, -0.051291421164664834, ...
#  7499   [1, 0, 1]  [0.023721097370560714, -0.07619006282773223, 0...
#  7500   [1, 0, 0]  [0.03483462192635219, -0.08326977916163564, 0....
#  7501      [0, 0]  [0.06395991737378144, 0.22979727912777712, 0.0...
#
#                                        component_vectors  \
#  0     [[-0.017363818625680535, -0.008368714225347117...
#  1     [[0.17726783932977042, 0.2823704799107373, 0.2...
#  2     [[-0.14081356790290522, -0.31293003805600256, ...
#  3     [[0.05639509817591394, 0.42584638465552666, -0...
#  4     [[0.28120340316543097, -0.20667952987503976, 0...
#  ...                                                 ...
#  7497  [[0.04807606262334019, 0.21840594283023754, 0....
#  7498  [[0.11646319761254649, -0.15412494108930155, -...
#  7499  [[0.09678566879846089, -0.289707159331925, -0....
#  7500  [[0.09678566879846089, -0.289707159331925, -0....
#  7501  [[0.20833570145162372, 0.38730288577361754, 0....
#
#                                         component_cosims  cosine_sim
#  0     [0.2258142366432325, 0.19464613306216083, 0.02...    0.147199
#  1               [0.3672395333933979, 0.345550456593291]    0.356395
#  2       [0.23783602128307468, 0.29465742962261704, nan]         NaN
#  3              [0.094249130305787, 0.26029439315581526]    0.177272
#  4              [0.0831822426969018, 0.2980882461247847]    0.190635
#  ...                                                 ...         ...
#  7497                          [nan, 0.3616001818742704]    0.361600
#  7498  [0.4195913287877676, 0.1717615828033502, 0.148...    0.246742
#  7499                    [nan, 0.03267634833953437, nan]    0.032676
#  7500     [nan, 0.2235260124811057, 0.35815045124409123]    0.290838
#  7501         [0.49367995110761237, 0.37259250096755386]    0.433136
#
#  [7502 rows x 10 columns],
#  6:                       ngram  freq      poisson  len  batch  stopwords  \
#  0               (by, movie)    20 -1067.490276    2      7     [1, 0]
#  1                  (22, 25)    22 -1079.251052    2      7     [0, 0]
#  2              (even, from)    21 -1079.790347    2      7     [0, 1]
#  3           (for, Regional)    22 -1084.940879    2      7     [1, 0]
#  4            (2.4, million)    25 -1086.828363    2      7     [0, 0]
#  ...                     ...   ...          ...  ...    ...        ...
#  4235  (for, Tubby, Bye-Bye)    57 -3068.389226    3      7  [1, 0, 0]
#  4236            (also, saw)    65 -3069.608356    2      7     [1, 0]
#  4237         (for, a, walk)    46 -3069.881036    3      7  [1, 1, 0]
#  4238    (became, a, priest)    48 -3070.699218    3      7  [0, 1, 0]
#  4239           (she, finds)    69 -3071.481784    2      7     [0, 0]
#
#                                               mwe_vector  \
#  0     [-0.1629579981305718, -0.09447728369767248, -0...
#  1     [0.09646137542409744, -0.10920374475662917, 0....
#  2     [-0.1021760147094379, -0.018917639685046617, -...
#  3     [0.1229490228858129, -0.037939780460225316, 0....
#  4     [-0.08707393671677001, 0.0638418612908377, -0....
#  ...                                                 ...
#  4235  [-0.04084488215627735, 0.18243884463802296, -0...
#  4236  [-0.0426018783404204, -0.04883948087139933, 0....
#  4237  [-0.02138447387218276, -0.03648494416631713, -...
#  4238  [0.0029487953446318935, -0.017549860850687396,...
#  4239  [-0.058762823091145, -0.058784378172475456, -0...
#
#                                        component_vectors  \
#  0     [[0.28711292855937226, -0.1647674840950132, 0....
#  1     [[0.13366955674314787, -0.11055951102667244, 0...
#  2     [[0.28031632381078825, -0.25246748476243347, 0...
#  3     [[0.44952248504384823, 0.02270649710610213, 0....
#  4     [[-0.03195105102761685, 0.10042505157293477, -...
#  ...                                                 ...
#  4235  [[0.44952248504384823, 0.02270649710610213, 0....
#  4236  [[0.15223131124929679, -0.12497728605368265, 0...
#  4237  [[0.44952248504384823, 0.02270649710610213, 0....
#  4238  [[0.23428935440941084, -0.06843756127784581, 0...
#  4239  [[-0.08220997564340302, -0.4984900292502098, 0...
#
#                                       component_cosims  cosine_sim
#  0                          [nan, 0.12019655873205425]    0.120197
#  1            [0.3891424386846438, 0.3458830354930319]    0.367513
#  2                          [0.10530278610405942, nan]    0.105303
#  3                          [nan, 0.14538962724138715]    0.145390
#  4         [0.003825999746906967, 0.33986591441095915]    0.171846
#  ...                                               ...         ...
#  4235   [nan, 0.2755566250193483, 0.24665023701297512]    0.261103
#  4236                       [nan, 0.25233277327417436]    0.252333
#  4237                    [nan, nan, 0.304587773110822]    0.304588
#  4238  [0.0422757290806286, nan, 0.041834587357544334]    0.042055
#  4239       [0.38400670053847097, 0.42284058565970073]    0.403424
#
#  [4240 rows x 10 columns],
#  7:                  ngram  freq      poisson  len  batch  stopwords  \
#  0              (6, 31)    23 -1141.471135    2      8     [0, 0]
#  1         (at, public)    23 -1168.039171    2      8     [1, 0]
#  2        (at, Charles)    23 -1174.361394    2      8     [1, 0]
#  3              (8, 25)    24 -1195.384956    2      8     [0, 0]
#  4            (at, Old)    24 -1200.247649    2      8     [1, 0]
#  ...                ...   ...          ...  ...    ...        ...
#  2697    (work, as, an)    45 -3067.824199    3      8  [0, 1, 1]
#  2698  (is, wearing, a)    45 -3067.863798    3      8  [1, 0, 1]
#  2699   (the, Arkansas)    61 -3068.128777    2      8     [1, 0]
#  2700        (It, said)    61 -3070.111500    2      8     [1, 0]
#  2701    (Paris, where)    66 -3070.821842    2      8     [0, 0]
#
#                                               mwe_vector  \
#  0     [-0.09800245070830757, -0.02985342734543162, -...
#  1     [-0.06013548713029627, 0.01989724093167674, 0....
#  2     [0.04076269301302235, 0.04881014296230952, 0.1...
#  3     [-0.056617668112076254, -0.006063875370784314,...
#  4     [-0.04159478916194338, 0.031659237817564016, -...
#  ...                                                 ...
#  2697  [-0.0840380779481089, -0.035573633131948716, -...
#  2698  [-0.11735095485845902, 0.05504818174532491, 0....
#  2699  [0.14833632919559736, 0.21295826085815422, -0....
#  2700  [0.014511516780219669, 0.07761942867806736, 0....
#  2701  [-0.009093013791467076, 0.16110553382102683, -...
#
#                                        component_vectors  \
#  0     [[-0.3696699897270773, -0.33777215850781067, -...
#  1     [[-0.4031764462815596, -0.8902051513063107, 0....
#  2     [[-0.4031764462815596, -0.8902051513063107, 0....
#  3     [[-0.33336487918765845, -0.2467895677147404, -...
#  4     [[-0.4031764462815596, -0.8902051513063107, 0....
#  ...                                                 ...
#  2697  [[-0.331064504853139, 0.3670507479964499, 0.13...
#  2698  [[0.1599675400695717, -1.2142660669757515, 0.1...
#  2699  [[0.2722426255822491, -0.12036026833479628, 0....
#  2700  [[-0.10449056271323251, -0.14572284439859834, ...
#  2701  [[-0.016277310811668395, 0.08044628107947334, ...
#
#                                 component_cosims  cosine_sim
#  0      [0.4102434584235554, 0.3150320944145937]    0.362638
#  1                    [nan, 0.19517247869309284]    0.195172
#  2                    [nan, 0.14662943932303188]    0.146629
#  3     [0.48313695348782815, 0.4251635803327495]    0.454150
#  4                    [nan, 0.32151223015876007]    0.321512
#  ...                                         ...         ...
#  2697            [0.23878432456768078, nan, nan]    0.238784
#  2698             [nan, 0.2647723427090082, nan]    0.264772
#  2699                 [nan, 0.19777712958188537]    0.197777
#  2700                  [nan, 0.3345094278364648]    0.334509
#  2701  [0.23146523329177618, 0.3457589275472654]    0.288612
#
#  [2702 rows x 10 columns],
#  8:                     ngram  freq      poisson  len  batch  stopwords  \
#  0       (far, more, than)    20 -1249.513911    3      9  [0, 0, 0]
#  1        (New, Jersey, 2)    20 -1287.619564    3      9  [0, 0, 1]
#  2      (years, ago, with)    20 -1294.099432    3      9  [0, 0, 1]
#  3      (a, precursor, to)    20 -1320.024875    3      9  [1, 0, 1]
#  4     (they, thought, he)    20 -1320.292310    3      9  [1, 0, 1]
#  ...                   ...   ...          ...  ...    ...        ...
#  1900        (an, Actress)    64 -3063.542319    2      9     [1, 0]
#  1901       (on, BBC, One)    49 -3064.226076    3      9  [1, 0, 0]
#  1902   (are, known, from)    44 -3064.908680    3      9  [1, 0, 1]
#  1903          (1969, the)    58 -3066.302592    2      9     [0, 1]
#  1904    (of, the, Vienna)    43 -3070.190322    3      9  [1, 1, 0]
#
#                                               mwe_vector  \
#  0     [-0.05117203625862896, -0.011730131253861851, ...
#  1     [0.029929965886228798, 0.019614950863428904, 0...
#  2     [-0.04405703610665624, 0.007584328833589947, -...
#  3     [-0.0029734721545477045, 0.0020415458598355444...
#  4     [-0.08780321755557581, 0.017212951513121938, 0...
#  ...                                                 ...
#  1900  [0.13353111530882536, -0.03064537042550406, 0....
#  1901  [-0.03965515114655713, 0.027267186745964705, 0...
#  1902  [0.027887379586360644, 0.012828921801134381, -...
#  1903  [0.11123760001240003, 0.003057437686854259, 0....
#  1904  [0.044622298605801906, -0.010210804846061709, ...
#
#                                        component_vectors  \
#  0     [[0.02501808055045857, 0.12922267578535526, -0...
#  1     [[0.39037290350970244, 0.43177698038064166, 0....
#  2     [[0.1921714099950739, 0.011549812522419442, -0...
#  3     [[-0.2894780306023958, 0.4405694248801326, 0.1...
#  4     [[-0.07124513692654735, 0.352210029433436, 0.2...
#  ...                                                 ...
#  1900  [[0.3400410039480157, 0.2865830817049436, -0.1...
#  1901  [[-0.2665523336293212, 0.4244677598967587, 0.3...
#  1902  [[0.3747997285688274, 0.3551097779040147, 0.30...
#  1903  [[0.17422389297068058, 0.07314245446145687, 0....
#  1904  [[0.016257910076496976, 0.48813958661408435, -...
#
#                                         component_cosims  cosine_sim
#  0     [0.21877702740084815, 0.18874428418317815, 0.2...    0.206945
#  1         [0.4231038041565851, 0.5687691398025131, nan]    0.495936
#  2        [0.17630411695551473, 0.2724972904551148, nan]    0.224401
#  3                         [nan, 0.206059757805131, nan]    0.206060
#  4                       [nan, 0.19464691737698725, nan]    0.194647
#  ...                                                 ...         ...
#  1900                          [nan, 0.2354075413742578]    0.235408
#  1901    [nan, 0.31848751130135844, 0.07784328955726649]    0.198165
#  1902                    [nan, -0.0313416510321024, nan]   -0.031342
#  1903                         [0.19285849037124309, nan]    0.192858
#  1904                    [nan, nan, 0.14910359623157235]    0.149104
#
#  [1905 rows x 10 columns],
#  9:                       ngram  freq      poisson  len  batch  stopwords  \
#  0               (like, New)    26 -1318.600619    2     10     [0, 0]
#  1            (to, adopt, a)    20 -1333.968950    3     10  [1, 0, 1]
#  2       (with, four, other)    20 -1347.371804    3     10  [1, 0, 0]
#  3           (to, select, a)    20 -1349.289806    3     10  [1, 0, 1]
#  4              (1957, 0, 0)    20 -1352.445128    3     10  [0, 1, 1]
#  ...                     ...   ...          ...  ...    ...        ...
#  1046         (to, the, San)    42 -3058.537203    3     10  [1, 1, 0]
#  1047             (1925, is)    61 -3058.711870    2     10     [0, 1]
#  1048        (famous, works)    67 -3061.093803    2     10     [0, 0]
#  1049  (the, government, is)    42 -3068.143523    3     10  [1, 0, 1]
#  1050        (II, of, Great)    46 -3068.446958    3     10  [0, 1, 0]
#
#                                               mwe_vector  \
#  0     [0.16483717597581873, -0.05488702431834461, -0...
#  1     [0.0627771060637643, -0.05536892502292891, 0.1...
#  2     [-0.06426622700443255, -0.062218695096777084, ...
#  3     [0.05299693996794607, -0.06789974559296459, 0....
#  4     [0.15870782859242205, 0.023532094483545377, -0...
#  ...                                                 ...
#  1046  [0.049363940174474104, -0.02095473051495523, -...
#  1047  [-0.0027474286089622765, -0.04228834246900524,...
#  1048  [-0.05597443171610651, -0.07190202232807975, 0...
#  1049  [-0.07546212446795078, -0.08159450547176739, 0...
#  1050  [-0.04333947025288984, -0.11962470038000739, 0...
#
#                                        component_vectors  \
#  0     [[0.029462694866503464, 0.07506456774845306, 0...
#  1     [[-0.1783449990369855, 0.22893071518579655, -0...
#  2     [[0.2175783764694863, 0.6050263852932964, 0.36...
#  3     [[-0.1783449990369855, 0.22893071518579655, -0...
#  4     [[0.05882494987007314, 0.26314432857623365, 0....
#  ...                                                 ...
#  1046  [[-0.1783449990369855, 0.22893071518579655, -0...
#  1047  [[-0.21642425887651542, 0.06428347117208026, 0...
#  1048  [[-0.17035764752423188, 0.06477540870201386, -...
#  1049  [[-0.5455761405017345, 0.0878495561119426, 0.5...
#  1050  [[-0.6504397510334359, 0.1312786715362068, 0.0...
#
#                                       component_cosims  cosine_sim
#  0           [0.11058517822449142, 0.3048363029737312]    0.207711
#  1                     [nan, 0.15617625112417993, nan]    0.156176
#  2     [nan, 0.11896491480567618, 0.14671182664014398]    0.132838
#  3                    [nan, 0.026415766426566206, nan]    0.026416
#  4                      [0.4313889027503045, nan, nan]    0.431389
#  ...                                               ...         ...
#  1046                  [nan, nan, 0.33320149207554167]    0.333201
#  1047                        [0.3505590853159407, nan]    0.350559
#  1048       [0.38933536488684684, 0.28410102668164516]    0.336718
#  1049                  [nan, 0.13070070429554248, nan]    0.130701
#  1050  [-0.05536975362828757, nan, 0.2776021066501867]    0.111116
#
#  [1051 rows x 10 columns],
#  10:                     ngram  freq      poisson  len  batch  stopwords  \
#  0            (0, 1986, 0)    20 -1369.463855    3     11  [1, 0, 1]
#  1      (of, airports, in)    20 -1382.030084    3     11  [1, 0, 1]
#  2    (be, interested, in)    21 -1405.460323    3     11  [1, 0, 1]
#  3        (3, times, with)    21 -1414.257916    3     11  [1, 0, 1]
#  4          (is, about, 4)    20 -1415.333630    3     11  [1, 0, 1]
#  ..                    ...   ...          ...  ...    ...        ...
#  445              (17, 14)    63 -3029.999477    2     11     [0, 0]
#  446      (be, seen, with)    46 -3039.843326    3     11  [1, 0, 1]
#  447      (of, the, child)    42 -3049.956190    3     11  [1, 1, 0]
#  448      (US, Air, Force)    54 -3063.887445    3     11  [0, 0, 0]
#  449   (is, also, popular)    45 -3069.877388    3     11  [1, 1, 0]
#
#                                              mwe_vector  \
#  0    [0.004032245938104358, -0.10099239260571988, -...
#  1    [-0.001409131353621825, 0.026811544536848315, ...
#  2    [0.015360619813121552, -0.007564374885574546, ...
#  3    [0.021558575019680042, 0.0035090680197854586, ...
#  4    [0.006776128038311374, -0.015998535177230894, ...
#  ..                                                 ...
#  445  [-0.05597883577904225, 0.13748376937071777, 0....
#  446  [0.015428880483140511, -0.0056935485177166505,...
#  447  [0.011496713916903465, -0.0011666612282177208,...
#  448  [-0.014412721302323501, 0.011763739991077259, ...
#  449  [-0.0031021352523743916, -0.036510428953036786...
#
#                                       component_vectors  \
#  0    [[-0.21171807417040894, -0.08416000212131934, ...
#  1    [[-0.5345478107260105, 0.3709532605976796, -0....
#  2    [[-0.256898633404277, 0.19154612994554843, -0....
#  3    [[-0.1802457529209295, 0.10518204909559396, 0....
#  4    [[-0.2582800600425533, 0.24416006520930267, 0....
#  ..                                                 ...
#  445  [[-0.06357347922360797, 0.3114308530305057, 0....
#  446  [[-0.256898633404277, 0.19154612994554843, -0....
#  447  [[-0.5345478107260105, 0.3709532605976796, -0....
#  448  [[-0.06008521942986711, -0.252119821560376, -0...
#  449  [[-0.2582800600425533, 0.24416006520930267, 0....
#
#                                        component_cosims  cosine_sim
#  0                       [nan, 0.5066984084504256, nan]    0.506698
#  1                     [nan, -0.09337558526014994, nan]   -0.093376
#  2                     [nan, 0.017405586006132755, nan]    0.017406
#  3                      [nan, 0.16804169168577882, nan]    0.168042
#  4                      [nan, 0.07474383887659478, nan]    0.074744
#  ..                                                 ...         ...
#  445           [0.4744323578358688, 0.5687818100444879]    0.521607
#  446                    [nan, 0.22537175232377168, nan]    0.225372
#  447                    [nan, nan, 0.17069247527220882]    0.170692
#  448  [0.23133306899610273, 0.182630572810059, 0.308...    0.240674
#  449                    [nan, nan, 0.16329767724381822]    0.163298
#
#  [450 rows x 10 columns],
#  11:                    ngram  freq      poisson  len  batch  stopwords  \
#  0    (in, Economics, in)    20 -1391.794712    3     12  [1, 0, 1]
#  1           (it, is, up)    20 -1419.985696    3     12  [1, 1, 0]
#  2      (of, Culture, of)    20 -1424.908614    3     12  [1, 0, 1]
#  3           (0, 1990, 0)    21 -1441.573960    3     12  [1, 0, 1]
#  4        (to, adapt, to)    22 -1445.580700    3     12  [1, 0, 1]
#  ..                   ...   ...          ...  ...    ...        ...
#  242         (2000, 2004)    63 -3012.624914    2     12     [0, 0]
#  243   (located, to, the)    42 -3013.024991    3     12  [0, 1, 1]
#  244       (wrote, in, a)    42 -3013.792114    3     12  [0, 1, 1]
#  245            (1997, 3)    62 -3033.751266    2     12     [0, 1]
#  246   (2012, 2013, 2014)    49 -3045.714690    3     12  [0, 0, 0]
#
#                                              mwe_vector  \
#  0    [-0.04452777875300968, -0.16064018938205082, 0...
#  1    [0.0778721440714853, 0.04415368167542999, -0.0...
#  2    [0.03887017436077509, 0.23422360434713513, 0.1...
#  3    [-0.05615595245194585, -0.01801587750557635, 0...
#  4    [-0.057004147814515044, 0.10911094621808351, -...
#  ..                                                 ...
#  242  [-0.014973201399326107, -0.14397762841902106, ...
#  243  [0.09801084152179365, -0.1748239826173746, -0....
#  244  [-0.0008005681989636128, 0.04428891119047615, ...
#  245  [-0.07386745366739453, 0.0641917790502292, 0.0...
#  246  [-0.0864836902546643, 0.11743854438028319, -0....
#
#                                       component_vectors  \
#  0    [[0.5629810879668564, 0.026239584921285253, -0...
#  1    [[0.2934021357914651, 0.09909737069848915, -0....
#  2    [[-0.19481735082871074, -0.0582632757737781, -...
#  3    [[-0.30950461430296183, -0.645443446491763, 0....
#  4    [[-0.03562086282278151, 0.0581984386801525, 0....
#  ..                                                 ...
#  242  [[0.29402622605954337, -0.10641062740491718, -...
#  243  [[0.44963157650036395, -0.3553854380127642, -0...
#  244  [[0.19024715407263884, -0.055203952500871414, ...
#  245  [[0.0012073304779684048, -0.07068583324749872,...
#  246  [[-0.15373353135677573, -0.00792515113634838, ...
#
#                                        component_cosims  cosine_sim
#  0                      [nan, 0.29091456824028794, nan]    0.290915
#  1                      [nan, nan, 0.00290765187589246]    0.002908
#  2                      [nan, 0.22592676959559294, nan]    0.225927
#  3                        [nan, 0.469705518058924, nan]    0.469706
#  4                        [nan, 0.277830413462306, nan]    0.277830
#  ..                                                 ...         ...
#  242         [0.20531372650312912, 0.19420307948000193]    0.199758
#  243                    [0.42547600719272927, nan, nan]    0.425476
#  244                    [0.28213113784587984, nan, nan]    0.282131
#  245                         [0.43286418962810247, nan]    0.432864
#  246  [0.3245192677983878, 0.3242696681980175, 0.369...    0.339566
#
#  [247 rows x 10 columns],
#  12:                     ngram  freq      poisson  len  batch  stopwords  \
#  0         (of, India, on)    20 -1436.451330    3     13  [1, 0, 1]
#  1       (it, because, it)    21 -1441.053246    3     13  [1, 0, 1]
#  2        (of, France, on)    20 -1450.583857    3     13  [1, 0, 1]
#  3              (0, –0, 0)    24 -1451.594131    3     13  [1, 0, 1]
#  4          (in, 1989, in)    20 -1460.000185    3     13  [1, 0, 1]
#  ..                    ...   ...          ...  ...    ...        ...
#  118        (a, good, way)    46 -3011.718806    3     13  [1, 0, 0]
#  119              (10, on)    58 -3025.188864    2     13     [0, 1]
#  120  (character, in, The)    43 -3034.241481    3     13  [0, 1, 1]
#  121             (a, need)    60 -3043.807783    2     13     [1, 0]
#  122      (name, is, also)    44 -3064.952969    3     13  [0, 1, 1]
#
#                                              mwe_vector  \
#  0    [-0.005481113363282327, 0.010979985667776181, ...
#  1    [0.014882181276500305, -0.01879481656614366, -...
#  2    [-0.005634832271250369, -0.000938806303815064,...
#  3    [0.0012083669447360782, 0.009282815154159524, ...
#  4    [0.018965036743103725, 0.007948806043793345, -...
#  ..                                                 ...
#  118  [0.029953138215138866, 0.032769182463150595, 0...
#  119  [-0.0036017321155458566, -0.001336783195607307...
#  120  [-0.03792254954842821, 0.0002802759160689948, ...
#  121  [0.06748242236670059, 0.07753027420850156, -0....
#  122  [0.016618857600389263, 0.06974767431432011, 0....
#
#                                       component_vectors  \
#  0    [[0.4164072531561375, 0.3893520116913338, 0.43...
#  1    [[0.3695335729265582, 0.0683732446818503, -0.1...
#  2    [[0.4164072531561375, 0.3893520116913338, 0.43...
#  3    [[0.19552554303839648, -0.1999099601197077, -0...
#  4    [[0.44729726712105256, 0.26915959883927276, 0....
#  ..                                                 ...
# ...
#
#                                       component_cosims  cosine_sim
#  0                      [nan, 0.2193893564264845, nan]    0.219389
#  1                     [nan, 0.09465519641750875, nan]    0.094655
#  2                     [nan, 0.04799167998396542, nan]    0.047992
#  3    [nan, -0.03056144603348497, 0.49878367599339846]    0.234111
#  4                     [nan, 0.19234242209825708, nan]    0.192342
#  ..                                                ...         ...
#  102   [0.15013084194470977, nan, 0.28762039592560423]    0.218876
#  103                    [nan, nan, 0.3716688839199078]    0.371669
#  104    [nan, 0.09470757654006828, 0.4220024110490137]    0.258355
#  105                   [nan, 0.17131320163731514, nan]    0.171313
#  106                   [nan, nan, 0.05451193195682071]    0.054512
#
#  [107 rows x 10 columns],
#  14:                        ngram  freq      poisson  len  batch  stopwords  \
#  0              (0, 2009, 10)    22 -1480.876210    3     15  [1, 0, 0]
#  1             (in, 2006, in)    20 -1486.614698    3     15  [1, 0, 1]
#  2                 (0, 19, 3)    22 -1494.182382    3     15  [1, 0, 1]
#  3          (of, freedom, of)    21 -1495.386088    3     15  [1, 0, 1]
#  4           (the, town, the)    20 -1514.718029    3     15  [1, 0, 1]
#  5               (0, 2009, 4)    23 -1562.993583    3     15  [1, 0, 1]
#  6                 (0, 18, 3)    23 -1565.844179    3     15  [1, 0, 1]
#  7                  (0, 2, 7)    23 -1592.135648    3     15  [1, 1, 0]
#  8             (to, flee, to)    24 -1595.707766    3     15  [1, 0, 1]
#  9              (0, 2001, 10)    25 -1669.576702    3     15  [1, 0, 0]
#  10             (0, 2005, 10)    25 -1677.042419    3     15  [1, 0, 0]
#  11        (as, powerful, as)    26 -1740.720144    3     15  [1, 0, 1]
#  12              (0, 2009, 7)    26 -1745.149686    3     15  [1, 0, 0]
#  13                (0, 20, 3)    26 -1767.507423    3     15  [1, 0, 1]
#  14          (Division, 2, 1)    27 -1792.675646    3     15  [0, 1, 1]
#  15        (from, January, 1)    26 -1809.257917    3     15  [1, 0, 1]
#  16            (a, person, a)    25 -1817.263561    3     15  [1, 0, 1]
#  17          (and, west, and)    26 -1879.778745    3     15  [1, 0, 1]
#  18              (0, 2001, 3)    28 -1891.729481    3     15  [1, 0, 1]
#  19              (0, 2009, 8)    29 -1940.067978    3     15  [1, 0, 0]
#  20                 (2, 9, 2)    30 -2026.627003    3     15  [1, 0, 1]
#  21                 (0, 2, 6)    30 -2072.124359    3     15  [1, 1, 0]
#  22              (0, 2006, 7)    32 -2140.642215    3     15  [1, 0, 0]
#  23              (0, 2000, 4)    32 -2151.056203    3     15  [1, 0, 1]
#  24         (he, thought, he)    33 -2174.811542    3     15  [1, 0, 1]
#  25             (0, 2003, 10)    33 -2191.218102    3     15  [1, 0, 0]
#  26             (0, 1, Total)    33 -2206.561193    3     15  [1, 1, 0]
#  27                (0, 22, 3)    33 -2221.966390    3     15  [1, 0, 1]
#  28              (0, 2009, 6)    34 -2276.808987    3     15  [1, 0, 0]
#  29                 (2017, 1)    45 -2295.239468    2     15     [0, 1]
#  30         (law, says, that)    37 -2308.650622    3     15  [0, 0, 1]
#  31              (0, 2003, 7)    35 -2322.783908    3     15  [1, 0, 0]
#  32     (for, President, for)    34 -2377.012253    3     15  [1, 0, 1]
#  33          (where, it, can)    36 -2404.137064    3     15  [0, 1, 1]
#  34              (0, 2009, 3)    36 -2431.593340    3     15  [1, 0, 1]
#  35  (United, States, United)    37 -2446.988052    3     15  [0, 0, 0]
#  36        (his, family, was)    36 -2485.730290    3     15  [1, 0, 1]
#  37              (0, 2005, 5)    38 -2542.745715    3     15  [1, 0, 0]
#  38               (Ret, 2, 4)    39 -2557.128912    3     15  [0, 1, 1]
#  39                (0, 17, 3)    38 -2557.950651    3     15  [1, 0, 1]
#  40              (0, 2001, 7)    40 -2646.183642    3     15  [1, 0, 0]
#  41              (0, 2001, 1)    39 -2654.182966    3     15  [1, 0, 1]
#  42           (his, name, is)    38 -2667.371974    3     15  [1, 0, 1]
#  43         (August, 2016, 4)    42 -2691.078174    3     15  [0, 0, 1]
#  44                (0, 13, 3)    40 -2698.156939    3     15  [1, 0, 1]
#  45                (0, 11, 3)    40 -2704.832937    3     15  [1, 0, 1]
#  46                (with, 10)    52 -2705.248009    2     15     [1, 0]
#  47               (Ret, 5, 4)    43 -2773.156738    3     15  [0, 0, 1]
#  48              (0, 2005, 7)    42 -2788.078876    3     15  [1, 0, 0]
#  49              (0, 2005, 6)    42 -2797.774642    3     15  [1, 0, 0]
#  50                 (2010, 5)    57 -2820.278532    2     15     [0, 0]
#  51              (0, 2005, 8)    43 -2850.219670    3     15  [1, 0, 0]
#  52              (0, 0, 1983)    43 -2890.861176    3     15  [1, 1, 0]
#  53             (0, Total, 7)    45 -2904.892882    3     15  [1, 0, 0]
#  54                (0, 12, 3)    43 -2905.147340    3     15  [1, 0, 1]
#  55           (on, the, game)    41 -2952.023332    3     15  [1, 1, 0]
#  56          (Division, 1, 1)    46 -3043.815744    3     15  [0, 1, 1]
#
#                                             mwe_vector  \
#  0   [-0.07183530664105524, 0.09425565408194797, 0....
#  1   [0.06765467223501567, 0.13790381988072964, -0....
#  2   [-0.004236259637085587, 0.022338571063547672, ...
#  3   [-0.0937132349088654, -0.054474240781413316, -...
#  4   [-0.05092660700038748, 0.06531535431344837, 0....
#  5   [-0.11142671625450934, 0.09767455762826545, 0....
#  6   [-0.016365619232703656, 0.010258930493217959, ...
#  7   [-0.02953277968032893, -0.020414574962591518, ...
#  8   [0.04841242824549537, -0.11940241998201638, 0....
#  9   [-0.02211459721183199, -0.011740534870103214, ...
#  10  [0.07266654780118927, -0.007082245113661309, 0...
#  11  [0.045304463652294624, 0.020730856062781324, -...
#  12  [-0.07364091399509393, 0.05529274829616032, 0....
#  13  [-0.08224785956557887, -0.01779219773208345, 0...
#  14  [-0.02710636419263876, -0.01160109471885942, 0...
#  15  [-0.157582899214218, -0.024602277699051406, 0....
#  16  [-0.08729509028644279, 0.03368210518964268, 0....
#  17  [-0.06915353680391895, 0.1099018200980333, 0.0...
#  18  [-0.05599573061716779, 0.022148860743753475, 0...
#  19  [-0.0699977720385679, 0.038439508560593465, 0....
#  20  [0.021191393646040925, -0.11380105273961545, 0...
#  21  [-0.025966005932280538, -0.0497126237686092, 0...
#  22  [-0.05625705359543127, 0.02224512828945953, 0....
#  23  [-0.10964393977176276, -0.05825601627192233, 0...
#  24  [-0.032985456267423115, 0.06953160815010273, 0...
#  25  [-0.08064376912727603, -0.0664477432657083, 0....
#  26  [0.00883180515277082, -0.03471295271707105, -0...
#  27  [-0.01235588170446246, 0.04369112852899423, -0...
#  28  [-0.08479528961458148, 0.06806671865813169, 0....
#  29  [-0.2187132838262841, 0.14717942890476143, 0.0...
#  30  [-0.10949091258578812, 0.03880428075626867, -0...
#  31  [-0.07872989584642243, -0.01811919118162401, 0...
#  32  [-0.2894072378757573, 0.052525745095926564, -0...
#  33  [0.06715272180262866, -0.005319490933563701, -...
#  34  [-0.14424811136341306, 0.03970073646509615, 0....
#  35  [-0.11742581826770182, 0.01893929078141667, -0...
#  36  [0.04520353896468522, -0.0012414212197942797, ...
#  37  [-0.057341207289982966, -0.033980911926353524,...
#  38  [-0.07465273873639981, -0.08321698596644007, 0...
#  39  [-0.010054588409351157, -0.055974791312717966,...
#  40  [-0.10854816613875196, 0.02584109422588119, 0....
#  41  [-0.057634009193824984, 0.021231883810983378, ...
#  42  [0.1042212490906996, 0.027834517697396473, -0....
#  43  [-0.062140103596747445, 0.058050289440282725, ...
#  44  [0.042491122335645656, -0.03834797900590065, -...
#  45  [0.03735583818289404, -0.10118645654976438, -0...
#  46  [-0.04602412016557808, -0.08939738483327403, 0...
#  47  [-0.08894640217694205, -0.09810477628705855, 0...
#  48  [-0.015223322854510795, 0.04938274697238565, -...
#  49  [-0.02963962292129273, 0.007193100135607591, 0...
#  50  [-0.0020350557816420944, 0.3818081725407302, -...
#  51  [0.0006616296152463789, -0.005596041575513703,...
#  52  [-0.11234723721509034, -0.2080124832972792, -0...
#  53  [-0.029654432151458538, 0.005190201089238089, ...
#  54  [0.030201013067730608, -0.11415725509421543, 0...
#  55  [0.04101498264718183, 0.024711362830418648, -0...
#  56  [-0.0805679608098356, -0.021917697793414324, 0...
#
#                                      component_vectors  \
#  0   [[-0.5642910799010921, 0.16564220030017535, -0...
#  1   [[0.03461441571670943, -0.16168365585783953, 0...
#  2   [[-0.5642910799010921, 0.16564220030017535, -0...
#  3   [[0.44089542818188543, -0.4134295874988768, 0....
#  4   [[0.48892506127654006, 0.1495594672853008, 0.1...
#  5   [[-0.5642910799010921, 0.16564220030017535, -0...
#  6   [[-0.5642910799010921, 0.16564220030017535, -0...
#  7   [[-0.5642910799010921, 0.16564220030017535, -0...
#  8   [[-0.7019541878410688, 0.07782000279443277, 0....
#  9   [[-0.5642910799010921, 0.16564220030017535, -0...
#  10  [[-0.5642910799010921, 0.16564220030017535, -0...
#  11  [[0.21013644595948952, 0.04453028271910553, 0....
#  12  [[-0.5642910799010921, 0.16564220030017535, -0...
#  13  [[-0.5642910799010921, 0.16564220030017535, -0...
#  14  [[-0.03439516279606161, 0.20884260826965204, 0...
#  15  [[-0.6963915001679009, -0.6151811745490471, -0...
#  16  [[-0.5635055042740232, -0.365985599485716, 0.6...
#  17  [[-0.41762309510587253, -0.045190027369706016,...
#  18  [[-0.5642910799010921, 0.16564220030017535, -0...
#  19  [[-0.5642910799010921, 0.16564220030017535, -0...
#  20  [[-0.0813530704385497, 0.11744415194314603, 0....
#  21  [[-0.5642910799010921, 0.16564220030017535, -0...
#  22  [[-0.5642910799010921, 0.16564220030017535, -0...
#  23  [[-0.5642910799010921, 0.16564220030017535, -0...
#  24  [[-0.009523622482891165, -0.12911250934439716,...
#  25  [[-0.5642910799010921, 0.16564220030017535, -0...
#  26  [[-0.5642910799010921, 0.16564220030017535, -0...
#  27  [[-0.5642910799010921, 0.16564220030017535, -0...
#  28  [[-0.5642910799010921, 0.16564220030017535, -0...
#  29  [[-0.30622443663647686, 0.26907035818174013, -...
#  30  [[0.08474462152947461, -0.032788594788964565, ...
#  31  [[-0.5642910799010921, 0.16564220030017535, -0...
#  32  [[-0.42929030887086544, 0.4175193853537019, 0....
#  33  [[0.10941900206015892, -0.002603384320930511, ...
#  34  [[-0.5642910799010921, 0.16564220030017535, -0...
#  35  [[-0.6834021215447421, 0.3421859880280019, -0....
#  36  [[-0.19439861088725943, 0.11283963879297873, 0...
#  37  [[-0.5642910799010921, 0.16564220030017535, -0...
#  38  [[0.011212912318592226, -0.3773834317627158, 0...
#  39  [[-0.5642910799010921, 0.16564220030017535, -0...
#  40  [[-0.5642910799010921, 0.16564220030017535, -0...
#  41  [[-0.5642910799010921, 0.16564220030017535, -0...
#  42  [[-0.19439861088725943, 0.11283963879297873, 0...
#  43  [[-0.09469943643908998, -0.13598440296935307, ...
#  44  [[-0.5642910799010921, 0.16564220030017535, -0...
#  45  [[-0.5642910799010921, 0.16564220030017535, -0...
#  46  [[-0.4844301251774914, -0.3297400098756939, 0....
#  47  [[0.011212912318592226, -0.3773834317627158, 0...
#  48  [[-0.5642910799010921, 0.16564220030017535, -0...
#  49  [[-0.5642910799010921, 0.16564220030017535, -0...
#  50  [[-0.3161194368089147, 0.14673417093571495, -0...
#  51  [[-0.5642910799010921, 0.16564220030017535, -0...
#  52  [[-0.5642910799010921, 0.16564220030017535, -0...
#  53  [[-0.5642910799010921, 0.16564220030017535, -0...
#  54  [[-0.5642910799010921, 0.16564220030017535, -0...
#  55  [[0.15529592905674677, 0.14659882175724034, 0....
#  56  [[-0.03439516279606161, 0.20884260826965204, 0...
#
#                                       component_cosims  cosine_sim
#  0        [nan, 0.335791763377438, 0.2700616376577594]    0.302927
#  1                   [nan, -0.004722882015737083, nan]   -0.004723
#  2                     [nan, 0.23763806471858698, nan]    0.237638
#  3                      [nan, 0.4359665563763755, nan]    0.435967
#  4                     [nan, 0.10868166692886402, nan]    0.108682
#  5                     [nan, 0.32083953255613007, nan]    0.320840
#  6                     [nan, 0.27158990133979954, nan]    0.271590
#  7                      [nan, nan, 0.4298836665091411]    0.429884
#  8                     [nan, 0.47167184382701083, nan]    0.471672
#  9      [nan, 0.4951454831007592, 0.35149760490471765]    0.423322
#  10      [nan, 0.4571868857480853, 0.4855160352916681]    0.471351
#  11                  [nan, -0.003467677006500268, nan]   -0.003468
#  12    [nan, 0.34902117315131453, 0.32616022998405203]    0.337591
#  13                    [nan, 0.25761145655713646, nan]    0.257611
#  14                    [0.14140834758407322, nan, nan]    0.141408
#  15                    [nan, 0.12828375915452875, nan]    0.128284
#  16                    [nan, 0.10804178590772967, nan]    0.108042
#  17                     [nan, 0.5772798011789453, nan]    0.577280
#  18                     [nan, 0.4578592959080362, nan]    0.457859
#  19       [nan, 0.3368410967581061, 0.331503059563367]    0.334172
#  20                     [nan, 0.6112566092928364, nan]    0.611257
#  21                     [nan, nan, 0.4618115653297288]    0.461812
#  22     [nan, 0.4176191861921489, 0.28911992004473364]    0.353370
#  23                    [nan, 0.25729428012176014, nan]    0.257294
#  24                    [nan, 0.34041375379628236, nan]    0.340414
#  25     [nan, 0.47875024100904234, 0.4089633895845636]    0.443857
#  26                    [nan, nan, 0.21164723630871812]    0.211647
#  27                    [nan, 0.27040340082384434, nan]    0.270403
#  28    [nan, 0.27248994743627136, 0.33798453623851915]    0.305237
#  29                         [0.13907466161430632, nan]    0.139075
#  30     [0.1798051507410707, 0.13202969926328834, nan]    0.155917
#  31      [nan, 0.5017461142061069, 0.3797227375739717]    0.440734
#  32                     [nan, 0.3215651327048661, nan]    0.321565
#  33                    [0.14556913667114352, nan, nan]    0.145569
#  34                    [nan, 0.27897503110148014, nan]    0.278975
#  35  [0.43841887942206037, 0.2771344031962486, 0.43...    0.384657
#  36                   [nan, 0.053980780976188324, nan]    0.053981
#  37      [nan, 0.43522964765769523, 0.310203788241493]    0.372717
#  38                    [0.40723173514781746, nan, nan]    0.407232
#  39                    [nan, 0.32201511222092644, nan]    0.322015
#  40     [nan, 0.5382012854428189, 0.33147211764712026]    0.434837
#  41                     [nan, 0.3531577486045476, nan]    0.353158
#  42                     [nan, 0.1254648209258122, nan]    0.125465
#  43        [0.81582194317563, 0.7062983457280041, nan]    0.761060
#  44                    [nan, 0.40840900820998766, nan]    0.408409
#  45                     [nan, 0.4578659421345452, nan]    0.457866
#  46                         [nan, 0.04875664278086924]    0.048757
#  47      [0.47341707937064825, 0.549300402795363, nan]    0.511359
#  48     [nan, 0.5180419142942086, 0.36848440700324137]    0.443263
#  49      [nan, 0.5159912870577916, 0.4269961648474196]    0.471494
#  50         [0.34553899593100657, 0.03530845979374065]    0.190424
#  51      [nan, 0.4822171729482364, 0.4323775459290765]    0.457297
#  52                     [nan, nan, 0.5479221015128851]    0.547922
#  53    [nan, 0.24065384324794786, 0.32878632881550157]    0.284720
#  54                    [nan, 0.37556204409853855, nan]    0.375562
#  55                    [nan, nan, 0.06897350270230246]    0.068974
#  56                    [0.23019725632032317, nan, nan]    0.230197  }

# %%
# Removed
    #print('Gathering MWE stats')
    # For each MWE, evaluate stats. Record vectors (in case we want to calculate different metrics later).
    #statsf = pd.DataFrame(columns=['ngram', 'stopwords', 'mwe_vector', 'component_vectors', 'component_cosims', 
    #                               'cosine_sim', 'base_nearest', 'mwe_nearest'])

    #for exp in batch_dfs[bb].ngram:
    #    statsf = mwe_score(exp,batch_model,statsf)

    #  Join back onto DataFrame
    #batch_dfs[bb] = batch_dfs[bb].merge(statsf, on='ngram')

# %%
# Merge dataframes, sort by compositionality metric, export

# Also want the default batches with batch no < 0
all_batches = ngram_eval[ngram_eval.batch < 0]

for d in range(batch_count):
    all_batches = all_batches.append(batch_dfs[d])
    
all_batches = all_batches.sort_values('cosine_sim')
all_batches = all_batches.reset_index(drop=True)

all_batches.to_csv(datapath+'/Models/2 GloVe/Results/simple_output_001.csv', index=False)

# %%
all_batches
