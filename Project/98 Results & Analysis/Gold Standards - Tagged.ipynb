# %% [markdown]
# "Gold standard" reference lists of MWEs, ranked for compositionality.
# As used in Roberts & Egg (2018).
#
# * __F_ENC__: Farahmand et al, 2015. __[farahmand_comp_data]__
#  * 1042 noun compounds
#  * 5 binary judgements -> Likert scale
# * __R_ENC__: Reddy et al, 2011. __[reddy_comp_data]__
#  * 90 noun compounds
#  * Mechanical Turk, 6 binary judgements -> Likert
# * __MC_VPC__: McCarthy et al 2003. __[mccarthy_comp_vpc]__
#  * 117 verb-particle pairs
#  * 3 judges, avergaed scores on 11-point scale.
# * __D_ADJN__: Biemann and Giesbrecht. __[disco_2011]__
#  * 68 Adj-NN compounds from (training and validation) for Disco 2011.
#  * Mechanical Turk, 11-point scale.
# * __MC_VN__: McCarthy et al 2007.  __[mccarthy_comp_vn]__
#  * 638 verb-object pairs
#  * 2 judges, 6-point scale.

# %%
import os

path = 'C:/Users/'+os.getlogin()+'/Google Drive/University/Dissertation'
datapath = 'C:/Users/'+os.getlogin()+'/Dissertation Data'
#datapath = 'E:/Dissertation Data'

os.chdir(path)
os.getcwd()
# Out:
# 'C:\\Users\\tom\\Google Drive\\University\\Dissertation'

# %%
import pandas as pd
import numpy as np

# %%
def exp_to_tuple(exp,sep=' '):
    return tuple(exp.split(sep))

# %%
# Import Farahmand et al's list of compound nouns - 1042

F_ENC = pd.read_csv(path+'/Data/Gold Standards/en_ncs_noncompositional_conventionalized/instances_judgments/comb-judgements.csv')

F_ENC['noncomp_score'] = F_ENC[['noncomp_1', 'noncomp_2', 'noncomp_3', 'noncomp_4']].sum(axis=1)

F_ENC = F_ENC[['compound', 'noncomp_score']].sort_values('noncomp_score', ascending=False).rename(columns={'compound' : 'mwe', 'noncomp_score' : 'gs_score'}).reset_index(drop=True)

F_ENC['mwe'] = F_ENC.mwe.apply(exp_to_tuple)

F_ENC
# Out:
#                         mwe  gs_score
# 0          (academy, award)         4
# 1              (hard, disk)         4
# 2            (goose, bumps)         4
# 3            (grass, roots)         4
# 4         (greenhouse, gas)         4
# ...                     ...       ...
# 1037      (graduation, day)         0
# 1038  (grain, requirements)         0
# 1039        (grape, leaves)         0
# 1040       (belief, system)         0
# 1041    (machine, language)         0
#
# [1042 rows x 2 columns]

# %%
# Import Reddy et al's noun compounds

R_ENC = pd.read_csv(path+'/Data/Gold Standards/ijcnlp_compositionality_data/MeanAndDeviations.clean.txt',
                   sep = "\s+").reset_index()

def subber(s):
    return s[:-2]

R_ENC['mwe'] = R_ENC['index'].apply(subber) + ' ' + R_ENC['#word'].apply(subber)
R_ENC['gs_score'] = 5 - R_ENC.Cpd_mean

R_ENC = R_ENC[['mwe' , 'gs_score']].sort_values('gs_score', ascending = False).reset_index(drop=True)

R_ENC['mwe'] = R_ENC.mwe.apply(exp_to_tuple)

R_ENC
# Out:
#                     mwe  gs_score
# 0        (gravy, train)  4.689655
# 1         (cloud, nine)  4.666667
# 2        (ivory, tower)  4.535714
# 3        (melting, pot)  4.461538
# 4      (silver, bullet)  4.333333
# ..                  ...       ...
# 85       (speed, limit)  0.172414
# 86     (swimming, pool)  0.133333
# 87  (graduate, student)  0.100000
# 88       (engine, room)  0.068966
# 89    (climate, change)  0.034483
#
# [90 rows x 2 columns]

# %%
# MC_VPC
MC_VPC1 = pd.read_csv(path+'/Data/Gold Standards/vpc_comp_mccarthy/Judge1',
                   sep = '\s*\:\s*', header = None, index_col=0,
                      na_values = '?', engine='python'
                     ).reset_index(drop=True).drop_duplicates()   # Duplicate entry for "look+up" - removed

MC_VPC1.columns= ['mwe', 'freq', 'comp1']
#MC_VPC1['comp1'] = MC_VPC1.comp1.astype(float)

MC_VPC2 = pd.read_csv(path+'/Data/Gold Standards/vpc_comp_mccarthy/Judge2',
                   sep = '\s*\:\s*', header = None, index_col=0,
                      na_values = '?', engine='python'
                     ).reset_index(drop=True).drop_duplicates()

MC_VPC2.columns= ['mwe', 'freq', 'comp2']

MC_VPC3 = pd.read_csv(path+'/Data/Gold Standards/vpc_comp_mccarthy/Judge3',
                   sep = '\s*\:\s*', header = None, index_col=0,
                      na_values = '?', engine='python'
                     ).reset_index(drop=True).drop_duplicates()

MC_VPC3.columns= ['mwe', 'freq', 'comp3']

MC_VPC = MC_VPC1.merge(MC_VPC2,on=['mwe', 'freq']).merge(MC_VPC3,on=['mwe', 'freq'])

MC_VPC['gs_score'] = 10 - MC_VPC[['comp1', 'comp2', 'comp3']].mean(axis=1, skipna=True)

MC_VPC = MC_VPC.sort_values('gs_score', ascending = False)[['mwe','gs_score']].reset_index(drop=True)

MC_VPC['mwe'] = MC_VPC.mwe.apply(exp_to_tuple, sep='+')

MC_VPC
# Out:
#                mwe  gs_score
# 0       (cock, up)  9.333333
# 1      (whip, off)  8.500000
# 2     (space, out)  8.333333
# 3     (stave, off)  8.333333
# 4     (write, off)  8.333333
# ..             ...       ...
# 111    (step, out)  1.333333
# 112    (lie, down)  1.000000
# 113   (pull, down)  0.333333
# 114    (see, down)  0.000000
# 115  (spill, down)  0.000000
#
# [116 rows x 2 columns]

# %%
D_ADJN_test = pd.read_csv(path+'/Data/Gold Standards/DISCo 2011/english/num_scores/DISCo_num_EN_test.tsv',
                   sep = '\t', header = None
                     ).reset_index(drop=True)
D_ADJN_test.columns = ['class', 'mwe', 'gs_score']

# Only interested in ADJ_NN compounds
D_ADJN_test = D_ADJN_test[D_ADJN_test['class'] == 'EN_ADJ_NN'].drop('class', axis=1)



D_ADJN_train = pd.read_csv(path+'/Data/Gold Standards/DISCo 2011/english/num_scores/DISCo_num_EN_train.tsv',
                   sep = '\t', header = None
                     ).reset_index(drop=True)
D_ADJN_train.columns = ['class', 'mwe', 'gs_score']

# Only interested in ADJ_NN compounds
D_ADJN_train = D_ADJN_train[D_ADJN_train['class'] == 'EN_ADJ_NN'].drop('class', axis=1)


D_ADJN = D_ADJN_train.append(D_ADJN_test)

D_ADJN['gs_score'] = 100 - D_ADJN.gs_score

D_ADJN = D_ADJN.sort_values('gs_score', ascending = False).reset_index(drop=True)

D_ADJN['mwe'] = D_ADJN.mwe.apply(exp_to_tuple)

D_ADJN
# Out:
#                    mwe  gs_score
# 0         (blue, chip)        89
# 1          (red, tape)        89
# 2       (second, hand)        86
# 3        (right, wing)        84
# 4        (smart, card)        82
# ..                 ...       ...
# 130  (short, distance)         3
# 131   (early, version)         2
# 132    (small, island)         2
# 133       (olive, oil)         1
# 134     (lemon, juice)         0
#
# [135 rows x 2 columns]

# %%
MC_VN = pd.read_csv(path+'/Data/Gold Standards/emnlp2007data.txt',
                   sep = '\t', header = None
                     ).reset_index(drop=True)
MC_VN.columns = ['mwe', 'judge1', 'judge2']

MC_VN['gs_score'] = 6- MC_VN[['judge1', 'judge2']].mean(axis=1)

MC_VN = MC_VN[['mwe','gs_score']].sort_values('gs_score', ascending=False).reset_index(drop=True)

MC_VN['mwe'] = MC_VN.mwe.apply(exp_to_tuple)

MC_VN
# Out:
#                     mwe  gs_score
# 0         (have, heart)       5.0
# 1          (catch, eye)       5.0
# 2          (take, step)       5.0
# 3          (take, root)       5.0
# 4         (leave, mark)       5.0
# ..                  ...       ...
# 633         (eat, food)       0.0
# 634       (pay, amount)       0.0
# 635        (buy, house)       0.0
# 636  (discuss, problem)       0.0
# 637     (borrow, money)       0.0
#
# [638 rows x 2 columns]

# %%
# R&E's own outputs

robegg = open(path+'/Data/RobertsEgg/MWE_en-filtered.utf8.txt', 'r', encoding='utf-8')

for lines in range(10):
    print(robegg.readline())
# Out:
# compo	assoc	mwe	words
#
# -2	36.4506646641	")− 1
#
# -2	28.826415177	"— weiler
#
# -2	22.6054361674	"—&# X200B
#
# -2	22.8166041032	$11.6 million
#
# -2	27.2593711387	$23.5 million
#
# -2	24.1214802321	$24.5 million
#
# -2	28.2280390416	$25.5 million
#
# -2	24.394108659	$28.5 million
#
# -2	22.9419298938	$297.00. Poços

# %%
with open(path+'/Data/RobertsEgg/MWE_en-unfiltered.utf8.txt', 'r', encoding='utf-8') as robegg:
    robegg_df = pd.read_csv(robegg, names=['compo', 'assoc', 'mwe', 'w1', 'w2', 'w3'], 
                              delimiter='\t', na_values = ['--'], quoting=3, skiprows=1, skipinitialspace=True)

# Remove negative compositionality scores - R&E's filter
#robegg_df = robegg_df[robegg_df.compo >= -1].reset_index(drop=True)

robegg_df['mwe'] = robegg_df.mwe.apply(exp_to_tuple)

robegg_df
# Out:
#            compo        assoc                                   mwe        w1  \
# 0      -0.216884   452.575930                (this, individual, as)       NaN
# 1      -0.177191  1291.822316                    (that, in, humans)       NaN
# 2      -0.161933   191.902424                 (individual, as, the) -0.161933
# 3      -0.160100    49.378076                   (It, returned, one)       NaN
# 4      -0.144707    48.891020                      (had, two, more)       NaN
# ...          ...          ...                                   ...       ...
# 917642  0.941358   407.051275                         (Avenue, and)  0.941358
# 917643  0.944386  3105.318760                    (whether, or, not)  0.944386
# 917644  0.946745   143.658118                        (Records, and)  0.946745
# 917645  0.946882    67.013677                                (މ, ަ)  0.936615
# 917646  0.961247   101.721937  (tttttttttt, tttttttttt, tttttttttt)  0.961247
#
#               w2        w3
# 0      -0.216884       NaN
# 1            NaN -0.177191
# 2            NaN       NaN
# 3      -0.160100       NaN
# 4            NaN -0.144707
# ...          ...       ...
# 917642       NaN       NaN
# 917643       NaN       NaN
# 917644       NaN       NaN
# 917645  0.957148       NaN
# 917646  0.961247  0.961247
#
# [917647 rows x 6 columns]

# %%
from scipy.stats import spearmanr

def spmr(a,b):
    return spearmanr(a,b,nan_policy='omit')[0]

# %%
def lowtup(intup):
    return tuple(str.lower(t) for t in intup)

def corr_with_gs(inframe, scorecol, gsframe, refscore='gs_score', tiebreak = 'assoc', lowcase = False, mult=-1):
    '''
    When duplicates occur, retain record with largest value of tiebreak
    '''
    
    if str(inframe) == str(gsframe) and scorecol == refscore:
        return (len(inframe), 1.0, 1.0)
    
    if lowcase:
            _intersection = inframe[['mwe', scorecol, tiebreak]].merge(gsframe[['mwe', refscore]], 
                                             left_on=inframe.mwe.apply(lowtup), 
                                             right_on = gsframe.mwe.apply(lowtup), 
                                             how='inner')
    else:
        _intersection = inframe[['mwe', scorecol, tiebreak]].merge(gsframe[['mwe', refscore]], 
                                             left_on=inframe.mwe, 
                                             right_on = gsframe.mwe, 
                                             how='inner')
    
    _intersection = _intersection.sort_values(['key_0', tiebreak], ascending = [True, False]).drop_duplicates(subset=['key_0']).reset_index(drop=True)
    
    _overlap = len(_intersection)
    if _overlap:
        c_pears = _intersection[scorecol].corr(_intersection[refscore], method="pearson")
        c_spear = _intersection[scorecol].corr(_intersection[refscore], method="spearman")
    else:
        c_pears = np.nan
        c_spear = np.nan
        
    return (_overlap, mult*c_spear, mult*c_pears)

# %%
def corr_df(inframe, scorecol, gsframe, refscore='gs_score', tiebreak = 'assoc', lowcase = False):
    '''
    When duplicates occur, retain record with largest value of tiebreak
    '''
    
    if str(inframe) == str(gsframe) and scorecol == refscore:
        return (len(inframe), 1.0, 1.0)
    
    if lowcase:
            _intersection = inframe[['mwe', scorecol, tiebreak]].merge(gsframe[['mwe', refscore]], 
                                             left_on=inframe.mwe.apply(lowtup), 
                                             right_on = gsframe.mwe.apply(lowtup), 
                                             how='inner')
    else:
        _intersection = inframe[['mwe', scorecol, tiebreak]].merge(gsframe[['mwe', refscore]], 
                                             left_on=inframe.mwe, 
                                             right_on = gsframe.mwe, 
                                             how='inner')
    
    _intersection = _intersection.sort_values(['key_0', tiebreak], ascending = [True, False]).drop_duplicates(subset=['key_0'])
           
    return _intersection

# %%
corr_with_gs(robegg_df,'compo', F_ENC)
# Out:
# (631, 0.45766406237623103, 0.47314644528078603)

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1)
          }

# %%
RE_results = {}

for gs in gs_dict.keys():
    RE_results[gs] = corr_with_gs(robegg_df,'compo', gs_dict[gs][0], refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
RE_results
# Out:
# {'F_ENC': (631, 0.45766406237623103, 0.47314644528078603),
#  'R_ENC': (61, 0.6148618326919655, 0.6030799131312391),
#  'MC_VPC': (47, 0.4244468935228092, 0.3720121808366054),
#  'D_ADJN': (118, 0.5282258091736578, 0.6049064597349988),
#  'MC_VN': (132, 0.39246363536118933, 0.39533955699893253),
#  'RE_WIKI15': (917647, 1.0, 1.0)}

# %%
# Import my results. Converter interprets the strings in 'ngram' as tuples.

converter = {'ngram' : eval,
             #'stopwords' : eval
             #'mwe_vector' : eval,
             #'component_vectors' : eval,
             #'base_nearest' : eval,
             #'mwe_nearest' : eval,
            }

simp_res = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/simp_tagged_light_001.csv', 
                       converters= converter
                      )

# %%
indexer = 14300
simp_res[indexer:indexer+20]
# Out:
#                                    ngram  freq      poisson  len  batch  \
# 14300  (of|IN, English|NNP, football|NN)    31 -2133.134193    3      5
# 14301               (radio|NN, voice|NN)    29 -1310.676359    2      2
# 14302        (have|VBP, the|DT, name|NN)    30 -2132.885827    3      1
# 14303    (who|WP, became|VBD, famous|JJ)    21 -1357.951288    3      6
# 14304           (of|IN, the|DT, 1994|CD)    20 -1505.049214    3      1
# 14305           (no|DT, one|NN, was|VBD)    25 -1609.347620    3      2
# 14306               (82|CD, American|JJ)    38 -1758.990197    2      5
# 14307           (part|NN, of|IN, any|DT)    37 -2533.766297    3      6
# 14308         (in|IN, France|NNP, at|IN)    21 -1498.941415    3      4
# 14309               (Some|DT, areas|NNS)    24 -1136.364848    2      1
# 14310    (served|VBD, as|IN, senator|NN)    21 -1263.342615    3      4
# 14311         (born|VBN, 9|CD, June|NNP)    20 -1328.131625    3      3
# 14312         (Each|DT, of|IN, them|PRP)    29 -1935.562576    3      1
# 14313     (born|VBN, October|NNP, 17|CD)    26 -1702.693905    3      4
# 14314                  (An|DT, adult|JJ)    26 -1154.118816    2      2
# 14315          (rate|NN, of|IN, fire|NN)    22 -1412.623234    3      6
# 14316        (New|NNP, Territories|NNPS)    26 -1154.855859    2      1
# 14317                     (|HYPH, on|RP)    40 -1948.926888    2      1
# 14318             (died|VBD, without|IN)    38 -1822.913053    2      4
# 14319    (then|RB, |HYPH, President|NNP)    28 -1888.821527    3      7
#
#        stopwords                    component_cosims  cosine_sim
# 14300  [1, 0, 0]       [nan, 0.12516817, 0.35590157]    0.240535
# 14301     [0, 0]            [0.17999308, 0.30109388]    0.240543
# 14302  [0, 1, 0]       [0.31752214, nan, 0.16357005]    0.240546
# 14303  [0, 0, 0]  [0.24747948, 0.1341637, 0.3400316]    0.240558
# 14304  [1, 1, 0]               [nan, nan, 0.2405645]    0.240564
# 14305  [0, 0, 1]       [0.23164734, 0.24948514, nan]    0.240566
# 14306     [0, 0]             [0.12862773, 0.3525061]    0.240567
# 14307  [0, 1, 0]       [0.22932333, nan, 0.25184056]    0.240582
# 14308  [1, 0, 1]              [nan, 0.24059233, nan]    0.240592
# 14309     [0, 0]             [0.23022379, 0.2509852]    0.240604
# 14310  [0, 1, 0]       [0.26653725, nan, 0.21467386]    0.240606
# 14311  [1, 0, 0]       [nan, 0.25668848, 0.22453599]    0.240612
# 14312  [0, 1, 0]       [0.34139514, nan, 0.13984488]    0.240620
# 14313  [1, 0, 0]       [nan, 0.26686692, 0.21438111]    0.240624
# 14314     [0, 0]             [0.13790509, 0.3433477]    0.240626
# 14315  [0, 1, 0]       [0.34946385, nan, 0.13180952]    0.240637
# 14316     [0, 0]           [0.023802374, 0.45747674]    0.240640
# 14317     [1, 0]                    [nan, 0.2406431]    0.240643
# 14318     [0, 0]            [0.24165347, 0.23963296]    0.240643
# 14319  [0, 1, 0]       [-0.06367423, nan, 0.5449678]    0.240647

# %%
# Remove POS tags from tuples for matching

import re

pipematcher = re.compile("(.*)\|")
pipematch2 = re.compile("\|([A-Z]{2,4}\$?|[\$\:,\.\"]|``|\-LRB\-?|\-RRB\-?)")

def g1(matchobj):
    return matchobj.group(1)

def tup_matcher(tupstr, pattern=pipematcher):
    ot = []
    for w in tupstr:
        if w == '|HYPH': w = '-|HYPH'
        if re.match(pattern, w):
            ot.append(g1(pattern.match(w)))
    return tuple(ot)


def tup_rem(tupstr, pattern=pipematch2):
    ot = []
    for w in tupstr:
        if w == '|HYPH': w = '-|HYPH'
        ot.append(re.sub(pattern,'',w))
    return tuple(ot)

testtup = simp_res.ngram[149878]

tup_matcher(testtup)
# Out:
# ('-', 'Normandie')

# %%
# Pipe, followed by 2-4 capitals and maybe a $ OR by specific punctuation marks OR by the tags for parentheses
pipematch2 = re.compile("\|([A-Z]{2,4}\$?|[\$\:,\.\"]|``|\-LRB\-?|\-RRB\-?)")

testtup = simp_res.ngram[14319]

tup_rem(testtup)
# Out:
# ('then', '-', 'President')

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1)
          }

# %%
simp_res['ngram_tag'] = simp_res.ngram
simp_res['ngram'] = simp_res.ngram_tag.apply(tup_rem)

simp_res
# Out:
#                        ngram  freq      poisson  len  batch   stopwords  \
# 0          (was, born, here)    32 -2119.509496    3      8   [1, 1, 0]
# 1               (s, then, -)    20 -1419.198013    3      4   [1, 0, 1]
# 2          (this, time, for)    20 -1389.097772    3      9   [0, 0, 1]
# 3        (other, two, being)    28 -1831.298757    3     10   [0, 0, 0]
# 4                 (In, This)    26 -1380.814735    2      7      [1, 0]
# ...                      ...   ...          ...  ...    ...         ...
# 149995             (%, 7, %)    20 -1332.973488    3     13        [-2]
# 149996        (the, Were, -)    22 -1422.855539    3     14  [1, -1, 1]
# 149997  (of, Schwarzburg, -)    24 -1551.293123    3     14  [1, -1, 1]
# 149998     (the, Nanboku, -)    33 -2145.863245    3     14  [1, -1, 1]
# 149999     (the, fastest, -)    34 -2213.693118    3     14  [1, -1, 1]
#
#                                component_cosims  cosine_sim  \
# 0                       [nan, nan, -0.21604778]   -0.216048
# 1                       [nan, -0.15213177, nan]   -0.152132
# 2               [-0.15749776, -0.13361101, nan]   -0.145554
# 3       [-0.13134842, -0.09783523, -0.19934192]   -0.142842
# 4                            [nan, -0.13744499]   -0.137445
# ...                                         ...         ...
# 149995                                       []         NaN
# 149996                          [nan, nan, nan]         NaN
# 149997                          [nan, nan, nan]         NaN
# 149998                          [nan, nan, nan]         NaN
# 149999                          [nan, nan, nan]         NaN
#
#                               ngram_tag
# 0          (was|VBD, born|VBN, here|RB)
# 1               (s|POS, then|RB, |HYPH)
# 2            (this|DT, time|NN, for|IN)
# 3         (other|JJ, two|CD, being|VBG)
# 4                      (In|IN, This|DT)
# ...                                 ...
# 149995               (%|NN, 7|CD, %|NN)
# 149996        (the|DT, Were|VBN, |HYPH)
# 149997  (of|IN, Schwarzburg|NNP, |HYPH)
# 149998     (the|DT, Nanboku|NNP, |HYPH)
# 149999     (the|DT, fastest|RBS, |HYPH)
#
# [150000 rows x 9 columns]

# %%
simp_res[simp_res.ngram == ('Ving', 'Rhames')]
# Out:
#                  ngram  freq     poisson  len  batch stopwords  \
# 144663  (Ving, Rhames)    20 -606.668931    2      1  [-1, -1]
#
#        component_cosims  cosine_sim               ngram_tag
# 144663       [nan, nan]         NaN  (Ving|NNP, Rhames|NNP)

# %%
simp_res = simp_res[~np.isnan(simp_res.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe'}).reset_index(drop=True)

simp_res
# Out:
#                         mwe  freq      poisson  len  batch  stopwords  \
# 0         (was, born, here)    32 -2119.509496    3      8  [1, 1, 0]
# 1              (s, then, -)    20 -1419.198013    3      4  [1, 0, 1]
# 2         (this, time, for)    20 -1389.097772    3      9  [0, 0, 1]
# 3       (other, two, being)    28 -1831.298757    3     10  [0, 0, 0]
# 4                (In, This)    26 -1380.814735    2      7     [1, 0]
# ...                     ...   ...          ...  ...    ...        ...
# 143642            (SSE4, 1)    32 -1397.623791    2      1     [0, 1]
# 143643            (-, Lapu)    22  -994.898375    2      1     [1, 0]
# 143644         (-, Marnand)    24 -1085.279502    2      1     [1, 0]
# 143645           (WIN, WIN)    70 -2402.440072    2      6     [0, 0]
# 143646            (Lapu, -)    23 -1038.646030    2      2     [0, 1]
#
#                                component_cosims  cosine_sim  \
# 0                       [nan, nan, -0.21604778]   -0.216048
# 1                       [nan, -0.15213177, nan]   -0.152132
# 2               [-0.15749776, -0.13361101, nan]   -0.145554
# 3       [-0.13134842, -0.09783523, -0.19934192]   -0.142842
# 4                            [nan, -0.13744499]   -0.137445
# ...                                         ...         ...
# 143642                          [0.980065, nan]    0.980065
# 143643                        [nan, 0.98205227]    0.982052
# 143644                        [nan, 0.98449343]    0.984493
# 143645                   [0.9861782, 0.9861782]    0.986178
# 143646                          [0.989316, nan]    0.989316
#
#                             ngram_tag
# 0        (was|VBD, born|VBN, here|RB)
# 1             (s|POS, then|RB, |HYPH)
# 2          (this|DT, time|NN, for|IN)
# 3       (other|JJ, two|CD, being|VBG)
# 4                    (In|IN, This|DT)
# ...                               ...
# 143642                (SSE4|NN, 1|CD)
# 143643              (|HYPH, Lapu|NNP)
# 143644           (|HYPH, Marnand|NNP)
# 143645               (WIN|VB, WIN|VB)
# 143646              (Lapu|NNP, |HYPH)
#
# [143647 rows x 9 columns]

# %%
_intersection = simp_res[['mwe', 'cosine_sim']].merge(F_ENC[['mwe', 'gs_score']], on='mwe', how='inner')

_intersection
# Out:
#                       mwe  cosine_sim  gs_score
# 0         (business, man)    0.093663         0
# 1             (zip, code)    0.102839         4
# 2            (death, row)    0.115153         4
# 3         (death, notice)    0.127828         0
# 4         (command, line)    0.150381         3
# ..                    ...         ...       ...
# 173       (touch, screen)    0.678733         1
# 174      (tape, recorder)    0.682743         0
# 175          (bony, fish)    0.688756         0
# 176   (particle, physics)    0.699622         0
# 177  (computer, graphics)    0.700243         0
#
# [178 rows x 3 columns]

# %%
simp_results = {}

for gs in gs_dict.keys():
    simp_results[gs] = corr_with_gs(simp_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
simp_results
# Out:
# {'F_ENC': (175, 0.22902421605697812, 0.2423163614162586),
#  'R_ENC': (11, 0.4100238428203847, 0.396349198913055),
#  'MC_VPC': (14, 0.11245927007520762, 0.10926147730010077),
#  'D_ADJN': (33, 0.26876149464489874, 0.30397591337092333),
#  'MC_VN': (35, 0.3390869220985702, 0.3611062679818502),
#  'RE_WIKI15': (74710, 0.5334823992028059, 0.5492710552900145)}

# %%
simp_low_results = {}

for gs in gs_dict.keys():
    simp_low_results[gs] = corr_with_gs(simp_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
simp_low_results
# Out:
# {'F_ENC': (222, 0.13521972409019778, 0.11963828494872672),
#  'R_ENC': (16, 0.25184121568510415, 0.2043730132921946),
#  'MC_VPC': (15, 0.16337759414053082, 0.06825241384104669),
#  'D_ADJN': (48, 0.1943313383568205, 0.22798529053510802),
#  'MC_VN': (37, 0.352470735408605, 0.37163346288397714),
#  'RE_WIKI15': (75734, 0.50623876520901, 0.5227199971813515)}

# %%
# 10% Wiki results - w2v

# %%
w10p_w2v = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/w10p_tagged_light_001.csv', 
                       converters= converter
                      )

# %%
w10p_w2v['ngram_tag'] = w10p_w2v.ngram
w10p_w2v['ngram'] = w10p_w2v.ngram_tag.apply(tup_rem)

w10p_w2v
# Out:
#                                ngram  freq      poisson  len  batch  \
# 0                  (delivered, from)    28 -1567.428918    2      5
# 1                   (then, had, two)    20 -1586.812073    3      3
# 2                (and, finally, for)    20 -1647.756550    3      4
# 3                  (one, before, it)    20 -1587.727730    3      7
# 4               (However, in, their)    20 -1642.620348    3      3
# ...                              ...   ...          ...  ...    ...
# 499995  (the, Barebones, Parliament)    23 -1552.893367    3     10
# 499996               (2nd, 2nd, 2nd)    24 -1598.434969    3     10
# 499997             (was, 49,445, in)    22 -1600.048879    3     10
# 499998              (a, modicum, of)    22 -1637.924770    3     10
# 499999       (a, semi-satellite, of)    22 -1640.856634    3     10
#
#          stopwords         component_cosims  cosine_sim  \
# 0           [0, 1]        [-0.2535712, nan]   -0.253571
# 1        [0, 1, 1]  [-0.24625674, nan, nan]   -0.246257
# 2        [1, 0, 1]  [nan, -0.22293654, nan]   -0.222937
# 3        [1, 0, 1]  [nan, -0.21940775, nan]   -0.219408
# 4        [0, 1, 1]   [-0.2108197, nan, nan]   -0.210820
# ...            ...                      ...         ...
# 499995  [1, -1, 0]   [nan, nan, 0.38508964]         NaN
# 499996        [-2]                       []         NaN
# 499997  [1, -1, 1]          [nan, nan, nan]         NaN
# 499998  [1, -1, 1]          [nan, nan, nan]         NaN
# 499999  [1, -1, 1]          [nan, nan, nan]         NaN
#
#                                        ngram_tag
# 0                       (delivered|VBD, from|IN)
# 1                     (then|RB, had|VBD, two|CD)
# 2                   (and|CC, finally|RB, for|IN)
# 3                    (one|CD, before|IN, it|PRP)
# 4                (However|RB, in|IN, their|PRP$)
# ...                                          ...
# 499995  (the|DT, Barebones|NNPS, Parliament|NNP)
# 499996                  (2nd|JJ, 2nd|JJ, 2nd|JJ)
# 499997               (was|VBD, 49,445|CD, in|IN)
# 499998                 (a|DT, modicum|NN, of|IN)
# 499999          (a|DT, semi-satellite|NN, of|IN)
#
# [500000 rows x 9 columns]

# %%
w10p_w2v = w10p_w2v[~np.isnan(w10p_w2v.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe', 'cosine_sim' : 'cosim_10w'}).reset_index(drop=True)

# %%
w10p_w2v
# Out:
#                                                 mwe  freq      poisson  len  \
# 0                                 (delivered, from)    28 -1567.428918    2
# 1                                  (then, had, two)    20 -1586.812073    3
# 2                               (and, finally, for)    20 -1647.756550    3
# 3                                 (one, before, it)    20 -1587.727730    3
# 4                              (However, in, their)    20 -1642.620348    3
# ...                                             ...   ...          ...  ...
# 482425  (środek.svgFile, Wygaszony, środek.svgFile)    36 -1588.358559    3
# 482426                       (Recurvirostridae, is)    25 -1276.332579    2
# 482427                           (OUL3, CRO1, CRO2)    36 -1515.104871    3
# 482428                                    (Lapu, -)    22 -1127.048317    2
# 482429                                       (ㄹ, ㄻ)    30 -1138.325224    2
#
#         batch  stopwords                      component_cosims  cosim_10w  \
# 0           5     [0, 1]                     [-0.2535712, nan]  -0.253571
# 1           3  [0, 1, 1]               [-0.24625674, nan, nan]  -0.246257
# 2           4  [1, 0, 1]               [nan, -0.22293654, nan]  -0.222937
# 3           7  [1, 0, 1]               [nan, -0.21940775, nan]  -0.219408
# 4           3  [0, 1, 1]                [-0.2108197, nan, nan]  -0.210820
# ...       ...        ...                                   ...        ...
# 482425      1  [0, 0, 0]     [0.9717464, 0.9375481, 0.9717464]   0.960347
# 482426      4     [0, 1]                     [0.96257687, nan]   0.962577
# 482427      2  [0, 0, 0]  [0.94491136, 0.97224206, 0.97286904]   0.963341
# 482428      2     [0, 1]                      [0.9648907, nan]   0.964891
# 482429      2     [0, 0]                [0.97117275, 0.982044]   0.976608
#
#                                                 ngram_tag
# 0                                (delivered|VBD, from|IN)
# 1                              (then|RB, had|VBD, two|CD)
# 2                            (and|CC, finally|RB, for|IN)
# 3                             (one|CD, before|IN, it|PRP)
# 4                         (However|RB, in|IN, their|PRP$)
# ...                                                   ...
# 482425  (środek.svgFile|NNP, Wygaszony|NNP, środek.svg...
# 482426                     (Recurvirostridae|NNP, is|VBZ)
# 482427                        (OUL3|NN, CRO1|NN, CRO2|NN)
# 482428                                  (Lapu|NNP, |HYPH)
# 482429                                     (ㄹ|SYM, ㄻ|SYM)
#
# [482430 rows x 9 columns]

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1),
           'W2V_SIMP20': (simp_res,'cosine_sim',1),
          }

# %%
w10p_w2v_results = {}

for gs in gs_dict.keys():
    w10p_w2v_results[gs] = corr_with_gs(w10p_w2v,'cosim_10w', gs_dict[gs][0], tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
w10p_w2v_results
# Out:
# {'F_ENC': (77, 0.3338230676249727, 0.34934247926095696),
#  'R_ENC': (10, 0.29696969696969694, 0.07717666068699167),
#  'MC_VPC': (32, 0.09080921630368811, 0.10787230663222218),
#  'D_ADJN': (9, 0.3025316904537665, 0.4184102581236103),
#  'MC_VN': (49, 0.22921891575582556, 0.23310807082891202),
#  'RE_WIKI15': (111526, 0.5975461349977123, 0.6042986100879869),
#  'W2V_SIMP20': (7230, 0.6237011383627981, 0.6350345458432904)}

# %%
w10p_w2v_low_results = {}

for gs in gs_dict.keys():
    w10p_w2v_low_results[gs] = corr_with_gs(w10p_w2v,'cosim_10w', gs_dict[gs][0], tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
w10p_w2v_low_results
# Out:
# {'F_ENC': (225, 0.10189399329703026, 0.10292981690017042),
#  'R_ENC': (33, 0.08777797459331552, 0.10858430253728699),
#  'MC_VPC': (40, 0.009219227683774676, 0.04929705380217415),
#  'D_ADJN': (47, 0.15577280705314026, 0.18893560425713435),
#  'MC_VN': (59, 0.0825885665715718, 0.07898790495746937),
#  'RE_WIKI15': (124553, 0.54478305802168, 0.5447835857143559),
#  'W2V_SIMP20': (16185, 0.5090069998411715, 0.5208077498480876)}

# %% [markdown]
# ## Results with cleansed tagged corpora
# Some tokens (e.g. hyphens) removed / recombined
#
# Also filtered candidate list to remove some low-quality items

# %%
converter = {'ngram' : eval,
             #'stopwords' : eval
             #'mwe_vector' : eval,
             #'component_vectors' : eval,
             #'base_nearest' : eval,
             #'mwe_nearest' : eval,
            }

simp_cln_res = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/simp_tagged_clean_light_001.csv', 
                       converters= converter
                      )

# %%
simp_cln_res['ngram_tag'] = simp_cln_res.ngram
simp_cln_res['ngram'] = simp_cln_res.ngram_tag.apply(tup_rem)

simp_cln_res
# Out:
#                            ngram  freq      poisson  len  batch   stopwords  \
# 0              (was, born, here)    32 -2115.954533    3      7   [1, 1, 0]
# 1                    (to, found)    54 -2767.761057    2      7      [1, 0]
# 2                       (:, end)    23 -1078.890289    2      2      [1, 0]
# 3               (born, in, then)    26 -1826.089851    3      3   [1, 1, 0]
# 4                (is, both, the)    35 -2521.230138    3     11   [1, 0, 1]
# ...                          ...   ...          ...  ...    ...         ...
# 149995     (of, Chaffin's, Farm)    58 -3167.096834    3      9  [1, -1, 0]
# 149996  (NHL, Plus/Minus, Award)    38 -1973.585423    3     10  [0, -1, 0]
# 149997         (the, Goblet, of)    40 -2656.494897    3     10  [1, -1, 1]
# 149998     (state, state, state)    48 -2965.054834    3     10        [-2]
# 149999      (Cup, Winners', Cup)    46 -2373.843488    3     12  [0, -1, 0]
#
#                      component_cosims  cosine_sim  \
# 0             [nan, nan, -0.26227063]   -0.262271
# 1                  [nan, -0.16069299]   -0.160693
# 2                  [nan, -0.15938467]   -0.159385
# 3             [nan, nan, -0.15382023]   -0.153820
# 4             [nan, -0.14895083, nan]   -0.148951
# ...                               ...         ...
# 149995         [nan, nan, 0.23580538]         NaN
# 149996  [0.14594129, nan, 0.28706568]         NaN
# 149997                [nan, nan, nan]         NaN
# 149998                             []         NaN
# 149999    [0.5904629, nan, 0.5904629]         NaN
#
#                                        ngram_tag
# 0                   (was|VBD, born|VBN, here|RB)
# 1                             (to|IN, found|VBN)
# 2                                  (:|:, end|VB)
# 3                     (born|VBN, in|IN, then|RB)
# 4                      (is|VBZ, both|CC, the|DT)
# ...                                          ...
# 149995          (of|IN, Chaffin|NNP's, Farm|NNP)
# 149996  (NHL|NNP, Plus|NNP/Minus|NNP, Award|NNP)
# 149997               (the|DT, Goblet|NNP, of|IN)
# 149998            (state|NN, state|NN, state|NN)
# 149999         (Cup|NNP, Winners|NNPS', Cup|NNP)
#
# [150000 rows x 9 columns]

# %%
simp_cln_res = simp_cln_res[~np.isnan(simp_cln_res.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe'}).reset_index(drop=True)

simp_cln_res
# Out:
#                       mwe  freq      poisson  len  batch  stopwords  \
# 0       (was, born, here)    32 -2115.954533    3      7  [1, 1, 0]
# 1             (to, found)    54 -2767.761057    2      7     [1, 0]
# 2                (:, end)    23 -1078.890289    2      2     [1, 0]
# 3        (born, in, then)    26 -1826.089851    3      3  [1, 1, 0]
# 4         (is, both, the)    35 -2521.230138    3     11  [1, 0, 1]
# ...                   ...   ...          ...  ...    ...        ...
# 143746         (GBR, GER)    31 -1020.735228    2      4     [0, 0]
# 143747            (3, -0)    61 -2648.449939    2      2     [1, 0]
# 143748       (Maerz, and)    49 -2302.220234    2      3     [0, 1]
# 143749         (WIN, WIN)    54 -1893.075074    2      3     [0, 0]
# 143750         (WIN, WIN)    70 -2399.962761    2      6     [0, 0]
#
#                 component_cosims  cosine_sim                     ngram_tag
# 0        [nan, nan, -0.26227063]   -0.262271  (was|VBD, born|VBN, here|RB)
# 1             [nan, -0.16069299]   -0.160693            (to|IN, found|VBN)
# 2             [nan, -0.15938467]   -0.159385                 (:|:, end|VB)
# 3        [nan, nan, -0.15382023]   -0.153820    (born|VBN, in|IN, then|RB)
# 4        [nan, -0.14895083, nan]   -0.148951     (is|VBZ, both|CC, the|DT)
# ...                          ...         ...                           ...
# 143746    [0.9553108, 0.9801254]    0.967718              (GBR|NN, GER|NN)
# 143747         [nan, 0.96958727]    0.969587                (3|CD, -0|SYM)
# 143748         [0.97895634, nan]    0.978956           (Maerz|NNP, and|CC)
# 143749  [0.97907865, 0.97907865]    0.979079            (WIN|NNP, WIN|NNP)
# 143750  [0.98635775, 0.98635775]    0.986358              (WIN|VB, WIN|VB)
#
# [143751 rows x 9 columns]

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1)
          }

# %%
simp_cln_results = {}

for gs in gs_dict.keys():
    simp_cln_results[gs] = corr_with_gs(simp_cln_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
simp_cln_results
# Out:
# {'F_ENC': (185, 0.19221739015340925, 0.2152835608183971),
#  'R_ENC': (13, 0.31129594706090835, 0.43709219321464243),
#  'MC_VPC': (14, 0.1477406097066453, 0.1137617851495493),
#  'D_ADJN': (37, 0.36341001733191636, 0.33764109902067596),
#  'MC_VN': (37, 0.35083809092223195, 0.4521265564587202),
#  'RE_WIKI15': (79326, 0.5555308640833292, 0.5688857603476392)}

# %%
simp_cln_low_results = {}

for gs in gs_dict.keys():
    simp_cln_low_results[gs] = corr_with_gs(simp_cln_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
simp_cln_low_results
# Out:
# {'F_ENC': (233, 0.10955715751243494, 0.10195783539750472),
#  'R_ENC': (17, 0.23190201505672198, 0.2169065227134563),
#  'MC_VPC': (15, 0.19210332497842636, 0.06129537111630709),
#  'D_ADJN': (50, 0.2617509476946104, 0.2584818638036634),
#  'MC_VN': (39, 0.3507440147572101, 0.44099631239336184),
#  'RE_WIKI15': (79818, 0.5245347427379836, 0.5399180885611622)}

# %% [markdown]
# Wiki (10%) results

# %%
converter = {'ngram' : eval,
             #'stopwords' : eval
             #'mwe_vector' : eval,
             #'component_vectors' : eval,
             #'base_nearest' : eval,
             #'mwe_nearest' : eval,
            }

w10p_cln_res = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/w10p_tagged_clean_light_001.csv', 
                       converters= converter
                      )

# %%
w10p_cln_res['ngram_tag'] = w10p_cln_res.ngram
w10p_cln_res['ngram'] = w10p_cln_res.ngram_tag.apply(tup_rem)

w10p_cln_res
# Out:
#                          ngram  freq      poisson  len  batch  stopwords  \
# 0       (However, since, then)    20 -1501.356357    3      4  [0, 0, 0]
# 1       (has, been, following)    20 -1563.921228    3      4  [1, 1, 0]
# 2            (both, times, by)    21 -1608.202878    3      8  [0, 0, 1]
# 3           (after, both, the)    20 -1643.568467    3      3  [1, 0, 1]
# 4       (However, even, after)    20 -1499.074445    3      2  [0, 0, 1]
# ...                        ...   ...          ...  ...    ...        ...
# 499995    (:, Paleogene, from)    24 -1669.762522    3     10       [-2]
# 499996          (of, $, 3,000)    22 -1681.886235    3     10       [-2]
# 499997            (la, la, la)    25 -1687.517191    3     10       [-2]
# 499998   (2015, -2016, school)    25 -1696.555611    3     10       [-2]
# 499999       (High, School, $)    23 -1705.340836    3     10       [-2]
#
#                              component_cosims  cosine_sim  \
# 0       [-0.22124107, -0.1947155, -0.2786541]   -0.231537
# 1                     [nan, nan, -0.22919384]   -0.229194
# 2             [-0.26926857, -0.18902278, nan]   -0.229146
# 3                     [nan, -0.22798495, nan]   -0.227985
# 4             [-0.17959411, -0.27630407, nan]   -0.227949
# ...                                       ...         ...
# 499995                                     []         NaN
# 499996                                     []         NaN
# 499997                                     []         NaN
# 499998                                     []         NaN
# 499999                                     []         NaN
#
#                                  ngram_tag
# 0          (However|RB, since|IN, then|RB)
# 1       (has|VBZ, been|VBN, following|VBG)
# 2              (both|CC, times|NNS, by|IN)
# 3              (after|IN, both|CC, the|DT)
# 4          (However|RB, even|RB, after|IN)
# ...                                    ...
# 499995       (:|:, Paleogene|NNP, from|IN)
# 499996              (of|IN, $|$, 3,000|CD)
# 499997            (la|NNP, la|NNP, la|NNP)
# 499998      (2015|CD, -2016|CD, school|NN)
# 499999         (High|NNP, School|NNP, $|$)
#
# [500000 rows x 9 columns]

# %%
w10p_cln_res = w10p_cln_res[~np.isnan(w10p_cln_res.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe', 'cosine_sim' : 'cosim_w'}).reset_index(drop=True)

w10p_cln_res
# Out:
#                            mwe  freq      poisson  len  batch  stopwords  \
# 0       (However, since, then)    20 -1501.356357    3      4  [0, 0, 0]
# 1       (has, been, following)    20 -1563.921228    3      4  [1, 1, 0]
# 2            (both, times, by)    21 -1608.202878    3      8  [0, 0, 1]
# 3           (after, both, the)    20 -1643.568467    3      3  [1, 0, 1]
# 4       (However, even, after)    20 -1499.074445    3      2  [0, 0, 1]
# ...                        ...   ...          ...  ...    ...        ...
# 473593      (OUL2, OUL3, CRO1)    36 -1537.197964    3      3  [0, 0, 0]
# 473594  (Recurvirostridae, is)    25 -1275.232759    2      4     [0, 1]
# 473595           (Laridae, is)    29 -1486.804386    2      4     [0, 1]
# 473596      (OUL3, CRO1, CRO2)    36 -1513.524083    3      2  [0, 0, 0]
# 473597                  (ㄹ, ㄻ)    30 -1137.007900    2      2     [0, 0]
#
#                              component_cosims   cosim_w  \
# 0       [-0.22124107, -0.1947155, -0.2786541] -0.231537
# 1                     [nan, nan, -0.22919384] -0.229194
# 2             [-0.26926857, -0.18902278, nan] -0.229146
# 3                     [nan, -0.22798495, nan] -0.227985
# 4             [-0.17959411, -0.27630407, nan] -0.227949
# ...                                       ...       ...
# 473593    [0.9592465, 0.95547867, 0.97482795]  0.963184
# 473594                       [0.9634324, nan]  0.963432
# 473595                        [0.965927, nan]  0.965927
# 473596    [0.9469416, 0.97366333, 0.98004997]  0.966885
# 473597                [0.96503365, 0.9856082]  0.975321
#
#                                  ngram_tag
# 0          (However|RB, since|IN, then|RB)
# 1       (has|VBZ, been|VBN, following|VBG)
# 2              (both|CC, times|NNS, by|IN)
# 3              (after|IN, both|CC, the|DT)
# 4          (However|RB, even|RB, after|IN)
# ...                                    ...
# 473593         (OUL2|NN, OUL3|NN, CRO1|NN)
# 473594      (Recurvirostridae|NNP, is|VBZ)
# 473595               (Laridae|NNP, is|VBZ)
# 473596         (OUL3|NN, CRO1|NN, CRO2|NN)
# 473597                      (ㄹ|SYM, ㄻ|SYM)
#
# [473598 rows x 9 columns]

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1),
           'SIMP_CLN' : (simp_cln_res,'cosine_sim',1)
          }

# %%
w10p_cln_results = {}

for gs in gs_dict.keys():
    w10p_cln_results[gs] = corr_with_gs(w10p_cln_res,'cosim_w', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
w10p_cln_results
# Out:
# {'F_ENC': (85, 0.40210269557435935, 0.43961139646416136),
#  'R_ENC': (10, 0.43030303030303024, 0.2957728492858003),
#  'MC_VPC': (33, 0.10338509004332604, 0.09433848777417968),
#  'D_ADJN': (9, 0.4117792453398488, 0.4680561982240944),
#  'MC_VN': (48, 0.09221705102476564, 0.13106046365452512),
#  'RE_WIKI15': (118713, 0.6059935849286735, 0.614088089608807),
#  'SIMP_CLN': (7195, 0.637405758213973, 0.6523061701448993)}

# %%
w10p_cln_low_results = {}

for gs in gs_dict.keys():
    w10p_cln_low_results[gs] = corr_with_gs(w10p_cln_res,'cosim_w', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
w10p_cln_low_results
# Out:
# {'F_ENC': (240, 0.16582141912531387, 0.178266045426923),
#  'R_ENC': (33, 0.2740344768732269, 0.24561427171704078),
#  'MC_VPC': (41, 0.023144184244394916, 0.049946724373688765),
#  'D_ADJN': (46, 0.13771828666123542, 0.19613921364612638),
#  'MC_VN': (56, 0.0198032488170276, 0.05403398343492424),
#  'RE_WIKI15': (131840, 0.5599330982060865, 0.56116313483496),
#  'SIMP_CLN': (16789, 0.5257183831443918, 0.53523878133824)}

# %% [markdown]
# ## Results with proper noun filtering
# Removed n-grams with all tokens tagged as NNP/NNPS (including possessive versions)

# %%
converter = {'ngram' : eval,
             #'stopwords' : eval
             #'mwe_vector' : eval,
             #'component_vectors' : eval,
             #'base_nearest' : eval,
             #'mwe_nearest' : eval,
            }

simp_nopn_res = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/simp_tagged_nopn_light_001.csv', 
                       converters= converter
                      )

# %%
simp_nopn_res['ngram_tag'] = simp_nopn_res.ngram
simp_nopn_res['ngram'] = simp_nopn_res.ngram_tag.apply(tup_rem)

simp_nopn_res
# Out:
#                         ngram  freq      poisson  len  batch   stopwords  \
# 0           (was, born, here)    32 -2115.954533    3      7   [1, 1, 0]
# 1         (and, finally, the)    33 -2348.089994    3      7   [1, 0, 1]
# 2                (born, here)    41 -1946.682114    2      6      [1, 0]
# 3             (is, both, the)    35 -2521.230138    3      7   [1, 0, 1]
# 4            (to, found, the)    25 -1819.659553    3      2   [1, 0, 1]
# ...                       ...   ...          ...  ...    ...         ...
# 149995   (1, Chemung, County)    52 -2990.167422    3     10  [1, -1, 0]
# 149996     (1, Tioga, County)    60 -3442.616347    3     10  [1, -1, 0]
# 149997  (state, state, state)    48 -2965.054834    3     13        [-2]
# 149998         (I, Kissed, a)    35 -2085.513275    3     14  [0, -1, 1]
# 149999  (of, non-humans, are)    55 -3459.031977    3     14  [1, -1, 1]
#
#                component_cosims  cosine_sim                         ngram_tag
# 0       [nan, nan, -0.17546517]   -0.175465      (was|VBD, born|VBN, here|RB)
# 1       [nan, -0.17055225, nan]   -0.170552      (and|CC, finally|RB, the|DT)
# 2            [nan, -0.16723849]   -0.167238               (born|VBN, here|RB)
# 3       [nan, -0.15586732, nan]   -0.155867         (is|VBZ, both|CC, the|DT)
# 4       [nan, -0.14139682, nan]   -0.141397        (to|IN, found|VBN, the|DT)
# ...                         ...         ...                               ...
# 149995    [nan, nan, 0.6229615]         NaN   (1|CD, Chemung|NNP, County|NNP)
# 149996   [nan, nan, 0.63835496]         NaN     (1|CD, Tioga|NNP, County|NNP)
# 149997                       []         NaN    (state|NN, state|NN, state|NN)
# 149998    [0.1323022, nan, nan]         NaN         (I|PRP, Kissed|VBD, a|DT)
# 149999          [nan, nan, nan]         NaN  (of|IN, non-humans|NNS, are|VBP)
#
# [150000 rows x 9 columns]

# %%
simp_nopn_res = simp_nopn_res[~np.isnan(simp_nopn_res.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe'}).reset_index(drop=True)

simp_nopn_res
# Out:
#                         mwe  freq      poisson  len  batch  stopwords  \
# 0         (was, born, here)    32 -2115.954533    3      7  [1, 1, 0]
# 1       (and, finally, the)    33 -2348.089994    3      7  [1, 0, 1]
# 2              (born, here)    41 -1946.682114    2      6     [1, 0]
# 3           (is, both, the)    35 -2521.230138    3      7  [1, 0, 1]
# 4          (to, found, the)    25 -1819.659553    3      2  [1, 0, 1]
# ...                     ...   ...          ...  ...    ...        ...
# 145601           (DNQ, DNQ)   113 -4174.165390    2      4     [0, 0]
# 145602              (3, -0)    61 -2648.449939    2      2     [1, 0]
# 145603         (Maerz, and)    49 -2302.220234    2      2     [0, 1]
# 145604           (GBR, GER)    31 -1020.735228    2      4     [0, 0]
# 145605           (WIN, WIN)    70 -2399.962761    2      6     [0, 0]
#
#                 component_cosims  cosine_sim                     ngram_tag
# 0        [nan, nan, -0.17546517]   -0.175465  (was|VBD, born|VBN, here|RB)
# 1        [nan, -0.17055225, nan]   -0.170552  (and|CC, finally|RB, the|DT)
# 2             [nan, -0.16723849]   -0.167238           (born|VBN, here|RB)
# 3        [nan, -0.15586732, nan]   -0.155867     (is|VBZ, both|CC, the|DT)
# 4        [nan, -0.14139682, nan]   -0.141397    (to|IN, found|VBN, the|DT)
# ...                          ...         ...                           ...
# 145601  [0.96868503, 0.96868503]    0.968685              (DNQ|NN, DNQ|NN)
# 145602         [nan, 0.97882754]    0.978828                (3|CD, -0|SYM)
# 145603         [0.97951883, nan]    0.979519           (Maerz|NNP, and|CC)
# 145604   [0.97934204, 0.9822897]    0.980816              (GBR|NN, GER|NN)
# 145605    [0.9854822, 0.9854822]    0.985482              (WIN|VB, WIN|VB)
#
# [145606 rows x 9 columns]

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1)
          }

# %%
simp_nopn_results = {}

for gs in gs_dict.keys():
    simp_nopn_results[gs] = corr_with_gs(simp_nopn_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
simp_nopn_results
# Out:
# {'F_ENC': (210, 0.17061638984666755, 0.19954712832600852),
#  'R_ENC': (17, 0.312232574580384, 0.4469984941590157),
#  'MC_VPC': (15, 0.13978584413286751, 0.09076594620784136),
#  'D_ADJN': (44, 0.3234060648948002, 0.2998132230982493),
#  'MC_VN': (39, 0.3585551167197633, 0.43022294223059876),
#  'RE_WIKI15': (79047, 0.6221155445728576, 0.6284548120728505)}

# %%
simp_nopn_low_results = {}

for gs in gs_dict.keys():
    simp_nopn_low_results[gs] = corr_with_gs(simp_nopn_res,'cosine_sim', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
simp_nopn_low_results
# Out:
# {'F_ENC': (228, 0.13013537276805118, 0.15275661698423235),
#  'R_ENC': (20, 0.2711869215727743, 0.39437120109987356),
#  'MC_VPC': (16, 0.19068991353923495, 0.03790067321279876),
#  'D_ADJN': (52, 0.26111278334538285, 0.2451324903283014),
#  'MC_VN': (40, 0.38331455079214344, 0.4417636968180419),
#  'RE_WIKI15': (79099, 0.5791301007276244, 0.5873246499013689)}

# %%
converter = {'ngram' : eval,
             #'stopwords' : eval
             #'mwe_vector' : eval,
             #'component_vectors' : eval,
             #'base_nearest' : eval,
             #'mwe_nearest' : eval,
            }

w10p_nopn_res = pd.read_csv(datapath+'/Models/1 w2v/Tagged/Results/w10p_tagged_nopn_light_001.csv', 
                       converters= converter
                      )

# %%
w10p_nopn_res['ngram_tag'] = w10p_nopn_res.ngram
w10p_nopn_res['ngram'] = w10p_nopn_res.ngram_tag.apply(tup_rem)

w10p_nopn_res
# Out:
#                            ngram  freq      poisson  len  batch  stopwords  \
# 0                (one, on, both)    22 -1743.834796    3      4  [1, 1, 0]
# 1              (were, once, the)    20 -1599.272787    3      7  [1, 0, 1]
# 2              (The, four, were)    21 -1718.246421    3      1  [1, 0, 1]
# 3          (In, addition, their)    20 -1565.757225    3      8  [1, 0, 1]
# 4       (was, subsequently, the)    21 -1759.767362    3      7  [1, 0, 1]
# ...                          ...   ...          ...  ...    ...        ...
# 499995              (of, I, 've)    23 -1786.381671    3     10       [-2]
# 499996                ((, BN, –)    28 -1788.082423    3     10       [-2]
# 499997          (/, 1,000, live)    27 -1810.125560    3     10       [-2]
# 499998               (/, vocals)    34 -1810.642550    2     10       [-2]
# 499999          ('s, easier, to)    25 -1813.141344    3     10       [-2]
#
#                component_cosims  cosine_sim  \
# 0       [nan, nan, -0.24756436]   -0.247564
# 1       [nan, -0.23794496, nan]   -0.237945
# 2       [nan, -0.23560974, nan]   -0.235610
# 3         [nan, -0.227985, nan]   -0.227985
# 4       [nan, -0.22302704, nan]   -0.223027
# ...                         ...         ...
# 499995                       []         NaN
# 499996                       []         NaN
# 499997                       []         NaN
# 499998                       []         NaN
# 499999                       []         NaN
#
#                                  ngram_tag
# 0                 (one|CD, on|IN, both|CC)
# 1              (were|VBD, once|IN, the|DT)
# 2              (The|DT, four|CD, were|VBD)
# 3         (In|IN, addition|NN, their|PRP$)
# 4       (was|VBD, subsequently|RB, the|DT)
# ...                                    ...
# 499995             (of|IN, I|PRP, 've|VBP)
# 499996             ((|-LRB-, BN|NN, –|SYM)
# 499997          (/|SYM, 1,000|CD, live|JJ)
# 499998                   (/|,, vocals|NNS)
# 499999         ('s|VBZ, easier|JJR, to|TO)
#
# [500000 rows x 9 columns]

# %%
w10p_nopn_res = w10p_nopn_res[~np.isnan(w10p_nopn_res.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe', 'cosine_sim' : 'cosim_wnpn'}).reset_index(drop=True)

w10p_nopn_res
# Out:
#                               mwe  freq      poisson  len  batch  stopwords  \
# 0                 (one, on, both)    22 -1743.834796    3      4  [1, 1, 0]
# 1               (were, once, the)    20 -1599.272787    3      7  [1, 0, 1]
# 2               (The, four, were)    21 -1718.246421    3      1  [1, 0, 1]
# 3           (In, addition, their)    20 -1565.757225    3      8  [1, 0, 1]
# 4        (was, subsequently, the)    21 -1759.767362    3      7  [1, 0, 1]
# ...                           ...   ...          ...  ...    ...        ...
# 479576              (Laridae, is)    29 -1486.804386    2      2     [0, 1]
# 479577         (OUL3, CRO1, CRO2)    36 -1513.524083    3      2  [0, 0, 0]
# 479578  (Recurvirostridae, is, a)    25 -1825.463688    3      5  [0, 1, 1]
# 479579     (Recurvirostridae, is)    25 -1275.232759    2      2     [0, 1]
# 479580                     (ㄹ, ㄻ)    30 -1137.007900    2      2     [0, 0]
#
#                           component_cosims  cosim_wnpn  \
# 0                  [nan, nan, -0.24756436]   -0.247564
# 1                  [nan, -0.23794496, nan]   -0.237945
# 2                  [nan, -0.23560974, nan]   -0.235610
# 3                    [nan, -0.227985, nan]   -0.227985
# 4                  [nan, -0.22302704, nan]   -0.223027
# ...                                    ...         ...
# 479576                    [0.9633833, nan]    0.963383
# 479577  [0.9517838, 0.9673035, 0.97172594]    0.963604
# 479578               [0.9652813, nan, nan]    0.965281
# 479579                    [0.9660529, nan]    0.966053
# 479580             [0.96715283, 0.9867557]    0.976954
#
#                                    ngram_tag
# 0                   (one|CD, on|IN, both|CC)
# 1                (were|VBD, once|IN, the|DT)
# 2                (The|DT, four|CD, were|VBD)
# 3           (In|IN, addition|NN, their|PRP$)
# 4         (was|VBD, subsequently|RB, the|DT)
# ...                                      ...
# 479576                 (Laridae|NNP, is|VBZ)
# 479577           (OUL3|NN, CRO1|NN, CRO2|NN)
# 479578  (Recurvirostridae|NNP, is|VBZ, a|DT)
# 479579        (Recurvirostridae|NNP, is|VBZ)
# 479580                        (ㄹ|SYM, ㄻ|SYM)
#
# [479581 rows x 9 columns]

# %%
gs_dict = {'F_ENC' : (F_ENC,'gs_score',-1), 
           'R_ENC' : (R_ENC,'gs_score',-1), 
           'MC_VPC': (MC_VPC,'gs_score',-1), 
           'D_ADJN': (D_ADJN,'gs_score',-1), 
           'MC_VN' : (MC_VN,'gs_score',-1),
           'RE_WIKI15' : (robegg_df,'compo',1),
           'SIMP_NOPN' : (simp_nopn_res,'cosine_sim',1)
          }

# %%
w10p_nopn_results = {}

for gs in gs_dict.keys():
    w10p_nopn_results[gs] = corr_with_gs(w10p_nopn_res,'cosim_wnpn', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1])
    
w10p_nopn_results
# Out:
# {'F_ENC': (95, 0.4266721721506415, 0.45486730180075524),
#  'R_ENC': (10, 0.3939393939393939, 0.4190778237989436),
#  'MC_VPC': (35, 0.06583859874083127, 0.07077462858090816),
#  'D_ADJN': (10, 0.38415348299103563, 0.49724820103614964),
#  'MC_VN': (52, 0.16808933397001719, 0.21351519046457657),
#  'RE_WIKI15': (108741, 0.6715535041774463, 0.67720591179744),
#  'SIMP_NOPN': (7698, 0.6267120295488908, 0.6406797435046593)}

# %%
w10p_nopn_low_results = {}

for gs in gs_dict.keys():
    w10p_nopn_low_results[gs] = corr_with_gs(w10p_nopn_res,'cosim_wnpn', gs_dict[gs][0],  tiebreak = 'poisson', refscore = gs_dict[gs][1], mult = gs_dict[gs][-1], lowcase = True)
    
w10p_nopn_low_results
# Out:
# {'F_ENC': (204, 0.1436148238189435, 0.15352605797589713),
#  'R_ENC': (21, 0.36115623859964363, 0.3314016954284363),
#  'MC_VPC': (43, 0.11005127666866041, 0.13655974090083092),
#  'D_ADJN': (33, 0.30239181003440924, 0.3432912398301981),
#  'MC_VN': (59, 0.08932539939212138, 0.10266876389855156),
#  'RE_WIKI15': (123372, 0.6172770425319167, 0.6165229150438205),
#  'SIMP_NOPN': (18950, 0.5191598243497096, 0.5288681376884276)}

# %% [markdown]
# # Investigations

# %%
import pickle

# %%
# Investigating lowered number of matches to reference sets - load long lists

with open(datapath+'/Corpora/wiki/enwiki_20200520/Tagged/stop.pkl', 'rb') as pfile:
    stop = pickle.load(pfile)
    
stop
# Out:
# {'%|NN',
#  '0|CD',
#  '1|CD',
#  '2|CD',
#  '3|CD',
#  'He|PRP',
#  'In|IN',
#  'It|PRP',
#  'The|DT',
#  'also|RB',
#  'and|CC',
#  'an|DT',
#  'are|VBP',
#  'as|IN',
#  'at|IN',
#  'a|DT',
#  'be|VB',
#  'but|CC',
#  'by|IN',
#  'first|JJ',
#  'for|IN',
#  'from|IN',
#  'had|VBD',
#  'has|VBZ',
#  'he|PRP',
#  'his|PRP$',
#  'in|IN',
#  'is|VBZ',
#  'its|PRP$',
#  'it|PRP',
#  'not|RB',
#  'of|IN',
#  'one|CD',
#  'on|IN',
#  'or|CC',
#  's|POS',
#  'that|IN',
#  'that|WDT',
#  'their|PRP$',
#  'the|DT',
#  'to|IN',
#  'to|TO',
#  'two|CD',
#  'was|VBD',
#  'were|VBD',
#  'which|WDT',
#  'who|WP',
#  'with|IN',
#  '|HYPH',
#  '–|SYM'}

# %%
ngram_eval = pd.read_pickle(datapath+'/Corpora/wiki/enwiki_20200520/Tagged/ngram_eval.pkl')

ngram_eval
# Out:
#                                                     ngram  freq      poisson  \
# 0                                  (311.22|CD, 500.86|CD)    20  -667.084219
# 1                                (Makhaya|NNP, Ntini|NNP)    20  -667.084219
# 2       (resting_place_coordinates|NNS, burial_place|VBP)    20  -667.084219
# 3                           (Dechawat|NNP, Poomjaeng|NNP)    20  -667.084219
# 4                                      (MSC1|NN, MSC2|NN)    20  -667.084219
# ...                                                   ...   ...          ...
# 499995                                (US|NNP, Steel|NNP)    32 -1679.033919
# 499996                            (Harry|NNP, Wilson|NNP)    32 -1679.034986
# 499997                          (a|DT, solo|JJ, piano|NN)    23 -1679.035464
# 499998                                (1962|CD, album|NN)    30 -1679.036008
# 499999                          (he|PRP, is|VBZ, set|VBN)    21 -1679.038189
#
#         len  batch
# 0         2      1
# 1         2      1
# 2         2      1
# 3         2      1
# 4         2      1
# ...     ...    ...
# 499995    2      3
# 499996    2      3
# 499997    3      2
# 499998    2      6
# 499999    3      3
#
# [500000 rows x 5 columns]

# %%
ngram = pd.read_pickle(datapath+'/Corpora/wiki/enwiki_20200520/Tagged/ngram_df.pkl')

ngram
# Out:
#                                                      ngram     freq  \
# 0                                   (311.22|CD, 500.86|CD)       20
# 1                                 (Makhaya|NNP, Ntini|NNP)       20
# 2        (resting_place_coordinates|NNS, burial_place|VBP)       20
# 3                            (Dechawat|NNP, Poomjaeng|NNP)       20
# 4                                       (MSC1|NN, MSC2|NN)       20
# ...                                                    ...      ...
# 1859185                                    (on|IN, the|DT)   473024
# 1859186                                   (and|CC, the|DT)   492576
# 1859187                                    (to|IN, the|DT)   714100
# 1859188                                    (in|IN, the|DT)  1388181
# 1859189                                    (of|IN, the|DT)  2256975
#
#               poisson  len
# 0       -6.670842e+02    2
# 1       -6.670842e+02    2
# 2       -6.670842e+02    2
# 3       -6.670842e+02    2
# 4       -6.670842e+02    2
# ...               ...  ...
# 1859185 -2.576335e+07    2
# 1859186 -2.778679e+07    2
# 1859187 -3.884106e+07    2
# 1859188 -7.588717e+07    2
# 1859189 -1.229829e+08    2
#
# [1859190 rows x 4 columns]

# %%
ngram['ngram_tag'] = ngram.ngram
ngram['ngram'] = ngram.ngram_tag.apply(tup_rem)

ngram
# Out:
#                                              ngram     freq       poisson  \
# 0                                 (311.22, 500.86)       20 -6.670842e+02
# 1                                 (Makhaya, Ntini)       20 -6.670842e+02
# 2        (resting_place_coordinates, burial_place)       20 -6.670842e+02
# 3                            (Dechawat, Poomjaeng)       20 -6.670842e+02
# 4                                     (MSC1, MSC2)       20 -6.670842e+02
# ...                                            ...      ...           ...
# 1859185                                  (on, the)   473024 -2.576335e+07
# 1859186                                 (and, the)   492576 -2.778679e+07
# 1859187                                  (to, the)   714100 -3.884106e+07
# 1859188                                  (in, the)  1388181 -7.588717e+07
# 1859189                                  (of, the)  2256975 -1.229829e+08
#
#          len                                          ngram_tag
# 0          2                             (311.22|CD, 500.86|CD)
# 1          2                           (Makhaya|NNP, Ntini|NNP)
# 2          2  (resting_place_coordinates|NNS, burial_place|VBP)
# 3          2                      (Dechawat|NNP, Poomjaeng|NNP)
# 4          2                                 (MSC1|NN, MSC2|NN)
# ...      ...                                                ...
# 1859185    2                                    (on|IN, the|DT)
# 1859186    2                                   (and|CC, the|DT)
# 1859187    2                                    (to|IN, the|DT)
# 1859188    2                                    (in|IN, the|DT)
# 1859189    2                                    (of|IN, the|DT)
#
# [1859190 rows x 5 columns]

# %%
ngram = ngram.rename(columns={'ngram' : 'mwe'})

# %%
corr_with_gs(ngram, 'poisson', F_ENC, refscore='gs_score', tiebreak = 'freq', lowcase = False, mult=-1)
# Out:
# (683, 0.1248773442571316, 0.09286634145590356)

# %%
ngram_eval['ngram_tag'] = ngram_eval.ngram
ngram_eval['ngram'] = ngram_eval.ngram_tag.apply(tup_rem)

ngram_eval = ngram_eval.rename(columns={'ngram' : 'mwe'})

# %%
corr_with_gs(ngram, 'poisson', F_ENC, refscore='gs_score', tiebreak = 'freq', lowcase = False, mult=-1)
# Out:
# (683, 0.1248773442571316, 0.09286634145590356)

# %%
ngram2 = ngram[:1650000]

# %%
corr_with_gs(ngram2, 'poisson', F_ENC, refscore='gs_score', tiebreak = 'freq', lowcase = False, mult=-1)
# Out:
# (457, 0.046601180634674895, 0.015429356936201467)

# %%
checky = ngram[['mwe', 'freq', 'poisson']].merge(F_ENC, 
                          left_on=ngram.mwe, 
                          right_on = F_ENC.mwe, 
                          how='left')

# %%
checky[~np.isnan(checky.gs_score)]
# Out:
#                          key_0                  mwe_x   freq        poisson  \
# 13106         (lecture, notes)       (lecture, notes)     22    -960.544055
# 13499            (mass, media)          (mass, media)     20    -962.678709
# 13818              (hype, man)            (hype, man)     20    -964.457053
# 14502           (cheek, teeth)         (cheek, teeth)     21    -968.324445
# 19993    (media, commentators)  (media, commentators)     20    -995.117244
# ...                        ...                    ...    ...            ...
# 1853863     (science, fiction)     (science, fiction)   4510 -202383.170972
# 1855615         (debut, album)         (debut, album)   5623 -274006.258700
# 1855669       (radio, station)       (radio, station)   5747 -276729.519270
# 1856709          (video, game)          (video, game)   7158 -347508.952280
# 1858612         (high, school)         (high, school)  18650 -901478.567876
#
#                          mwe_y  gs_score
# 13106         (lecture, notes)       0.0
# 13499            (mass, media)       2.0
# 13818              (hype, man)       3.0
# 14502           (cheek, teeth)       3.0
# 19993    (media, commentators)       0.0
# ...                        ...       ...
# 1853863     (science, fiction)       0.0
# 1855615         (debut, album)       0.0
# 1855669       (radio, station)       0.0
# 1856709          (video, game)       1.0
# 1858612         (high, school)       3.0
#
# [737 rows x 6 columns]

# %%
checky = checky[~np.isnan(checky.gs_score)].reset_index()
checky
# Out:
#        index                  key_0                  mwe_x   freq  \
# 0      13106       (lecture, notes)       (lecture, notes)     22
# 1      13499          (mass, media)          (mass, media)     20
# 2      13818            (hype, man)            (hype, man)     20
# 3      14502         (cheek, teeth)         (cheek, teeth)     21
# 4      19993  (media, commentators)  (media, commentators)     20
# ..       ...                    ...                    ...    ...
# 732  1853863     (science, fiction)     (science, fiction)   4510
# 733  1855615         (debut, album)         (debut, album)   5623
# 734  1855669       (radio, station)       (radio, station)   5747
# 735  1856709          (video, game)          (video, game)   7158
# 736  1858612         (high, school)         (high, school)  18650
#
#            poisson                  mwe_y  gs_score
# 0      -960.544055       (lecture, notes)       0.0
# 1      -962.678709          (mass, media)       2.0
# 2      -964.457053            (hype, man)       3.0
# 3      -968.324445         (cheek, teeth)       3.0
# 4      -995.117244  (media, commentators)       0.0
# ..             ...                    ...       ...
# 732 -202383.170972     (science, fiction)       0.0
# 733 -274006.258700         (debut, album)       0.0
# 734 -276729.519270       (radio, station)       0.0
# 735 -347508.952280          (video, game)       1.0
# 736 -901478.567876         (high, school)       3.0
#
# [737 rows x 7 columns]

# %%
indexer = 80
checky[indexer:indexer+20]
# Out:
#      index                   key_0                   mwe_x  freq      poisson  \
# 80  502236            (tax, haven)            (tax, haven)    36 -1681.658395
# 81  508598          (target, cell)          (target, cell)    33 -1689.424204
# 82  513550       (freelance, work)       (freelance, work)    34 -1695.311851
# 83  517032          (back, pocket)          (back, pocket)    35 -1699.481858
# 84  520599         (death, notice)         (death, notice)    33 -1703.946015
# 85  526275            (back, door)            (back, door)    32 -1710.707878
# 86  543686           (film, world)           (film, world)    30 -1731.910769
# 87  548489           (space, race)           (space, race)    32 -1737.756404
# 88  554056     (language, contact)     (language, contact)    33 -1744.859747
# 89  576594      (government, work)      (government, work)    31 -1774.170539
# 90  581396         (video, output)         (video, output)    34 -1780.235780
# 91  584541    (coffee, plantation)    (coffee, plantation)    38 -1784.386614
# 92  587742  (safety, improvements)  (safety, improvements)    36 -1788.679490
# 93  596220  (property, investment)  (property, investment)    35 -1800.221636
# 94  607440            (state, oil)            (state, oil)    33 -1815.633600
# 95  630068       (emitting, diode)       (emitting, diode)    45 -1847.323886
# 96  633596     (bridge, structure)     (bridge, structure)    35 -1852.355564
# 97  640014           (sports, day)           (sports, day)    34 -1861.711332
# 98  640039       (volunteer, army)       (volunteer, army)    37 -1861.747872
# 99  663474          (brain, drain)          (brain, drain)    41 -1896.011207
#
#                      mwe_y  gs_score
# 80            (tax, haven)       4.0
# 81          (target, cell)       1.0
# 82       (freelance, work)       0.0
# 83          (back, pocket)       0.0
# 84         (death, notice)       0.0
# 85            (back, door)       0.0
# 86           (film, world)       0.0
# 87           (space, race)       4.0
# 88     (language, contact)       1.0
# 89      (government, work)       0.0
# 90         (video, output)       0.0
# 91    (coffee, plantation)       0.0
# 92  (safety, improvements)       0.0
# 93  (property, investment)       0.0
# 94            (state, oil)       0.0
# 95       (emitting, diode)       1.0
# 96     (bridge, structure)       0.0
# 97           (sports, day)       0.0
# 98       (volunteer, army)       0.0
# 99          (brain, drain)       4.0

# %%
indexer = 482500
step= 40

ngram_eval[indexer:indexer+step]
# Out:
#                              mwe  freq      poisson  len  batch  \
# 482500    (band, also, appeared)    22 -1658.680960    3      3
# 482501          (only, an, hour)    22 -1658.681735    3      3
# 482502         (varsity, soccer)    35 -1658.683447    2      2
# 482503                   (p, 50)    31 -1658.684325    2      2
# 482504       (makes, the, claim)    22 -1658.686033    3      1
# 482505          (worked, on, by)    21 -1658.686716    3      6
# 482506         (of, illness, or)    21 -1658.687431    3      3
# 482507         (the, ballot, or)    21 -1658.688718    3      5
# 482508          (en, , Yvelines)    25 -1658.689364    3      3
# 482509             (1997, South)    29 -1658.694543    2      5
# 482510      (24, December, 2011)    22 -1658.694940    3      1
# 482511         (a, postponement)    31 -1658.695612    2      1
# 482512        (season, with, 22)    21 -1658.697507    3      6
# 482513           (Central, bank)    31 -1658.697767    2      2
# 482514       (A, commentary, on)    22 -1658.698708    3      2
# 482515       (chief, magistrate)    35 -1658.700660    2      1
# 482516      (speed, skater, and)    23 -1658.701415    3      3
# 482517                 (best, 8)    29 -1658.701718    2      1
# 482518         (attack, and, is)    20 -1658.703806    3      5
# 482519      (engineering, which)    29 -1658.704694    2      1
# 482520          (ranking, which)    30 -1658.704833    2      5
# 482521       (US$, 1.5, billion)    26 -1658.710047    3      4
# 482522              (was, 14, –)    20 -1658.712187    3      1
# 482523          (online, forums)    35 -1658.714169    2      1
# 482524  (Rock, Springs, Wyoming)    26 -1658.714353    3      1
# 482525        (West, Texas, and)    21 -1658.714481    3      2
# 482526           (not, consumed)    31 -1658.715228    2      1
# 482527               (A, garden)    30 -1658.715701    2      1
# 482528           (every, branch)    31 -1658.717479    2      4
# 482529               (2, km, of)    20 -1658.717890    3      4
# 482530               (began, of)    26 -1658.719355    2      6
# 482531          (the, left, end)    21 -1658.719824    3      5
# 482532            (wife, Pamela)    33 -1658.720471    2      2
# 482533           (run, for, his)    21 -1658.721120    3      3
# 482534          (thought, it, a)    21 -1658.721698    3      7
# 482535        (a, pretender, to)    22 -1658.721768    3      8
# 482536           (in, black, on)    20 -1658.723583    3      5
# 482537           (Streets, were)    30 -1658.724042    2      4
# 482538     (gave, his, approval)    23 -1658.724948    3      3
# 482539            (2009, Grammy)    31 -1658.726511    2      1
#
#                                    ngram_tag
# 482500      (band|NN, also|RB, appeared|VBD)
# 482501             (only|RB, an|DT, hour|NN)
# 482502               (varsity|NN, soccer|NN)
# 482503                         (p|NN, 50|CD)
# 482504         (makes|VBZ, the|DT, claim|NN)
# 482505            (worked|VBN, on|IN, by|IN)
# 482506            (of|IN, illness|NN, or|CC)
# 482507            (the|DT, ballot|NN, or|CC)
# 482508          (en|IN, |HYPH, Yvelines|NNP)
# 482509                  (1997|CD, South|NNP)
# 482510        (24|CD, December|NNP, 2011|CD)
# 482511               (a|DT, postponement|NN)
# 482512           (season|NN, with|IN, 22|CD)
# 482513                (Central|NNP, bank|NN)
# 482514          (A|DT, commentary|NN, on|IN)
# 482515             (chief|JJ, magistrate|NN)
# 482516         (speed|NN, skater|NN, and|CC)
# 482517                      (best|JJS, 8|CD)
# 482518           (attack|NN, and|CC, is|VBZ)
# 482519           (engineering|NN, which|WDT)
# 482520               (ranking|NN, which|WDT)
# 482521           (US$|$, 1.5|CD, billion|CD)
# 482522               (was|VBD, 14|CD, –|SYM)
# 482523               (online|JJ, forums|NNS)
# 482524  (Rock|NNP, Springs|NNP, Wyoming|NNP)
# 482525         (West|NNP, Texas|NNP, and|CC)
# 482526                (not|RB, consumed|VBN)
# 482527                     (A|DT, garden|NN)
# 482528                 (every|DT, branch|NN)
# 482529                  (2|CD, km|NN, of|IN)
# 482530                    (began|VBD, of|IN)
# 482531             (the|DT, left|JJ, end|NN)
# 482532                 (wife|NN, Pamela|NNP)
# 482533            (run|VB, for|IN, his|PRP$)
# 482534           (thought|VBD, it|PRP, a|DT)
# 482535           (a|DT, pretender|NN, to|IN)
# 482536              (in|IN, black|JJ, on|IN)
# 482537              (Streets|NNPS, were|VBD)
# 482538     (gave|VBD, his|PRP$, approval|NN)
# 482539                 (2009|CD, Grammy|NNP)

# %%
import re

# %%
# Filtering patterns

_tagnums = re.compile("(\d+(\.\d+)?$)|(.+\|CD$)")  # All numeric, with optional decimal point OR anything tagged |CD
_nans    = re.compile("nan", re.I)                 # Occasional lists like (NaN, NaN, NaN)
_timerad = re.compile("[apf]\.?m.?", re.I)         # a.m. P.M, FM - time and radio station indicators

def tupallmatch(tupin, pattern):
    return all(pattern.match(w) for w in tupin)

def tupmatchlist(tupin, patterns):
    for w,p in zip(tupin, patterns):
        if p.match(w): pass
        else: return False
    return True

# %%
teststr = 'a.M'
_timerad.match(teststr)
# Out:
# <_sre.SRE_Match object; span=(0, 3), match='a.M'>

# %%
testtup = ('311.22|CD', 'males|NNS')

tupmatchlist(testtup, [_tagnums, re.compile('males\|NNS')])
# Out:
# True

# %%
# initially;    1,859,190 
ngrams_filt = ngram[~ngram.ngram_tag.apply(tupallmatch , args= [_tagnums])]
# all numeric;  1,834,686
ngrams_filt = ngrams_filt[~ngrams_filt.ngram_tag.apply(tupmatchlist, args = [[_tagnums, re.compile('males\|NNS')]])]
# x|CD males;   1,834,542
ngrams_filt = ngrams_filt[~ngrams_filt.ngram_tag.apply(tupallmatch , args= [_nans])]
# NaN NaN;      1,834,540
ngrams_filt = ngrams_filt[~ngrams_filt.ngram_tag.apply(tupmatchlist, args = [[_tagnums, _timerad]])]
# Times, radio; 1,833,811

# %%
ngrams_filt
# Out:
#                                                mwe     freq       poisson  \
# 1                                 (Makhaya, Ntini)       20 -6.670842e+02
# 2        (resting_place_coordinates, burial_place)       20 -6.670842e+02
# 3                            (Dechawat, Poomjaeng)       20 -6.670842e+02
# 4                                     (MSC1, MSC2)       20 -6.670842e+02
# 5                                 (Deshin, Shekpa)       20 -6.684920e+02
# ...                                            ...      ...           ...
# 1859185                                  (on, the)   473024 -2.576335e+07
# 1859186                                 (and, the)   492576 -2.778679e+07
# 1859187                                  (to, the)   714100 -3.884106e+07
# 1859188                                  (in, the)  1388181 -7.588717e+07
# 1859189                                  (of, the)  2256975 -1.229829e+08
#
#          len                                          ngram_tag
# 1          2                           (Makhaya|NNP, Ntini|NNP)
# 2          2  (resting_place_coordinates|NNS, burial_place|VBP)
# 3          2                      (Dechawat|NNP, Poomjaeng|NNP)
# 4          2                                 (MSC1|NN, MSC2|NN)
# 5          2                           (Deshin|NNP, Shekpa|NNP)
# ...      ...                                                ...
# 1859185    2                                    (on|IN, the|DT)
# 1859186    2                                   (and|CC, the|DT)
# 1859187    2                                    (to|IN, the|DT)
# 1859188    2                                    (in|IN, the|DT)
# 1859189    2                                    (of|IN, the|DT)
#
# [1833811 rows x 5 columns]

# %% [markdown]
# Combined reference set

# %%
all_refs = MC_VN.rename(columns={'gs_score' : 'MC_VN'}).merge(F_ENC.rename(columns={'gs_score' : 'F_ENC'}),how='outer')

all_refs = all_refs.merge(R_ENC.rename(columns={'gs_score' : 'R_ENC'}),how='outer')

all_refs = all_refs.merge(MC_VPC.rename(columns={'gs_score' : 'MC_VPC'}),how='outer')

all_refs = all_refs.merge(D_ADJN.rename(columns={'gs_score' : 'D_ADJN'}),how='outer')

# %%
# 2,021 if there is no overlap between the sets, get 1,996

all_refs
# Out:
#                     mwe  MC_VN  F_ENC  R_ENC  MC_VPC  D_ADJN
# 0         (have, heart)    5.0    NaN    NaN     NaN     NaN
# 1          (catch, eye)    5.0    NaN    NaN     NaN     NaN
# 2          (take, step)    5.0    NaN    NaN     NaN     NaN
# 3          (take, root)    5.0    NaN    NaN     NaN     NaN
# 4         (leave, mark)    5.0    NaN    NaN     NaN     NaN
# ...                 ...    ...    ...    ...     ...     ...
# 1991  (short, distance)    NaN    NaN    NaN     NaN     3.0
# 1992   (early, version)    NaN    NaN    NaN     NaN     2.0
# 1993    (small, island)    NaN    NaN    NaN     NaN     2.0
# 1994       (olive, oil)    NaN    NaN    NaN     NaN     1.0
# 1995     (lemon, juice)    NaN    NaN    NaN     NaN     0.0
#
# [1996 rows x 6 columns]

# %%
# Scale each column to 0-1000

def rescaler(x, col, scale = 1):
    mn = col.min()
    mx = col.max()
    
    return scale * (x - mn) / (mx - mn)

# %%
all_refs['MC_VN'] = all_refs.MC_VN.apply(rescaler, col = all_refs.MC_VN, scale = 1000)
all_refs['F_ENC'] = all_refs.F_ENC.apply(rescaler, col = all_refs.F_ENC, scale = 1000)
all_refs['R_ENC'] = all_refs.R_ENC.apply(rescaler, col = all_refs.R_ENC, scale = 1000)
all_refs['MC_VPC'] = all_refs.MC_VPC.apply(rescaler, col = all_refs.MC_VPC, scale = 1000)
all_refs['D_ADJN'] = all_refs.D_ADJN.apply(rescaler, col = all_refs.D_ADJN, scale = 1000)

# %%
all_refs
# Out:
#                     mwe   MC_VN  F_ENC  R_ENC  MC_VPC     D_ADJN
# 0         (have, heart)  1000.0    NaN    NaN     NaN        NaN
# 1          (catch, eye)  1000.0    NaN    NaN     NaN        NaN
# 2          (take, step)  1000.0    NaN    NaN     NaN        NaN
# 3          (take, root)  1000.0    NaN    NaN     NaN        NaN
# 4         (leave, mark)  1000.0    NaN    NaN     NaN        NaN
# ...                 ...     ...    ...    ...     ...        ...
# 1991  (short, distance)     NaN    NaN    NaN     NaN  33.707865
# 1992   (early, version)     NaN    NaN    NaN     NaN  22.471910
# 1993    (small, island)     NaN    NaN    NaN     NaN  22.471910
# 1994       (olive, oil)     NaN    NaN    NaN     NaN  11.235955
# 1995     (lemon, juice)     NaN    NaN    NaN     NaN   0.000000
#
# [1996 rows x 6 columns]

# %%
all_refs['REF'] = all_refs.drop('mwe', axis=1).apply(np.nanmean, axis=1)

# %%
all_refs
# Out:
#                     mwe   MC_VN  F_ENC  R_ENC  MC_VPC     D_ADJN          REF
# 0         (have, heart)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 1          (catch, eye)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 2          (take, step)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 3          (take, root)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 4         (leave, mark)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# ...                 ...     ...    ...    ...     ...        ...          ...
# 1991  (short, distance)     NaN    NaN    NaN     NaN  33.707865    33.707865
# 1992   (early, version)     NaN    NaN    NaN     NaN  22.471910    22.471910
# 1993    (small, island)     NaN    NaN    NaN     NaN  22.471910    22.471910
# 1994       (olive, oil)     NaN    NaN    NaN     NaN  11.235955    11.235955
# 1995     (lemon, juice)     NaN    NaN    NaN     NaN   0.000000     0.000000
#
# [1996 rows x 7 columns]

# %% [markdown]
# Looking for lost items between original and POS-tagged experiments on 10% corpus

# %%
w10p_w2v
# Out:
#                                                 mwe  freq      poisson  len  \
# 0                                 (delivered, from)    28 -1567.428918    2
# 1                                  (then, had, two)    20 -1586.812073    3
# 2                               (and, finally, for)    20 -1647.756550    3
# 3                                 (one, before, it)    20 -1587.727730    3
# 4                              (However, in, their)    20 -1642.620348    3
# ...                                             ...   ...          ...  ...
# 482425  (środek.svgFile, Wygaszony, środek.svgFile)    36 -1588.358559    3
# 482426                       (Recurvirostridae, is)    25 -1276.332579    2
# 482427                           (OUL3, CRO1, CRO2)    36 -1515.104871    3
# 482428                                    (Lapu, -)    22 -1127.048317    2
# 482429                                       (ㄹ, ㄻ)    30 -1138.325224    2
#
#         batch  stopwords                      component_cosims  cosim_10w  \
# 0           5     [0, 1]                     [-0.2535712, nan]  -0.253571
# 1           3  [0, 1, 1]               [-0.24625674, nan, nan]  -0.246257
# 2           4  [1, 0, 1]               [nan, -0.22293654, nan]  -0.222937
# 3           7  [1, 0, 1]               [nan, -0.21940775, nan]  -0.219408
# 4           3  [0, 1, 1]                [-0.2108197, nan, nan]  -0.210820
# ...       ...        ...                                   ...        ...
# 482425      1  [0, 0, 0]     [0.9717464, 0.9375481, 0.9717464]   0.960347
# 482426      4     [0, 1]                     [0.96257687, nan]   0.962577
# 482427      2  [0, 0, 0]  [0.94491136, 0.97224206, 0.97286904]   0.963341
# 482428      2     [0, 1]                      [0.9648907, nan]   0.964891
# 482429      2     [0, 0]                [0.97117275, 0.982044]   0.976608
#
#                                                 ngram_tag
# 0                                (delivered|VBD, from|IN)
# 1                              (then|RB, had|VBD, two|CD)
# 2                            (and|CC, finally|RB, for|IN)
# 3                             (one|CD, before|IN, it|PRP)
# 4                         (However|RB, in|IN, their|PRP$)
# ...                                                   ...
# 482425  (środek.svgFile|NNP, Wygaszony|NNP, środek.svg...
# 482426                     (Recurvirostridae|NNP, is|VBZ)
# 482427                        (OUL3|NN, CRO1|NN, CRO2|NN)
# 482428                                  (Lapu|NNP, |HYPH)
# 482429                                     (ㄹ|SYM, ㄻ|SYM)
#
# [482430 rows x 9 columns]

# %%
w10p_tag = all_refs.merge(w10p_w2v[['mwe', 'cosim_10w']], how='inner', on='mwe').drop_duplicates(subset=['mwe'])

# %%
w10p_tag = all_refs.merge(w10p_w2v[['mwe', 'cosim_10w', 'ngram_tag']], how='inner', on='mwe')

# %%
ind = 0
w10p_tag[ind:ind+30]
# Out:
#                        mwe   MC_VN  F_ENC  R_ENC  MC_VPC  D_ADJN     REF  \
# 0            (shed, light)  1000.0    NaN    NaN     NaN     NaN  1000.0
# 1            (shed, light)  1000.0    NaN    NaN     NaN     NaN  1000.0
# 2               (see, fit)   900.0    NaN    NaN     NaN     NaN   900.0
# 3          (bear, witness)   900.0    NaN    NaN     NaN     NaN   900.0
# 4          (bear, witness)   900.0    NaN    NaN     NaN     NaN   900.0
# 5            (take, leave)   800.0    NaN    NaN     NaN     NaN   800.0
# 6          (cause, damage)   800.0    NaN    NaN     NaN     NaN   800.0
# 7          (have, control)   800.0    NaN    NaN     NaN     NaN   800.0
# 8            (have, faith)   800.0    NaN    NaN     NaN     NaN   800.0
# 9            (have, faith)   800.0    NaN    NaN     NaN     NaN   800.0
# 10         (cause, injury)   800.0    NaN    NaN     NaN     NaN   800.0
# 11           (take, pride)   800.0    NaN    NaN     NaN     NaN   800.0
# 12          (have, dinner)   800.0    NaN    NaN     NaN     NaN   800.0
# 13          (have, dinner)   800.0    NaN    NaN     NaN     NaN   800.0
# 14         (put, pressure)   800.0    NaN    NaN     NaN     NaN   800.0
# 15            (give, life)   800.0    NaN    NaN     NaN     NaN   800.0
# 16         (provide, help)   800.0    NaN    NaN     NaN     NaN   800.0
# 17  (receive, information)   800.0    NaN    NaN     NaN     NaN   800.0
# 18          (raise, money)   700.0    NaN    NaN     NaN     NaN   700.0
# 19      (exert, influence)   700.0    NaN    NaN     NaN     NaN   700.0
# 20             (got, hold)   700.0    NaN    NaN     NaN     NaN   700.0
# 21          (give, credit)   700.0    NaN    NaN     NaN     NaN   700.0
# 22          (take, refuge)   700.0    NaN    NaN     NaN     NaN   700.0
# 23          (pay, tribute)   700.0    NaN    NaN     NaN     NaN   700.0
# 24           (take, notes)   600.0    NaN    NaN     NaN     NaN   600.0
# 25          (return, home)   600.0    NaN    NaN     NaN     NaN   600.0
# 26         (leave, office)   600.0    NaN    NaN     NaN     NaN   600.0
# 27           (make, sense)   600.0    NaN    NaN     NaN     NaN   600.0
# 28      (gain, experience)   500.0    NaN    NaN     NaN     NaN   500.0
# 29      (form, government)   500.0    NaN    NaN     NaN     NaN   500.0
#
#     cosim_10w                     ngram_tag
# 0    0.025012          (shed|VBD, light|NN)
# 1    0.109381          (shed|VBN, light|NN)
# 2    0.164587             (see|VBP, fit|JJ)
# 3    0.196912        (bear|VBP, witness|NN)
# 4    0.208045         (bear|VB, witness|NN)
# 5    0.313061           (take|VB, leave|NN)
# 6    0.382958        (cause|VBP, damage|NN)
# 7    0.102348        (have|VBP, control|NN)
# 8    0.206265          (have|VBP, faith|NN)
# 9    0.230265           (have|VB, faith|NN)
# 10   0.366189         (cause|VB, injury|NN)
# 11   0.249006           (take|VB, pride|NN)
# 12   0.142207         (have|VBP, dinner|NN)
# 13   0.164438          (have|VB, dinner|NN)
# 14   0.114471        (put|VBN, pressure|NN)
# 15   0.225289            (give|VB, life|NN)
# 16   0.315301         (provide|VB, help|NN)
# 17   0.356687  (receive|VB, information|NN)
# 18   0.205812         (raise|VBP, money|NN)
# 19   0.299670      (exert|VB, influence|NN)
# 20   0.067559            (got|VBD, hold|NN)
# 21   0.196437          (give|VB, credit|NN)
# 22   0.228891         (take|VBP, refuge|NN)
# 23   0.218673         (pay|VBP, tribute|NN)
# 24   0.133919          (take|VB, notes|NNS)
# 25   0.258523          (return|VB, home|NN)
# 26   0.264347         (leave|VB, office|NN)
# 27   0.204494          (make|VBP, sense|NN)
# 28   0.045640      (gain|NN, experience|NN)
# 29   0.227888      (form|VB, government|NN)

# %%
w10p_w2v_orig = pd.read_csv(datapath+'/Models/1 w2v/Results/wiki10pc_light_001.csv', 
                       converters= converter
                      )

# %%
w10p_w2v_orig = w10p_w2v_orig[~np.isnan(w10p_w2v_orig.cosine_sim)].sort_values('cosine_sim').rename(columns={'ngram' : 'mwe', 'cosine_sim' : 'cosim_10w'}).reset_index(drop=True)

# %%
w10p_w2v_orig
# Out:
#                              mwe      poisson  len  batch  stopwords  \
# 0          (1980s, 1970s, 1960s)   504.762099    3      8  [0, 0, 0]
# 1        (amongst, many, others)   712.565055    3      1  [0, 0, 0]
# 2       (European, register, of)   588.560764    3      1  [0, 0, 1]
# 3          (1950s, 1940s, 1930s)   576.491489    3     10  [0, 0, 0]
# 4                (As, far, back)   449.645748    3      3  [0, 0, 0]
# ...                          ...          ...  ...    ...        ...
# 453464                  (宿, け/犬)   416.659769    2      2     [0, 0]
# 453465                    (ㄴ, ㄹ)  4110.216943    2      5     [0, 0]
# 453466                    (ㄹ, ㅁ)  3227.287802    2      6     [0, 0]
# 453467                 (ㄹ, ㅁ, ㅂ)  5594.044824    3      4  [0, 0, 0]
# 453468                 (ㄴ, ㄹ, ㅁ)  5961.118040    3      2  [0, 0, 0]
#
#                                component_cosims  cosim_10w
# 0        [-0.23996054, -0.23782371, -0.2340202]  -0.237268
# 1       [-0.15940933, -0.21269974, -0.19618905]  -0.189433
# 2                [-0.1621425, -0.21278596, nan]  -0.187464
# 3        [-0.18906975, -0.1606813, -0.19921347]  -0.182988
# 4        [-0.09595686, -0.2087354, -0.24125503]  -0.181982
# ...                                         ...        ...
# 453464                   [0.9859951, 0.9874592]   0.986727
# 453465                 [0.98334867, 0.99101293]   0.987181
# 453466                 [0.99340194, 0.98948646]   0.991444
# 453467          [0.9960094, 0.99351, 0.9925519]   0.994024
# 453468        [0.9962357, 0.9969212, 0.9942658]   0.995808
#
# [453469 rows x 7 columns]

# %%
w10p_orig = all_refs.merge(w10p_w2v_orig[['mwe', 'cosim_10w']], how='inner', on='mwe').drop_duplicates()

# %%
w10p_orig
# Out:
#                    mwe   MC_VN  F_ENC  R_ENC  MC_VPC     D_ADJN          REF  \
# 0          (set, foot)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 1       (shake, hands)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 2        (shed, light)  1000.0    NaN    NaN     NaN        NaN  1000.000000
# 3        (give, birth)   900.0    NaN    NaN     NaN        NaN   900.000000
# 4         (take, part)   900.0    NaN    NaN     NaN        NaN   900.000000
# ..                 ...     ...    ...    ...     ...        ...          ...
# 691  (short, distance)     NaN    NaN    NaN     NaN  33.707865    33.707865
# 692   (early, version)     NaN    NaN    NaN     NaN  22.471910    22.471910
# 693    (small, island)     NaN    NaN    NaN     NaN  22.471910    22.471910
# 694       (olive, oil)     NaN    NaN    NaN     NaN  11.235955    11.235955
# 695     (lemon, juice)     NaN    NaN    NaN     NaN   0.000000     0.000000
#
#      cosim_10w
# 0     0.008091
# 1     0.336349
# 2     0.097372
# 3     0.372657
# 4     0.328196
# ..         ...
# 691   0.319870
# 692   0.344406
# 693   0.527137
# 694   0.521160
# 695   0.802557
#
# [696 rows x 8 columns]

# %%
kept = w10p_orig.merge(w10p_tag, on='mwe', how='inner').drop_duplicates()
kept
# Out:
#                        mwe  MC_VN_x  F_ENC_x    R_ENC_x    MC_VPC_x  D_ADJN_x  \
# 0            (shed, light)   1000.0      NaN        NaN         NaN       NaN
# 1          (bear, witness)    900.0      NaN        NaN         NaN       NaN
# 2          (cause, damage)    800.0      NaN        NaN         NaN       NaN
# 3          (put, pressure)    800.0      NaN        NaN         NaN       NaN
# 4           (raise, money)    700.0      NaN        NaN         NaN       NaN
# 5           (take, refuge)    700.0      NaN        NaN         NaN       NaN
# 6           (pay, tribute)    700.0      NaN        NaN         NaN       NaN
# 7           (return, home)    600.0      NaN        NaN         NaN       NaN
# 8            (make, sense)    600.0      NaN        NaN         NaN       NaN
# 9       (gain, experience)    500.0      NaN        NaN         NaN       NaN
# 10       (commit, suicide)    400.0      NaN        NaN         NaN       NaN
# 11            (get, drunk)    400.0      NaN        NaN         NaN       NaN
# 12              (go, home)    300.0      NaN        NaN         NaN       NaN
# 13          (help, people)    200.0      NaN        NaN         NaN       NaN
# 14             (shot, put)      NaN   1000.0        NaN         NaN       NaN
# 15       (floating, point)      NaN    750.0        NaN         NaN       NaN
# 16          (home, ground)      NaN    750.0        NaN         NaN       NaN
# 17         (fallen, angel)      NaN    750.0        NaN         NaN       NaN
# 18            (cast, iron)      NaN    500.0        NaN         NaN       NaN
# 19     (machine, learning)      NaN    500.0        NaN         NaN       NaN
# 20           (mass, media)      NaN    500.0        NaN         NaN       NaN
# 21      (organized, crime)      NaN    250.0        NaN         NaN       NaN
# 22          (post, office)      NaN      0.0        NaN         NaN       NaN
# 23           (ski, resort)      NaN      0.0        NaN         NaN       NaN
# 24        (lecture, notes)      NaN      0.0        NaN         NaN       NaN
# 25          (land, claims)      NaN      0.0        NaN         NaN       NaN
# 26  (muscle, contractions)      NaN      0.0        NaN         NaN       NaN
# 27      (office, building)      NaN      0.0        NaN         NaN       NaN
# 28     (magnifying, glass)      NaN      0.0        NaN         NaN       NaN
# 29          (human, being)      NaN      NaN  81.481415         NaN       NaN
# 30        (swimming, pool)      NaN      NaN  21.234446         NaN       NaN
# 31            (spell, out)      NaN      NaN        NaN  857.142857       NaN
# 32             (sell, out)      NaN      NaN        NaN  821.428571       NaN
# 33              (look, up)      NaN      NaN        NaN  785.714286       NaN
# 34              (wind, up)      NaN      NaN        NaN  678.571429       NaN
# 35            (point, out)      NaN      NaN        NaN  535.714286       NaN
# 36             (look, out)      NaN      NaN        NaN  500.000000       NaN
# 37             (come, off)      NaN      NaN        NaN  428.571429       NaN
# 38              (feed, on)      NaN      NaN        NaN  357.142857       NaN
# 39              (walk, on)      NaN      NaN        NaN  214.285714       NaN
#
#           REF_x  cosim_10w_x  MC_VN_y  F_ENC_y    R_ENC_y    MC_VPC_y  \
# 0   1000.000000     0.097372   1000.0      NaN        NaN         NaN
# 1    900.000000     0.235828    900.0      NaN        NaN         NaN
# 2    800.000000     0.529138    800.0      NaN        NaN         NaN
# 3    800.000000     0.331696    800.0      NaN        NaN         NaN
# 4    700.000000     0.402098    700.0      NaN        NaN         NaN
# 5    700.000000     0.452950    700.0      NaN        NaN         NaN
# 6    700.000000     0.413777    700.0      NaN        NaN         NaN
# 7    600.000000     0.475525    600.0      NaN        NaN         NaN
# 8    600.000000     0.459291    600.0      NaN        NaN         NaN
# 9    500.000000     0.415918    500.0      NaN        NaN         NaN
# 10   400.000000     0.523489    400.0      NaN        NaN         NaN
# 11   400.000000     0.516912    400.0      NaN        NaN         NaN
# 12   300.000000     0.428841    300.0      NaN        NaN         NaN
# 13   200.000000     0.530716    200.0      NaN        NaN         NaN
# 14  1000.000000     0.071781      NaN   1000.0        NaN         NaN
# 15   750.000000     0.089600      NaN    750.0        NaN         NaN
# 16   750.000000     0.340345      NaN    750.0        NaN         NaN
# 17   750.000000     0.317566      NaN    750.0        NaN         NaN
# 18   500.000000     0.405832      NaN    500.0        NaN         NaN
# 19   500.000000     0.412297      NaN    500.0        NaN         NaN
# 20   500.000000     0.475294      NaN    500.0        NaN         NaN
# 21   250.000000     0.411769      NaN    250.0        NaN         NaN
# 22     0.000000     0.314585      NaN      0.0        NaN         NaN
# 23     0.000000     0.571244      NaN      0.0        NaN         NaN
# 24     0.000000     0.334605      NaN      0.0        NaN         NaN
# 25     0.000000     0.410571      NaN      0.0        NaN         NaN
# 26     0.000000     0.663075      NaN      0.0        NaN         NaN
# 27     0.000000     0.567051      NaN      0.0        NaN         NaN
# 28     0.000000     0.423113      NaN      0.0        NaN         NaN
# 29    81.481415     0.442554      NaN      NaN  81.481415         NaN
# 30    21.234446     0.574566      NaN      NaN  21.234446         NaN
# 31   857.142857     0.149776      NaN      NaN        NaN  857.142857
# 32   821.428571     0.237881      NaN      NaN        NaN  821.428571
# 33   785.714286     0.334338      NaN      NaN        NaN  785.714286
# 34   678.571429     0.204346      NaN      NaN        NaN  678.571429
# 35   535.714286     0.184394      NaN      NaN        NaN  535.714286
# 36   500.000000     0.384093      NaN      NaN        NaN  500.000000
# 37   428.571429     0.428967      NaN      NaN        NaN  428.571429
# 38   357.142857     0.497643      NaN      NaN        NaN  357.142857
# 39   214.285714     0.595446      NaN      NaN        NaN  214.285714
#
#     D_ADJN_y        REF_y  cosim_10w_y
# 0        NaN  1000.000000     0.025012
# 1        NaN   900.000000     0.196912
# 2        NaN   800.000000     0.382958
# 3        NaN   800.000000     0.114471
# 4        NaN   700.000000     0.205812
# 5        NaN   700.000000     0.228891
# 6        NaN   700.000000     0.218673
# 7        NaN   600.000000     0.258523
# 8        NaN   600.000000     0.204494
# 9        NaN   500.000000     0.045640
# 10       NaN   400.000000     0.364881
# 11       NaN   400.000000     0.370344
# 12       NaN   300.000000     0.241142
# 13       NaN   200.000000     0.346564
# 14       NaN  1000.000000    -0.012235
# 15       NaN   750.000000     0.296670
# 16       NaN   750.000000     0.191271
# 17       NaN   750.000000     0.346780
# 18       NaN   500.000000     0.145681
# 19       NaN   500.000000     0.191776
# 20       NaN   500.000000     0.285339
# 21       NaN   250.000000     0.193151
# 22       NaN     0.000000     0.227001
# 23       NaN     0.000000     0.459746
# 24       NaN     0.000000     0.246429
# 25       NaN     0.000000     0.058256
# 26       NaN     0.000000     0.626916
# 27       NaN     0.000000     0.299113
# 28       NaN     0.000000     0.267289
# 29       NaN    81.481415     0.045730
# 30       NaN    21.234446     0.206932
# 31       NaN   857.142857     0.233186
# 32       NaN   821.428571     0.067974
# 33       NaN   785.714286     0.202297
# 34       NaN   678.571429     0.070905
# 35       NaN   535.714286    -0.138180
# 36       NaN   500.000000     0.214005
# 37       NaN   428.571429     0.199765
# 38       NaN   357.142857     0.164193
# 39       NaN   214.285714     0.550852

# %%
lost = w10p_orig.merge(w10p_tag, on='mwe', how='left').drop_duplicates()
lost = lost[np.isnan(lost.cosim_10w_y)]
lost
# Out:
#                    mwe  MC_VN_x  F_ENC_x  R_ENC_x  MC_VPC_x   D_ADJN_x  \
# 0          (set, foot)   1000.0      NaN      NaN       NaN        NaN
# 1       (shake, hands)   1000.0      NaN      NaN       NaN        NaN
# 3        (give, birth)    900.0      NaN      NaN       NaN        NaN
# 4         (take, part)    900.0      NaN      NaN       NaN        NaN
# 5         (turn, back)    900.0      NaN      NaN       NaN        NaN
# ..                 ...      ...      ...      ...       ...        ...
# 691  (short, distance)      NaN      NaN      NaN       NaN  33.707865
# 692   (early, version)      NaN      NaN      NaN       NaN  22.471910
# 693    (small, island)      NaN      NaN      NaN       NaN  22.471910
# 694       (olive, oil)      NaN      NaN      NaN       NaN  11.235955
# 695     (lemon, juice)      NaN      NaN      NaN       NaN   0.000000
#
#            REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y  D_ADJN_y  \
# 0    1000.000000     0.008091      NaN      NaN      NaN       NaN       NaN
# 1    1000.000000     0.336349      NaN      NaN      NaN       NaN       NaN
# 3     900.000000     0.372657      NaN      NaN      NaN       NaN       NaN
# 4     900.000000     0.328196      NaN      NaN      NaN       NaN       NaN
# 5     900.000000     0.428909      NaN      NaN      NaN       NaN       NaN
# ..           ...          ...      ...      ...      ...       ...       ...
# 691    33.707865     0.319870      NaN      NaN      NaN       NaN       NaN
# 692    22.471910     0.344406      NaN      NaN      NaN       NaN       NaN
# 693    22.471910     0.527137      NaN      NaN      NaN       NaN       NaN
# 694    11.235955     0.521160      NaN      NaN      NaN       NaN       NaN
# 695     0.000000     0.802557      NaN      NaN      NaN       NaN       NaN
#
#      REF_y  cosim_10w_y
# 0      NaN          NaN
# 1      NaN          NaN
# 3      NaN          NaN
# 4      NaN          NaN
# 5      NaN          NaN
# ..     ...          ...
# 691    NaN          NaN
# 692    NaN          NaN
# 693    NaN          NaN
# 694    NaN          NaN
# 695    NaN          NaN
#
# [656 rows x 15 columns]

# %%
new = w10p_orig.merge(w10p_tag, on='mwe', how='right').drop_duplicates()
new = new[np.isnan(new.cosim_10w_x)]
new
# Out:
#                         mwe  MC_VN_x  F_ENC_x  R_ENC_x  MC_VPC_x  D_ADJN_x  \
# 40               (see, fit)      NaN      NaN      NaN       NaN       NaN
# 41            (take, leave)      NaN      NaN      NaN       NaN       NaN
# 42          (have, control)      NaN      NaN      NaN       NaN       NaN
# 43            (have, faith)      NaN      NaN      NaN       NaN       NaN
# 44          (cause, injury)      NaN      NaN      NaN       NaN       NaN
# ..                      ...      ...      ...      ...       ...       ...
# 172        (retail, outlet)      NaN      NaN      NaN       NaN       NaN
# 173            (big, issue)      NaN      NaN      NaN       NaN       NaN
# 174        (full, training)      NaN      NaN      NaN       NaN       NaN
# 175             (big, fish)      NaN      NaN      NaN       NaN       NaN
# 176  (written, examination)      NaN      NaN      NaN       NaN       NaN
#
#      REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y    D_ADJN_y  \
# 40     NaN          NaN    900.0      NaN      NaN       NaN         NaN
# 41     NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 42     NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 43     NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 44     NaN          NaN    800.0      NaN      NaN       NaN         NaN
# ..     ...          ...      ...      ...      ...       ...         ...
# 172    NaN          NaN      NaN      NaN      NaN       NaN  325.842697
# 173    NaN          NaN      NaN      NaN      NaN       NaN  325.842697
# 174    NaN          NaN      NaN      NaN      NaN       NaN  123.595506
# 175    NaN          NaN      NaN      NaN      NaN       NaN   89.887640
# 176    NaN          NaN      NaN      NaN      NaN       NaN   89.887640
#
#           REF_y  cosim_10w_y
# 40   900.000000     0.164587
# 41   800.000000     0.313061
# 42   800.000000     0.102348
# 43   800.000000     0.206265
# 44   800.000000     0.366189
# ..          ...          ...
# 172  325.842697     0.426785
# 173  325.842697     0.091107
# 174  123.595506     0.263529
# 175   89.887640     0.267810
# 176   89.887640     0.163778
#
# [137 rows x 15 columns]

# %%
lost_ng = lost.merge(ngram, on='mwe', how='left').drop_duplicates()

# %%
lost_ng
# Out:
#                   mwe  MC_VN_x  F_ENC_x  R_ENC_x  MC_VPC_x   D_ADJN_x  \
# 0         (set, foot)   1000.0      NaN      NaN       NaN        NaN
# 1         (set, foot)   1000.0      NaN      NaN       NaN        NaN
# 2         (set, foot)   1000.0      NaN      NaN       NaN        NaN
# 3      (shake, hands)   1000.0      NaN      NaN       NaN        NaN
# 4       (give, birth)    900.0      NaN      NaN       NaN        NaN
# ..                ...      ...      ...      ...       ...        ...
# 734  (early, version)      NaN      NaN      NaN       NaN  22.471910
# 735   (small, island)      NaN      NaN      NaN       NaN  22.471910
# 736      (olive, oil)      NaN      NaN      NaN       NaN  11.235955
# 737      (olive, oil)      NaN      NaN      NaN       NaN  11.235955
# 738    (lemon, juice)      NaN      NaN      NaN       NaN   0.000000
#
#            REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y  D_ADJN_y  \
# 0    1000.000000     0.008091      NaN      NaN      NaN       NaN       NaN
# 1    1000.000000     0.008091      NaN      NaN      NaN       NaN       NaN
# 2    1000.000000     0.008091      NaN      NaN      NaN       NaN       NaN
# 3    1000.000000     0.336349      NaN      NaN      NaN       NaN       NaN
# 4     900.000000     0.372657      NaN      NaN      NaN       NaN       NaN
# ..           ...          ...      ...      ...      ...       ...       ...
# 734    22.471910     0.344406      NaN      NaN      NaN       NaN       NaN
# 735    22.471910     0.527137      NaN      NaN      NaN       NaN       NaN
# 736    11.235955     0.521160      NaN      NaN      NaN       NaN       NaN
# 737    11.235955     0.521160      NaN      NaN      NaN       NaN       NaN
# 738     0.000000     0.802557      NaN      NaN      NaN       NaN       NaN
#
#      REF_y  cosim_10w_y  freq       poisson  len               ngram_tag
# 0      NaN          NaN    40  -2036.929515    2      (set|VBD, foot|NN)
# 1      NaN          NaN    58  -2987.779195    2      (set|VBN, foot|NN)
# 2      NaN          NaN    95  -4577.321101    2       (set|VB, foot|NN)
# 3      NaN          NaN    62  -2818.844870    2   (shake|VB, hands|NNS)
# 4      NaN          NaN   116  -5511.576947    2    (give|VBP, birth|NN)
# ..     ...          ...   ...           ...  ...                     ...
# 734    NaN          NaN   299 -15942.867054    2  (early|JJ, version|NN)
# 735    NaN          NaN   421 -21581.909948    2   (small|JJ, island|NN)
# 736    NaN          NaN   172  -7969.712469    2      (olive|NN, oil|NN)
# 737    NaN          NaN   242 -10817.437945    2      (olive|JJ, oil|NN)
# 738    NaN          NaN   107  -4473.786343    2    (lemon|NN, juice|NN)
#
# [739 rows x 19 columns]

# %%
cutoff = ngram.iloc[499999].poisson  # Poisson for evaluated ngrams were all this or above

# %%
cutoff2 = ngram.iloc[499999+58532].poisson  # Approximation of cutoff without proper nouns

# %%
cutoff2
# Out:
# -1750.6127623282243

# %%
lost_ng[lost_ng.poisson >= cutoff]
# Out:
#                  mwe  MC_VN_x  F_ENC_x     R_ENC_x  MC_VPC_x  D_ADJN_x  \
# 581  (cutting, edge)      NaN      NaN  798.148167       NaN       NaN
#
#           REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y  D_ADJN_y  \
# 581  798.148167     0.368593      NaN      NaN      NaN       NaN       NaN
#
#      REF_y  cosim_10w_y  freq      poisson  len              ngram_tag
# 581    NaN          NaN    27 -1151.063357    2  (cutting|JJ, edge|NN)

# %%
lost_ng[lost_ng.poisson >= cutoff2]
# Out:
#                  mwe  MC_VN_x  F_ENC_x     R_ENC_x  MC_VPC_x  D_ADJN_x  \
# 111     (tax, haven)      NaN   1000.0         NaN       NaN       NaN
# 513     (back, door)      NaN      0.0         NaN       NaN       NaN
# 581  (cutting, edge)      NaN      NaN  798.148167       NaN       NaN
#
#            REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y  D_ADJN_y  \
# 111  1000.000000     0.287075      NaN      NaN      NaN       NaN       NaN
# 513     0.000000     0.510744      NaN      NaN      NaN       NaN       NaN
# 581   798.148167     0.368593      NaN      NaN      NaN       NaN       NaN
#
#      REF_y  cosim_10w_y  freq      poisson  len              ngram_tag
# 111    NaN          NaN    36 -1681.658395    2     (tax|NN, haven|NN)
# 513    NaN          NaN    32 -1710.707878    2     (back|RB, door|NN)
# 581    NaN          NaN    27 -1151.063357    2  (cutting|JJ, edge|NN)

# %%
new_ng = new.merge(ngram, on='mwe', how='left').drop_duplicates()

# %%
new_ng
# Out:
#                         mwe  MC_VN_x  F_ENC_x  R_ENC_x  MC_VPC_x  D_ADJN_x  \
# 0                (see, fit)      NaN      NaN      NaN       NaN       NaN
# 1             (take, leave)      NaN      NaN      NaN       NaN       NaN
# 2           (have, control)      NaN      NaN      NaN       NaN       NaN
# 3           (have, control)      NaN      NaN      NaN       NaN       NaN
# 4             (have, faith)      NaN      NaN      NaN       NaN       NaN
# ..                      ...      ...      ...      ...       ...       ...
# 149        (retail, outlet)      NaN      NaN      NaN       NaN       NaN
# 150            (big, issue)      NaN      NaN      NaN       NaN       NaN
# 151        (full, training)      NaN      NaN      NaN       NaN       NaN
# 152             (big, fish)      NaN      NaN      NaN       NaN       NaN
# 153  (written, examination)      NaN      NaN      NaN       NaN       NaN
#
#      REF_x  cosim_10w_x  MC_VN_y  F_ENC_y  R_ENC_y  MC_VPC_y    D_ADJN_y  \
# 0      NaN          NaN    900.0      NaN      NaN       NaN         NaN
# 1      NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 2      NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 3      NaN          NaN    800.0      NaN      NaN       NaN         NaN
# 4      NaN          NaN    800.0      NaN      NaN       NaN         NaN
# ..     ...          ...      ...      ...      ...       ...         ...
# 149    NaN          NaN      NaN      NaN      NaN       NaN  325.842697
# 150    NaN          NaN      NaN      NaN      NaN       NaN  325.842697
# 151    NaN          NaN      NaN      NaN      NaN       NaN  123.595506
# 152    NaN          NaN      NaN      NaN      NaN       NaN   89.887640
# 153    NaN          NaN      NaN      NaN      NaN       NaN   89.887640
#
#           REF_y  cosim_10w_y  freq      poisson  len  \
# 0    900.000000     0.164587    34 -1598.636530    2
# 1    800.000000     0.313061    27 -1375.915654    2
# 2    800.000000     0.102348    20 -1155.062179    2
# 3    800.000000     0.102348    57 -3162.753864    2
# 4    800.000000     0.206265    28 -1530.354543    2
# ..          ...          ...   ...          ...  ...
# 149  325.842697     0.426785    30 -1416.984286    2
# 150  325.842697     0.091107    23 -1212.001700    2
# 151  123.595506     0.263529    29 -1589.395661    2
# 152   89.887640     0.267810    24 -1241.839313    2
# 153   89.887640     0.163778    20 -1047.127726    2
#
#                          ngram_tag
# 0                (see|VBP, fit|JJ)
# 1              (take|VB, leave|NN)
# 2           (have|VBP, control|NN)
# 3            (have|VB, control|NN)
# 4             (have|VBP, faith|NN)
# ..                             ...
# 149         (retail|JJ, outlet|NN)
# 150             (big|JJ, issue|NN)
# 151         (full|JJ, training|NN)
# 152              (big|JJ, fish|NN)
# 153  (written|VBN, examination|NN)
#
# [154 rows x 19 columns]

# %%
new_ng.poisson.mean()
# Out:
# -1600.413967569273

# %%
lost_ng.poisson.mean()
# Out:
# -22361.1718501027

# %%
ngram
# Out:
#                                                mwe     freq       poisson  \
# 0                                 (311.22, 500.86)       20 -6.670842e+02
# 1                                 (Makhaya, Ntini)       20 -6.670842e+02
# 2        (resting_place_coordinates, burial_place)       20 -6.670842e+02
# 3                            (Dechawat, Poomjaeng)       20 -6.670842e+02
# 4                                     (MSC1, MSC2)       20 -6.670842e+02
# ...                                            ...      ...           ...
# 1859185                                  (on, the)   473024 -2.576335e+07
# 1859186                                 (and, the)   492576 -2.778679e+07
# 1859187                                  (to, the)   714100 -3.884106e+07
# 1859188                                  (in, the)  1388181 -7.588717e+07
# 1859189                                  (of, the)  2256975 -1.229829e+08
#
#          len                                          ngram_tag
# 0          2                             (311.22|CD, 500.86|CD)
# 1          2                           (Makhaya|NNP, Ntini|NNP)
# 2          2  (resting_place_coordinates|NNS, burial_place|VBP)
# 3          2                      (Dechawat|NNP, Poomjaeng|NNP)
# 4          2                                 (MSC1|NN, MSC2|NN)
# ...      ...                                                ...
# 1859185    2                                    (on|IN, the|DT)
# 1859186    2                                   (and|CC, the|DT)
# 1859187    2                                    (to|IN, the|DT)
# 1859188    2                                    (in|IN, the|DT)
# 1859189    2                                    (of|IN, the|DT)
#
# [1859190 rows x 5 columns]

# %%
ngram.freq.corr(ngram.poisson, method = 'pearson')
# Out:
# -0.9988625470563577

# %%
# Remove POS tags from tuples for matching

import re

pipematcher = re.compile("(.*)\|")
pipematch2 = re.compile("(\|[A-Z]{2,4}\$?|[\$\:,\.\"]|``|\-LRB\-?|\-RRB\-?)")

def g1(matchobj):
    return matchobj.group(1)

def tup_matcher(tupstr, pattern=pipematcher):
    ot = []
    for w in tupstr:
        if w == '|HYPH': w = '-|HYPH'
        if re.match(pattern, w):
            ot.append(g1(pattern.match(w)))
    return tuple(ot)


def tup_rem(tupstr, pattern=pipematch2):
    ot = []
    for w in tupstr:
        if w == '|HYPH': w = '-|HYPH'
        ot.append(re.sub(pattern,'',w))
    return tuple(ot)

# %%
def tup_tags(tupstr, pattern=pipematch2):
    ot = []
    for w in tupstr:
        if w == '|HYPH': w = '-|HYPH'
        if re.search(pattern, w):
            ot.append(g1(pattern.search(w)))
    return tuple(ot)

# %%
pipematch2 = re.compile("(\|[A-Z]{2,4}\$?|[\$\:,\.\"]|``|\-LRB\-?|\-RRB\-?)")

testtup = ngram.iloc[2].ngram_tag
print(testtup)
tup_tags(testtup, pattern=pipematch2)
# Out:
# ('resting_place_coordinates|NNS', 'burial_place|VBP')
# ('|NNS', '|VBP')

# %%
w10p_w2v['taglist'] = w10p_w2v.ngram_tag.apply(tup_tags)

# %%
w10p_w2v.taglist.value_counts()
# Out:
# (|NNP, |NNP)           58532
# (|JJ, |NN)             19048
# (|NN, |NN)             15187
# (|IN, |NNP)            13136
# (|NN, |IN)             11329
#                        ...
# (|JJ, |WP, |VBP)           1
# (|HYPH, |VBG, |NNP)        1
# (|PRP, |CC, |VBD)          1
# (|IN, |JJS, |DT)           1
# (|JJ, |NN, |RBR)           1
# Name: taglist, Length: 6218, dtype: int64

# %%
w10p_w2v
# Out:
#                                                 mwe  freq      poisson  len  \
# 0                                 (delivered, from)    28 -1567.428918    2
# 1                                  (then, had, two)    20 -1586.812073    3
# 2                               (and, finally, for)    20 -1647.756550    3
# 3                                 (one, before, it)    20 -1587.727730    3
# 4                              (However, in, their)    20 -1642.620348    3
# ...                                             ...   ...          ...  ...
# 482425  (środek.svgFile, Wygaszony, środek.svgFile)    36 -1588.358559    3
# 482426                       (Recurvirostridae, is)    25 -1276.332579    2
# 482427                           (OUL3, CRO1, CRO2)    36 -1515.104871    3
# 482428                                    (Lapu, -)    22 -1127.048317    2
# 482429                                       (ㄹ, ㄻ)    30 -1138.325224    2
#
#         batch  stopwords                      component_cosims  cosim_10w  \
# 0           5     [0, 1]                     [-0.2535712, nan]  -0.253571
# 1           3  [0, 1, 1]               [-0.24625674, nan, nan]  -0.246257
# 2           4  [1, 0, 1]               [nan, -0.22293654, nan]  -0.222937
# 3           7  [1, 0, 1]               [nan, -0.21940775, nan]  -0.219408
# 4           3  [0, 1, 1]                [-0.2108197, nan, nan]  -0.210820
# ...       ...        ...                                   ...        ...
# 482425      1  [0, 0, 0]     [0.9717464, 0.9375481, 0.9717464]   0.960347
# 482426      4     [0, 1]                     [0.96257687, nan]   0.962577
# 482427      2  [0, 0, 0]  [0.94491136, 0.97224206, 0.97286904]   0.963341
# 482428      2     [0, 1]                      [0.9648907, nan]   0.964891
# 482429      2     [0, 0]                [0.97117275, 0.982044]   0.976608
#
#                                                 ngram_tag            taglist
# 0                                (delivered|VBD, from|IN)        (|VBD, |IN)
# 1                              (then|RB, had|VBD, two|CD)   (|RB, |VBD, |CD)
# 2                            (and|CC, finally|RB, for|IN)    (|CC, |RB, |IN)
# 3                             (one|CD, before|IN, it|PRP)   (|CD, |IN, |PRP)
# 4                         (However|RB, in|IN, their|PRP$)  (|RB, |IN, |PRP$)
# ...                                                   ...                ...
# 482425  (środek.svgFile|NNP, Wygaszony|NNP, środek.svg...       (., |NNP, .)
# 482426                     (Recurvirostridae|NNP, is|VBZ)       (|NNP, |VBZ)
# 482427                        (OUL3|NN, CRO1|NN, CRO2|NN)    (|NN, |NN, |NN)
# 482428                                  (Lapu|NNP, |HYPH)      (|NNP, |HYPH)
# 482429                                     (ㄹ|SYM, ㄻ|SYM)       (|SYM, |SYM)
#
# [482430 rows x 10 columns]
