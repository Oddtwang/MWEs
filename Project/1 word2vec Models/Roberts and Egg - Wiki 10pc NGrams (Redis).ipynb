# %%
import os

path = 'C:/Users/'+os.getlogin()+'/Google Drive/University/Dissertation'
datapath = 'E:/Dissertation Data'
    
os.chdir(path+'/Code')
os.getcwd()
# Out:
# 'C:\\Users\\User\\Google Drive\\University\\Dissertation\\Code'

# %% [markdown]
# We collect lexical co-occurrence statistics on all words in
# the English Wikipedia, using the WikiExtractor tool2 to retrieve
# plain text from the April 2015 dump (ca. 2.8B words),
# and using simple regular expressions to segment sentences
# and words, and remove URLs and punctuation. We perform
# no POS tagging, lemmatisation, case normalisation,
# or removal of numbers or symbols.

# %%
import pickle
import pandas as pd
import re
import numpy as np

import nltk
from nltk.tokenize import MWETokenizer

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
    
from nltk.tokenize import WhitespaceTokenizer

# %%
w10p = PlaintextCorpusReader(datapath+'/Corpora/wiki/enwiki_20200520/','enwiki_20200520_10pc.txt',
                            word_tokenizer = WhitespaceTokenizer()
                            )

# %%
# Import word and sentence generators

from generators import sent_gen, word_gen, Sent_Seq

# %% [markdown]
# We collect word frequency information with the
# SRILM language modelling toolkit (Stolcke, 2002), counting
# n-grams (n <= 3), treating MWEs as contiguous bigrams
# and trigrams), and identify MWE candidates by computing
# the Poisson collocation measure (Quasthoff and Wolff,
# 2002) for all bigrams and trigrams (ca. 23M n-grams).
# This method should be readily extensible to include longer
# n-grams.

# %%
from redis import Redis
from rediscollections import RedisOrderedDict, key_val_tuples

# %%
from nltk.metrics.spearman import (
    spearman_correlation,
    ranks_from_scores,
)

# %%
eval_count = 500000

# %%
r = Redis()

od = RedisOrderedDict(r, 'w10p:w10p_poisson')

# %%
# Total no. of n-gram candidates (above minimum frequency)
len(od)
# Out:
# 2002318

# %%
# Redis ordered dict contains Poisson scores for n-grams - pull requisite set from there

ngram_eval = pd.DataFrame.from_records( key_val_tuples(od, end=eval_count-1) , columns = ['ngram', 'poisson'])

# %%
ngram_eval['len'] = ngram_eval.ngram.apply(len)

# %%
ngram_eval
# Out:
#                                 ngram       poisson  len
# 0                           (of, the)  3.874652e+06    2
# 1       (References, External, links)  2.566994e+06    3
# 2                   (External, links)  2.229096e+06    2
# 3                           (in, the)  2.094387e+06    2
# 4                           (0, 0, 0)  1.798530e+06    3
# ...                               ...           ...  ...
# 499995            (Work, started, on)  3.883693e+02    3
# 499996        (of, these, techniques)  3.883679e+02    3
# 499997             (Stadio, Flaminio)  3.883678e+02    2
# 499998                    (IRE, 3, C)  3.883678e+02    3
# 499999  (The, Official, Encyclopedia)  3.883646e+02    3
#
# [500000 rows x 3 columns]

# %%
#len(w10p.words())
# Out:
# 305657697

# %% [markdown]
# We then automatically score the million most strongly associated
# n-grams (i.e., roughly the top 5% of the Poisson-ranked
# list) for compositionality.
#
# Using word2vec (Mikolov et al., 2013) with the parameters
# found to be most effective by Baroni et al. (2014), we
# build a word embedding vector for every simplex word in
# the vocabulary (ca. 1M types), as well as for each MWE candidate.
#
# * Continuous bag of words model with 400-dimensional vectors, window size 5, subsampling with t = 10^-5, negative sampling with 10 samples. We build vectors only for tokens observed 20 times or more in the corpus.
#
# We then compute the cosine similarity of the vector
# representation for a MWE candidate with the vectors of its
# constituent words, and take the arithmetic mean.
# In scoring
# the compositionality of a candidate, we do not measure the
# cosine similarity of the MWE with any stop words it may
# contain, as stop words may be assumed to be semantically
# uninformative.
# * Stop words are taken here to be the 50 most frequent words in the vocabulary.

# %%
# Stopwords from corpus - 50 most frequent
from nltk import FreqDist

fdist = FreqDist(word_gen(w10p, sent_mark=''))

stop = set( word for word, f in fdist.most_common(50))

# Might be quicker to get these from the Redis hashdict (though it's not ordered) rather than counting

# %%
stop
# Out:
# {'0',
#  '1',
#  '2',
#  '3',
#  'A',
#  'He',
#  'In',
#  'It',
#  'New',
#  'The',
#  'a',
#  'also',
#  'an',
#  'and',
#  'are',
#  'as',
#  'at',
#  'be',
#  'been',
#  'but',
#  'by',
#  'first',
#  'for',
#  'from',
#  'had',
#  'has',
#  'have',
#  'he',
#  'her',
#  'his',
#  'in',
#  'is',
#  'it',
#  'its',
#  'not',
#  'of',
#  'on',
#  'one',
#  'or',
#  'that',
#  'the',
#  'their',
#  'this',
#  'to',
#  'two',
#  'was',
#  'were',
#  'which',
#  'who',
#  'with'}

# %%
# Also pickle the stoplist, save counting again later
with open(datapath+'/Corpora/wiki/enwiki_20200520/10pc_stop.pkl', 'wb') as pfile:
    pickle.dump(stop, pfile)

# %%
del fdist

# %%
from batcher import batcher  # Custom module with logic for assigning n-grams to batches, avoiding overlap

# %%
batches, batch_count = batcher(ngram_eval.ngram, stopwords=stop, max_batches = 10)

batches
# Out:
# {('References', 'External', 'links'): 1,
#  ('United', 'States'): 1,
#  ('New', 'York'): 1,
#  ('as', 'well', 'as'): 1,
#  ('See', 'also'): 1,
#  ('part', 'of', 'the'): 1,
#  ('can', 'be'): 1,
#  ('World', 'War', 'II'): 1,
#  ('did', 'not'): 1,
#  ('member', 'of', 'the'): 1,
#  ('Los', 'Angeles'): 1,
#  ('Kitt', 'Peak', 'Spacewatch'): 1,
#  ('due', 'to'): 1,
#  ('more', 'than'): 1,
#  ('High', 'School'): 1,
#  ('was', 'born', 'in'): 1,
#  ('based', 'on'): 1,
#  ('Apps', 'Goals', 'Apps'): 1,
#  ('where', 'he'): 1,
#  ('New', 'Zealand'): 1,
#  ('during', 'the'): 1,
#  ('a', 'number', 'of'): 1,
#  ('would', 'be'): 1,
#  ('List', 'of'): 1,
#  ('University', 'of'): 1,
#  ('end', 'of', 'the'): 1,
#  ('According', 'to'): 1,
#  ('Air', 'Force'): 1,
#  ('United', 'Kingdom'): 1,
#  ('along', 'with'): 1,
#  ('known', 'as', 'the'): 1,
#  ('does', 'not'): 1,
#  ('Hong', 'Kong'): 1,
#  ('New', 'South', 'Wales'): 1,
#  ('There', 'are'): 1,
#  ('Further', 'reading'): 1,
#  ('was', 'released'): 1,
#  ('Register', 'of', 'Historic'): 1,
#  ('Prime', 'Minister'): 1,
#  ('may', 'be'): 1,
#  ('at', 'the', 'time'): 1,
#  ('rather', 'than'): 1,
#  ('San', 'Francisco'): 1,
#  ('may', 'refer', 'to'): 1,
#  ('Hall', 'of', 'Fame'): 1,
#  ('Early', 'life'): 1,
#  ('a', 'new'): 1,
#  ('World', 'War', 'I'): 1,
#  ('Socorro', 'LINEAR'): 1,
#  ('de', 'la'): 1,
#  ('at', 'least'): 1,
#  ('In', 'addition'): 1,
#  ('is', 'located'): 1,
#  ('Track', 'listing'): 1,
#  ('will', 'be'): 1,
#  ('returned', 'to'): 1,
#  ('under', 'the'): 1,
#  ('took', 'place'): 1,
#  ('able', 'to'): 1,
#  ('is', 'an', 'American'): 1,
#  ('moved', 'to'): 1,
#  ('when', 'he'): 1,
#  ('they', 'were'): 1,
#  ('directed', 'by'): 1,
#  ('high', 'school'): 1,
#  ('Mount', 'Lemmon', 'Survey'): 1,
#  ('there', 'were'): 1,
#  ('went', 'on', 'to'): 1,
#  ('such', 'as', 'the'): 1,
#  ('members', 'of', 'the'): 1,
#  ('out', 'of'): 1,
#  ('Award', 'for', 'Best'): 1,
#  ('Did', 'not', 'advance'): 1,
#  ('New', 'Jersey'): 1,
#  ('House', 'of', 'Representatives'): 1,
#  ('every', '100', 'females'): 1,
#  ('As', 'a', 'result'): 1,
#  ('age', 'or', 'older'): 1,
#  ('World', 'Cup'): 1,
#  ('into', 'the'): 1,
#  ('Supreme', 'Court'): 1,
#  ('Film', 'Festival'): 1,
#  ('South', 'Africa'): 1,
#  ('North', 'Carolina'): 1,
#  ('19th', 'century'): 1,
#  ('per', 'square', 'mile'): 1,
#  ('Personal', 'life'): 1,
#  ('his', 'wife'): 1,
#  ('his', 'own'): 1,
#  ('Civil', 'War'): 1,
#  ('Grand', 'Prix'): 1,
#  ('according', 'to'): 1,
#  ('was', 'appointed'): 1,
#  ('no', 'longer'): 1,
#  ('a', 'series', 'of'): 1,
#  ('order', 'to'): 1,
#  ('could', 'be'): 1,
#  ('their', 'own'): 1,
#  ('Summer', 'Olympics'): 1,
#  ('Football', 'League'): 1,
#  ('a', 'few'): 1,
#  ('For', 'example'): 1,
#  ('they', 'are'): 1,
#  ('Major', 'League', 'Baseball'): 1,
#  ('North', 'America'): 1,
#  ('median', 'income'): 1,
#  ('Year', 'Title', 'Role'): 1,
#  ('20th', 'century'): 1,
#  ('At', 'the'): 1,
#  ('do', 'not'): 1,
#  ('associated', 'with'): 1,
#  ('there', 'are'): 1,
#  ('announced', 'that'): 1,
#  ('was', 'named'): 1,
#  ('a', 'variety', 'of'): 1,
#  ('age', 'of', '18'): 1,
#  ('was', 'built'): 1,
#  ('Puerto', 'Rico'): 1,
#  ('head', 'coach'): 1,
#  ('San', 'Diego'): 1,
#  ('a', 'large'): 1,
#  ('a', 'small'): 1,
#  ('was', 'founded', 'in'): 1,
#  ('less', 'than'): 1,
#  ('65', 'years', 'of'): 1,
#  ('should', 'be'): 1,
#  ('Soviet', 'Union'): 1,
#  ('a', 'total', 'of'): 1,
#  ('referred', 'to'): 1,
#  ('stated', 'that'): 1,
#  ('up', 'to'): 1,
#  ('average', 'household', 'size'): 1,
#  ('responsible', 'for'): 1,
#  ('this', 'time'): 1,
#  ('back', 'to'): 1,
#  ('couples', 'living', 'together'): 1,
#  ('There', 'were'): 1,
#  ('someone', 'living', 'alone'): 1,
#  ('written', 'by'): 1,
#  ('same', 'year'): 1,
#  ('is', 'now'): 1,
#  ('best', 'known', 'for'): 1,
#  ('first', 'time'): 1,
#  ('Battle', 'of'): 1,
#  ('was', 'an', 'American'): 1,
#  ('Washington', 'D.C'): 1,
#  ('Department', 'of'): 1,
#  ('followed', 'by'): 1,
#  ('was', 'elected'): 1,
#  ('won', 'the'): 1,
#  ('University', 'Press'): 1,
#  ('St', 'Louis'): 1,
#  ('Billboard', 'Hot', '100'): 1,
#  ('Roman', 'Catholic'): 1,
#  ('said', 'that'): 1,
#  ('would', 'have'): 1,
#  ('a', 'single'): 1,
#  ('Official', 'website'): 1,
#  ('after', 'the'): 1,
#  ('his', 'father'): 1,
#  ('studio', 'album'): 1,
#  ('Hispanic', 'or', 'Latino'): 1,
#  ('railway', 'station'): 1,
#  ('his', 'death'): 1,
#  ('et', 'al'): 1,
#  ('During', 'the'): 1,
#  ('made', 'up', 'of'): 1,
#  ('Premier', 'League'): 1,
#  ('and', 'other'): 1,
#  ('rest', 'of', 'the'): 1,
#  ('within', 'the'): 1,
#  ('produced', 'by'): 1,
#  ('Rio', 'de', 'Janeiro'): 1,
#  ('per', 'capita', 'income'): 1,
#  ('used', 'to'): 1,
#  ('Sri', 'Lanka'): 1,
#  ('Las', 'Vegas'): 1,
#  ('general', 'election'): 1,
#  ('The', 'racial', 'makeup'): 1,
#  ('average', 'family', 'size'): 1,
#  ('Great', 'Britain'): 1,
#  ('must', 'be'): 1,
#  ('each', 'other'): 1,
#  ('no', 'husband', 'present'): 1,
#  ('decided', 'to'): 1,
#  ('side', 'of', 'the'): 1,
#  ('backing', 'vocals'): 1,
#  ('replaced', 'by'): 1,
#  ('International', 'Airport'): 1,
#  ('United', 'Nations'): 1,
#  ('may', 'have'): 1,
#  ('owned', 'by'): 1,
#  ('female', 'householder', 'with'): 1,
#  ('through', 'the'): 1,
#  ('version', 'of', 'the'): 1,
#  ('x', 'x', 'x'): 1,
#  ('continued', 'to'): 1,
#  ('years', 'later'): 1,
#  ('its', 'own'): 1,
#  ('use', 'of'): 1,
#  ('led', 'to'): 1,
#  ('found', 'in'): 1,
#  ('was', 'established', 'in'): 1,
#  ('appeared', 'in'): 1,
#  ('where', 'she'): 1,
#  ('over', 'the'): 1,
#  ('consists', 'of'): 1,
#  ('a', 'group', 'of'): 1,
#  ('years', 'old'): 1,
#  ('ice', 'hockey'): 1,
#  ('was', 'awarded'): 1,
#  ('his', 'career'): 1,
#  ('Buenos', 'Aires'): 1,
#  ('an', 'average', 'density'): 1,
#  ('son', 'of'): 1,
#  ('involved', 'in'): 1,
#  ('made', 'his', 'debut'): 1,
#  ('same', 'time'): 1,
#  ('could', 'not'): 1,
#  ('around', 'the', 'world'): 1,
#  ('Northern', 'Ireland'): 1,
#  ('television', 'series'): 1,
#  ('died', 'in'): 1,
#  ('South', 'Korea'): 1,
#  ('served', 'as', 'the'): 1,
#  ('took', 'part', 'in'): 1,
#  ('some', 'of', 'the'): 1,
#  ('listed', 'on', 'the'): 1,
#  ('led', 'by'): 1,
#  ('published', 'in'): 1,
#  ('New', 'Orleans'): 1,
#  ('They', 'are'): 1,
#  ('most', 'of', 'the'): 1,
#  ('a', 'list', 'of'): 1,
#  ('South', 'Carolina'): 1,
#  ('music', 'video'): 1,
#  ('and', 'then'): 1,
#  ('prior', 'to'): 1,
#  ('considered', 'to', 'be'): 1,
#  ('Conservative', 'Conservative', 'Conservative'): 1,
#  ('grew', 'up', 'in'): 1,
#  ('following', 'year'): 1,
#  ('president', 'of', 'the'): 1,
#  ('Communist', 'Party'): 1,
#  ('45', 'to', '64'): 1,
#  ('used', 'for'): 1,
#  ('is', 'a', 'former'): 1,
#  ('The', 'population', 'density'): 1,
#  ('House', 'of', 'Commons'): 1,
#  ('a', 'village', 'in'): 1,
#  ('British', 'Columbia'): 1,
#  ('TV', 'series'): 1,
#  ('between', 'the'): 1,
#  ('President', 'of', 'the'): 1,
#  ('Czech', 'Republic'): 1,
#  ('once', 'again'): 1,
#  ('Member', 'of', 'Parliament'): 1,
#  ('or', 'more', 'races'): 1,
#  ('Elementary', 'School'): 1,
#  ('Legislative', 'Assembly'): 1,
#  ('footballer', 'who', 'plays'): 1,
#  ('graduated', 'from'): 1,
#  ('Nova', 'Scotia'): 1,
#  ('away', 'from'): 1,
#  ('World', 'Championships'): 1,
#  ('0–0', '0–0', '0–0'): 1,
#  ('her', 'husband'): 1,
#  ('an', 'important'): 1,
#  ('similar', 'to'): 1,
#  ('was', 'originally'): 1,
#  ('poverty', 'line', 'including'): 1,
#  ('was', 'promoted', 'to'): 1,
#  ('a', 'population', 'of'): 1,
#  ('can', 'also', 'be'): 1,
#  ('Democratic', 'Party'): 1,
#  ('Eurovision', 'Song', 'Contest'): 1,
#  ('all', 'households', 'were'): 1,
#  ('above', 'sea', 'level'): 1,
#  ('football', 'team'): 1,
#  ('One', 'of', 'the'): 1,
#  ('football', 'player'): 1,
#  ('Labour', 'Labour', 'Labour'): 1,
#  ('related', 'to'): 1,
#  ('18th', 'century'): 1,
#  ('parts', 'of'): 1,
#  ('is', 'currently'): 1,
#  ('him', 'to'): 1,
#  ('was', 'held'): 1,
#  ('resulted', 'in'): 1,
#  ('They', 'were'): 1,
#  ('participated', 'in'): 1,
#  ('when', 'it'): 1,
#  ('was', 'nominated', 'for'): 1,
#  ('fact', 'that'): 1,
#  ('Secretary', 'of', 'State'): 1,
#  ('at', 'that', 'time'): 1,
#  ('an', 'area', 'of'): 1,
#  ('an', 'attempt', 'to'): 1,
#  ('was', 'born', 'on'): 1,
#  ('most', 'important'): 1,
#  ('Native', 'American'): 1,
#  ('where', 'it'): 1,
#  ('i', 'c', 'g'): 1,
#  ('25', 'to', '44'): 1,
#  ('peaked', 'at', 'number'): 1,
#  ('South', 'African'): 1,
#  ('derived', 'from'): 1,
#  ('The', 'film'): 1,
#  ('Notre', 'Dame'): 1,
#  ('half', 'of', 'the'): 1,
#  ('lack', 'of'): 1,
#  ('so', 'that'): 1,
#  ('OppositionResult', 'OppositionResult', 'OppositionResult'): 1,
#  ('living', 'with', 'them'): 1,
#  ('they', 'had'): 1,
#  ('unable', 'to'): 1,
#  ('return', 'to'): 1,
#  ('Kansas', 'City'): 1,
#  ('Ministry', 'of'): 1,
#  ('Bosnia', 'and', 'Herzegovina'): 1,
#  ('Saudi', 'Arabia'): 1,
#  ('against', 'the'): 1,
#  ('a', 'major'): 1,
#  ('Due', 'to'): 1,
#  ('São', 'Paulo'): 1,
#  ('Armed', 'Forces'): 1,
#  ('Museum', 'of', 'Art'): 1,
#  ('those', 'who'): 1,
#  ('throughout', 'the'): 1,
#  ('housing', 'units'): 1,
#  ('official', 'website'): 1,
#  ('is', 'a', 'species'): 1,
#  ('transferred', 'to'): 1,
#  ('because', 'of'): 1,
#  ('Indian', 'National', 'Congress'): 1,
#  ('4', '0'): 1,
#  ('Human', 'Rights'): 1,
#  ('Peak', 'chart', 'positions'): 1,
#  ('Places', 'listings', 'in'): 1,
#  ('Academy', 'of', 'Sciences'): 1,
#  ('when', 'she'): 1,
#  ('Fine', 'Arts'): 1,
#  ('across', 'the'): 1,
#  ('Rhode', 'Island'): 1,
#  ('Institute', 'of', 'Technology'): 1,
#  ('NCAA', 'Division', 'I'): 1,
#  ('joined', 'the'): 1,
#  ('rock', 'band'): 1,
#  ('X', 'X', 'X'): 1,
#  ('National', 'Park'): 1,
#  ('Anderson', 'Mesa', 'LONEOS'): 1,
#  ('refers', 'to'): 1,
#  ('reported', 'that'): 1,
#  ('He', 'played'): 1,
#  ('designed', 'by'): 1,
#  ('years', 'ago'): 1,
#  ('role', 'in'): 1,
#  ('Tel', 'Aviv'): 1,
#  ('access', 'to'): 1,
#  ('failed', 'to'): 1,
#  ('published', 'by'): 1,
#  ('added', 'to', 'the'): 1,
#  ('used', 'in'): 1,
#  ('wide', 'range', 'of'): 1,
#  ('Warner', 'Bros'): 1,
#  ('regular', 'season'): 1,
#  ('would', 'not'): 1,
#  ('Tag', 'Team', 'Championship'): 1,
#  ('FA', 'Cup'): 1,
#  ('Albums', 'Chart'): 1,
#  ('gold', 'medal'): 1,
#  ('4', '5', '6'): 1,
#  ('began', 'to'): 1,
#  ('ability', 'to'): 1,
#  ('form', 'of'): 1,
#  ('science', 'fiction'): 1,
#  ('Papua', 'New', 'Guinea'): 1,
#  ('may', 'also', 'refer'): 1,
#  ('UK', 'Singles', 'Chart'): 1,
#  ('footballer', 'who', 'played'): 1,
#  ('focused', 'on'): 1,
#  ('Middle', 'East'): 1,
#  ('national', 'team'): 1,
#  ('rugby', 'union'): 1,
#  ('any', 'race', 'were'): 1,
#  ('a', 'lot', 'of'): 1,
#  ('Census', 'Bureau'): 1,
#  ('Royal', 'Navy'): 1,
#  ('coat', 'of', 'arms'): 1,
#  ('total', 'area', 'of'): 1,
#  ('days', 'later'): 1,
#  ('daughter', 'of'): 1,
#  ('operated', 'by'): 1,
#  ('was', 'created'): 1,
#  ('compared', 'to'): 1,
#  ('his', 'brother'): 1,
#  ('used', 'by'): 1,
#  ('beginning', 'of', 'the'): 1,
#  ('A', 'Pts', 'PIM'): 1,
#  ('trying', 'to'): 1,
#  ('next', 'day'): 1,
#  ('United', 'Arab', 'Emirates'): 1,
#  ('whom', 'he'): 1,
#  ('bass', 'guitar'): 1,
#  ('Critical', 'reception'): 1,
#  ('Order', 'of'): 1,
#  ('Historical', 'Society'): 1,
#  ('Official', 'Website'): 1,
#  ('population', 'were', 'below'): 1,
#  ('families', 'residing', 'in'): 1,
#  ('Olympic', 'Games'): 1,
#  ('came', 'to'): 1,
#  ('majority', 'of'): 1,
#  ('radio', 'station'): 1,
#  ('portion', 'of', 'the'): 1,
#  ('wanted', 'to'): 1,
#  ('even', 'though'): 1,
#  ('among', 'others'): 1,
#  ('Year-end', 'charts', 'Chart'): 1,
#  ('Prior', 'to'): 1,
#  ('became', 'the'): 1,
#  ('forced', 'to'): 1,
#  ('The', 'song'): 1,
#  ('Tamil', 'Nadu'): 1,
#  ('population', 'was', 'spread'): 1,
#  ('Notes', 'External', 'links'): 1,
#  ('development', 'of'): 1,
#  ('17th', 'century'): 1,
#  ('director', 'of', 'the'): 1,
#  ('San', 'Jose'): 1,
#  ('Salt', 'Lake', 'City'): 1,
#  ('West', 'Virginia'): 1,
#  ('real', 'estate'): 1,
#  ('said', 'to', 'have'): 1,
#  ('went', 'to'): 1,
#  ('head', 'of', 'the'): 1,
#  ('inspired', 'by'): 1,
#  ('Athlete', 'Event'): 1,
#  ('Catalina', 'CSS'): 1,
#  ('Costa', 'Rica'): 1,
#  ('an', 'independent'): 1,
#  ('Name', 'Nationality', 'Time'): 1,
#  ('amount', 'of'): 1,
#  ('His', 'father'): 1,
#  ('younger', 'brother'): 1,
#  ('dedicated', 'to'): 1,
#  ('caused', 'by'): 1,
#  ('tried', 'to'): 1,
#  ('CD', 'digital', 'download'): 1,
#  ('deal', 'with'): 1,
#  ('north', 'of'): 1,
#  ('New', 'Mexico'): 1,
#  ('Opponent', 'Score', 'Result'): 1,
#  ('Western', 'Australia'): 1,
#  ('south', 'of'): 1,
#  ('Symphony', 'Orchestra'): 1,
#  ('Champions', 'League'): 1,
#  ('takes', 'place'): 1,
#  ('Toronto', 'Maple', 'Leafs'): 1,
#  ('consisted', 'of'): 1,
#  ('argued', 'that'): 1,
#  ('this', 'period'): 1,
#  ('hip', 'hop'): 1,
#  ('city', 'of'): 1,
#  ('human', 'rights'): 1,
#  ('under', 'age', '18'): 1,
#  ('Hockey', 'League'): 1,
#  ('Foreign', 'Affairs'): 1,
#  ('close', 'to'): 1,
#  ('Middle', 'Ages'): 1,
#  ('Medal', 'of', 'Honor'): 1,
#  ('first', 'round'): 1,
#  ('only', 'one'): 1,
#  ('OppositionScore', 'OppositionScore', 'OppositionScore'): 1,
#  ('an', 'unincorporated', 'community'): 1,
#  ('Palomar', 'NEAT'): 1,
#  ('Primary', 'School'): 1,
#  ('intended', 'to'): 1,
#  ('7', '8', '9'): 1,
#  ('New', 'Hampshire'): 1,
#  ('was', 'completed', 'in'): 1,
#  ('believed', 'to', 'be'): 1,
#  ('After', 'the'): 1,
#  ('was', 'an', 'English'): 1,
#  ('is', 'still'): 1,
#  ('was', 'given'): 1,
#  ('St', "John's"): 1,
#  ('Weekly', 'charts', 'Chart'): 1,
#  ('leader', 'of', 'the'): 1,
#  ('Rank', 'Time', 'Rank'): 1,
#  ('Star', 'Trek'): 1,
#  ('depending', 'on'): 1,
#  ('history', 'of'): 1,
#  ('16th', 'century'): 1,
#  ('He', 'then'): 1,
#  ('they', 'have'): 1,
#  ('his', 'mother'): 1,
#  ('Notable', 'people'): 1,
#  ('interest', 'in'): 1,
#  ('North', 'American'): 1,
#  ('NR', 'NR', 'NR'): 1,
#  ('along', 'the'): 1,
#  ('San', 'Antonio'): 1,
#  ('Super', 'Bowl'): 1,
#  ('post', 'office'): 1,
#  ('relationship', 'with'): 1,
#  ('Career', 'statistics'): 1,
#  ('Club', 'Season', 'League'): 1,
#  ('Bharatiya', 'Janata', 'Party'): 1,
#  ('assigned', 'to'): 1,
#  ('As', 'of'): 1,
#  ('his', 'family'): 1,
#  ('sent', 'to'): 1,
#  ('In', 'the', 'early'): 1,
#  ('same', 'name'): 1,
#  ('2010', 'census'): 1,
#  ('W', 'D', 'L'): 1,
#  ('bronze', 'medal'): 1,
#  ('For', 'services', 'to'): 1,
#  ('among', 'the'): 1,
#  ('his', 'work'): 1,
#  ('World', 'Championship'): 1,
#  ('focus', 'on'): 1,
#  ('chairman', 'of', 'the'): 1,
#  ('consisting', 'of'): 1,
#  ('competed', 'in', 'the'): 1,
#  ('Duke', 'of'): 1,
#  ('before', 'being'): 1,
#  ('There', 'is', 'also'): 1,
#  ('Bibliography', 'External', 'links'): 1,
#  ('noted', 'that'): 1,
#  ('his', 'life'): 1,
#  ('Infantry', 'Regiment'): 1,
#  ('Ret', 'Ret'): 1,
#  ('Green', 'Bay', 'Packers'): 1,
#  ('an', 'interview'): 1,
#  ('having', 'been'): 1,
#  ('wide', 'variety', 'of'): 1,
#  ('collection', 'of'): 1,
#  ('influenced', 'by'): 1,
#  ('before', 'the'): 1,
#  ('opened', 'in'): 1,
#  ('She', 'has'): 1,
#  ('a', 'very'): 1,
#  ('Born', 'in'): 1,
#  ('is', 'often'): 1,
#  ('supported', 'by'): 1,
#  ('lived', 'in'): 1,
#  ('was', 'selected'): 1,
#  ('proved', 'to', 'be'): 1,
#  ('Tampa', 'Bay'): 1,
#  ('is', 'known', 'for'): 1,
#  ('prime', 'minister'): 1,
#  ('response', 'to'): 1,
#  ('was', 'later'): 1,
#  ('Motion', 'Picture'): 1,
#  ('most', 'popular'): 1,
#  ('thought', 'to', 'be'): 1,
#  ('Board', 'of'): 1,
#  ('her', 'own'): 1,
#  ('attempted', 'to'): 1,
#  ('Kuala', 'Lumpur'): 1,
#  ('presidential', 'election'): 1,
#  ('suggested', 'that'): 1,
#  ('refused', 'to'): 1,
#  ('claimed', 'that'): 1,
#  ('basketball', 'player'): 1,
#  ('New', 'England'): 1,
#  ('revealed', 'that'): 1,
#  ('Our', 'Lady', 'of'): 1,
#  ('5', '0'): 1,
#  ('Winter', 'Olympics'): 1,
#  ('when', 'the'): 1,
#  ('cannot', 'be'): 1,
#  ('is', 'home', 'to'): 1,
#  ('silver', 'medal'): 1,
#  ('1–1', '1–1'): 1,
#  ('making', 'it'): 1,
#  ('near', 'the'): 1,
#  ('way', 'to'): 1,
#  ('free', 'agent'): 1,
#  ('Marine', 'Corps'): 1,
#  ('state', 'of'): 1,
#  ('contract', 'with'): 1,
#  ('BBC', 'Radio'): 1,
#  ('Most', 'of', 'the'): 1,
#  ('was', 'formed'): 1,
#  ('Chairman', 'of', 'the'): 1,
#  ('because', 'it'): 1,
#  ('a', 'short'): 1,
#  ('St', "Mary's"): 1,
#  ('managed', 'to'): 1,
#  ('many', 'of', 'the'): 1,
#  ('said', 'to', 'be'): 1,
#  ('start', 'of', 'the'): 1,
#  ('type', 'of'): 1,
#  ('George', 'W', 'Bush'): 1,
#  ('front', 'of', 'the'): 1,
#  ('believed', 'that'): 1,
#  ("bachelor's", 'degree'): 1,
#  ('agreed', 'to'): 1,
#  ('Billboard', '200'): 1,
#  ('was', 'renamed'): 1,
#  ('based', 'in'): 1,
#  ('Walt', 'Disney'): 1,
#  ('board', 'of', 'directors'): 1,
#  ('Science', 'and', 'Technology'): 1,
#  ('much', 'of', 'the'): 1,
#  ('served', 'in', 'the'): 1,
#  ('types', 'of'): 1,
#  ('Earl', 'of'): 1,
#  ('included', 'in', 'the'): 1,
#  ('Attorney', 'General'): 1,
#  ('attempts', 'to'): 1,
#  ('surrounded', 'by'): 1,
#  ('rugby', 'league'): 1,
#  ('states', 'that'): 1,
#  ('instead', 'of'): 1,
#  ('most', 'common'): 1,
#  ('Chamber', 'of', 'Commerce'): 1,
#  ('Barack', 'Obama'): 1,
#  ('Pan', 'American', 'Games'): 1,
#  ('Member', 'of', 'the'): 1,
#  ('N/A', 'N/A'): 1,
#  ('take', 'place'): 1,
#  ('Detroit', 'Red', 'Wings'): 1,
#  ('an', 'annual'): 1,
#  ('was', 'succeeded', 'by'): 1,
#  ('town', 'of'): 1,
#  ('In', 'January'): 1,
#  ('control', 'of', 'the'): 1,
#  ('changed', 'its', 'name'): 1,
#  ('Did', 'not', 'qualify'): 1,
#  ('is', 'a', 'historic'): 1,
#  ('The', 'album'): 1,
#  ('Awards', 'Best'): 1,
#  ('martial', 'arts'): 1,
#  ("master's", 'degree'): 1,
#  ('Most', 'Valuable', 'Player'): 1,
#  ('is', 'a', 'genus'): 1,
#  ("People's", 'Republic', 'of'): 1,
#  ('European', 'Union'): 1,
#  ('Star', 'Wars'): 1,
#  ('tries', 'to'): 1,
#  ('her', 'father'): 1,
#  ('a', 'song', 'by'): 1,
#  ('believed', 'to', 'have'): 1,
#  ('resulting', 'in'): 1,
#  ('Micropolitan', 'Statistical', 'Area'): 1,
#  ('positive', 'reviews'): 1,
#  ('is', 'situated'): 1,
#  ('west', 'of'): 1,
#  ('stating', 'that'): 1,
#  ('construction', 'of'): 1,
#  ('creation', 'of'): 1,
#  ('equipped', 'with'): 1,
#  ('A', 'number', 'of'): 1,
#  ('her', 'mother'): 1,
#  ('might', 'be'): 1,
#  ('most', 'famous'): 1,
#  ('Regular', 'season'): 1,
#  ('edition', 'of', 'the'): 1,
#  ('was', 'founded', 'by'): 1,
#  ('died', 'on'): 1,
#  ('On', 'July'): 1,
#  ('On', 'March'): 1,
#  ('van', 'der'): 1,
#  ('section', 'of', 'the'): 1,
#  ('was', 'educated'): 1,
#  ('should', 'not', 'be'): 1,
#  ('going', 'to'): 1,
#  ('lead', 'vocals'): 1,
#  ('Santa', 'Fe'): 1,
#  ('First', 'Division'): 1,
#  ('a', 'long'): 1,
#  ('law', 'enforcement'): 1,
#  ('Awards', 'and', 'nominations'): 1,
#  ('both', 'sides'): 1,
#  ('shut', 'down'): 1,
#  ('an', 'effort', 'to'): 1,
#  ('after', 'being'): 1,
#  ('his', "father's"): 1,
#  ('expected', 'to'): 1,
#  ('Uttar', 'Pradesh'): 1,
#  ('Infantry', 'Division'): 1,
#  ('a', 'range', 'of'): 1,
#  ('Journal', 'of'): 1,
#  ('At', 'that', 'time'): 1,
#  ('References', 'Sources'): 1,
#  ('South', 'Korean'): 1,
#  ('a', 'strong'): 1,
#  ('Denis', 'Schiffermüller', '1775'): 1,
#  ('about', 'the'): 1,
#  ('World', 'Series'): 1,
#  ('The', 'main'): 1,
#  ('founder', 'of'): 1,
#  ('a', 'great'): 1,
#  ('east', 'of'): 1,
#  ('In', 'popular', 'culture'): 1,
#  ('top', 'of', 'the'): 1,
#  ('On', 'January'): 1,
#  ('NFL', 'Draft'): 1,
#  ('marine', 'gastropod', 'mollusk'): 1,
#  ('second', 'round'): 1,
#  ('background', 'vocals'): 1,
#  ('National', 'Wildlife', 'Refuge'): 1,
#  ('any', 'other'): 1,
#  ('Boston', 'Red', 'Sox'): 1,
#  ('She', 'also'): 1,
#  ('John', 'F', 'Kennedy'): 1,
#  ('North', 'Dakota'): 1,
#  ('South', 'America'): 1,
#  ('In', 'June'): 1,
#  ('West', 'Indies'): 1,
#  ('a', 'special'): 1,
#  ('per', 'cent'): 1,
#  ('accompanied', 'by'): 1,
#  ('terms', 'of'): 1,
#  ('six', 'months'): 1,
#  ('Post', 'Office'): 1,
#  ('qualified', 'for', 'the'): 1,
#  ('appeared', 'on'): 1,
#  ('On', 'April'): 1,
#  ('Santa', 'Cruz'): 1,
#  ('a', 'period', 'of'): 1,
#  ('House', 'of', 'Lords'): 1,
#  ('same', 'day'): 1,
#  ('On', 'June'): 1,
#  ('Church', 'of', 'England'): 1,
#  ('Center', 'for'): 1,
#  ('Rotten', 'Tomatoes'): 1,
#  ('a', 'pair', 'of'): 1,
#  ('and', 'later'): 1,
#  ('Puerto', 'Rican'): 1,
#  ('Charts', 'Chart'): 1,
#  ('debuted', 'at', 'number'): 1,
#  ('need', 'to'): 1,
#  ('R', 'R', 'R'): 1,
#  ('400', 'm'): 1,
#  ('Some', 'of', 'the'): 1,
#  ('want', 'to'): 1,
#  ('D', 'D', 'D'): 1,
#  ('Ottoman', 'Empire'): 1,
#  ('was', 'sold', 'to'): 1,
#  ('Jesus', 'Christ'): 1,
#  ('per', 'year'): 1,
#  ('focuses', 'on'): 1,
#  ('attached', 'to'): 1,
#  ('On', 'October'): 1,
#  ('an', 'average', 'of'): 1,
#  ('On', 'May'): 1,
#  ('Title', 'Album', 'details'): 1,
#  ('Chief', 'of', 'Staff'): 1,
#  ('In', 'March'): 1,
#  ('Coast', 'Guard'): 1,
#  ('continues', 'to'): 1,
#  ('participate', 'in'): 1,
#  ('On', 'September'): 1,
#  ('Linnaeus', '1758'): 1,
#  ('Bachelor', 'of', 'Arts'): 1,
#  ('men', 'and', 'women'): 1,
#  ('10', '11', '12'): 1,
#  ('In', 'May'): 1,
#  ('living', 'in'): 1,
#  ('most', 'notably'): 1,
#  ('is', 'served', 'by'): 1,
#  ('In', 'September'): 1,
#  ('several', 'times'): 1,
#  ('health', 'care'): 1,
#  ('three', 'times'): 1,
#  ('Task', 'Force'): 1,
#  ('20th', 'Century', 'Fox'): 1,
#  ('aired', 'on'): 1,
#  ('was', 'acquired', 'by'): 1,
#  ('Rolling', 'Stone'): 1,
#  ('type', 'locality', 'for'): 1,
#  ('In', 'October'): 1,
#  ('seems', 'to', 'have'): 1,
#  ('Latin', 'America'): 1,
#  ('National', 'Guard'): 1,
#  ('saying', 'that'): 1,
#  ('designed', 'to'): 1,
#  ('many', 'other'): 1,
#  ('Chief', 'Justice'): 1,
#  ('returning', 'to'): 1,
#  ('his', 'retirement'): 1,
#  ('San', 'Juan'): 1,
#  ('comes', 'from'): 1,
#  ('In', 'November'): 1,
#  ('an', 'early'): 1,
#  ('a', 'heart', 'attack'): 1,
#  ('In', 'April'): 1,
#  ('carried', 'out', 'by'): 1,
#  ('became', 'one', 'of'): 1,
#  ('interested', 'in'): 1,
#  ('In', 'July'): 1,
#  ('On', 'November'): 1,
#  ('before', 'moving', 'to'): 1,
#  ('suggests', 'that'): 1,
#  ('reference', 'to'): 1,
#  ('Bishop', 'of'): 1,
#  ('comic', 'book'): 1,
#  ('performed', 'by'): 1,
#  ('The', 'company'): 1,
#  ('The', 'station'): 1,
#  ('Supporting', 'Actor'): 1,
#  ('On', 'August'): 1,
#  ('UEFA', 'Europa', 'League'): 1,
#  ('ranging', 'from'): 1,
#  ('each', 'year'): 1,
#  ('Lok', 'Sabha'): 1,
#  ('On', 'December'): 1,
#  ('found', 'that'): 1,
#  ('developed', 'by'): 1,
#  ('an', 'additional'): 1,
#  ('fontsize:XS', 'text'): 1,
#  ('Digital', 'download'): 1,
#  ('middle', 'of', 'the'): 1,
#  ('Following', 'the'): 1,
#  ('Gold', 'Silver', 'Bronze'): 1,
#  ('Award', 'for', 'Outstanding'): 1,
#  ('Microsoft', 'Windows'): 1,
#  ('divided', 'into', 'two'): 1,
#  ('record', 'label'): 1,
#  ('appears', 'to', 'be'): 1,
#  ('St', 'Petersburg'): 1,
#  ('In', 'December'): 1,
#  ('4', '1'): 1,
#  ('is', 'the', 'largest'): 1,
#  ('a', 'young'): 1,
#  ('collaboration', 'with'): 1,
#  ('Saint', 'Petersburg'): 1,
#  ('Supporting', 'Actress'): 1,
#  ('Trinidad', 'and', 'Tobago'): 1,
#  ('may', 'also', 'be'): 1,
#  ('Liberal', 'Party'): 1,
#  ('Director', 'of'): 1,
#  ('most', 'successful'): 1,
#  ('History', 'of'): 1,
#  ('NHL', 'Entry', 'Draft'): 1,
#  ('15th', 'century'): 1,
#  ('enough', 'to'): 1,
#  ('West', 'Bromwich', 'Albion'): 1,
#  ('all', 'of', 'the'): 1,
#  ('a', 'combination', 'of'): 1,
#  ('was', 'introduced'): 1,
#  ('In', 'February'): 1,
#  ('Queen', 'Elizabeth'): 1,
#  ('Based', 'on'): 1,
#  ('Washington', 'DC'): 1,
#  ('21st', 'century'): 1,
#  ('a', 'household', 'in'): 1,
#  ('Grand', 'Slam'): 1,
#  ('taken', 'over', 'by'): 1,
#  ('On', 'February'): 1,
#  ('box', 'office'): 1,
#  ('Pearl', 'Harbor'): 1,
#  ('Le', 'Mans'): 1,
#  ('South', 'Australia'): 1,
#  ('merged', 'with'): 1,
#  ('contact', 'with'): 1,
#  ('U.S', 'Army'): 1,
#  ('Middle', 'School'): 1,
#  ('Performing', 'Arts'): 1,
#  ('allowed', 'to'): 1,
#  ('New', 'Brunswick'): 1,
#  ('Notes', 'and', 'references'): 1,
#  ('They', 'have'): 1,
#  ('field', 'goal'): 1,
#  ('see', 'MPC'): 1,
#  ('In', 'the', 'late'): 1,
#  ('executive', 'producer'): 1,
#  ('Heavyweight', 'Championship'): 1,
#  ('Commonwealth', 'Games'): 1,
#  ('higher', 'education'): 1,
#  ('their', 'home', 'games'): 1,
#  ('leading', 'to'): 1,
#  ('a', 'good'): 1,
#  ('In', 'August'): 1,
#  ('is', 'usually'): 1,
#  ('worked', 'with'): 1,
#  ('is', 'an', 'English'): 1,
#  ('described', 'by'): 1,
#  ('thousands', 'of'): 1,
#  ('Discography', 'Studio', 'albums'): 1,
#  ('baseball', 'player'): 1,
#  ('required', 'to'): 1,
#  ('support', 'for'): 1,
#  ('capable', 'of'): 1,
#  ('Super', 'League'): 1,
#  ('kind', 'of'): 1,
#  ('Stock', 'Exchange'): 1,
#  ('branch', 'of', 'the'): 1,
#  ('Sierra', 'Leone'): 1,
#  ('wrote', 'that'): 1,
#  ('National', 'Assembly'): 1,
#  ('secondary', 'school'): 1,
#  ('Community', 'College'): 1,
#  ('Along', 'with'): 1,
#  ('winner', 'of', 'the'): 1,
#  ('W', 'L'): 1,
#  ('provided', 'by'): 1,
#  ('came', 'from'): 1,
#  ('belonging', 'to'): 1,
#  ('voiced', 'by'): 1,
#  ('was', 'buried'): 1,
#  ('Ohio', 'State'): 1,
#  ('opportunity', 'to'): 1,
#  ('site', 'of', 'the'): 1,
#  ('Johns', 'Hopkins'): 1,
#  ('so', 'far'): 1,
#  ('Males', 'had'): 1,
#  ('Club', 'career'): 1,
#  ('13th', 'century'): 1,
#  ('Local', 'Government'): 1,
#  ('joint', 'venture'): 1,
#  ('For', 'instance'): 1,
#  ('Secondary', 'School'): 1,
#  ('Long', 'Island'): 1,
#  ('is', 'named'): 1,
#  ('their', 'respective'): 1,
#  ('Main', 'Street'): 1,
#  ('14th', 'century'): 1,
#  ('would', 'go', 'on'): 1,
#  ('removed', 'from'): 1,
#  ('South', 'Dakota'): 1,
#  ('remainder', 'of', 'the'): 1,
#  ('a', 'year'): 1,
#  ('presence', 'of'): 1,
#  ('Film', 'Critics'): 1,
#  ('contributed', 'to'): 1,
#  ('edited', 'by'): 1,
#  ('In', '2011'): 1,
#  ('4', '2'): 1,
#  ('Southeast', 'Asia'): 1,
#  ('Nobel', 'Prize'): 1,
#  ('Public', 'Library'): 1,
#  ('Tour', 'de', 'France'): 1,
#  ('retired', 'from'): 1,
#  ('In', '2012'): 1,
#  ('Diocese', 'of'): 1,
#  ('In', '2009'): 1,
#  ('tend', 'to'): 1,
#  ('soap', 'opera'): 1,
#  ('continue', 'to'): 1,
#  ('was', 'killed'): 1,
#  ('Long', 'Beach'): 1,
#  ('a', 'significant'): 1,
#  ('4', '3'): 1,
#  ('Sri', 'Lankan'): 1,
#  ('political', 'party'): 1,
#  ('finished', 'the', 'season'): 1,
#  ('basketball', 'team'): 1,
#  ('climate', 'change'): 1,
#  ('nineteenth', 'century'): 1,
#  ('a', 'set', 'of'): 1,
#  ('every', 'year'): 1,
#  ('belonged', 'to'): 1,
#  ('was', 'changed', 'to'): 1,
#  ('an', 'example', 'of'): 1,
#  ('concluded', 'that'): 1,
#  ('Playing', 'career'): 1,
#  ('up', 'with'): 1,
#  ('take', 'part', 'in'): 1,
#  ('Release', 'date'): 1,
#  ('Round', 'of', '16'): 1,
#  ('Donald', 'Trump'): 1,
#  ('El', 'Salvador'): 1,
#  ('GF', 'GA'): 1,
#  ('twentieth', 'century'): 1,
#  ('point', 'of', 'view'): 1,
#  ('Hollywood', 'Blvd'): 1,
#  ('football', 'club'): 1,
#  ('establishment', 'of'): 1,
#  ('was', 'married', 'to'): 1,
#  ('commander', 'of', 'the'): 1,
#  ('whether', 'or', 'not'): 1,
#  ('civil', 'parish'): 1,
#  ('command', 'of'): 1,
#  ('Xbox', '360'): 1,
#  ('an', 'international'): 1,
#  ('Dominican', 'Republic'): 1,
#  ('en', 'route'): 1,
#  ('higher', 'than'): 1,
#  ('even', 'if'): 1,
#  ('would', 'become'): 1,
#  ('Professional', 'career'): 1,
#  ('Madison', 'Square', 'Garden'): 1,
#  ('falls', 'in', 'love'): 1,
#  ('Grade', 'II'): 1,
#  ('After', 'graduating', 'from'): 1,
#  ('except', 'for'): 1,
#  ('Big', 'Ten'): 1,
#  ('Andhra', 'Pradesh'): 1,
#  ('radio', 'stations'): 1,
#  ('signed', 'with'): 1,
#  ('an', 'assistant'): 1,
#  ('and', 'others'): 1,
#  ('federal', 'government'): 1,
#  ('local', 'government'): 1,
#  ...}

# %%
len(batches)
# Out:
# 500000

# %%
# Should be able to add batch information using df.map() but am encountering errors apparently relating
#  to indexing - workaround (though slower).

ngb_cols = ["ngram", "batch"]
rows = []

for ng in ngram_eval['ngram']:
    rows.append({"ngram" : ng,
                "batch" : batches[ng]})
    
ng_batch = pd.DataFrame(rows, columns = ngb_cols)

ng_batch
# Out:
#                                 ngram  batch
# 0                           (of, the)     -2
# 1       (References, External, links)      1
# 2                   (External, links)      2
# 3                           (in, the)     -2
# 4                           (0, 0, 0)     -2
# ...                               ...    ...
# 499995            (Work, started, on)      8
# 499996        (of, these, techniques)      8
# 499997             (Stadio, Flaminio)      1
# 499998                    (IRE, 3, C)      1
# 499999  (The, Official, Encyclopedia)      2
#
# [500000 rows x 2 columns]

# %%
ngram_eval = ngram_eval.merge(ng_batch, on='ngram')

ngram_eval
# Out:
#                                 ngram       poisson  len  batch
# 0                           (of, the)  3.874652e+06    2     -2
# 1       (References, External, links)  2.566994e+06    3      1
# 2                   (External, links)  2.229096e+06    2      2
# 3                           (in, the)  2.094387e+06    2     -2
# 4                           (0, 0, 0)  1.798530e+06    3     -2
# ...                               ...           ...  ...    ...
# 499995            (Work, started, on)  3.883693e+02    3      8
# 499996        (of, these, techniques)  3.883679e+02    3      8
# 499997             (Stadio, Flaminio)  3.883678e+02    2      1
# 499998                    (IRE, 3, C)  3.883678e+02    3      1
# 499999  (The, Official, Encyclopedia)  3.883646e+02    3      2
#
# [500000 rows x 4 columns]

# %%
ngram_eval.batch.value_counts()
# Out:
#  1     94011
#  2     79538
#  3     69221
#  4     56154
#  5     48934
#  6     38288
#  7     30374
# -1     29076
#  8     22495
#  9     19272
#  10    11300
# -2      1337
# Name: batch, dtype: int64

# %%
ngram_eval.to_pickle(datapath+'/Corpora/wiki/enwiki_20200520/10pc_ngram_eval.pkl')

# %%
ngram_eval = pd.read_pickle(datapath+'/Corpora/wiki/enwiki_20200520/10pc_ngram_eval.pkl')

# %%
ngram_all = pd.DataFrame.from_records( key_val_tuples(od) , columns = ['ngram', 'poisson'])

# %%
ngram_all
# Out:
#                                  ngram       poisson
# 0                            (of, the)  3.874652e+06
# 1        (References, External, links)  2.566994e+06
# 2                    (External, links)  2.229096e+06
# 3                            (in, the)  2.094387e+06
# 4                            (0, 0, 0)  1.798530e+06
# ...                                ...           ...
# 2002313                      (and, to) -9.971941e+04
# 2002314                       (and, a) -1.003225e+05
# 2002315                     (was, the) -1.339807e+05
# 2002316                      (and, in) -1.616960e+05
# 2002317                     (and, the) -2.390755e+05
#
# [2002318 rows x 2 columns]

# %%
search = ('Clatsop', 'County', 'Oregon')

ngram_all[ngram_all.ngram == search]
# Out:
#                             ngram     poisson
# 337618  (Clatsop, County, Oregon)  558.754543

# %%
ngram_eval[ngram_eval.ngram == search]
# Out:
#                             ngram     poisson  len  batch
# 337618  (Clatsop, County, Oregon)  558.754543    3      1

# %%
from redisprob import RedisHashFreqDist
tg = RedisHashFreqDist(r, 'w10p:w10p_tg')

# %%
tg[search]
# Out:
# 26

# %%
from gensim.models import Word2Vec

# %%
batch_model = Word2Vec.load(datapath+'/Models/1 w2v/wiki10pc_batch1.model')

# %%
'+'.join(search) in batch_model.wv.vocab
# Out:
# False
